# %%
import pandas as pd
import numpy as np
import re
#import dask as d
#import dask.dataframe as dd
#from dask.delayed import delayed

pattern = "^(.*)(?=[0-9a-f]{8}-[0-9a-f]{4}-[1-5][0-9a-f]{3}-[89ab][0-9a-f]{3}-[0-9a-f]{12})"

df1 = pd.read_excel("My Report_SAP_R075 2022-09-19 13_03 CEST.xlsx", skiprows = range(0,21), usecols = ['Worker',
                                                                             'Party ID', 
                                                                             'Employee ID',
                                                                             'GUID', 
                                                                             'Cost Center - ID', 
                                                                             'Cost Center - Name', 
                                                                             'Company Reference ID',
                                                                             'Company - Name', 
                                                                             'Management Level', 
                                                                             'Job Level - Primary Position', 
                                                                             'Work Email', 
                                                                             'Status Details', 
                                                                             'Line of Service', 
                                                                             'Hire Date', 
                                                                             'Assignment Reason (Alternative)', 
                                                                             'Host Country (Alternative)', 
                                                                             'Host Country / Territory', 
                                                                             'Country/Territory', 
                                                                             'Company Hierarchy', 
                                                                             'Worker Type', 
                                                                             'Contingent Worker Type', 
                                                                             'Job Category'])
df1 = df1.sort_values('Party ID')
df1['Party ID'] = df1['Party ID'].str.replace(f'{pattern}', '')
df1 = df1[df1['Party ID'].str.len() == 36]
df1 = df1[df1['Contingent Worker Type'] != 'Enterprise BOT']
#df1.to_csv("WD_R075_10.08.csv")


df2 = pd.read_excel("My Report_SAP_R139 2022-09-19 13_02 CEST.xlsx", skiprows = range(0,27), usecols = ['Worker',
                                                                             'Party ID', 
                                                                             'Employee ID', 
                                                                             'GUID', 
                                                                             'Cost Center ID', 
                                                                             'Cost Center Name',
                                                                             'Company - Name', 
                                                                             'Management Level', 
                                                                             'Job Level - Primary Position', 
                                                                             'Email - Primary Work', 
                                                                             'Employee Status', 
                                                                             'Cost Center Level 3', 
                                                                             'Hire Date', 
                                                                             'Termination Date', 
                                                                             'Country/Territory of Work Location', 
                                                                             'Country', 
                                                                             'Worker Type', 
                                                                             'Contingent Worker Type', 
                                                                             'Job Category'])
df2 = df2.sort_values('Party ID')
df2['Party ID'] = df2['Party ID'].str.replace(f'{pattern}', '')
df2 = df2[df2['Party ID'].str.len() == 36]
df2 = df2[df2['Contingent Worker Type'] != 'Enterprise BOT']
#df2.to_csv("WD_R139_10.08.csv")

df3 = pd.read_excel("My Report_SAP_R311 2022-09-19 12_53 CEST.xlsx", skiprows = range(0,20), usecols = ['Worker',
                                                                             'Party ID', 
                                                                             'Employee ID', 
                                                                             'GUID', 
                                                                             'Cost Center ID', 
                                                                             'Cost Center - Name', 
                                                                             'Company Reference ID',
                                                                             'Company - Name', 
                                                                             'Management Level', 
                                                                             'Job Level', 
                                                                             'Email - Primary Work',
                                                                             'Employee Status', 
                                                                             'PwC Global Line Of Service', 
                                                                             'Hire Date', 
                                                                             'Company Hierarchy', 
                                                                             'Cost Center Level 3', 
                                                                             'Worker Type', 
                                                                             'Contingent Worker Type', 
                                                                             'Job Category',
                                                                             'Is Inbound IA? (Exception Process)'])
df3 = df3.sort_values('Party ID')
df3['Party ID'] = df3['Party ID'].str.replace(f'{pattern}', '')
df3 = df3[df3['Party ID'].str.len() == 36]
df3 = df3[df3['Contingent Worker Type'] != 'Enterprise BOT']
#df3.to_csv("WD_R311.csv")

df4 = pd.read_excel("PMDM_Active_Employee_Report_10.08.xlsx", skiprows = range(0,5), usecols = ['Party ID', 'INAB GUID 1', 'INAB GUID 2', 'Cost Center Code', 'Cost Center Description', 'Legal Entity Party ID','Legal Entity Name', 'Job Level ', 'Grade', 'Cloud Mail', 'Territory', 'Global LoS', 'Contract Type', 'Job Category'])

#df5 = pd.read_excel("RRM_extract_10.08.xlsx")

#dfwd1 = pd.concat([df1,df2]) 

#dfwd2 = pd.merge(dfwd1, df3, how = 'outer', left_on = ['Party ID', 'Employee ID'], right_on = ['Party ID', 'Employee ID'], indicator = 'Exists_dfwd1_df3')
#dfwd2 = pd.concat([dfwd1,df3], ignore_index=True).drop_duplicates() 
#dfwd3 = pd.merge(dfwd2, df4, on = 'Party ID',how = 'outer', indicator='Exists_dfwd2_df4')

# %%
df1.rename(columns={'Status Details':'Employee Status',
                    'Cost Center - ID':'Cost Center ID',
                    'Cost Center - Name':'Cost Center Name'}, inplace = True)

df2.rename(columns={'Email - Primary Work':'Work Email'}, inplace = True)

df3.rename(columns={'Email - Primary Work':'Work Email',
                    'Cost Center - Name':'Cost Center Name',
                    'Job Level':'Job Level - Primary Position'}, inplace = True)

dfwd1 = pd.merge(df1, df2, how = 'outer', left_on = ['Worker', 
                                                     'Party ID', 
                                                     'Employee ID', 
                                                     'GUID', 
                                                     'Cost Center ID', 
                                                     'Cost Center Name', 
                                                     'Company - Name', 
                                                     'Management Level', 
                                                     'Job Level - Primary Position',
                                                     'Work Email',
                                                     'Employee Status',
                                                     'Hire Date',
                                                     'Worker Type',
                                                     'Contingent Worker Type',
                                                     'Job Category'], right_on = ['Worker',
                                                                                  'Party ID', 
                                                                                  'Employee ID',
                                                                                  'GUID', 
                                                                                  'Cost Center ID', 
                                                                                  'Cost Center Name', 
                                                                                  'Company - Name', 
                                                                                  'Management Level', 
                                                                                  'Job Level - Primary Position',
                                                                                  'Work Email',
                                                                                  'Employee Status',
                                                                                  'Hire Date',
                                                                                  'Worker Type',
                                                                                  'Contingent Worker Type',
                                                                                  'Job Category'], indicator = 'Exists_df1_df2')

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
display(dfwd1)
# Out:
#                              Worker  Employee ID  \
# 0                       Zezheng Gan    100689987
# 1                       Simon Letko    101074699
# 2             Jan Philipp Boltz [C]    100723663
# 3           Marie-Theres Zimmerling    101231784
# 4                       Lia Ballach    101110909
# ...                             ...          ...
# 67602            Foziya Durstmüller    101239404
# 67603  Carla Elizabeth Tovar Palomo    101257812
# 67604                  Anton Pürrer    101203502
# 67605                Thomas Löscher    100680609
# 67606                   Jurian Goei    100654125
#
#                                    Party ID           GUID Employee Status  \
# 0      0000fb73-0624-4e47-a87b-72bc7d1da06f        zgan005          Active
# 1      000235db-d90f-4881-8774-8bb5c9d8eb76      sletko002          Active
# 2      0005e477-fa19-406e-b5f5-fea23f60afed      jboltz002          Active
# 3      00066b84-677f-476f-bcda-9e45b2463f30  mzimmerlin002          Active
# 4      00071b71-c5d2-4f77-b995-db14fb54675f    lballach001          Active
# ...                                     ...            ...             ...
# 67602  e074baf7-9ed6-4c6b-9dc0-acefe11b1418            NaN      Terminated
# 67603  f5ef1191-967d-4b56-9493-0a68108b27bf            NaN      Terminated
# 67604  ffdb22e5-bd89-49a2-80c1-550976a0d495            NaN      Terminated
# 67605  eb03c42d-214a-47bd-b766-9d568f4e024f   tloescher001      Terminated
# 67606  dd311d6c-9ac1-4b86-9426-425f3ab2bfd8       jgoei003      Terminated
#
#                             Work Email  Hire Date        Worker Type  \
# 0                  zezheng.gan@pwc.com 2018-09-01           Employee
# 1                simon.l.letko@pwc.com 2022-09-12           Employee
# 2            jan.philipp.boltz@pwc.com 2018-07-01  Contingent Worker
# 3      marie-theres.zimmerling@pwc.com 2022-07-01           Employee
# 4                  lia.ballach@pwc.com 2021-10-01           Employee
# ...                                ...        ...                ...
# 67602                              NaN 2022-05-01           Employee
# 67603  carla.v.tovar.palomo@vialto.com 2022-06-01           Employee
# 67604            anton.puerrer@pwc.com 2022-03-01           Employee
# 67605          thomas.loescher@pwc.com 2018-04-01           Employee
# 67606                j.goei@nl.pwc.com 2008-09-01           Employee
#
#       Contingent Worker Type      Job Category  Management Level  \
# 0                        NaN   Client Services  Senior Associate
# 1                        NaN   Client Services        Specialist
# 2                     Vendor  Practice Support        Specialist
# 3                        NaN   Client Services         Associate
# 4                        NaN  Practice Support  Senior Associate
# ...                      ...               ...               ...
# 67602                    NaN   Client Services  Senior Associate
# 67603                    NaN   Client Services  Senior Associate
# 67604                    NaN   Client Services          Director
# 67605                    NaN   Client Services  Senior Associate
# 67606                    NaN   Client Services    Senior Manager
#
#       Job Level - Primary Position Country/Territory         Line of Service  \
# 0                              NaN       Netherlands               Assurance
# 1                     Specialist 5           Austria               Assurance
# 2                              NaN           Germany  Internal Firm Services
# 3                              NaN           Germany                Advisory
# 4                              NaN           Germany  Internal Firm Services
# ...                            ...               ...                     ...
# 67602           Senior Associate 2               NaN                     NaN
# 67603           Senior Associate 2               NaN                     NaN
# 67604                          NaN               NaN                     NaN
# 67605                          NaN               NaN                     NaN
# 67606                          NaN               NaN                     NaN
#
#       Assignment Reason (Alternative) Host Country (Alternative)  \
# 0                                 NaN                        NaN
# 1                                 NaN                        NaN
# 2                                 NaN                        NaN
# 3                                 NaN                        NaN
# 4                                 NaN                        NaN
# ...                               ...                        ...
# 67602                             NaN                        NaN
# 67603                             NaN                        NaN
# 67604                             NaN                        NaN
# 67605                             NaN                        NaN
# 67606                             NaN                        NaN
#
#       Host Country / Territory  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 67602                      NaN
# 67603                      NaN
# 67604                      NaN
# 67605                      NaN
# 67606                      NaN
#
#                                           Company - Name Company Hierarchy  \
# 0                                   PwC Accountants N.V.   PwC Netherlands
# 1      PwC Österreich GmbH Wirtschaftsprüfungsgesells...       PwC Austria
# 2      PRICEWATERHOUSECOOPERS Gesellschaft mit beschr...       PwC Germany
# 3      PRICEWATERHOUSECOOPERS Gesellschaft mit beschr...       PwC Germany
# 4      PRICEWATERHOUSECOOPERS Gesellschaft mit beschr...       PwC Germany
# ...                                                  ...               ...
# 67602                        Galaxy Steuerberatungs GmbH               NaN
# 67603                        Galaxy Steuerberatungs GmbH               NaN
# 67604  PwC Österreich GmbH Wirtschaftsprüfungsgesells...               NaN
# 67605                               PwC Accountants N.V.               NaN
# 67606                               PwC Accountants N.V.               NaN
#
#                        Company Reference ID Cost Center ID  \
# 0      f30abfab-4c61-4f45-b40c-1ab13706fd3c     NL12000412
# 1      5715ad3e-bf5d-46a2-a831-e68192667608     AT18000019
# 2      ff6d5af8-9ae6-47d9-8317-eaa8b0e2e7b9     DE01000238
# 3      ff6d5af8-9ae6-47d9-8317-eaa8b0e2e7b9     DE01000792
# 4      ff6d5af8-9ae6-47d9-8317-eaa8b0e2e7b9     DE01000015
# ...                                     ...            ...
# 67602                                   NaN     GXA1000001
# 67603                                   NaN     GXA1000001
# 67604                                   NaN     AT18000030
# 67605                                   NaN         NAAAH3
# 67606                                   NaN         NAAAH4
#
#                Cost Center Name Termination Date  \
# 0                       BAS SRG              NaT
# 1                ASS FS Banking              NaT
# 2               INFRA FS Berlin              NaT
# 3      ADV BC Risk & Regulatory              NaT
# 4              HC Human Capital              NaT
# ...                         ...              ...
# 67602                 Gx AT Tax       2022-07-31
# 67603                 Gx AT Tax       2022-08-31
# 67604                  ASS Wien       2022-07-31
# 67605                  CMAAS FS       2018-11-30
# 67606           No Use CMAAS FI       2018-05-20
#
#       Country/Territory of Work Location      Country  \
# 0                                    NaN          NaN
# 1                                    NaN          NaN
# 2                                    NaN          NaN
# 3                                    NaN          NaN
# 4                                    NaN          NaN
# ...                                  ...          ...
# 67602                            Austria      Austria
# 67603                            Austria      Austria
# 67604                            Austria      Austria
# 67605                        Netherlands  Netherlands
# 67606                        Netherlands  Netherlands
#
#            Cost Center Level 3 Exists_df1_df2
# 0                          NaN      left_only
# 1                          NaN      left_only
# 2                          NaN      left_only
# 3                          NaN      left_only
# 4                          NaN      left_only
# ...                        ...            ...
# 67602                      NaN     right_only
# 67603                      NaN     right_only
# 67604  ASS Industrial Services     right_only
# 67605            NLD Assurance     right_only
# 67606            NLD Assurance     right_only
#
# [67607 rows x 27 columns]

# %%
dfwd2 = pd.merge(dfwd1, df3, how = 'outer', left_on = ['Worker', 
                                                       'Party ID', 
                                                       'Employee ID', 
                                                       'GUID', 
                                                       'Cost Center ID', 
                                                       'Cost Center Name', 
                                                       'Company - Name', 
                                                       'Management Level', 
                                                       'Job Level - Primary Position',
                                                       'Work Email',
                                                       'Employee Status',
                                                       'Hire Date',
                                                       'Worker Type',
                                                       'Contingent Worker Type',
                                                       'Job Category'], right_on = ['Worker',
                                                                                    'Party ID', 
                                                                                    'Employee ID', 
                                                                                    'GUID', 
                                                                                    'Cost Center ID', 
                                                                                    'Cost Center Name', 
                                                                                    'Company - Name', 
                                                                                    'Management Level', 
                                                                                    'Job Level - Primary Position', 
                                                                                    'Work Email',
                                                                                    'Employee Status',  
                                                                                    'Hire Date', 
                                                                                    'Worker Type', 
                                                                                    'Contingent Worker Type', 
                                                                                    'Job Category'], indicator = 'Exists_dfwd1_df3')

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
display(dfwd2)
# Out:
#                         Worker  Employee ID  \
# 0                  Zezheng Gan    100689987
# 1                  Simon Letko    101074699
# 2        Jan Philipp Boltz [C]    100723663
# 3      Marie-Theres Zimmerling    101231784
# 4                  Lia Ballach    101110909
# ...                        ...          ...
# 69990              Leo Horlitz    101304636
# 69991         Julius Turschner    101247147
# 69992               Nida Temaj    101297133
# 69993             Tobias Lemke    100876064
# 69994             Luca Grädler    101233186
#
#                                    Party ID           GUID Employee Status  \
# 0      0000fb73-0624-4e47-a87b-72bc7d1da06f        zgan005          Active
# 1      000235db-d90f-4881-8774-8bb5c9d8eb76      sletko002          Active
# 2      0005e477-fa19-406e-b5f5-fea23f60afed      jboltz002          Active
# 3      00066b84-677f-476f-bcda-9e45b2463f30  mzimmerlin002          Active
# 4      00071b71-c5d2-4f77-b995-db14fb54675f    lballach001          Active
# ...                                     ...            ...             ...
# 69990  ff7616e0-e202-449e-a38b-f4d3b4c7c1a0    lhorlitz001     Future Hire
# 69991  ff780117-8338-4dc3-b1f6-b4d462a41471  jturschner001     Future Hire
# 69992  ff8a05a2-3516-4098-8a41-a9511cd71b53      ntemaj001     Future Hire
# 69993  ffeb5e4f-aa38-48df-96c0-18736a1b5391      tlemke001     Future Hire
# 69994  fffb6356-c779-4e5f-83fb-57b915857986            NaN     Future Hire
#
#                             Work Email  Hire Date        Worker Type  \
# 0                  zezheng.gan@pwc.com 2018-09-01           Employee
# 1                simon.l.letko@pwc.com 2022-09-12           Employee
# 2            jan.philipp.boltz@pwc.com 2018-07-01  Contingent Worker
# 3      marie-theres.zimmerling@pwc.com 2022-07-01           Employee
# 4                  lia.ballach@pwc.com 2021-10-01           Employee
# ...                                ...        ...                ...
# 69990              leo.horlitz@pwc.com 2022-11-01           Employee
# 69991                              NaN 2022-10-01           Employee
# 69992                              NaN 2022-10-15           Employee
# 69993                              NaN 2023-01-01           Employee
# 69994                              NaN 2023-01-15           Employee
#
#       Contingent Worker Type      Job Category  Management Level  \
# 0                        NaN   Client Services  Senior Associate
# 1                        NaN   Client Services        Specialist
# 2                     Vendor  Practice Support        Specialist
# 3                        NaN   Client Services         Associate
# 4                        NaN  Practice Support  Senior Associate
# ...                      ...               ...               ...
# 69990                    NaN   Client Services         Associate
# 69991                    NaN   Client Services    Intern/Trainee
# 69992                    NaN   Client Services    Intern/Trainee
# 69993                    NaN   Client Services           Manager
# 69994                    NaN   Client Services    Intern/Trainee
#
#       Job Level - Primary Position Country/Territory         Line of Service  \
# 0                              NaN       Netherlands               Assurance
# 1                     Specialist 5           Austria               Assurance
# 2                              NaN           Germany  Internal Firm Services
# 3                              NaN           Germany                Advisory
# 4                              NaN           Germany  Internal Firm Services
# ...                            ...               ...                     ...
# 69990                          NaN               NaN                     NaN
# 69991                          NaN               NaN                     NaN
# 69992                          NaN               NaN                     NaN
# 69993                          NaN               NaN                     NaN
# 69994                          NaN               NaN                     NaN
#
#       Assignment Reason (Alternative) Host Country (Alternative)  \
# 0                                 NaN                        NaN
# 1                                 NaN                        NaN
# 2                                 NaN                        NaN
# 3                                 NaN                        NaN
# 4                                 NaN                        NaN
# ...                               ...                        ...
# 69990                             NaN                        NaN
# 69991                             NaN                        NaN
# 69992                             NaN                        NaN
# 69993                             NaN                        NaN
# 69994                             NaN                        NaN
#
#       Host Country / Territory  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 69990                      NaN
# 69991                      NaN
# 69992                      NaN
# 69993                      NaN
# 69994                      NaN
#
#                                           Company - Name Company Hierarchy_x  \
# 0                                   PwC Accountants N.V.     PwC Netherlands
# 1      PwC Österreich GmbH Wirtschaftsprüfungsgesells...         PwC Austria
# 2      PRICEWATERHOUSECOOPERS Gesellschaft mit beschr...         PwC Germany
# 3      PRICEWATERHOUSECOOPERS Gesellschaft mit beschr...         PwC Germany
# 4      PRICEWATERHOUSECOOPERS Gesellschaft mit beschr...         PwC Germany
# ...                                                  ...                 ...
# 69990                         PwC Strategy& Germany GmbH                 NaN
# 69991  PRICEWATERHOUSECOOPERS Gesellschaft mit beschr...                 NaN
# 69992  PRICEWATERHOUSECOOPERS Gesellschaft mit beschr...                 NaN
# 69993  PRICEWATERHOUSECOOPERS Gesellschaft mit beschr...                 NaN
# 69994  PRICEWATERHOUSECOOPERS Gesellschaft mit beschr...                 NaN
#
#                      Company Reference ID_x Cost Center ID  \
# 0      f30abfab-4c61-4f45-b40c-1ab13706fd3c     NL12000412
# 1      5715ad3e-bf5d-46a2-a831-e68192667608     AT18000019
# 2      ff6d5af8-9ae6-47d9-8317-eaa8b0e2e7b9     DE01000238
# 3      ff6d5af8-9ae6-47d9-8317-eaa8b0e2e7b9     DE01000792
# 4      ff6d5af8-9ae6-47d9-8317-eaa8b0e2e7b9     DE01000015
# ...                                     ...            ...
# 69990                                   NaN     DEZ1010001
# 69991                                   NaN     DE01000243
# 69992                                   NaN     DE01001163
# 69993                                   NaN     DE01000632
# 69994                                   NaN     DE01000194
#
#                Cost Center Name Termination Date  \
# 0                       BAS SRG              NaT
# 1                ASS FS Banking              NaT
# 2               INFRA FS Berlin              NaT
# 3      ADV BC Risk & Regulatory              NaT
# 4              HC Human Capital              NaT
# ...                         ...              ...
# 69990      ADV SC DE Consulting              NaT
# 69991                ASR IS Ost              NaT
# 69992           FwM New Venture              NaT
# 69993      ADV BC FS Consulting              NaT
# 69994              ASR IS Mitte              NaT
#
#       Country/Territory of Work Location Country Cost Center Level 3_x  \
# 0                                    NaN     NaN                   NaN
# 1                                    NaN     NaN                   NaN
# 2                                    NaN     NaN                   NaN
# 3                                    NaN     NaN                   NaN
# 4                                    NaN     NaN                   NaN
# ...                                  ...     ...                   ...
# 69990                                NaN     NaN                   NaN
# 69991                                NaN     NaN                   NaN
# 69992                                NaN     NaN                   NaN
# 69993                                NaN     NaN                   NaN
# 69994                                NaN     NaN                   NaN
#
#       Exists_df1_df2 Is Inbound IA? (Exception Process)  \
# 0          left_only                                NaN
# 1          left_only                                NaN
# 2          left_only                                NaN
# 3          left_only                                NaN
# 4          left_only                                NaN
# ...              ...                                ...
# 69990            NaN                                 No
# 69991            NaN                                 No
# 69992            NaN                                 No
# 69993            NaN                                 No
# 69994            NaN                                 No
#
#       PwC Global Line Of Service Company Hierarchy_y  \
# 0                            NaN                 NaN
# 1                            NaN                 NaN
# 2                            NaN                 NaN
# 3                            NaN                 NaN
# 4                            NaN                 NaN
# ...                          ...                 ...
# 69990                   Advisory         PwC Germany
# 69991                  Assurance         PwC Germany
# 69992     Internal Firm Services         PwC Germany
# 69993                   Advisory         PwC Germany
# 69994                  Assurance         PwC Germany
#
#                      Company Reference ID_y    Cost Center Level 3_y  \
# 0                                       NaN                      NaN
# 1                                       NaN                      NaN
# 2                                       NaN                      NaN
# 3                                       NaN                      NaN
# 4                                       NaN                      NaN
# ...                                     ...                      ...
# 69990  5cc1b3b6-8a15-47d6-b5ad-600d68e496a9             ADV Strategy
# 69991  ff6d5af8-9ae6-47d9-8317-eaa8b0e2e7b9                Assurance
# 69992  ff6d5af8-9ae6-47d9-8317-eaa8b0e2e7b9  IFS Firmwide Management
# 69993  ff6d5af8-9ae6-47d9-8317-eaa8b0e2e7b9           ADV Consulting
# 69994  ff6d5af8-9ae6-47d9-8317-eaa8b0e2e7b9                Assurance
#
#       Exists_dfwd1_df3
# 0            left_only
# 1            left_only
# 2            left_only
# 3            left_only
# 4            left_only
# ...                ...
# 69990       right_only
# 69991       right_only
# 69992       right_only
# 69993       right_only
# 69994       right_only
#
# [69995 rows x 33 columns]

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

col = dfwd2.pop('Party ID')
dfwd2.insert(0, 'WD_PartyID', col)

col = dfwd2.pop('Employee ID')
dfwd2.insert(1, 'WD_EmployeeID', col)

#dfwd2.set_index(['WD_PartyID', 'WD_EmployeeID'])

col = dfwd2.pop('Employee Status')
dfwd2.insert(2, 'WD_EmployeeStatus', col)

col = dfwd2.pop('Worker')
dfwd2.insert(3, 'WD_Worker', col)

col = dfwd2.pop('Hire Date')
dfwd2.insert(4, col.name, col)

col = dfwd2.pop('Termination Date')
dfwd2.insert(5, col.name, col)

col = dfwd2.pop('GUID')
dfwd2.insert(6, 'WD_GUID', col)

dfwd2['Line of Service Build'] = dfwd2['Line of Service'].fillna(dfwd2['Cost Center Level 3_x']).fillna(dfwd2['Cost Center Level 3_y']).fillna(dfwd2['PwC Global Line Of Service'])
dfwd2.insert(7, 'LoS', dfwd2['Line of Service Build'])
dfwd2 = dfwd2.drop(columns = ['Line of Service', 'Cost Center Level 3_x', 'Cost Center Level 3_y', 'PwC Global Line Of Service', 'Line of Service Build'])

col = dfwd2.pop('Job Level - Primary Position')
dfwd2.insert(7, 'Role Level', col)

dfwd2['Role LoS Build'] = dfwd2['Role Level'].fillna(dfwd2['LoS'])
dfwd2.insert(7, 'WD_LoS', dfwd2['Role LoS Build'])
dfwd2 = dfwd2.drop(columns = ['Role Level', 'LoS', 'Role LoS Build'])

col = dfwd2.pop('Cost Center ID')
dfwd2.insert(8, 'WD_CC_Code', col)

col = dfwd2.pop('Cost Center Name')
dfwd2.insert(9, 'WD_CC_Name', col)

dfwd2['Company Reference ID Build'] = dfwd2['Company Reference ID_x'].fillna(dfwd2['Company Reference ID_y'])
dfwd2.insert(10, 'WD_CR_Code', dfwd2['Company Reference ID Build'])
dfwd2 = dfwd2.drop(columns = ['Company Reference ID_x', 'Company Reference ID_y', 'Company Reference ID Build'])

dfwd2['Company Hierarchy Build'] = dfwd2['Company Hierarchy_x'].fillna(dfwd2['Company Hierarchy_y'])
dfwd2.insert(11, 'WD_CompanyHierarchy', dfwd2['Company Hierarchy Build'])
dfwd2 = dfwd2.drop(columns = ['Company Hierarchy_x', 'Company Hierarchy_y', 'Company Hierarchy Build'])

dfwd2['Host Country Build'] = dfwd2['Host Country (Alternative)'].fillna(dfwd2['Country'])
dfwd2.insert(12, 'Host Country', dfwd2['Host Country Build'])
dfwd2 = dfwd2.drop(columns = ['Host Country (Alternative)', 'Country', 'Host Country Build'])

dfwd2['Country/Territory Build'] = dfwd2['Country/Territory'].fillna(dfwd2['Host Country / Territory']).fillna(dfwd2['Country/Territory of Work Location'])
dfwd2.insert(12, 'Location', dfwd2['Country/Territory Build'])
dfwd2 = dfwd2.drop(columns = ['Country/Territory', 'Host Country / Territory', 'Country/Territory of Work Location', 'Country/Territory Build'])

if dfwd2['WD_EmployeeStatus'].iteritems() == 'Secondment':
    if dfwd2[(dfwd2['Assignment Reason (Alternative)'] != 'No Longer on Assignment (Long)')]:
        if dfwd2[len(dfwd2['Host Country (Alternative)']) == 0]:
            dfwd2['Territory'] = dfwd2['Host Country (Alternative)']
elif dfwd2['WD_EmployeeStatus'].iteritems() == 'Secondment': 
    if dfwd2[(dfwd2['Assignment Reason (Alternative)'] != 'No Longer on Assignment (Long)')]:
        if dfwd2[len(dfwd2['Host Country / Territory']) == 0]: 
            dfwd2['Territory'] = dfwd2['Host Country / Territory'] 
else:
    dfwd2['Territory'] = dfwd2['WD_CompanyHierarchy'].str.replace('PwC ', '')

dfwd2 = dfwd2.drop(columns = ['Assignment Reason (Alternative)'])
    
dfwd2['Country Build'] = dfwd2['Territory'].fillna(dfwd2['Location']).fillna(dfwd2['Host Country'])
dfwd2.insert(12, 'WD_Country', dfwd2['Country Build'])
dfwd2 = dfwd2.drop(columns = ['Territory', 'Location', 'Host Country', 'Country Build']).drop_duplicates()

col = dfwd2.pop('Company - Name')
dfwd2.insert(13, 'WD_LE_Name', col)

col = dfwd2.pop('Management Level')
dfwd2.insert(14, 'WD_Role', col)

col = dfwd2.pop('Work Email')
dfwd2.insert(15, 'WD_Email', col)

col = dfwd2.pop('Worker Type')
dfwd2.insert(16, 'WD_WorkerType', col)

col = dfwd2.pop('Job Category')
dfwd2.insert(17, 'WD_JobCategory', col)

col = dfwd2.pop('Contingent Worker Type')
dfwd2.insert(18, 'WD_CW_Type', col)

col = dfwd2.pop('Is Inbound IA? (Exception Process)')
dfwd2.insert(19, 'Is IA?', col)

count1 = dfwd2['WD_PartyID'].value_counts()
count1 = pd.DataFrame({'WD_PartyID':count1.index, 'CountPID':count1.values})
dfwd2 = pd.merge(dfwd2, count1, on = 'WD_PartyID', how = 'outer')

count2 = dfwd2['WD_EmployeeID'].value_counts()
count2 = pd.DataFrame({'WD_EmployeeID':count2.index, 'CountEID':count2.values})
dfwd2 = pd.merge(dfwd2, count2, on = 'WD_EmployeeID', how = 'outer')

#cols = dfwd2.columns.tolist()

#dfwd2 = dfwd2[['WD_PartyID',
# 'WD_EmployeeID',
# 'WD_EmployeeStatus',
# 'Status Details',
# 'Employee Status_x',
# 'Employee Status_y',
# 'WD_Worker',
# 'Hire_Date',
# 'Hire Date',
# 'Hire Date_x',
# 'Hire Date_y',
# 'Termination Date',
# 'WD_GUID',
# 'WD_LoS',
# 'WD_CC_Code',
# 'WD_CC_Name',
# 'WD_CR_Code',
# 'WD_CompanyHierarchy',
# 'WD_Country',
# 'WD_LE_Name',
# 'WD_Role',
# 'WD_Email',
# 'WD_WorkerType',
# 'WD_JobCategory',
# 'WD_CW_Type',
# 'Is IA?',
# 'Exists_df1_df2',
# 'Exists_dfwd1_df3',
# 'CountPID',
# 'CountEID']]

#dfwd2['EmpIDCount'] = dfwd2.groupby('')

display(dfwd2)
# Out:
#                                  WD_PartyID  WD_EmployeeID WD_EmployeeStatus  \
# 0      0000fb73-0624-4e47-a87b-72bc7d1da06f      100689987            Active
# 1      000235db-d90f-4881-8774-8bb5c9d8eb76      101074699            Active
# 2      000235db-d90f-4881-8774-8bb5c9d8eb76      101074699            Active
# 3      0005e477-fa19-406e-b5f5-fea23f60afed      100723663            Active
# 4      00066b84-677f-476f-bcda-9e45b2463f30      101231784            Active
# ...                                     ...            ...               ...
# 69990  ff6ad920-d740-45f6-9d0e-93f23b8810e5      101279003       Future Hire
# 69991  ff7616e0-e202-449e-a38b-f4d3b4c7c1a0      101304636       Future Hire
# 69992  ff780117-8338-4dc3-b1f6-b4d462a41471      101247147       Future Hire
# 69993  ff8a05a2-3516-4098-8a41-a9511cd71b53      101297133       Future Hire
# 69994  fffb6356-c779-4e5f-83fb-57b915857986      101233186       Future Hire
#
#                      WD_Worker  Hire Date Termination Date        WD_GUID  \
# 0                  Zezheng Gan 2018-09-01              NaT        zgan005
# 1                  Simon Letko 2022-09-12              NaT      sletko002
# 2                  Simon Letko 2021-09-01       2022-02-28      sletko002
# 3        Jan Philipp Boltz [C] 2018-07-01              NaT      jboltz002
# 4      Marie-Theres Zimmerling 2022-07-01              NaT  mzimmerlin002
# ...                        ...        ...              ...            ...
# 69990          Eva Maria Sacco 2023-01-01              NaT            NaN
# 69991              Leo Horlitz 2022-11-01              NaT    lhorlitz001
# 69992         Julius Turschner 2022-10-01              NaT  jturschner001
# 69993               Nida Temaj 2022-10-15              NaT      ntemaj001
# 69994             Luca Grädler 2023-01-15              NaT            NaN
#
#                         WD_LoS  WD_CC_Code                WD_CC_Name  \
# 0                    Assurance  NL12000412                   BAS SRG
# 1                 Specialist 5  AT18000019            ASS FS Banking
# 2                    Assurance  AT18000019            ASS FS Banking
# 3       Internal Firm Services  DE01000238           INFRA FS Berlin
# 4                     Advisory  DE01000792  ADV BC Risk & Regulatory
# ...                        ...         ...                       ...
# 69990   Internal Firm Services  DE01000121      FIN Treasury Germany
# 69991             ADV Strategy  DEZ1010001      ADV SC DE Consulting
# 69992                Assurance  DE01000243                ASR IS Ost
# 69993  IFS Firmwide Management  DE01001163           FwM New Venture
# 69994                Assurance  DE01000194              ASR IS Mitte
#
#                                  WD_CR_Code WD_CompanyHierarchy   WD_Country  \
# 0      f30abfab-4c61-4f45-b40c-1ab13706fd3c     PwC Netherlands  Netherlands
# 1      5715ad3e-bf5d-46a2-a831-e68192667608         PwC Austria      Austria
# 2                                       NaN                 NaN      Austria
# 3      ff6d5af8-9ae6-47d9-8317-eaa8b0e2e7b9         PwC Germany      Germany
# 4      ff6d5af8-9ae6-47d9-8317-eaa8b0e2e7b9         PwC Germany      Germany
# ...                                     ...                 ...          ...
# 69990  ff6d5af8-9ae6-47d9-8317-eaa8b0e2e7b9         PwC Germany      Germany
# 69991  5cc1b3b6-8a15-47d6-b5ad-600d68e496a9         PwC Germany      Germany
# 69992  ff6d5af8-9ae6-47d9-8317-eaa8b0e2e7b9         PwC Germany      Germany
# 69993  ff6d5af8-9ae6-47d9-8317-eaa8b0e2e7b9         PwC Germany      Germany
# 69994  ff6d5af8-9ae6-47d9-8317-eaa8b0e2e7b9         PwC Germany      Germany
#
#                                               WD_LE_Name           WD_Role  \
# 0                                   PwC Accountants N.V.  Senior Associate
# 1      PwC Österreich GmbH Wirtschaftsprüfungsgesells...        Specialist
# 2      PwC Österreich GmbH Wirtschaftsprüfungsgesells...    Intern/Trainee
# 3      PRICEWATERHOUSECOOPERS Gesellschaft mit beschr...        Specialist
# 4      PRICEWATERHOUSECOOPERS Gesellschaft mit beschr...         Associate
# ...                                                  ...               ...
# 69990  PRICEWATERHOUSECOOPERS Gesellschaft mit beschr...    Senior Manager
# 69991                         PwC Strategy& Germany GmbH         Associate
# 69992  PRICEWATERHOUSECOOPERS Gesellschaft mit beschr...    Intern/Trainee
# 69993  PRICEWATERHOUSECOOPERS Gesellschaft mit beschr...    Intern/Trainee
# 69994  PRICEWATERHOUSECOOPERS Gesellschaft mit beschr...    Intern/Trainee
#
#                               WD_Email      WD_WorkerType    WD_JobCategory  \
# 0                  zezheng.gan@pwc.com           Employee   Client Services
# 1                simon.l.letko@pwc.com           Employee   Client Services
# 2                simon.l.letko@pwc.com           Employee   Client Services
# 3            jan.philipp.boltz@pwc.com  Contingent Worker  Practice Support
# 4      marie-theres.zimmerling@pwc.com           Employee   Client Services
# ...                                ...                ...               ...
# 69990                              NaN           Employee  Practice Support
# 69991              leo.horlitz@pwc.com           Employee   Client Services
# 69992                              NaN           Employee   Client Services
# 69993                              NaN           Employee   Client Services
# 69994                              NaN           Employee   Client Services
#
#       WD_CW_Type Is IA? Exists_df1_df2 Exists_dfwd1_df3  CountPID  CountEID
# 0            NaN    NaN      left_only        left_only         1         1
# 1            NaN    NaN      left_only        left_only         2         2
# 2            NaN    NaN     right_only        left_only         2         2
# 3         Vendor    NaN      left_only        left_only         1         1
# 4            NaN    NaN      left_only        left_only         1         1
# ...          ...    ...            ...              ...       ...       ...
# 69990        NaN     No            NaN       right_only         1         1
# 69991        NaN     No            NaN       right_only         1         1
# 69992        NaN     No            NaN       right_only         1         1
# 69993        NaN     No            NaN       right_only         1         1
# 69994        NaN     No            NaN       right_only         1         1
#
# [69995 rows x 24 columns]

# %%
dfwd2.to_excel('DataMergeSAPOuterLongMultiIndex1.1dropdupesAnalysis.xlsx')

# %%
print('\n'.join([''.join([('PwC'[(x-y)%3] if((x*0.05)**2+(y*0.1)**2-1)**3-(x*0.05)**2*(y*0.1)**3<=0 else' ') for x in range(-30,30)]) for y in range(15,-15,-1)]))
# Out:
#
#
#
#                 wCPwCPwCP           PwCPwCPwC
#             wCPwCPwCPwCPwCPwC   PwCPwCPwCPwCPwCPw
#           PwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPw
#          PwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCP
#         PwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwC
#         wCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCP
#         CPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPw
#         PwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwC
#         wCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCP
#         CPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPw
#          wCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPw
#           PwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPw
#           wCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwC
#             wCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPw
#              PwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPw
#               CPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPw
#                 CPwCPwCPwCPwCPwCPwCPwCPwCPwCP
#                   CPwCPwCPwCPwCPwCPwCPwCPwC
#                     CPwCPwCPwCPwCPwCPwCPw
#                        PwCPwCPwCPwCPwC
#                           wCPwCPwCP
#                              CPw
#                               w
