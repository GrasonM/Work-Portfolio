# %%
company code mapping: view or table 
    Error catching table
    
PMDM problematic fields

# %%
import pandas as pd
import datetime
from datetime import datetime, date, timedelta
today = date.today()

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 50)

df1a = pd.read_json('JPPM-TL.json', typ = 'frame')
df1a2 = pd.json_normalize(df1a['BKG'])

df2a = pd.read_json('JPPM-TL2.json', typ = 'frame')
df2a2 = pd.json_normalize(df2a['BKG'])

df3a = pd.read_json('JPPM-TL3.json', typ = 'frame')
df3a2 = pd.json_normalize(df3a['BKG'])

print(f'JPPM-TL-{today}')
#df1a2.to_excel(f'JPPM-TL-{today}.xlsx', index = False)
#df2a2.to_excel(f'JPPM2-TL-{today}.xlsx', index = False)
#df3a2.to_excel(f'JPPM3-TL-{today}.xlsx', index = False)
# Out:
# JPPM-TL-2022-11-22

# %%
display(df1a2,df2a2,df3a2)
# Out:
#           BKG_ID  BKG_JOB_ID            BKG_BTY_ID         BKG_START  \
# 0    264980752.0    34478017  Provisional/Reserved  2022-11-01T09:00
# 1            NaN    24297772  Provisional/Reserved  2022-04-01T09:00
# 2    264980777.0    34478017  Provisional/Reserved  2022-11-01T09:00
# 3    264945302.0    24301807  Provisional/Reserved  2022-04-01T09:00
# 4            NaN    28433942  Provisional/Reserved  2022-10-04T09:00
# ..           ...         ...                   ...               ...
# 295  263525397.0    28409517  Provisional/Reserved  2022-04-01T09:00
# 296  263525517.0    28409517  Provisional/Reserved  2022-04-01T09:00
# 297  263525317.0    28398232  Provisional/Reserved  2022-04-01T09:00
# 298  263530507.0    28398397  Provisional/Reserved  2022-04-01T09:00
# 299  263525352.0    28409517  Provisional/Reserved  2022-04-01T09:00
#
#               BKG_END  BKG_TIME  BKG_FIXEDTIME  BKG_CMP_ID  \
# 0    2022-11-01T18:00        60              1           0
# ...

# %% [raw]
# display(df1)

# %%
df2
