# %%
import pandas as pd
import numpy as np
import re
#import dask as d
#import dask.dataframe as dd
#from dask.delayed import delayed

pattern = "^(.*)(?=[0-9a-f]{8}-[0-9a-f]{4}-[1-5][0-9a-f]{3}-[89ab][0-9a-f]{3}-[0-9a-f]{12})"

df1 = pd.read_excel("My Report_R075_all 2022-10-04 18_01 CEST.xlsx", skiprows = range(0,20), usecols = ['Worker',
                                                                                                        'Party ID', 
                                                                                                        'Employee ID',
                                                                                                        'GUID', 
                                                                                                        'Cost Center - ID', 
                                                                                                        'Cost Center - Name', 
                                                                                                        'Company Reference ID',
                                                                                                        'Company - Name', 
                                                                                                        'Management Level', 
                                                                                                        'Job Level - Primary Position', 
                                                                                                        'Work Email', 
                                                                                                        'Status Details', 
                                                                                                        'Line of Service', 
                                                                                                        'Hire Date', 
                                                                                                        'Assignment Reason (Alternative)', 
                                                                                                        'Host Country (Alternative)', 
                                                                                                        'Host Country / Territory', 
                                                                                                        'Country/Territory', 
                                                                                                        'Company Hierarchy', 
                                                                                                        'Worker Type', 
                                                                                                        'Contingent Worker Type', 
                                                                                                        'Job Category'])
df1 = df1.sort_values('Party ID')
df1['Party ID'] = df1['Party ID'].str.replace(f'{pattern}', '')
df1 = df1[df1['Party ID'].str.len() == 36]
df1 = df1[df1['Contingent Worker Type'] != 'Enterprise BOT']
#df1.to_csv("WD_R075_10.08.csv")


df2 = pd.read_excel("My Report_R139_almost_all 2022-10-04 18_53 CEST.xlsx", skiprows = range(0,26), usecols = ['Worker',
                                                                                                               'Party ID', 
                                                                                                               'Employee ID', 
                                                                                                               'GUID', 
                                                                                                               'Cost Center ID', 
                                                                                                               'Cost Center Name',
                                                                                                               'Company - Name', 
                                                                                                               'Management Level', 
                                                                                                               'Job Level - Primary Position', 
                                                                                                               'Email - Primary Work', 
                                                                                                               'Employee Status', 
                                                                                                               'Cost Center Level 3', 
                                                                                                               'Hire Date', 
                                                                                                               'Termination Date', 
                                                                                                               'Country/Territory of Work Location', 
                                                                                                               'Country', 
                                                                                                               'Worker Type', 
                                                                                                               'Contingent Worker Type', 
                                                                                                               'Job Category'])
df2 = df2.sort_values('Party ID')
df2['Party ID'] = df2['Party ID'].str.replace(f'{pattern}', '')
df2 = df2[df2['Party ID'].str.len() == 36]
df2 = df2[df2['Contingent Worker Type'] != 'Enterprise BOT']
#df2.to_csv("WD_R139_10.08.csv")

df3 = pd.read_excel("My Report_R311_almost_all 2022-10-04 18_24 CEST.xlsx", skiprows = range(0,20), usecols = ['Worker',
                                                                                                               'Party ID', 
                                                                                                               'Employee ID', 
                                                                                                               'GUID', 
                                                                                                               'Cost Center ID', 
                                                                                                               'Cost Center - Name', 
                                                                                                               'Company Reference ID',
                                                                                                               'Company - Name', 
                                                                                                               'Management Level', 
                                                                                                               'Job Level', 
                                                                                                               'Email - Primary Work',
                                                                                                               'Employee Status', 
                                                                                                               'PwC Global Line Of Service', 
                                                                                                               'Hire Date', 
                                                                                                               'Company Hierarchy', 
                                                                                                               'Cost Center Level 3', 
                                                                                                               'Worker Type', 
                                                                                                               'Contingent Worker Type', 
                                                                                                               'Job Category',
                                                                                                               'Is Inbound IA? (Exception Process)'])
df3 = df3.sort_values('Party ID')
df3['Party ID'] = df3['Party ID'].str.replace(f'{pattern}', '')
df3 = df3[df3['Party ID'].str.len() == 36]
df3 = df3[df3['Contingent Worker Type'] != 'Enterprise BOT']
#df3.to_csv("WD_R311_10.08.csv")

df4 = pd.read_excel("PMDM_Active_Employee_Report_10.08.xlsx", skiprows = range(0,5), usecols = ['Party ID', 'INAB GUID 1', 'INAB GUID 2', 'Cost Center Code', 'Cost Center Description', 'Legal Entity Party ID','Legal Entity Name', 'Job Level ', 'Grade', 'Cloud Mail', 'Territory', 'Global LoS', 'Contract Type', 'Job Category'])

#df5 = pd.read_excel("RRM_extract_10.08.xlsx")

#dfwd1 = pd.concat([df1,df2]) 

#dfwd2 = pd.merge(dfwd1, df3, how = 'outer', left_on = ['Party ID', 'Employee ID'], right_on = ['Party ID', 'Employee ID'], indicator = 'Exists_dfwd1_df3')
#dfwd2 = pd.concat([dfwd1,df3], ignore_index=True).drop_duplicates() 
#dfwd3 = pd.merge(dfwd2, df4, on = 'Party ID',how = 'outer', indicator='Exists_dfwd2_df4')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _handle_usecols(self, columns, usecols_key)
#    2836                         try:
# -> 2837                             col_indices.append(usecols_key.index(col))
#    2838                         except ValueError:
#
# ValueError: 'Company Reference ID' is not in list
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-0145fddfbf70> in <module>
#       8 pattern = "^(.*)(?=[0-9a-f]{8}-[0-9a-f]{4}-[1-5][0-9a-f]{3}-[89ab][0-9a-f]{3}-[0-9a-f]{12})"
#       9
# ---> 10 df1 = pd.read_excel("My Report_R075_all 2022-10-04 18_01 CEST.xlsx", skiprows = range(0,20), usecols = ['Worker',
#      11                                                                              'Party ID',
#      12                                                                              'Employee ID',
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols)
#     309         )
#     310
# --> 311     return io.parse(
#     312         sheet_name=sheet_name,
#     313         header=header,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\excel\_base.py in parse(self, sheet_name, header, names, index_col, usecols, squeeze, converters, true_values, false_values, skiprows, nrows, na_values, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     904             DataFrame from the passed in Excel file.
#     905         """
# --> 906         return self._reader.parse(
#     907             sheet_name=sheet_name,
#     908             header=header,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\excel\_base.py in parse(self, sheet_name, header, names, index_col, usecols, squeeze, dtype, true_values, false_values, skiprows, nrows, na_values, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     492             # GH 12292 : error when read one empty column from excel file
#     493             try:
# --> 494                 parser = TextParser(
#     495                     data,
#     496                     names=names,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in TextParser(*args, **kwds)
#    2317     """
#    2318     kwds["engine"] = "python"
# -> 2319     return TextFileReader(*args, **kwds)
#    2320
#    2321
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     944             self.options["has_index_names"] = kwds["has_index_names"]
#     945
# --> 946         self._make_engine(self.engine)
#     947
#     948     def close(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1187                     'are "c", "python", or "python-fwf")'
#    1188                 )
# -> 1189             self._engine = klass(self.f, **self.options)
#    1190
#    1191     def _failover_to_python(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, **kwds)
#    2403                 self.num_original_columns,
#    2404                 self.unnamed_cols,
# -> 2405             ) = self._infer_columns()
#    2406         except (TypeError, ValueError):
#    2407             self.close()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _infer_columns(self)
#    2779                 columns = [names]
#    2780             else:
# -> 2781                 columns = self._handle_usecols(columns, columns[0])
#    2782         else:
#    2783             try:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _handle_usecols(self, columns, usecols_key)
#    2837                             col_indices.append(usecols_key.index(col))
#    2838                         except ValueError:
# -> 2839                             _validate_usecols_names(self.usecols, usecols_key)
#    2840                     else:
#    2841                         col_indices.append(col)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _validate_usecols_names(usecols, names)
#    1300     missing = [c for c in usecols if c not in names]
#    1301     if len(missing) > 0:
# -> 1302         raise ValueError(
#    1303             f"Usecols do not match columns, columns expected but not found: {missing}"
#    1304         )
#
# ValueError: Usecols do not match columns, columns expected but not found: ['Company Reference ID', 'Job Level - Primary Position', 'Host Country / Territory', 'Status Details', 'Management Level', 'Worker', 'Company Hierarchy', 'GUID', 'Company - Name', 'Contingent Worker Type', 'Cost Center - Name', 'Party ID', 'Hire Date', 'Assignment Reason (Alternative)', 'Employee ID', 'Job Category', 'Host Country (Alternative)', 'Cost Center - ID', 'Worker Type', 'Line of Service', 'Work Email', 'Country/Territory']

# %%
df1.rename(columns={'Status Details':'Employee Status',
                    'Cost Center - ID':'Cost Center ID',
                    'Cost Center - Name':'Cost Center Name'}, inplace = True)

df2.rename(columns={'Email - Primary Work':'Work Email'}, inplace = True)

df3.rename(columns={'Email - Primary Work':'Work Email',
                    'Cost Center - Name':'Cost Center Name',
                    'Job Level':'Job Level - Primary Position'}, inplace = True)

dfwd1 = pd.merge(df1, df2, how = 'outer', left_on = ['Worker', 
                                                     'Party ID', 
                                                     'Employee ID', 
                                                     'GUID', 
                                                     'Cost Center ID', 
                                                     'Cost Center Name', 
                                                     'Company - Name', 
                                                     'Management Level', 
                                                     'Job Level - Primary Position',
                                                     'Work Email',
                                                     'Employee Status',
                                                     'Hire Date',
                                                     'Worker Type',
                                                     'Contingent Worker Type',
                                                     'Job Category'], right_on = ['Worker',
                                                                                  'Party ID', 
                                                                                  'Employee ID',
                                                                                  'GUID', 
                                                                                  'Cost Center ID', 
                                                                                  'Cost Center Name', 
                                                                                  'Company - Name', 
                                                                                  'Management Level', 
                                                                                  'Job Level - Primary Position',
                                                                                  'Work Email',
                                                                                  'Employee Status',
                                                                                  'Hire Date',
                                                                                  'Worker Type',
                                                                                  'Contingent Worker Type',
                                                                                  'Job Category'], indicator = 'Exists_df1_df2')

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
display(dfwd1)
# Out:
#                         Worker  Employee ID  \
# 0                  Zezheng Gan    100689987
# 1        Jan Philipp Boltz [C]    100723663
# 2      Marie-Theres Zimmerling    101231784
# 3                  Lia Ballach    101110909
# 4            Vera van Reeuwijk    100580482
# ...                        ...          ...
# 68049          Julia Ohngemach    101070788
# 68050        Alexandra Platzer    100776147
# 68051       Foziya Durstmüller    101239404
# 68052       Foziya Durstmüller    101239404
# 68053             Anton Pürrer    101203502
#
#                                    Party ID           GUID Employee Status  \
# 0      0000fb73-0624-4e47-a87b-72bc7d1da06f        zgan005          Active
# 1      0005e477-fa19-406e-b5f5-fea23f60afed      jboltz002          Active
# 2      00066b84-677f-476f-bcda-9e45b2463f30  mzimmerlin002          Active
# 3      00071b71-c5d2-4f77-b995-db14fb54675f    lballach001          Active
# 4      00073489-ea10-4811-a6d1-47675881338f   vreeuwijk003          Active
# ...                                     ...            ...             ...
# 68049  8c0ae1cb-bf96-4346-96d5-a9744024fe9d  johngemach001      Terminated
# 68050  c8ae0dfe-c31f-4acc-9788-c4eb3afb65bd    aplatzer001      Terminated
# 68051  e074baf7-9ed6-4c6b-9dc0-acefe11b1418            NaN      Terminated
# 68052  e074baf7-9ed6-4c6b-9dc0-acefe11b1418            NaN      Terminated
# 68053  ffdb22e5-bd89-49a2-80c1-550976a0d495            NaN      Terminated
#
#                             Work Email  Hire Date        Worker Type  \
# 0                  zezheng.gan@pwc.com 2018-09-01           Employee
# 1            jan.philipp.boltz@pwc.com 2018-07-01  Contingent Worker
# 2      marie-theres.zimmerling@pwc.com 2022-07-01           Employee
# 3                  lia.ballach@pwc.com 2021-10-01           Employee
# 4            vera.van.reeuwijk@pwc.com 2018-12-01           Employee
# ...                                ...        ...                ...
# 68049          julia.ohngemach@pwc.com 2021-04-01           Employee
# 68050        alexandra.platzer@pwc.com 2016-04-04           Employee
# 68051                              NaN 2022-05-01           Employee
# 68052                              NaN 2022-05-01           Employee
# 68053            anton.puerrer@pwc.com 2022-03-01           Employee
#
#       Contingent Worker Type      Job Category  Management Level  \
# 0                        NaN   Client Services  Senior Associate
# 1                     Vendor  Practice Support        Specialist
# 2                        NaN   Client Services         Associate
# 3                        NaN  Practice Support  Senior Associate
# 4                        NaN  Practice Support  Senior Associate
# ...                      ...               ...               ...
# 68049                    NaN               NaN               NaN
# 68050                    NaN   Client Services          Director
# 68051                    NaN   Client Services  Senior Associate
# 68052                    NaN   Client Services  Senior Associate
# 68053                    NaN   Client Services          Director
#
#       Job Level - Primary Position Country/Territory         Line of Service  \
# 0                              NaN       Netherlands               Assurance
# 1                              NaN           Germany  Internal Firm Services
# 2                              NaN           Germany                Advisory
# 3                              NaN           Germany  Internal Firm Services
# 4                              NaN       Netherlands               Assurance
# ...                            ...               ...                     ...
# 68049                          NaN               NaN                     NaN
# 68050                          NaN               NaN                     NaN
# 68051           Senior Associate 2               NaN                     NaN
# 68052           Senior Associate 2               NaN                     NaN
# 68053                          NaN               NaN                     NaN
#
#       Assignment Reason (Alternative) Host Country (Alternative)  \
# 0                                 NaN                        NaN
# 1                                 NaN                        NaN
# 2                                 NaN                        NaN
# 3                                 NaN                        NaN
# 4                                 NaN                        NaN
# ...                               ...                        ...
# 68049                             NaN                        NaN
# 68050                             NaN                        NaN
# 68051                             NaN                        NaN
# 68052                             NaN                        NaN
# 68053                             NaN                        NaN
#
#       Host Country / Territory  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 68049                      NaN
# 68050                      NaN
# 68051                      NaN
# 68052                      NaN
# 68053                      NaN
#
#                                           Company - Name Company Hierarchy  \
# 0                                   PwC Accountants N.V.   PwC Netherlands
# 1      PRICEWATERHOUSECOOPERS Gesellschaft mit beschr...       PwC Germany
# 2      PRICEWATERHOUSECOOPERS Gesellschaft mit beschr...       PwC Germany
# 3      PRICEWATERHOUSECOOPERS Gesellschaft mit beschr...       PwC Germany
# 4                                   PwC Accountants N.V.   PwC Netherlands
# ...                                                  ...               ...
# 68049  PwC Österreich GmbH Wirtschaftsprüfungsgesells...               NaN
# 68050  PwC Österreich GmbH Wirtschaftsprüfungsgesells...               NaN
# 68051                        Galaxy Steuerberatungs GmbH               NaN
# 68052                        Galaxy Steuerberatungs GmbH               NaN
# 68053  PwC Österreich GmbH Wirtschaftsprüfungsgesells...               NaN
#
#                        Company Reference ID Cost Center ID  \
# 0      f30abfab-4c61-4f45-b40c-1ab13706fd3c     NL12000412
# 1      ff6d5af8-9ae6-47d9-8317-eaa8b0e2e7b9     DE01000238
# 2      ff6d5af8-9ae6-47d9-8317-eaa8b0e2e7b9     DE01000792
# 3      ff6d5af8-9ae6-47d9-8317-eaa8b0e2e7b9     DE01000015
# 4      f30abfab-4c61-4f45-b40c-1ab13706fd3c     NL12000393
# ...                                     ...            ...
# 68049                                   NaN            NaN
# 68050                                   NaN     AT18000055
# 68051                                   NaN     GXA1000001
# 68052                                   NaN     GXA1000001
# 68053                                   NaN     AT18000030
#
#                Cost Center Name Termination Date  \
# 0                       BAS SRG              NaT
# 1               INFRA FS Berlin              NaT
# 2      ADV BC Risk & Regulatory              NaT
# 3              HC Human Capital              NaT
# 4             Audit DT Planning              NaT
# ...                         ...              ...
# 68049                       NaN       2022-03-31
# 68050               TLS CT Wien       2022-01-31
# 68051                 Gx AT Tax       2022-06-30
# 68052                 Gx AT Tax       2022-07-31
# 68053                  ASS Wien       2022-07-31
#
#       Country/Territory of Work Location  Country      Cost Center Level 3  \
# 0                                    NaN      NaN                      NaN
# 1                                    NaN      NaN                      NaN
# 2                                    NaN      NaN                      NaN
# 3                                    NaN      NaN                      NaN
# 4                                    NaN      NaN                      NaN
# ...                                  ...      ...                      ...
# 68049                                NaN  Austria                      NaN
# 68050                            Austria  Austria                      Tax
# 68051                            Austria  Austria                      NaN
# 68052                            Austria  Austria                      NaN
# 68053                            Austria  Austria  ASS Industrial Services
#
#       Exists_df1_df2
# 0          left_only
# 1          left_only
# 2          left_only
# 3          left_only
# 4          left_only
# ...              ...
# 68049     right_only
# 68050     right_only
# 68051     right_only
# 68052     right_only
# 68053     right_only
#
# [68054 rows x 27 columns]

# %%
dfwd2 = pd.merge(dfwd1, df3, how = 'outer', left_on = ['Worker', 
                                                       'Party ID', 
                                                       'Employee ID', 
                                                       'GUID', 
                                                       'Cost Center ID', 
                                                       'Cost Center Name', 
                                                       'Company - Name', 
                                                       'Management Level', 
                                                       'Job Level - Primary Position',
                                                       'Work Email',
                                                       'Employee Status',
                                                       'Hire Date',
                                                       'Worker Type',
                                                       'Contingent Worker Type',
                                                       'Job Category'], right_on = ['Worker',
                                                                                    'Party ID', 
                                                                                    'Employee ID', 
                                                                                    'GUID', 
                                                                                    'Cost Center ID', 
                                                                                    'Cost Center Name', 
                                                                                    'Company - Name', 
                                                                                    'Management Level', 
                                                                                    'Job Level - Primary Position', 
                                                                                    'Work Email',
                                                                                    'Employee Status',  
                                                                                    'Hire Date', 
                                                                                    'Worker Type', 
                                                                                    'Contingent Worker Type', 
                                                                                    'Job Category'], indicator = 'Exists_dfwd1_df3')

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
display(dfwd2)
# Out:
#                         Worker  Employee ID  \
# 0                  Zezheng Gan    100689987
# 1        Jan Philipp Boltz [C]    100723663
# 2      Marie-Theres Zimmerling    101231784
# 3                  Lia Ballach    101110909
# 4            Vera van Reeuwijk    100580482
# ...                        ...          ...
# 71460             Tobias Lemke    100876064
# 71461         Neuchâtel Stacie    101276657
# 71462             Luca Grädler    101233186
# 71463        Viktorija Lindner    101294345
# 71464           Rocco Rossetti    101290067
#
#                                    Party ID           GUID Employee Status  \
# 0      0000fb73-0624-4e47-a87b-72bc7d1da06f        zgan005          Active
# 1      0005e477-fa19-406e-b5f5-fea23f60afed      jboltz002          Active
# 2      00066b84-677f-476f-bcda-9e45b2463f30  mzimmerlin002          Active
# 3      00071b71-c5d2-4f77-b995-db14fb54675f    lballach001          Active
# 4      00073489-ea10-4811-a6d1-47675881338f   vreeuwijk003          Active
# ...                                     ...            ...             ...
# 71460  ffeb5e4f-aa38-48df-96c0-18736a1b5391      tlemke001     Future Hire
# 71461  ffeebcfe-1827-484e-b235-bd2f3df377c2     nstacie001     Future Hire
# 71462  fffb6356-c779-4e5f-83fb-57b915857986            NaN     Future Hire
# 71463  96312aa0-5a62-4f38-a4dc-d9c1a393c79b            NaN     Future Hire
# 71464  02dec11b-9704-4150-931f-0acaac3f2c95            NaN     Future Hire
#
#                             Work Email  Hire Date        Worker Type  \
# 0                  zezheng.gan@pwc.com 2018-09-01           Employee
# 1            jan.philipp.boltz@pwc.com 2018-07-01  Contingent Worker
# 2      marie-theres.zimmerling@pwc.com 2022-07-01           Employee
# 3                  lia.ballach@pwc.com 2021-10-01           Employee
# 4            vera.van.reeuwijk@pwc.com 2018-12-01           Employee
# ...                                ...        ...                ...
# 71460                              NaN 2023-01-01           Employee
# 71461                              NaN 2022-09-05           Employee
# 71462                              NaN 2023-01-15           Employee
# 71463      viktorija.lindner@gmail.com 2022-09-01           Employee
# 71464                              NaN 2022-09-01           Employee
#
#       Contingent Worker Type      Job Category  Management Level  \
# 0                        NaN   Client Services  Senior Associate
# 1                     Vendor  Practice Support        Specialist
# 2                        NaN   Client Services         Associate
# 3                        NaN  Practice Support  Senior Associate
# 4                        NaN  Practice Support  Senior Associate
# ...                      ...               ...               ...
# 71460                    NaN   Client Services           Manager
# 71461                    NaN  Practice Support    Intern/Trainee
# 71462                    NaN   Client Services    Intern/Trainee
# 71463                    NaN   Client Services           Manager
# 71464                    NaN   Client Services         Associate
#
#       Job Level - Primary Position Country/Territory         Line of Service  \
# 0                              NaN       Netherlands               Assurance
# 1                              NaN           Germany  Internal Firm Services
# 2                              NaN           Germany                Advisory
# 3                              NaN           Germany  Internal Firm Services
# 4                              NaN       Netherlands               Assurance
# ...                            ...               ...                     ...
# 71460                          NaN               NaN                     NaN
# 71461                          NaN               NaN                     NaN
# 71462                          NaN               NaN                     NaN
# 71463                    Manager 2               NaN                     NaN
# 71464                          NaN               NaN                     NaN
#
#       Assignment Reason (Alternative) Host Country (Alternative)  \
# 0                                 NaN                        NaN
# 1                                 NaN                        NaN
# 2                                 NaN                        NaN
# 3                                 NaN                        NaN
# 4                                 NaN                        NaN
# ...                               ...                        ...
# 71460                             NaN                        NaN
# 71461                             NaN                        NaN
# 71462                             NaN                        NaN
# 71463                             NaN                        NaN
# 71464                             NaN                        NaN
#
#       Host Country / Territory  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 71460                      NaN
# 71461                      NaN
# 71462                      NaN
# 71463                      NaN
# 71464                      NaN
#
#                                           Company - Name Company Hierarchy_x  \
# 0                                   PwC Accountants N.V.     PwC Netherlands
# 1      PRICEWATERHOUSECOOPERS Gesellschaft mit beschr...         PwC Germany
# 2      PRICEWATERHOUSECOOPERS Gesellschaft mit beschr...         PwC Germany
# 3      PRICEWATERHOUSECOOPERS Gesellschaft mit beschr...         PwC Germany
# 4                                   PwC Accountants N.V.     PwC Netherlands
# ...                                                  ...                 ...
# 71460  PRICEWATERHOUSECOOPERS Gesellschaft mit beschr...                 NaN
# 71461                               PwC Accountants N.V.                 NaN
# 71462  PRICEWATERHOUSECOOPERS Gesellschaft mit beschr...                 NaN
# 71463   PwC Transaction Services Wirtschaftsprüfung GmbH                 NaN
# 71464                                  PwC Advisory N.V.                 NaN
#
#                      Company Reference ID_x Cost Center ID  \
# 0      f30abfab-4c61-4f45-b40c-1ab13706fd3c     NL12000412
# 1      ff6d5af8-9ae6-47d9-8317-eaa8b0e2e7b9     DE01000238
# 2      ff6d5af8-9ae6-47d9-8317-eaa8b0e2e7b9     DE01000792
# 3      ff6d5af8-9ae6-47d9-8317-eaa8b0e2e7b9     DE01000015
# 4      f30abfab-4c61-4f45-b40c-1ab13706fd3c     NL12000393
# ...                                     ...            ...
# 71460                                   NaN     DE01000632
# 71461                                   NaN     NL12000365
# 71462                                   NaN     DE01000194
# 71463                                   NaN     AT07000048
# 71464                                   NaN     NL13000540
#
#                     Cost Center Name Termination Date  \
# 0                            BAS SRG              NaT
# 1                    INFRA FS Berlin              NaT
# 2           ADV BC Risk & Regulatory              NaT
# 3                   HC Human Capital              NaT
# 4                  Audit DT Planning              NaT
# ...                              ...              ...
# 71460           ADV BC FS Consulting              NaT
# 71461               Audit NC Utrecht              NaT
# 71462                   ASR IS Mitte              NaT
# 71463           ADV FS Banking & Cap              NaT
# 71464  Cons General Tech Traineeship              NaT
#
#       Country/Territory of Work Location Country Cost Center Level 3_x  \
# 0                                    NaN     NaN                   NaN
# 1                                    NaN     NaN                   NaN
# 2                                    NaN     NaN                   NaN
# 3                                    NaN     NaN                   NaN
# 4                                    NaN     NaN                   NaN
# ...                                  ...     ...                   ...
# 71460                                NaN     NaN                   NaN
# 71461                                NaN     NaN                   NaN
# 71462                                NaN     NaN                   NaN
# 71463                                NaN     NaN                   NaN
# 71464                                NaN     NaN                   NaN
#
#       Exists_df1_df2 Is Inbound IA? (Exception Process)  \
# 0          left_only                                NaN
# 1          left_only                                NaN
# 2          left_only                                NaN
# 3          left_only                                NaN
# 4          left_only                                NaN
# ...              ...                                ...
# 71460            NaN                                 No
# 71461            NaN                                 No
# 71462            NaN                                 No
# 71463            NaN                                 No
# 71464            NaN                                 No
#
#       PwC Global Line Of Service Company Hierarchy_y  \
# 0                            NaN                 NaN
# 1                            NaN                 NaN
# 2                            NaN                 NaN
# 3                            NaN                 NaN
# 4                            NaN                 NaN
# ...                          ...                 ...
# 71460                   Advisory         PwC Germany
# 71461                  Assurance     PwC Netherlands
# 71462                  Assurance         PwC Germany
# 71463                   Advisory         PwC Austria
# 71464                   Advisory     PwC Netherlands
#
#                      Company Reference ID_y  Cost Center Level 3_y  \
# 0                                       NaN                    NaN
# 1                                       NaN                    NaN
# 2                                       NaN                    NaN
# 3                                       NaN                    NaN
# 4                                       NaN                    NaN
# ...                                     ...                    ...
# 71460  ff6d5af8-9ae6-47d9-8317-eaa8b0e2e7b9         ADV Consulting
# 71461  f30abfab-4c61-4f45-b40c-1ab13706fd3c  Audit Noord - Centrum
# 71462  ff6d5af8-9ae6-47d9-8317-eaa8b0e2e7b9              Assurance
# 71463  a8209460-03f6-4935-8c14-721279792e3e               Advisory
# 71464  430725e5-828b-4099-b4ac-7324ee5f33c3    Advisory Consulting
#
#       Exists_dfwd1_df3
# 0            left_only
# 1            left_only
# 2            left_only
# 3            left_only
# 4            left_only
# ...                ...
# 71460       right_only
# 71461       right_only
# 71462       right_only
# 71463       right_only
# 71464       right_only
#
# [71465 rows x 33 columns]

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

col = dfwd2.pop('Party ID')
dfwd2.insert(0, 'WD_PartyID', col)

col = dfwd2.pop('Employee ID')
dfwd2.insert(1, 'WD_EmployeeID', col)

#dfwd2.set_index(['WD_PartyID', 'WD_EmployeeID'])

col = dfwd2.pop('Employee Status')
dfwd2.insert(2, 'WD_EmployeeStatus', col)

col = dfwd2.pop('Worker')
dfwd2.insert(3, 'WD_Worker', col)

col = dfwd2.pop('Hire Date')
dfwd2.insert(4, col.name, col)

col = dfwd2.pop('Termination Date')
dfwd2.insert(5, col.name, col)

col = dfwd2.pop('GUID')
dfwd2.insert(6, 'WD_GUID', col)

dfwd2['Line of Service Build'] = dfwd2['Line of Service'].fillna(dfwd2['Cost Center Level 3_x']).fillna(dfwd2['Cost Center Level 3_y']).fillna(dfwd2['PwC Global Line Of Service'])
dfwd2.insert(7, 'LoS', dfwd2['Line of Service Build'])
dfwd2 = dfwd2.drop(columns = ['Line of Service', 'Cost Center Level 3_x', 'Cost Center Level 3_y', 'PwC Global Line Of Service', 'Line of Service Build'])

col = dfwd2.pop('Job Level - Primary Position')
dfwd2.insert(7, 'Role Level', col)

dfwd2['Role LoS Build'] = dfwd2['Role Level'].fillna(dfwd2['LoS'])
dfwd2.insert(7, 'WD_LoS', dfwd2['Role LoS Build'])
dfwd2 = dfwd2.drop(columns = ['Role Level', 'LoS', 'Role LoS Build'])

col = dfwd2.pop('Cost Center ID')
dfwd2.insert(8, 'WD_CC_Code', col)

col = dfwd2.pop('Cost Center Name')
dfwd2.insert(9, 'WD_CC_Name', col)

dfwd2['Company Reference ID Build'] = dfwd2['Company Reference ID_x'].fillna(dfwd2['Company Reference ID_y'])
dfwd2.insert(10, 'WD_CR_Code', dfwd2['Company Reference ID Build'])
dfwd2 = dfwd2.drop(columns = ['Company Reference ID_x', 'Company Reference ID_y', 'Company Reference ID Build'])

dfwd2['Company Hierarchy Build'] = dfwd2['Company Hierarchy_x'].fillna(dfwd2['Company Hierarchy_y'])
dfwd2.insert(11, 'WD_CompanyHierarchy', dfwd2['Company Hierarchy Build'])
dfwd2 = dfwd2.drop(columns = ['Company Hierarchy_x', 'Company Hierarchy_y', 'Company Hierarchy Build'])

dfwd2['Host Country Build'] = dfwd2['Host Country (Alternative)'].fillna(dfwd2['Country'])
dfwd2.insert(12, 'Host Country', dfwd2['Host Country Build'])
dfwd2 = dfwd2.drop(columns = ['Host Country (Alternative)', 'Country', 'Host Country Build'])

dfwd2['Country/Territory Build'] = dfwd2['Country/Territory'].fillna(dfwd2['Host Country / Territory']).fillna(dfwd2['Country/Territory of Work Location'])
dfwd2.insert(12, 'Location', dfwd2['Country/Territory Build'])
dfwd2 = dfwd2.drop(columns = ['Country/Territory', 'Host Country / Territory', 'Country/Territory of Work Location', 'Country/Territory Build'])

if dfwd2['WD_EmployeeStatus'].iteritems() == 'Secondment':
    if dfwd2[(dfwd2['Assignment Reason (Alternative)'] != 'No Longer on Assignment (Long)')]:
        if dfwd2[len(dfwd2['Host Country (Alternative)']) == 0]:
            dfwd2['Territory'] = dfwd2['Host Country (Alternative)']
elif dfwd2['WD_EmployeeStatus'].iteritems() == 'Secondment': 
    if dfwd2[(dfwd2['Assignment Reason (Alternative)'] != 'No Longer on Assignment (Long)')]:
        if dfwd2[len(dfwd2['Host Country / Territory']) == 0]: 
            dfwd2['Territory'] = dfwd2['Host Country / Territory'] 
else:
    dfwd2['Territory'] = dfwd2['WD_CompanyHierarchy'].str.replace('PwC ', '')

dfwd2 = dfwd2.drop(columns = ['Assignment Reason (Alternative)'])
    
dfwd2['Country Build'] = dfwd2['Territory'].fillna(dfwd2['Location']).fillna(dfwd2['Host Country'])
dfwd2.insert(12, 'WD_Country', dfwd2['Country Build'])
dfwd2 = dfwd2.drop(columns = ['Territory', 'Location', 'Host Country', 'Country Build']).drop_duplicates()

col = dfwd2.pop('Company - Name')
dfwd2.insert(13, 'WD_LE_Name', col)

col = dfwd2.pop('Management Level')
dfwd2.insert(14, 'WD_Role', col)

col = dfwd2.pop('Work Email')
dfwd2.insert(15, 'WD_Email', col)

col = dfwd2.pop('Worker Type')
dfwd2.insert(16, 'WD_WorkerType', col)

col = dfwd2.pop('Job Category')
dfwd2.insert(17, 'WD_JobCategory', col)

col = dfwd2.pop('Contingent Worker Type')
dfwd2.insert(18, 'WD_CW_Type', col)

col = dfwd2.pop('Is Inbound IA? (Exception Process)')
dfwd2.insert(19, 'Is IA?', col)

count1 = dfwd2['WD_PartyID'].value_counts()
count1 = pd.DataFrame({'WD_PartyID':count1.index, 'CountPID':count1.values})
dfwd2 = pd.merge(dfwd2, count1, on = 'WD_PartyID', how = 'outer')

count2 = dfwd2['WD_EmployeeID'].value_counts()
count2 = pd.DataFrame({'WD_EmployeeID':count2.index, 'CountEID':count2.values})
dfwd2 = pd.merge(dfwd2, count2, on = 'WD_EmployeeID', how = 'outer')

#cols = dfwd2.columns.tolist()

#dfwd2 = dfwd2[['WD_PartyID',
# 'WD_EmployeeID',
# 'WD_EmployeeStatus',
# 'Status Details',
# 'Employee Status_x',
# 'Employee Status_y',
# 'WD_Worker',
# 'Hire_Date',
# 'Hire Date',
# 'Hire Date_x',
# 'Hire Date_y',
# 'Termination Date',
# 'WD_GUID',
# 'WD_LoS',
# 'WD_CC_Code',
# 'WD_CC_Name',
# 'WD_CR_Code',
# 'WD_CompanyHierarchy',
# 'WD_Country',
# 'WD_LE_Name',
# 'WD_Role',
# 'WD_Email',
# 'WD_WorkerType',
# 'WD_JobCategory',
# 'WD_CW_Type',
# 'Is IA?',
# 'Exists_df1_df2',
# 'Exists_dfwd1_df3',
# 'CountPID',
# 'CountEID']]

#dfwd2['EmpIDCount'] = dfwd2.groupby('')

display(dfwd2)
# Out:
#                                  WD_PartyID  WD_EmployeeID WD_EmployeeStatus  \
# 0      0000fb73-0624-4e47-a87b-72bc7d1da06f      100689987            Active
# 1      0005e477-fa19-406e-b5f5-fea23f60afed      100723663            Active
# 2      00066b84-677f-476f-bcda-9e45b2463f30      101231784            Active
# 3      00071b71-c5d2-4f77-b995-db14fb54675f      101110909            Active
# 4      00073489-ea10-4811-a6d1-47675881338f      100580482            Active
# ...                                     ...            ...               ...
# 70988  ffc2ce98-ce13-404a-99c0-4dc31ea76eca      101271101       Future Hire
# 70989  ffeb5e4f-aa38-48df-96c0-18736a1b5391      100876064       Future Hire
# 70990  ffeebcfe-1827-484e-b235-bd2f3df377c2      101276657       Future Hire
# 70991  fffb6356-c779-4e5f-83fb-57b915857986      101233186       Future Hire
# 70992  02dec11b-9704-4150-931f-0acaac3f2c95      101290067       Future Hire
#
#                      WD_Worker  Hire Date Termination Date        WD_GUID  \
# 0                  Zezheng Gan 2018-09-01              NaT        zgan005
# 1        Jan Philipp Boltz [C] 2018-07-01              NaT      jboltz002
# 2      Marie-Theres Zimmerling 2022-07-01              NaT  mzimmerlin002
# 3                  Lia Ballach 2021-10-01              NaT    lballach001
# 4            Vera van Reeuwijk 2018-12-01              NaT   vreeuwijk003
# ...                        ...        ...              ...            ...
# 70988     Vasilisa Pecherskaia 2022-08-15              NaT  vpecherska001
# 70989             Tobias Lemke 2023-01-01              NaT      tlemke001
# 70990         Neuchâtel Stacie 2022-09-05              NaT     nstacie001
# 70991             Luca Grädler 2023-01-15              NaT            NaN
# 70992           Rocco Rossetti 2022-09-01              NaT            NaN
#
#                        WD_LoS  WD_CC_Code                     WD_CC_Name  \
# 0                   Assurance  NL12000412                        BAS SRG
# 1      Internal Firm Services  DE01000238                INFRA FS Berlin
# 2                    Advisory  DE01000792       ADV BC Risk & Regulatory
# 3      Internal Firm Services  DE01000015               HC Human Capital
# 4                   Assurance  NL12000393              Audit DT Planning
# ...                       ...         ...                            ...
# 70988          ADV Consulting  DE01000605         ADV BC CIPS Consulting
# 70989          ADV Consulting  DE01000632           ADV BC FS Consulting
# 70990   Audit Noord - Centrum  NL12000365               Audit NC Utrecht
# 70991               Assurance  DE01000194                   ASR IS Mitte
# 70992     Advisory Consulting  NL13000540  Cons General Tech Traineeship
#
#                                  WD_CR_Code WD_CompanyHierarchy   WD_Country  \
# 0      f30abfab-4c61-4f45-b40c-1ab13706fd3c     PwC Netherlands  Netherlands
# 1      ff6d5af8-9ae6-47d9-8317-eaa8b0e2e7b9         PwC Germany      Germany
# 2      ff6d5af8-9ae6-47d9-8317-eaa8b0e2e7b9         PwC Germany      Germany
# 3      ff6d5af8-9ae6-47d9-8317-eaa8b0e2e7b9         PwC Germany      Germany
# 4      f30abfab-4c61-4f45-b40c-1ab13706fd3c     PwC Netherlands  Netherlands
# ...                                     ...                 ...          ...
# 70988  ff6d5af8-9ae6-47d9-8317-eaa8b0e2e7b9         PwC Germany      Germany
# 70989  ff6d5af8-9ae6-47d9-8317-eaa8b0e2e7b9         PwC Germany      Germany
# 70990  f30abfab-4c61-4f45-b40c-1ab13706fd3c     PwC Netherlands  Netherlands
# 70991  ff6d5af8-9ae6-47d9-8317-eaa8b0e2e7b9         PwC Germany      Germany
# 70992  430725e5-828b-4099-b4ac-7324ee5f33c3     PwC Netherlands  Netherlands
#
#                                               WD_LE_Name           WD_Role  \
# 0                                   PwC Accountants N.V.  Senior Associate
# 1      PRICEWATERHOUSECOOPERS Gesellschaft mit beschr...        Specialist
# 2      PRICEWATERHOUSECOOPERS Gesellschaft mit beschr...         Associate
# 3      PRICEWATERHOUSECOOPERS Gesellschaft mit beschr...  Senior Associate
# 4                                   PwC Accountants N.V.  Senior Associate
# ...                                                  ...               ...
# 70988  PRICEWATERHOUSECOOPERS Gesellschaft mit beschr...    Senior Manager
# 70989  PRICEWATERHOUSECOOPERS Gesellschaft mit beschr...           Manager
# 70990                               PwC Accountants N.V.    Intern/Trainee
# 70991  PRICEWATERHOUSECOOPERS Gesellschaft mit beschr...    Intern/Trainee
# 70992                                  PwC Advisory N.V.         Associate
#
#                               WD_Email      WD_WorkerType    WD_JobCategory  \
# 0                  zezheng.gan@pwc.com           Employee   Client Services
# 1            jan.philipp.boltz@pwc.com  Contingent Worker  Practice Support
# 2      marie-theres.zimmerling@pwc.com           Employee   Client Services
# 3                  lia.ballach@pwc.com           Employee  Practice Support
# 4            vera.van.reeuwijk@pwc.com           Employee  Practice Support
# ...                                ...                ...               ...
# 70988                              NaN           Employee   Client Services
# 70989                              NaN           Employee   Client Services
# 70990                              NaN           Employee  Practice Support
# 70991                              NaN           Employee   Client Services
# 70992                              NaN           Employee   Client Services
#
#       WD_CW_Type Is IA? Exists_df1_df2 Exists_dfwd1_df3  CountPID  CountEID
# 0            NaN    NaN      left_only        left_only         1         1
# 1         Vendor    NaN      left_only        left_only         1         1
# 2            NaN    NaN      left_only        left_only         1         1
# 3            NaN    NaN      left_only        left_only         1         1
# 4            NaN    NaN      left_only        left_only         1         1
# ...          ...    ...            ...              ...       ...       ...
# 70988        NaN     No            NaN       right_only         1         1
# 70989        NaN     No            NaN       right_only         1         1
# 70990        NaN     No            NaN       right_only         1         1
# 70991        NaN     No            NaN       right_only         1         1
# 70992        NaN     No            NaN       right_only         1         1
#
# [70993 rows x 24 columns]

# %%
dfwd2.to_excel('DataMergeWDOuterMergedFields0.7.8.1Analysis.xlsx')

# %%
import datacompy, pandas as pd

df1 = pd.read_excel()
df2 = pd.read_excel()

# %%
print('\n'.join([''.join([('PwC'[(x-y)%3] if((x*0.05)**2+(y*0.1)**2-1)**3-(x*0.05)**2*(y*0.1)**3<=0 else' ') for x in range(-30,30)]) for y in range(15,-15,-1)]))
# Out:
#
#
#
#                 wCPwCPwCP           PwCPwCPwC
#             wCPwCPwCPwCPwCPwC   PwCPwCPwCPwCPwCPw
#           PwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPw
#          PwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCP
#         PwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwC
#         wCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCP
#         CPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPw
#         PwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwC
#         wCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCP
#         CPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPw
#          wCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPw
#           PwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPw
#           wCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwC
#             wCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPw
#              PwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPw
#               CPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPw
#                 CPwCPwCPwCPwCPwCPwCPwCPwCPwCP
#                   CPwCPwCPwCPwCPwCPwCPwCPwC
#                     CPwCPwCPwCPwCPwCPwCPw
#                        PwCPwCPwCPwCPwC
#                           wCPwCPwCP
#                              CPw
#                               w
