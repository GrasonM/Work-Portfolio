# %%
Hi Grason,

I would like to ask you to add to your Python solution new CVs:

GCV_API.GCV_STG.NS-JobLevel-en
https://api-staging.pwcinternal.com:7443/GlobalCVService/GlobalCVService.svc/cv/NS-JobLevel-en

GCV_API.GCV_STG.NS-ManagementLevel-en
https://api-staging.pwcinternal.com:7443/GlobalCVService/GlobalCVService.svc/cv/NS-ManagementLevel-en

GCV_API.GCV_STG.NS-PwCNetworkNode-en
https://api-staging.pwcinternal.com:7443/GlobalCVService/GlobalCVService.svc/cv/NS-PwCNetworkNode-en

GCV_API.GCV_STG_ONB.ORD-CostCenterHierarchy_Normalised
https://api-staging.pwcinternal.com:7443/GlobalCVService/GlobalCVService.svc/cv/Integration_ORD-CostCenterHierarchy_Normalised

NS-PwCNetworkNode-en

Please note that for 'ORD-CostCenterHierarchy_Normalised' I used 'STG_ONB' prefix :) This is because CV's where name begins with Integration* belong to the stage-onboarding environment.

# %%
import pyodbc
#Currently determining which datatypes need to be used
#stackoverflow.com/questions/20229441/implications-of-nvarchar-50-vs-nvarchar-max
#stackoverflow.com/questions/35366/what-are-the-main-performance-differences-between-varchar-and-nvarchar-sql-serve
#stackoverflow.com/questions/612430/when-must-we-use-nvarchar-nchar-instead-of-varchar-char-in-sql-server
def create_tables():
    
    """create tables in the SQL Server Database"""
    commands = (
    """ 
    CREATE TABLE [GCV_PRD].[NS-PwCNetworkNode-en-Territory] (
    Id varchar(50),
    Name varchar(50),
    VocabName varchar(50),
    ActiveStatus varchar(50),
    ApprovalStatus varchar(50),
    CreatedDate datetime,
    ModifiedDate datetime,
    NodeName varchar(50),
    PRID varchar(50),
    PartyID varchar(50),
    NetworkNodeID varchar(50),
    LocalAccountingCurrency varchar(50),
    RegionalReportingCurrency varchar(50),
    Definition nvarchar(255),
    EffectiveDate datetime,
    LastEditedReason nvarchar(255),
    Systemofrecord varchar(50),
    SourceMDMGERCode varchar(50),
    SourceMDMSortPrefix varchar(50),
    NodeTypeId varchar(50),
    NodeType varchar(50),
    Abbreviation varchar(50),
    SCMember varchar(50),
    GGCEPrefix varchar(50),
    NLTMember varchar(50),
    Disambiguator varchar(50),
    Comments nvarchar(MAX),
    TBDRateElementId varchar(50),
    TBDRateElementName nvarchar(50),
    TBDRateElementLevel varchar(50)
    )
    """,
    """ 
    CREATE TABLE [GCV_PRD].[NS-ResourceRole-en] (
    Id varchar(50),
    Name varchar(50),
    VocabName varchar(50),
    ActiveStatus varchar(50),
    ApprovalStatus varchar(50),
    CreatedDate datetime,
    ModifiedDate datetime,
    ResourceRoleName varchar(50),
    Definition nvarchar(255),
    EffectiveDate datetime,
    LastEditedReason nvarchar(255),
    Systemofrecord varchar(50)
    )
    """,
    """ 
    CREATE TABLE [GCV_PRD].[NS-ResourceType-en] (
    Id varchar(50),
    Name varchar(50),
    VocabName varchar(50),
    ActiveStatus varchar(50),
    ApprovalStatus varchar(50),
    CreatedDate datetime,
    ModifiedDate datetime,
    BusinessObjectTypeName varchar(50),
    Definition nvarchar(255),
    EffectiveDate datetime,
    LastEditedReason nvarchar(255),
    Systemofrecord varchar(50)
    )
    """,
   #""" 
    #CREATE TABLE [GCV_PRD].[Onboarding_ORD-CostCentreLegalEntity-en-GlobalHierarchy_Denormalised] (
    #CostCenterPwCNetworkNodeId varchar(50),
    #CostCenterPwCNetworkDescriptor varchar(50),
    #CostCenterId varchar(50),
    #LocalCostCenterCode varchar(50),
    #CostCenterName nvarchar(255),
    #UniversalCostCenterCode varchar(50),
    #LegalEntityPartyId varchar(50),
    #LegalEntityName nvarchar(255),
    #ModifiedDate datetime
    #)
    #""",
    """ 
    CREATE TABLE [GCV_PRD].[NS-PwCNetworkNode-en] (
    Id varchar(50),
    Name nvarchar(255),
    VocabName varchar(255),
    ActiveStatus varchar(50),
    ApprovalStatus varchar(50),
    CreatedDate datetime,
    ModifiedDate datetime,
    NodeName nvarchar(255),
    EffectiveDate datetime,
    LastEditedReason nvarchar(MAX),
    Systemofrecord varchar(255),
    SourceMDMGERCode varchar(50),
    SourceMDMSortPrefix varchar(50),
    PRID varchar(50),
    PartyID varchar(50),
    NetworkNodeID varchar(50),
    LocalAccountingCurrency varchar(50),
    RegionalReportingCurrency varchar(50),
    Disambiguator varchar(255),
    Comments nvarchar(MAX),
    GGCEPrefix varchar(255),
    Definition nvarchar(MAX),
    ExpiryDate datetime,
    Abbreviation varchar(50),
    SCMember varchar(255),
    NLTMember varchar(255),
    NodeTypeId varchar(50),
    NodeType varchar(255),
    TBDRateElementId varchar(50),
    TBDRateElementName nvarchar(255),
    TBDRateElementLevel varchar(255)
    )
    """,
    """ 
    CREATE TABLE [GCV_PRD].[LEL-PwCLegalEntity-en] (
    PartyReferenceId varchar(50),
    PartyId varchar(255),
    Name nvarchar(MAX),
    ResponsibleNetworkNodeId varchar(255),
    ResponsibleNetworkNode varchar(255),
    OperatingNetworkNodeId varchar(255),
    OperatingNetworkNode varchar(255),
    EmployingNetworkNodeId varchar(255),
    EmployingNetworkNode varchar(255),
    DUNS varchar(255),
    LELNumber varchar(255),
    GFSId varchar(255),
    RegisteredAddressLine1 nvarchar(255),
    RegisteredAddressLine2 nvarchar(255),
    RegisteredAddressLine3 nvarchar(255),
    RegisteredCity nvarchar(255),
    RegisteredCountrySubdivisionId nvarchar(255),
    RegisteredCountrySubdivisionCode varchar(255),
    RegisteredCountrySubdivisionName nvarchar(255),
    RegisteredCountryId varchar(255),
    RegisteredCountryCode varchar(255),
    RegisteredCountryName varchar(255),
    RegisteredPostalCode varchar(255),
    OperatingAddressLine1 nvarchar(255),
    OperatingAddressLine2 nvarchar(255),
    OperatingAddressLine3 nvarchar(255),
    OperatingCity varchar(255),
    OperatingCountrySubdivisionId nvarchar(255),
    OperatingCountrySubdivisionCode varchar(255),
    OperatingCountrySubdivisionName varchar(255),
    OperatingCountryId varchar(255),
    OperatingCountryCode varchar(255),
    OperatingCountryName varchar(255),
    OperatingPostalCode varchar(255),
    BillingAddressLine1 nvarchar(255),
    BillingAddressLine2 nvarchar(255),
    BillingAddressLine3 nvarchar(255),
    BillingCity varchar(255),
    BillingCountrySubdivisionId nvarchar(255),
    BillingCountrySubdivisionCode varchar(255),
    BillingCountrySubdivisionName varchar(255),
    BillingCountryId varchar(255),
    BillingCountryCode varchar(255),
    BillingCountryName varchar(255),
    BillingPostalCode varchar(255),
    EmployingLE varchar(255),
    CreatedDate datetime,
    PartyRoleId varchar(255),
    PartyRole varchar(255),
    ModifiedDate datetime,
    LicenseTypeId nvarchar(255),
    LicenseType varchar(255),
    OrganisationTypeId varchar(255),
    OrganisationType varchar(255)
    )
    """,
    """ 
    CREATE TABLE [GCV_PRD].[ORD-CostCenter] (
    Local_Cost_Center_Code varchar(255),
    Cost_Center_Name nvarchar(255),
    Cost_Center_SK varchar(255),
    Universal_Cost_Center_Code varchar(255),
    Cost_Center_NK varchar(255),
    Cost_Type_Descriptor varchar(255),
    Cost_Type_UID varchar(255),
    PwC_Network_Descriptor varchar(255),
    PwC_Network_UID varchar(255),
    OS_Global_Sub_LoS_Descriptor nvarchar(255),
    Global_LoS_UID nvarchar(255),
    OS_Function_Descriptor varchar(255),
    Function_UID varchar(255),
    EmployingFlag varchar(255),
    Cost_Center_Status varchar(255),
    Active_Status varchar(255),
    Effective_Date datetime,
    Expiration_Date datetime,
    Comments nvarchar(255),
    Created_Datetime datetime,
    Last_Modified_Datetime datetime
    )
    """,)
    conn = None
    try:
        server = 'GX-ZWESQLPWV342.glblcloud.ad.pwcinternal.com'
        database = 'CommonConfig'
        conn = pyodbc.connect('Trusted_Connection=yes',DRIVER='{SQL Server}',SERVER=server,DATABASE=database)
        cur = conn.cursor()
        # create table one by one
        for command in commands:
            cur.execute(command)
        # close communication with the SQL Server
        cur.close()
        # commit the changes
        conn.commit()
    except (Exception, pyodbc.DatabaseError) as error:
        print(error)
    finally:
        if conn is not None:
            conn.close()
            
if __name__ == '__main__':
    create_tables()

# %%
import pyodbc
#Currently determining which datatypes need to be used
#stackoverflow.com/questions/20229441/implications-of-nvarchar-50-vs-nvarchar-max
#stackoverflow.com/questions/35366/what-are-the-main-performance-differences-between-varchar-and-nvarchar-sql-serve
#stackoverflow.com/questions/612430/when-must-we-use-nvarchar-nchar-instead-of-varchar-char-in-sql-server
def create_tables():
    
    """create tables in the SQL Server Database"""
    commands = (
    """ 
    CREATE TABLE [GCV_STG].[ORD-CostCenter] (
    Local_Cost_Center_Code varchar(50),
    Cost_Center_Name nvarchar(255),
    Cost_Center_SK varchar(255),
    Universal_Cost_Center_Code varchar(255),
    Cost_Center_NK varchar(255),
    Cost_Type_Descriptor varchar(255),
    Cost_Type_UID varchar(255),
    PwC_Network_Descriptor varchar(255),
    PwC_Network_UID varchar(255),
    OS_Global_Sub_LoS_Descriptor nvarchar(255),
    Global_LoS_UID nvarchar(255),
    OS_Function_Descriptor varchar(255),
    Function_UID varchar(255),
    EmployingFlag int,
    Cost_Center_Status varchar(255),
    Record_Status varchar(50),
    Active_Status varchar(255),
    Effective_Date datetime,
    Expiration_Date datetime,
    Comments nvarchar(255),
    Ownership_Folder varchar(255),
    Created_Datetime datetime,
    Last_Modified_Datetime datetime,
    Batch_Number varchar(255)
    )
    """,
    """ 
    ALTER TABLE [GCV_STG].[ORD-CostCenter] 
    ADD importTime DATETIME NOT NULL DEFAULT (GETDATE());
    """,)
    conn = None
    try:
        server = 'GX-ZWESQLPWV342.glblcloud.ad.pwcinternal.com'
        database = 'CommonConfig'
        conn = pyodbc.connect('Trusted_Connection=yes',DRIVER='{SQL Server}',SERVER=server,DATABASE=database)
        cur = conn.cursor()
        # create table one by one
        for command in commands:
            cur.execute(command)
        # close communication with the SQL Server
        cur.close()
        # commit the changes
        conn.commit()
    except (Exception, pyodbc.DatabaseError) as error:
        print(error)
    finally:
        if conn is not None:
            conn.close()
            
if __name__ == '__main__':
    create_tables()

# %%
import pyodbc
#Currently determining which datatypes need to be used
#stackoverflow.com/questions/20229441/implications-of-nvarchar-50-vs-nvarchar-max
#stackoverflow.com/questions/35366/what-are-the-main-performance-differences-between-varchar-and-nvarchar-sql-serve
#stackoverflow.com/questions/612430/when-must-we-use-nvarchar-nchar-instead-of-varchar-char-in-sql-server
def create_tables():
    
    """create tables in the SQL Server Database"""
    commands = (
    """ 
    CREATE SCHEMA GCV_PRD;
    """,
    """ 
    CREATE SCHEMA GCV_STG;
    """,)
    conn = None
    try:
        server = 'GX-ZWESQLPWV342.glblcloud.ad.pwcinternal.com'
        database = 'CommonConfig'
        conn = pyodbc.connect('Trusted_Connection=yes',DRIVER='{SQL Server}',SERVER=server,DATABASE=database)
        cur = conn.cursor()
        # create table one by one
        for command in commands:
            cur.execute(command)
        # close communication with the SQL Server
        cur.close()
        # commit the changes
        conn.commit()
    except (Exception, pyodbc.DatabaseError) as error:
        print(error)
    finally:
        if conn is not None:
            conn.close()
            
if __name__ == '__main__':
    create_tables()

# %%
import pyodbc
#Currently determining which datatypes need to be used
#stackoverflow.com/questions/20229441/implications-of-nvarchar-50-vs-nvarchar-max
#stackoverflow.com/questions/35366/what-are-the-main-performance-differences-between-varchar-and-nvarchar-sql-serve
#stackoverflow.com/questions/612430/when-must-we-use-nvarchar-nchar-instead-of-varchar-char-in-sql-server
def create_tables():
    
    """create tables in the SQL Server Database"""
    commands = (
    """ 
    CREATE TABLE NS-JobLevel-en (

    )
    """,
    """ 
    CREATE TABLE NS-ManagementLevel-en (

    )
    """,
    """ 
    CREATE TABLE NS-WorkerType-en (

    )
    """,
    """ 
    CREATE TABLE NS-WorkerType-en_NS-ContractType-en_Normalised (

    )
    """,)
    conn = None
    try:
        conn = pyodbc.connect('Trusted_Connection=yes',DRIVER='{SQL Server}',SERVER=server,DATABASE=database)
        cur = conn.cursor()
        # create table one by one
        for command in commands:
            cur.execute(command)
        # close communication with the SQL Server
        cur.close()
        # commit the changes
        conn.commit()
    except (Exception, pyodbc.DatabaseError) as error:
        print(error)
    finally:
        if conn is not None:
            conn.close()
            
if __name__ == '__main__':
    create_tables()

# %%
import pyodbc
#Currently determining which datatypes need to be used
#stackoverflow.com/questions/20229441/implications-of-nvarchar-50-vs-nvarchar-max
#stackoverflow.com/questions/35366/what-are-the-main-performance-differences-between-varchar-and-nvarchar-sql-serve
#stackoverflow.com/questions/612430/when-must-we-use-nvarchar-nchar-instead-of-varchar-char-in-sql-server
def create_tables():
    
    """alter tables in the SQL Server Database"""
    commands = (
    """ 
    ALTER TABLE [GCV_PRD].[NS-JobLevel-en]
    ADD importTime DATETIME NOT NULL DEFAULT (GETDATE());
    """,
    """ 
    ALTER TABLE [GCV_PRD].[NS-ManagementLevel-en]
    ADD importTime DATETIME NOT NULL DEFAULT (GETDATE());
    """,
    """ 
    ALTER TABLE [GCV_PRD].[NS-WorkerType-en]
    ADD importTime DATETIME NOT NULL DEFAULT (GETDATE());
    """,
    """ 
    ALTER TABLE [GCV_PRD].[NS-WorkerType-en_NS-ContractType-en_Normalised]
    ADD importTime DATETIME NOT NULL DEFAULT (GETDATE());
    """,
    """ 
    ALTER TABLE [GCV_PRD].[NS-PwCNetworkNode-en-Territory]
    ADD importTime DATETIME NOT NULL DEFAULT (GETDATE());
    """,
    """ 
    ALTER TABLE [GCV_PRD].[NS-ResourceRole-en] 
    ADD importTime DATETIME NOT NULL DEFAULT (GETDATE());
    """,
    """ 
    ALTER TABLE [GCV_PRD].[NS-ResourceType-en] 
    ADD importTime DATETIME NOT NULL DEFAULT (GETDATE());
    """,
    """ 
    ALTER TABLE [GCV_STG].[Onboarding_ORD-CostCentreLegalEntity-en-GlobalHierarchy_Denormalised] 
    ADD importTime DATETIME NOT NULL DEFAULT (GETDATE());
    """,
    """ 
    ALTER TABLE [GCV_PRD].[NS-PwCNetworkNode-en] 
    ADD importTime DATETIME NOT NULL DEFAULT (GETDATE());
    """,
    """ 
    ALTER TABLE [GCV_PRD].[LEL-PwCLegalEntity-en] 
    ADD importTime DATETIME NOT NULL DEFAULT (GETDATE());
    """,
    """ 
    ALTER TABLE [GCV_STG].[ORD-CostCenter] 
    ADD importTime DATETIME NOT NULL DEFAULT (GETDATE());
    """,
    """
    ALTER TABLE [GCV_PRD].[ORD-CostCenter] 
    ADD importTime DATETIME NOT NULL DEFAULT (GETDATE());
    """,
    """ 
    ALTER TABLE [GCV_PRD].[NS-JobLevel-en_backup]
    ADD importTime DATETIME NOT NULL DEFAULT (GETDATE());
    """,
    """ 
    ALTER TABLE [GCV_PRD].[NS-ManagementLevel-en_backup]
    ADD importTime DATETIME NOT NULL DEFAULT (GETDATE());
    """,
    """ 
    ALTER TABLE [GCV_PRD].[NS-WorkerType-en_backup]
    ADD importTime DATETIME NOT NULL DEFAULT (GETDATE());
    """,
    """ 
    ALTER TABLE [GCV_PRD].[NS-WorkerType-en_NS-ContractType-en_Normalised_backup]
    ADD importTime DATETIME NOT NULL DEFAULT (GETDATE());
    """,
    """ 
    ALTER TABLE [GCV_PRD].[NS-PwCNetworkNode-en-Territory_backup]
    ADD importTime DATETIME NOT NULL DEFAULT (GETDATE());
    """,
    """ 
    ALTER TABLE [GCV_PRD].[NS-ResourceRole-en_backup] 
    ADD importTime DATETIME NOT NULL DEFAULT (GETDATE());
    """,
    """ 
    ALTER TABLE [GCV_PRD].[NS-ResourceType-en_backup] 
    ADD importTime DATETIME NOT NULL DEFAULT (GETDATE());
    """,
    """ 
    ALTER TABLE [GCV_STG].[Onboarding_ORD-CostCentreLegalEntity-en-GlobalHierarchy_Denormalised_backup] 
    ADD importTime DATETIME NOT NULL DEFAULT (GETDATE());
    """,
    """ 
    ALTER TABLE [GCV_PRD].[NS-PwCNetworkNode-en_backup] 
    ADD importTime DATETIME NOT NULL DEFAULT (GETDATE());
    """,
    """ 
    ALTER TABLE [GCV_PRD].[LEL-PwCLegalEntity-en_backup] 
    ADD importTime DATETIME NOT NULL DEFAULT (GETDATE());
    """,
    """ 
    ALTER TABLE [GCV_STG].[ORD-CostCenter_backup] 
    ADD importTime DATETIME NOT NULL DEFAULT (GETDATE());
    """,
    """
    ALTER TABLE [GCV_PRD].[ORD-CostCenter_backup] 
    ADD importTime DATETIME NOT NULL DEFAULT (GETDATE());
    """,)
    conn = None
    try:
        server = 'GX-ZWESQLPWV342.glblcloud.ad.pwcinternal.com'
        database = 'CommonConfig'
        conn = pyodbc.connect('Trusted_Connection=yes',DRIVER='{SQL Server}',SERVER=server,DATABASE=database)
        cur = conn.cursor()
        # create table one by one
        for command in commands:
            cur.execute(command)
        # close communication with the SQL Server
        cur.close()
        # commit the changes
        conn.commit()
    except (Exception, pyodbc.DatabaseError) as error:
        print(error)
    finally:
        if conn is not None:
            conn.close()
            
if __name__ == '__main__':
    create_tables()

# %%
import pyodbc
#Currently determining which datatypes need to be used
#stackoverflow.com/questions/20229441/implications-of-nvarchar-50-vs-nvarchar-max
#stackoverflow.com/questions/35366/what-are-the-main-performance-differences-between-varchar-and-nvarchar-sql-serve
#stackoverflow.com/questions/612430/when-must-we-use-nvarchar-nchar-instead-of-varchar-char-in-sql-server
def create_tables():
    
    """alter tables in the SQL Server Database"""
    commands = (
    """ 
    ALTER TABLE [GCV_PRD].[LEL-PwCLegalEntity-en]
    ALTER COLUMN [ResponsibleNetworkNodeId] nvarchar(255);
    """,
    """ 
    ALTER TABLE [GCV_PRD].[LEL-PwCLegalEntity-en]
    ALTER COLUMN [ResponsibleNetworkNode] nvarchar(255);
    """,
    """ 
    ALTER TABLE [GCV_PRD].[LEL-PwCLegalEntity-en]
    ALTER COLUMN [OperatingNetworkNodeId] nvarchar(255);
    """,
    """ 
    ALTER TABLE [GCV_PRD].[LEL-PwCLegalEntity-en]
    ALTER COLUMN [OperatingNetworkNode] nvarchar(255);
    """,
    """ 
    ALTER TABLE [GCV_PRD].[LEL-PwCLegalEntity-en]
    ALTER COLUMN [EmployingNetworkNodeId] nvarchar(255);
    """,
    """ 
    ALTER TABLE [GCV_PRD].[LEL-PwCLegalEntity-en]
    ALTER COLUMN [EmployingNetworkNode] nvarchar(255);
    """,   
    """ 
    ALTER TABLE [GCV_PRD].[LEL-PwCLegalEntity-en_backup]
    ALTER COLUMN [ResponsibleNetworkNodeId] nvarchar(255);
    """,
    """ 
    ALTER TABLE [GCV_PRD].[LEL-PwCLegalEntity-en_backup]
    ALTER COLUMN [ResponsibleNetworkNode] nvarchar(255);
    """,
    """ 
    ALTER TABLE [GCV_PRD].[LEL-PwCLegalEntity-en_backup]
    ALTER COLUMN [OperatingNetworkNodeId] nvarchar(255);
    """,
    """ 
    ALTER TABLE [GCV_PRD].[LEL-PwCLegalEntity-en_backup]
    ALTER COLUMN [OperatingNetworkNode] nvarchar(255);
    """,
    """ 
    ALTER TABLE [GCV_PRD].[LEL-PwCLegalEntity-en_backup]
    ALTER COLUMN [EmployingNetworkNodeId] nvarchar(255);
    """,
    """ 
    ALTER TABLE [GCV_PRD].[LEL-PwCLegalEntity-en_backup]
    ALTER COLUMN [EmployingNetworkNode] nvarchar(255);
    """
    )
    conn = None
    try:
        server = 'GX-ZWESQLPWV342.glblcloud.ad.pwcinternal.com'
        database = 'GCV_API'
        conn = pyodbc.connect('Trusted_Connection=yes',DRIVER='{SQL Server}',SERVER=server,DATABASE=database)
        cur = conn.cursor()
        # create table one by one
        for command in commands:
            cur.execute(command)
        # close communication with the SQL Server
        cur.close()
        # commit the changes
        conn.commit()
    except (Exception, pyodbc.DatabaseError) as error:
        print(error)
    finally:
        if conn is not None:
            conn.close()
            
if __name__ == '__main__':
    create_tables()

# %%
import pyodbc
#Currently determining which datatypes need to be used
#stackoverflow.com/questions/20229441/implications-of-nvarchar-50-vs-nvarchar-max
#stackoverflow.com/questions/35366/what-are-the-main-performance-differences-between-varchar-and-nvarchar-sql-serve
#stackoverflow.com/questions/612430/when-must-we-use-nvarchar-nchar-instead-of-varchar-char-in-sql-server
def create_tables():
    
    """create tables in the SQL Server Database"""
    commands = (
    """ 
    CREATE TABLE [GCV_PRD].[ORD_CostCenterHierarchy_Normalised] (
    id bigint IDENTITY(1,1) NOT NULL PRIMARY KEY,
    NetworkNodeID varchar(255),
    NetworkNodeName varchar(255),
    NodeId varchar(255),
    NodeCode varchar(255),
    NodeName varchar(255),
    NodeUniversalCode varchar(255),
    HierarchyNodeID varchar(255),
    HierarchyNodeName varchar(255),
    HierarchyNodeRecordStatus varchar(255),
    HierarchyNodeEffectiveDate varchar(255),
    HierarchyNodeExpirationDate varchar(255),
    HierarchyId varchar(255),
    HierarchyName varchar(255),
    ParentNetworkNodeID varchar(255),
    ParentNetworkNodeName varchar(255),
    ParentNodeId varchar(255),
    ParentNodeCode varchar(255),
    ParentNodeName varchar(255),
    ParentNodeUniversalCode varchar(255),
    ActiveStatus varchar(255),
    CreatedDate varchar(255),
    ModifiedDate varchar(255),
	importTime datetime NOT NULL DEFAULT GETDATE()
    )
    """,
    """
    CREATE INDEX nonclustered_importTime ON GCV_PRD.ORD_CostCenterHierarchy_Normalised (importTime);
    """,)
    conn = None
    try:
        server = 'GX-ZWESQLPWV342.glblcloud.ad.pwcinternal.com'
        database = 'GCV_API'
        conn = pyodbc.connect('Trusted_Connection=yes',DRIVER='{SQL Server}',SERVER=server,DATABASE=database)
        cur = conn.cursor()
        # create table one by one
        for command in commands:
            cur.execute(command)
        # close communication with the SQL Server
        cur.close()
        # commit the changes
        conn.commit()
    except (Exception, pyodbc.DatabaseError) as error:
        print(error)
    finally:
        if conn is not None:
            conn.close()
            
if __name__ == '__main__':
    create_tables()

# %%
"""
CREATE TABLE [import].[Users](
[PartyID] [nvarchar](50) NOT NULL,
[EmployeeID] [nvarchar](150) NOT NULL,
[Country] [nvarchar](255) NULL,
[LE_Name] [nvarchar](255) NULL,
[Company Code] [nvarchar](255) NULL,
[Worker] [nvarchar](255) NULL,
[Email] [nvarchar](255) NULL,
[Vendor ID] [nvarchar](255) NULL,
[CC_Name] [nvarchar](255) NULL,
[CC_Code] [nvarchar](255) NULL,
[GlobalGrade] [nvarchar](255) NULL,
[LoS] [nvarchar](255) NULL,
[Active] [nvarchar](255) NULL,
 CONSTRAINT [PK_Concur] PRIMARY KEY CLUSTERED 
(
[PartyID] ASC,
[EmployeeID] ASC
)
""",
# Out:
# ('\nCREATE TABLE [import].[Users](\n\t[PartyID] [nvarchar](50) NOT NULL,\n\t[EmployeeID] [nvarchar](150) NOT NULL,\n\t[Country] [nvarchar](255) NULL,\n\t[LE_Name] [nvarchar](255) NULL,\n\t[Company Code] [nvarchar](255) NULL,\n\t[Worker] [nvarchar](255) NULL,\n\t[Email] [nvarchar](255) NULL,\n\t[Vendor ID] [nvarchar](255) NULL,\n\t[CC_Name] [nvarchar](255) NULL,\n\t[CC_Code] [nvarchar](255) NULL,\n\t[GlobalGrade] [nvarchar](255) NULL,\n\t[LoS] [nvarchar](255) NULL,\n\t[Active] [nvarchar](255) NULL,\n CONSTRAINT [PK_Concur] PRIMARY KEY CLUSTERED \n(\n\t[PartyID] ASC,\n\t[EmployeeID] ASC\n)\n',)

# %%
import pyodbc
#Currently determining which datatypes need to be used
#stackoverflow.com/questions/20229441/implications-of-nvarchar-50-vs-nvarchar-max
#stackoverflow.com/questions/35366/what-are-the-main-performance-differences-between-varchar-and-nvarchar-sql-serve
#stackoverflow.com/questions/612430/when-must-we-use-nvarchar-nchar-instead-of-varchar-char-in-sql-server
def create_tables():
    
    """create tables in the SQL Server Database"""
    commands = (
    """
    CREATE TABLE [import].[Users](
    [PartyID] [nvarchar](50) NOT NULL,
    [EmployeeID] [nvarchar](150) NOT NULL,
    [Country] [nvarchar](255) NULL,
    [LE_Name] [nvarchar](255) NULL,
    [Company Code] [nvarchar](255) NULL,
    [Worker] [nvarchar](255) NULL,
    [Email] [nvarchar](255) NULL,
    [Vendor ID] [nvarchar](255) NULL,
    [CC_Name] [nvarchar](255) NULL,
    [CC_Code] [nvarchar](255) NULL,
    [GlobalGrade] [nvarchar](255) NULL,
    [LoS] [nvarchar](255) NULL,
    [Active] [nvarchar](255) NULL,
    CONSTRAINT [PK_Concur] PRIMARY KEY CLUSTERED 
    """)
    conn = None
    try:
        server = 'GX-ZWESQLPWV342.glblcloud.ad.pwcinternal.com'
        database = 'Concur'
        conn = pyodbc.connect('Trusted_Connection=yes',DRIVER='{SQL Server}',SERVER=server,DATABASE=database)
        cur = conn.cursor()
        # create table one by one
        for command in commands:
            cur.execute(command)
        # close communication with the SQL Server
        cur.close()
        # commit the changes
        conn.commit()
    except (Exception, pyodbc.DatabaseError) as error:
        print(error)
    finally:
        if conn is not None:
            conn.close()
            
if __name__ == '__main__':
    create_tables()
# Out:
#   File "<fstring>", line 1
#     (SQL Server)
#          ^
# SyntaxError: invalid syntax

# %%
import pyodbc
#Currently determining which datatypes need to be used
#stackoverflow.com/questions/20229441/implications-of-nvarchar-50-vs-nvarchar-max
#stackoverflow.com/questions/35366/what-are-the-main-performance-differences-between-varchar-and-nvarchar-sql-serve
#stackoverflow.com/questions/612430/when-must-we-use-nvarchar-nchar-instead-of-varchar-char-in-sql-server
def create_tables():
    
    """alter table fields in the SQL Server Database"""
    commands = (
    """ 
    ALTER TABLE import.Null_PartyID_Rows
    ALTER COLUMN [Country] nvarchar(255);
    """,
    """ 
    ALTER TABLE import.Null_PartyID_Rows
    ALTER COLUMN [LE_Name] nvarchar(255);
    """,
    """ 
    ALTER TABLE import.Null_PartyID_Rows
    ALTER COLUMN [Company Code] nvarchar(255);
    """,
    """ 
    ALTER TABLE import.Null_PartyID_Rows
    ALTER COLUMN [First Name] nvarchar(255);
    """,
    """ 
    ALTER TABLE import.Null_PartyID_Rows
    ALTER COLUMN [Last Name] nvarchar(255);
    """,
    """ 
    ALTER TABLE import.Null_PartyID_Rows
    ALTER COLUMN [EmployeeID] nvarchar(255);
    """,
    """ 
    ALTER TABLE import.Null_PartyID_Rows
    ALTER COLUMN [Email] nvarchar(255);
    """,
    """ 
    ALTER TABLE import.Null_PartyID_Rows
    ALTER COLUMN [CC_Name] nvarchar(255);
    """,
    """ 
    ALTER TABLE import.Null_PartyID_Rows
    ALTER COLUMN [CC_Code] nvarchar(255);
    """,
    """ 
    ALTER TABLE import.Null_PartyID_Rows
    ALTER COLUMN [GlobalGrade] nvarchar(255);
    """,
    """ 
    ALTER TABLE import.Null_PartyID_Rows
    ALTER COLUMN [Office Location] nvarchar(255);
    """,
    """ 
    ALTER TABLE import.Null_PartyID_Rows
    ALTER COLUMN [Territory] nvarchar(255);
    """,
    """ 
    ALTER TABLE import.Null_PartyID_Rows
    ALTER COLUMN [Company] nvarchar(255);
    """,
    """ 
    ALTER TABLE import.Null_PartyID_Rows
    ALTER COLUMN [LoS] nvarchar(255);
    """,
    """ 
    ALTER TABLE import.Null_PartyID_Rows
    ALTER COLUMN [Vendor ID] nvarchar(255);
    """,
    """ 
    ALTER TABLE import.Null_PartyID_Rows
    ALTER COLUMN [Active] nvarchar(255);
    """
    )
    conn = None
    try:
        server = 'GX-ZWESQLPWV342.glblcloud.ad.pwcinternal.com'
        database = 'Concur'
        conn = pyodbc.connect('Trusted_Connection=yes',DRIVER='{SQL Server}',SERVER=server,DATABASE=database)
        cur = conn.cursor()
        # create table one by one
        for command in commands:
            cur.execute(command)
        # close communication with the SQL Server
        cur.close()
        # commit the changes
        conn.commit()
    except (Exception, pyodbc.DatabaseError) as error:
        print(error)
    finally:
        if conn is not None:
            conn.close()
            
if __name__ == '__main__':
    create_tables()

# %%
import pyodbc
#Currently determining which datatypes need to be used
#stackoverflow.com/questions/20229441/implications-of-nvarchar-50-vs-nvarchar-max
#stackoverflow.com/questions/35366/what-are-the-main-performance-differences-between-varchar-and-nvarchar-sql-serve
#stackoverflow.com/questions/612430/when-must-we-use-nvarchar-nchar-instead-of-varchar-char-in-sql-server
def create_tables():
    
    """alter table fields in the SQL Server Database"""
    commands = (
    """ 
    ALTER TABLE [GCV_STG].[NS-ManagementLevel-en-NS-JobLevel-en_NS-ResourceRole-en_Normalised]
    ADD importTime DATETIME NOT NULL DEFAULT (GETDATE());
    """,
    """ 
    ALTER TABLE [GCV_PRD].[NS-ManagementLevel-en-NS-JobLevel-en_NS-ResourceRole-en_Normalised]
    ADD importTime DATETIME NOT NULL DEFAULT (GETDATE());
    """,
    """ 
    ALTER TABLE [GCV_STG].[NS-ManagementLevel-en-NS-JobLevel-en_NS-ResourceRole-en_Normalised_backup]
    ADD importTime DATETIME NOT NULL DEFAULT (GETDATE());
    """,
    """ 
    ALTER TABLE [GCV_PRD].[NS-ManagementLevel-en-NS-JobLevel-en_NS-ResourceRole-en_Normalised_backup]
    ADD importTime DATETIME NOT NULL DEFAULT (GETDATE());
    """        
    )
    conn = None
    try:
        server = 'GX-ZWESQLPWV342.glblcloud.ad.pwcinternal.com'
        database = 'GCV_API'
        conn = pyodbc.connect('Trusted_Connection=yes',DRIVER='{SQL Server}',SERVER=server,DATABASE=database)
        cur = conn.cursor()
        # create table one by one
        for command in commands:
            cur.execute(command)
        # close communication with the SQL Server
        cur.close()
        # commit the changes
        conn.commit()
    except (Exception, pyodbc.DatabaseError) as error:
        print(error)
    finally:
        if conn is not None:
            conn.close()
            
if __name__ == '__main__':
    create_tables()

# %%
import pyodbc
#Currently determining which datatypes need to be used
#stackoverflow.com/questions/20229441/implications-of-nvarchar-50-vs-nvarchar-max
#stackoverflow.com/questions/35366/what-are-the-main-performance-differences-between-varchar-and-nvarchar-sql-serve
#stackoverflow.com/questions/612430/when-must-we-use-nvarchar-nchar-instead-of-varchar-char-in-sql-server
def create_tables():
    
    """alter tables in the SQL Server Database"""
    commands = (
    """ 
    TRUNCATE TABLE [import].[Concur_Users]
    """,
    """ 
    ALTER TABLE [import].[Concur_Users]
    ADD import_timestamp DATETIME NOT NULL DEFAULT (GETDATE());
    """
    )
    conn = None
    try:
        server = 'GX-ZWESQLPWV342.glblcloud.ad.pwcinternal.com'
        database = 'Concur'
        conn = pyodbc.connect('Trusted_Connection=yes',DRIVER='{SQL Server}',SERVER=server,DATABASE=database)
        cur = conn.cursor()
        # create table one by one
        for command in commands:
            cur.execute(command)
        # close communication with the SQL Server
        cur.close()
        # commit the changes
        conn.commit()
    except (Exception, pyodbc.DatabaseError) as error:
        print(error)
    finally:
        if conn is not None:
            conn.close()
            
if __name__ == '__main__':
    create_tables()

# %%
import pyodbc
#Currently determining which datatypes need to be used
#stackoverflow.com/questions/20229441/implications-of-nvarchar-50-vs-nvarchar-max
#stackoverflow.com/questions/35366/what-are-the-main-performance-differences-between-varchar-and-nvarchar-sql-serve
#stackoverflow.com/questions/612430/when-must-we-use-nvarchar-nchar-instead-of-varchar-char-in-sql-server
def create_tables():
    
    """create tables in the SQL Server Database"""
    commands = (
    """ 
    CREATE TABLE [GCV_PRD].[NS-ManagementLevel-en-NS-JobLevel-en_NS-ResourceRole-en_Normalised] (
    Local_Cost_Center_Code varchar(50),
    Cost_Center_Name nvarchar(255),
    Cost_Center_SK varchar(255),
    Universal_Cost_Center_Code varchar(255),
    Cost_Center_NK varchar(255),
    Cost_Type_Descriptor varchar(255),
    Cost_Type_UID varchar(255),
    PwC_Network_Descriptor varchar(255),
    PwC_Network_UID varchar(255),
    OS_Global_Sub_LoS_Descriptor nvarchar(255),
    Global_LoS_UID nvarchar(255),
    OS_Function_Descriptor varchar(255),
    Function_UID varchar(255),
    EmployingFlag int,
    Cost_Center_Status varchar(255),
    Record_Status varchar(50),
    Active_Status varchar(255),
    Effective_Date datetime,
    Expiration_Date datetime,
    Comments nvarchar(255),
    Ownership_Folder varchar(255),
    Created_Datetime datetime,
    Last_Modified_Datetime datetime,
    Batch_Number varchar(255)
    )
    """,
    """ 
    CREATE TABLE [GCV_STG].[NS-ManagementLevel-en-NS-JobLevel-en_NS-ResourceRole-en_Normalised] (
    Local_Cost_Center_Code varchar(50),
    Cost_Center_Name nvarchar(255),
    Cost_Center_SK varchar(255),
    Universal_Cost_Center_Code varchar(255),
    Cost_Center_NK varchar(255),
    Cost_Type_Descriptor varchar(255),
    Cost_Type_UID varchar(255),
    PwC_Network_Descriptor varchar(255),
    PwC_Network_UID varchar(255),
    OS_Global_Sub_LoS_Descriptor nvarchar(255),
    Global_LoS_UID nvarchar(255),
    OS_Function_Descriptor varchar(255),
    Function_UID varchar(255),
    EmployingFlag int,
    Cost_Center_Status varchar(255),
    Record_Status varchar(50),
    Active_Status varchar(255),
    Effective_Date datetime,
    Expiration_Date datetime,
    Comments nvarchar(255),
    Ownership_Folder varchar(255),
    Created_Datetime datetime,
    Last_Modified_Datetime datetime,
    Batch_Number varchar(255)
    )
    """,
    conn = None
    try:
        server = 'GX-ZWESQLPWV342.glblcloud.ad.pwcinternal.com'
        database = 'GCV_API'
        conn = pyodbc.connect('Trusted_Connection=yes',DRIVER='{SQL Server}',SERVER=server,DATABASE=database)
        cur = conn.cursor()
        # create table one by one
        for command in commands:
            cur.execute(command)
        # close communication with the SQL Server
        cur.close()
        # commit the changes
        conn.commit()
    except (Exception, pyodbc.DatabaseError) as error:
        print(error)
    finally:
        if conn is not None:
            conn.close()
            
if __name__ == '__main__':
    create_tables()

# %%
TRUNCATE TABLE [%s]
