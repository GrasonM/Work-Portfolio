# %%
import pkg_resources
installed_packages = pkg_resources.working_set
installed_packages_list = sorted(["%s==%s" % (i.key, i.version)
    for i in installed_packages])

for module in enumerate(installed_packages_list):
    print(f'pip install {module[1]}')
# Out:
# pip install aiohttp==3.8.1
# pip install aiosignal==1.2.0
# pip install alabaster==0.7.12
# pip install anaconda-client==1.9.0
# pip install anaconda-navigator==2.1.4
# pip install anaconda-project==0.10.2
# pip install anyio==3.5.0
# pip install appdirs==1.4.4
# pip install argon2-cffi-bindings==21.2.0
# pip install argon2-cffi==21.3.0
# pip install arrow==1.2.2
# pip install astroid==2.6.6
# pip install astropy==5.0.4
# pip install asttokens==2.0.5
# pip install async-timeout==4.0.1
# pip install atomicwrites==1.4.0
# pip install attrs==21.4.0
# pip install automat==20.2.0
# pip install autopep8==1.6.0
# pip install babel==2.9.1
# pip install backcall==0.2.0
# pip install backports.functools-lru-cache==1.6.4
# pip install backports.tempfile==1.0
# pip install backports.weakref==1.0.post1
# pip install bcrypt==3.2.0
# pip install beautifulsoup4==4.11.1
# pip install binaryornot==0.4.4
# pip install bitarray==2.4.1
# pip install bkcharts==0.2
# pip install black==19.10b0
# pip install bleach==4.1.0
# pip install blis==0.7.8
# pip install bokeh==2.4.2
# pip install boto3==1.21.32
# pip install botocore==1.24.32
# pip install bottleneck==1.3.4
# pip install brotlipy==0.7.0
# pip install bs4==0.0.1
# pip install cachetools==4.2.2
# pip install catalogue==2.0.7
# pip install certifi==2021.10.8
# pip install cffi==1.15.0
# pip install chardet==4.0.0
# pip install charset-normalizer==2.0.4
# pip install click==8.0.4
# pip install cloudpickle==2.0.0
# pip install clyent==1.2.2
# pip install colorama==0.4.4
# pip install colorcet==2.0.6
# pip install comtypes==1.1.10
# pip install conda-build==3.21.8
# pip install conda-content-trust==0+unknown
# pip install conda-pack==0.6.0
# pip install conda-package-handling==1.8.1
# pip install conda-repo-cli==1.0.4
# pip install conda-token==0.3.0
# pip install conda-verify==3.4.2
# pip install conda==4.12.0
# pip install constantly==15.1.0
# pip install cookiecutter==1.7.3
# pip install cryptography==3.4.8
# pip install cssselect==1.1.0
# pip install cx-oracle==8.3.0
# pip install cycler==0.11.0
# pip install cymem==2.0.6
# pip install cython==0.29.28
# pip install cytoolz==0.11.0
# pip install daal4py==2021.5.0
# pip install dask==2022.2.1
# pip install datashader==0.13.0
# pip install datashape==0.5.4
# pip install debugpy==1.5.1
# pip install decorator==5.1.1
# pip install defusedxml==0.7.1
# pip install diff-match-patch==20200713
# pip install distributed==2022.2.1
# pip install docutils==0.17.1
# pip install en-core-web-sm==3.4.0
# pip install entrypoints==0.4
# pip install et-xmlfile==1.1.0
# pip install executing==0.8.3
# pip install fake-useragent==0.1.14
# pip install fastjsonschema==2.15.1
# pip install feedfinder2==0.0.4
# pip install feedparser==6.0.10
# pip install filelock==3.6.0
# pip install flake8==3.9.2
# pip install flask==1.1.2
# pip install fonttools==4.25.0
# pip install frozenlist==1.2.0
# pip install fsspec==2022.2.0
# pip install future==0.18.2
# pip install gensim==4.1.2
# pip install glob2==0.7
# pip install google-api-core==1.25.1
# pip install google-auth==1.33.0
# pip install google-cloud-core==1.7.1
# pip install google-cloud-storage==1.31.0
# pip install google-crc32c==1.1.2
# pip install google-resumable-media==1.3.1
# pip install googleapis-common-protos==1.53.0
# pip install greenlet==1.1.1
# pip install grpcio==1.42.0
# pip install h5py==3.6.0
# pip install heapdict==1.0.1
# pip install hl7==0.4.5
# pip install hl7apy==1.3.4
# pip install holoviews==1.14.8
# pip install hvplot==0.7.3
# pip install hyperlink==21.0.0
# pip install idna==3.3
# pip install imagecodecs==2021.8.26
# pip install imageio==2.9.0
# pip install imagesize==1.3.0
# pip install importlib-metadata==4.11.3
# pip install incremental==21.3.0
# pip install inflection==0.5.1
# pip install iniconfig==1.1.1
# pip install intake==0.6.5
# pip install intervaltree==3.1.0
# pip install ipykernel==6.9.1
# pip install ipython-genutils==0.2.0
# pip install ipython==8.2.0
# pip install ipywidgets==7.6.5
# pip install isort==5.9.3
# pip install itemadapter==0.3.0
# pip install itemloaders==1.0.4
# pip install itsdangerous==2.0.1
# pip install jdcal==1.4.1
# pip install jedi==0.18.1
# pip install jieba3k==0.35.1
# pip install jinja2-time==0.2.0
# pip install jinja2==2.11.3
# pip install jmespath==0.10.0
# pip install joblib==1.1.0
# pip install json5==0.9.6
# pip install jsonschema==4.4.0
# pip install jupyter-client==6.1.12
# pip install jupyter-console==6.4.0
# pip install jupyter-core==4.9.2
# pip install jupyter-server==1.13.5
# pip install jupyter==1.0.0
# pip install jupyterlab-pygments==0.1.2
# pip install jupyterlab-server==2.10.3
# pip install jupyterlab-widgets==1.0.0
# pip install jupyterlab==3.3.2
# pip install keyring==23.4.0
# pip install kiwisolver==1.3.2
# pip install langcodes==3.3.0
# pip install lazy-object-proxy==1.6.0
# pip install libarchive-c==2.9
# pip install llvmlite==0.38.0
# pip install locationtagger==0.0.1
# pip install locket==0.2.1
# pip install lxml==4.8.0
# pip install markdown==3.3.4
# pip install markupsafe==2.0.1
# pip install matplotlib-inline==0.1.2
# pip install matplotlib==3.5.1
# pip install mccabe==0.6.1
# pip install menuinst==1.4.18
# pip install mistune==0.8.4
# pip install mkl-fft==1.3.1
# pip install mkl-random==1.2.2
# pip install mkl-service==2.4.0
# pip install mock==4.0.3
# pip install mpmath==1.2.1
# pip install msgpack==1.0.2
# pip install multidict==5.1.0
# pip install multipledispatch==0.6.0
# pip install munkres==1.1.4
# pip install murmurhash==1.0.7
# pip install mypy-extensions==0.4.3
# pip install navigator-updater==0.2.1
# pip install nbclassic==0.3.5
# pip install nbclient==0.5.13
# pip install nbconvert==6.4.4
# pip install nbformat==5.3.0
# pip install nest-asyncio==1.5.5
# pip install networkx==2.7.1
# pip install newspaper3k==0.2.8
# pip install nltk==3.7
# pip install nose==1.3.7
# pip install notebook==6.4.8
# pip install numba==0.55.1
# pip install numexpr==2.8.1
# pip install numpy==1.21.5
# pip install numpydoc==1.2
# pip install olefile==0.46
# pip install openpyxl==3.0.9
# pip install packaging==21.3
# pip install pandas==1.4.2
# pip install pandocfilters==1.5.0
# pip install panel==0.13.0
# pip install param==1.12.0
# pip install paramiko==2.8.1
# pip install parse==1.19.0
# pip install parsel==1.6.0
# pip install parso==0.8.3
# pip install partd==1.2.0
# pip install pathlib==1.0.1
# pip install pathspec==0.7.0
# pip install pathy==0.6.2
# pip install patsy==0.5.2
# pip install pep8==1.7.1
# pip install pexpect==4.8.0
# pip install pickleshare==0.7.5
# pip install pillow==9.0.1
# pip install pip==21.2.4
# pip install pkginfo==1.8.2
# pip install plotly==5.6.0
# pip install pluggy==1.0.0
# pip install poyo==0.5.0
# pip install preshed==3.0.6
# pip install prometheus-client==0.13.1
# pip install prompt-toolkit==3.0.20
# pip install protego==0.1.16
# pip install protobuf==3.19.1
# pip install psutil==5.8.0
# pip install ptyprocess==0.7.0
# pip install pure-eval==0.2.2
# pip install py==1.11.0
# pip install pyasn1-modules==0.2.8
# pip install pyasn1==0.4.8
# pip install pycodestyle==2.7.0
# pip install pycosat==0.6.3
# pip install pycountry==22.3.5
# pip install pycparser==2.21
# pip install pyct==0.4.6
# pip install pycurl==7.44.1
# pip install pydantic==1.9.1
# pip install pydispatcher==2.0.5
# pip install pydocstyle==6.1.1
# pip install pyee==8.2.2
# pip install pyerfa==2.0.0
# pip install pyflakes==2.3.1
# pip install pygments==2.11.2
# pip install pyhamcrest==2.0.2
# pip install pyjwt==2.1.0
# pip install pylint==2.9.6
# pip install pyls-spyder==0.4.0
# pip install pynacl==1.4.0
# pip install pyodbc==4.0.32
# pip install pyopenssl==21.0.0
# pip install pyparsing==3.0.4
# pip install pyppeteer==1.0.2
# pip install pyquery==1.4.3
# pip install pyreadline==2.1
# pip install pyrsistent==0.18.0
# pip install pysocks==1.7.1
# pip install pytest==7.1.1
# pip install python-dateutil==2.8.2
# pip install python-lsp-black==1.0.0
# pip install python-lsp-jsonrpc==1.0.0
# pip install python-lsp-server==1.2.4
# pip install python-slugify==5.0.2
# pip install python-snappy==0.6.0
# pip install python-xml-hl7==1.3.0
# pip install pytz==2021.3
# pip install pyviz-comms==2.0.2
# pip install pywavelets==1.3.0
# pip install pywin32-ctypes==0.2.0
# pip install pywin32==302
# pip install pywinpty==2.0.2
# pip install pyyaml==6.0
# pip install pyzmq==22.3.0
# pip install qdarkstyle==3.0.2
# pip install qstylizer==0.1.10
# pip install qtawesome==1.0.3
# pip install qtconsole==5.3.0
# pip install qtpy==2.0.1
# pip install queuelib==1.5.0
# pip install regex==2022.3.15
# pip install requests-file==1.5.1
# pip install requests-html==0.10.0
# pip install requests==2.28.1
# pip install rope==0.22.0
# pip install rsa==4.7.2
# pip install rtree==0.9.7
# pip install ruamel-yaml-conda==0.15.100
# pip install ruamel.yaml.clib==0.2.7
# pip install ruamel.yaml==0.17.21
# pip install s3transfer==0.5.0
# pip install scikit-image==0.19.2
# pip install scikit-learn-intelex==2021.20220215.102710
# pip install scikit-learn==1.0.2
# pip install scipy==1.7.3
# pip install scrapy==2.6.1
# pip install seaborn==0.11.2
# pip install send2trash==1.8.0
# pip install service-identity==18.1.0
# pip install setuptools==61.2.0
# pip install sgmllib3k==1.0.0
# pip install sip==4.19.13
# pip install six==1.16.0
# pip install smart-open==5.2.1
# pip install sniffio==1.2.0
# pip install snowballstemmer==2.2.0
# pip install sortedcollections==2.1.0
# pip install sortedcontainers==2.4.0
# pip install soupsieve==2.3.1
# pip install spacy-legacy==3.0.9
# pip install spacy-loggers==1.0.3
# pip install spacy==3.4.0
# pip install sphinx==4.4.0
# pip install sphinxcontrib-applehelp==1.0.2
# pip install sphinxcontrib-devhelp==1.0.2
# pip install sphinxcontrib-htmlhelp==2.0.0
# pip install sphinxcontrib-jsmath==1.0.1
# pip install sphinxcontrib-qthelp==1.0.3
# pip install sphinxcontrib-serializinghtml==1.1.5
# pip install spyder-kernels==2.1.3
# pip install spyder==5.1.5
# pip install sqlalchemy==1.4.32
# pip install srsly==2.4.3
# pip install stack-data==0.2.0
# pip install statsmodels==0.13.2
# pip install sympy==1.10.1
# pip install tables==3.6.1
# pip install tabulate==0.8.9
# pip install tbb==0.2
# pip install tblib==1.7.0
# pip install tenacity==8.0.1
# pip install terminado==0.13.1
# pip install testpath==0.5.0
# pip install text-unidecode==1.3
# pip install textdistance==4.2.1
# pip install thinc==8.1.0
# pip install threadpoolctl==2.2.0
# pip install three-merge==0.1.1
# pip install tifffile==2021.7.2
# pip install tinycss==0.4
# pip install tinysegmenter==0.3
# pip install tldextract==3.2.0
# pip install toml==0.10.2
# pip install tomli==1.2.2
# pip install toolz==0.11.2
# pip install tornado==6.1
# pip install tqdm==4.64.0
# pip install traitlets==5.1.1
# pip install twisted-iocpsupport==1.0.2
# pip install twisted==22.2.0
# pip install typed-ast==1.4.3
# pip install typer==0.4.2
# pip install typing-extensions==4.1.1
# pip install ujson==5.1.0
# pip install unidecode==1.2.0
# pip install urllib3==1.26.9
# pip install w3lib==1.21.0
# pip install wasabi==0.9.1
# pip install watchdog==2.1.6
# pip install wcwidth==0.2.5
# pip install webencodings==0.5.1
# pip install websocket-client==0.58.0
# pip install websockets==10.4
# pip install werkzeug==2.0.3
# pip install wheel==0.37.1
# pip install widgetsnbextension==3.5.2
# pip install win-inet-pton==1.1.0
# pip install win-unicode-console==0.5
# pip install wincertstore==0.2
# pip install wrapt==1.12.1
# pip install xarray==0.20.1
# pip install xlrd==2.0.1
# pip install xlsxwriter==3.0.3
# pip install xlwings==0.24.9
# pip install yapf==0.31.0
# pip install yarl==1.6.3
# pip install zict==2.0.0
# pip install zipp==3.7.0
# pip install zope.interface==5.4.0

# %%
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
import smtplib, ssl

SMTPHOST = "smtp.gmail.com"
SMTPPORT = 465
FROMEMAIL = "grason.moye@pwc.com"
FROMEMAILPASSWORD = "Qpwoeiruty10!="

def CreateEmailMessage(toAddress, message):
    messageDetails = MIMEMultipart()
    
    messageDetails['From'] = FROMEMAIL
    messageDetails['To'] = toAddress
    messageDetails['Subject'] = "Test Email!"
    
    messageDetails.attach(MIMEText(message, 'plain'))
    
    return messageDetails

def SendEmailMessage(toAddress, message):
        messageDetails = CreateEmailMessage(toAddress, message)
        #context = ssl.create_default_context()
        
        try:
            server = smtplib.SMTP_SSL(SMTPHOST, SMTPPORT)
            server.helo()
            #server.starttls() #context=context)
            #server.login(FROMEMAIL, FROMEMAILPASSWORD)
            server.sendmail(FROMEMAIL, toAddress, messageDetails.as_string())
        except Exception as ex:
            print(ex)
        finally:
            server.quit()

# %%
SendEmailMessage("grason.moye@pwc.com", "Hello, this is an official PwC test email! :)")
# Out:
# (530, b'5.7.0 Authentication Required. Learn more at\n5.7.0  https://support.google.com/mail/?p=WantAuthError l21-20020a37f915000000b006bc56c063fcsm9850632qkj.62 - gsmtp', 'grason.moye@pwc.com')

# %%
pip install pkg_resources
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement pkg_resources (from versions: none)
# ERROR: No matching distribution found for pkg_resources
