# %%
duplication_extraction()
# Out:
# <ipython-input-93-a4dada6721cc>:40: DtypeWarning: Columns (24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1pre = pd.read_csv(f'DataAndDuplicateReportAutomation/{processlist[0]}')
# 122269
# 1050
# Index(['PersonPartyID', 'LegalEntityPartyID', 'rateType', 'MultiIndexCount',
#        'NumberOfChangesNeeded'],
#       dtype='object')
#                             PersonPartyID  \
# 0    574B73D6-91FE-40E2-BF84-22B3B6510D52
# 1    21662B0F-825F-4527-BF5B-55ED5DB3F593
# 2    9FFF9399-F5BD-4244-A2F2-01FC8CAE6ABC
# 3    9FFF9399-F5BD-4244-A2F2-01FC8CAE6ABC
# 4    A448AAB2-857A-46C6-A84F-0CA4282747A9
# ..                                    ...
# 957  A82A191B-F854-4870-B329-769977C13FF9
# 958  D7F01E26-D9B5-437D-9880-173AF0FA4543
# 959  402A952E-EF2F-4EF8-821E-2BCFB922FF50
# 960  402A952E-EF2F-4EF8-821E-2BCFB922FF50
# 961  5951368C-98FD-433E-A0AF-BDDA8EB4B3EA
#
#                        LegalEntityPartyID rateType  MultiIndexCount  \
# ...
