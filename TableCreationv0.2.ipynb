# %%
import pyodbc
#Currently determining which datatypes need to be used
#stackoverflow.com/questions/20229441/implications-of-nvarchar-50-vs-nvarchar-max
#stackoverflow.com/questions/35366/what-are-the-main-performance-differences-between-varchar-and-nvarchar-sql-serve
#stackoverflow.com/questions/612430/when-must-we-use-nvarchar-nchar-instead-of-varchar-char-in-sql-server
def create_tables():
    
    """create tables in the SQL Server Database"""
    commands = (
    """ 
    CREATE TABLE NS-JobLevel-en (
    Id varchar(50),
    Name nvarchar(50),
    VocabName varchar(50),
    ActiveStatus varchar(50),
    ApprovalStatus varchar(50),
    CreatedDate datetime,
    ModifiedDate datetime,
    JobLevelName nvarchar(50),
    EffectiveDate datetime,
    LastEditedReason nvarchar(255),
    Systemofrecord varchar(50),
    SortOrder varchar(50)
    )
    """,
    """ 
    CREATE TABLE LEL-PwCLegalEntity-en (
    PartyReferenceId varchar(50),
    PartyId varchar(255),
    Name nvarchar(255),
    ResponsibleNetworkNodeId varchar(50),
    ResponsibleNetworkNode varchar(50),
    OperatingNetworkNodeId varchar(50),
    OperatingNetworkNode varchar(50),
    EmployingNetworkNodeId varchar(50),
    EmployingNetworkNode varchar(50),
    DUNS varchar(50),
    LELNumber varchar(50),
    GFSId varchar(50),
    RegisteredAddressLine1 nvarchar(255),
    RegisteredAddressLine2 nvarchar(255),
    RegisteredAddressLine3 nvarchar(255),
    RegisteredCity nvarchar(50),
    RegisteredCountrySubdivisionId nvarchar(50),
    RegisteredCountrySubdivisionCode varchar(50),
    RegisteredCountrySubdivisionName nvarchar(50),
    RegisteredCountryId varchar(50),
    RegisteredCountryCode varchar(50),
    RegisteredCountryName varchar(50),
    RegisteredPostalCode varchar(50),
    OperatingAddressLine1 nvarchar(255),
    OperatingAddressLine2 nvarchar(255),
    OperatingAddressLine3 nvarchar(255),
    OperatingCity varchar(50),
    OperatingCountrySubdivisionId nvarchar(50),
    OperatingCountrySubdivisionCode varchar(50),
    OperatingCountrySubdivisionName varchar(50),
    OperatingCountryId varchar(50),
    OperatingCountryCode varchar(50),
    OperatingCountryName varchar(50),
    OperatingPostalCode varchar(50),
    BillingAddressLine1 nvarchar(255),
    BillingAddressLine2 nvarchar(255),
    BillingAddressLine3 nvarchar(255),
    BillingCity varchar(50),
    BillingCountrySubdivisionId nvarchar(50),
    BillingCountrySubdivisionCode varchar(50),
    BillingCountrySubdivisionName varchar(50),
    BillingCountryId varchar(50),
    BillingCountryCode varchar(50),
    BillingCountryName varchar(50),
    BillingPostalCode varchar(50),
    EmployingLE varchar(50),
    CreatedDate datetime,
    PartyRoleId varchar(50),
    PartyRole varchar(50),
    ModifiedDate datetime,
    LicenseTypeId nvarchar(255),
    LicenseType varchar(50),
    OrganisationTypeId varchar(50),
    OrganisationType varchar(50)
    )
    """,
    """ 
    CREATE TABLE NS-ManagementLevel-en (
    Id varchar(50),
    Name nvarchar(50),
    VocabName varchar(255),
    ActiveStatus varchar(50),
    ApprovalStatus varchar(50),
    CreatedDate datetime,
    ModifiedDate datetime,
    ManagementLevelName varchar(50),
    Abbreviation varchar(50),
    Definition nvarchar(255),
    EffectiveDate datetime,
    LastEditedReason nvarchar(255),
    Systemofrecord varchar(50),
    SortOrder varchar(50),
    GERCode varchar(50),
    Comments nvarchar(255)
    )
    """,
    """ 
    CREATE TABLE NS-PwCNetworkNode-en (
    Id varchar(50),
    Name nvarchar(255),
    VocabName varchar(50),
    ActiveStatus varchar(50),
    ApprovalStatus varchar(50),
    CreatedDate datetime,
    ModifiedDate datetime,
    NodeName nvarchar(50),
    EffectiveDate datetime,
    LastEditedReason nvarchar(255),
    Systemofrecord varchar(50),
    SourceMDMGERCode varchar(50),
    SourceMDMSortPrefix varchar(50),
    PRID varchar(50),
    PartyID varchar(50),
    NetworkNodeID varchar(50),
    LocalAccountingCurrency varchar(50),
    RegionalReportingCurrency varchar(50),
    Disambiguator varchar(50),
    Comments nvarchar(255),
    GGCEPrefix varchar(50),
    Definition nvarchar(255),
    ExpiryDate datetime,
    Abbreviation varchar(50),
    SCMember varchar(50),
    NLTMember varchar(50),
    NodeTypeId varchar(50),
    NodeType varchar(50),
    TBDRateElementId varchar(50),
    TBDRateElementName nvarchar(50),
    TBDRateElementLevel varchar(50)
    )
    """,
    """ 
    CREATE TABLE NS-PwCNetworkNode-en-Territory (
    Id varchar(50),
    Name varchar(50),
    VocabName varchar(50),
    ActiveStatus varchar(50),
    ApprovalStatus varchar(50),
    CreatedDate datetime,
    ModifiedDate datetime,
    NodeName varchar(50),
    PRID varchar(50),
    PartyID varchar(50),
    NetworkNodeID varchar(50),
    LocalAccountingCurrency varchar(50),
    RegionalReportingCurrency varchar(50),
    Definition nvarchar(255),
    EffectiveDate datetime,
    LastEditedReason nvarchar(255),
    Systemofrecord varchar(50),
    SourceMDMGERCode varchar(50),
    SourceMDMSortPrefix varchar(50),
    NodeTypeId varchar(50),
    NodeType varchar(50),
    Abbreviation varchar(50),
    SCMember varchar(50),
    GGCEPrefix varchar(50),
    NLTMember varchar(50),
    Disambiguator varchar(50),
    Comments nvarchar(255),
    TBDRateElementId varchar(50),
    TBDRateElementName nvarchar(50),
    TBDRateElementLevel varchar(50)
    )
    """,
    """ 
    CREATE TABLE NS-ResourceRole-en (
    Id varchar(50),
    Name varchar(50),
    VocabName varchar(50),
    ActiveStatus varchar(50),
    ApprovalStatus varchar(50),
    CreatedDate datetime,
    ModifiedDate datetime,
    ResourceRoleName varchar(50),
    Definition nvarchar(255),
    EffectiveDate datetime,
    LastEditedReason nvarchar(255),
    Systemofrecord varchar(50)
    )
    """,
    """ 
    CREATE TABLE NS-ResourceType-en (
    Id varchar(50),
    Name varchar(50),
    VocabName varchar(50),
    ActiveStatus varchar(50),
    ApprovalStatus varchar(50),
    CreatedDate datetime,
    ModifiedDate datetime,
    BusinessObjectTypeName varchar(50),
    Definition nvarchar(255),
    EffectiveDate datetime,
    LastEditedReason nvarchar(255),
    Systemofrecord varchar(50)
    )
    """,
    """ 
    CREATE TABLE NS-WorkerType-en (
    Id varchar(50),
    Name varchar(50),
    VocabName varchar(50),
    ActiveStatus varchar(50),
    ApprovalStatus varchar(50),
    CreatedDate datetime,
    ModifiedDate datetime,
    ResourceSubTypeName varchar(50),
    Definition nvarchar(255),
    EffectiveDate datetime,
    LastEditedReason nvarchar(255),
    Systemofrecord varchar(50)
    )
    """,
    """ 
    CREATE TABLE NS-WorkerType-en_NS-ContractType-en_Normalised (
    Id varchar(50),
    Descriptor varchar(50),
    ParentId varchar(50),
    RelModifiedDate datetime,
    ResourceSubTypeName varchar(50),
    Definition nvarchar(255),
    EffectiveDate datetime,
    ExpiryDate datetime,
    LastEditedReason nvarchar(255),
    Comments nvarchar(255),
    Systemofrecord varchar(50)
    )
    """,
    """ 
    CREATE TABLE Onboarding_ORD-CostCentreLegalEntity-en-GlobalHierarchy_Denormalised (
    CostCenterPwCNetworkNodeId varchar(50),
    CostCenterPwCNetworkDescriptor varchar(50),
    CostCenterId varchar(50),
    LocalCostCenterCode varchar(50),
    CostCenterName nvarchar(255),
    UniversalCostCenterCode varchar(50),
    LegalEntityPartyId varchar(50),
    LegalEntityName nvarchar(255),
    ModifiedDate datetime
    )
    """,
    """ 
    CREATE TABLE ORD-CostCenter (
    Local_Cost_Center_Code varchar(50),
    Cost_Center_Name nvarchar(255),
    Cost_Center_SK varchar(50),
    Universal_Cost_Center_Code varchar(50),
    Cost_Center_NK varchar(50),
    Cost_Type_Descriptor varchar(50),
    Cost_Type_UID varchar(50),
    PwC_Network_Descriptor varchar(50),
    PwC_Network_UID varchar(50),
    OS_Global_Sub_LoS_Descriptor nvarchar(255),
    Global_LoS_UID nvarchar(255),
    OS_Function_Descriptor varchar(50),
    Function_UID varchar(50),
    Employing_Flag varchar(50),
    Cost_Center_Status varchar(50),
    Active_Status varchar(50),
    Effective_Date datetime,
    Expiration_Date datetime,
    Comments nvarchar(255),
    Ownership_Folder varchar(50),
    Created_Datetime datetime,
    Last_Modified_Datetime datetime,
    Batch_Number varchar(50)
    )
    """,)
    conn = None
    try:
        conn = pyodbc.connect('Trusted_Connection=yes',DRIVER='{SQL Server}',SERVER=server,DATABASE=database)
        cur = conn.cursor()
        # create table one by one
        for command in commands:
            cur.execute(command)
        # close communication with the SQL Server
        cur.close()
        # commit the changes
        conn.commit()
    except (Exception, pyodbc.DatabaseError) as error:
        print(error)
    finally:
        if conn is not None:
            conn.close()
            
if __name__ == '__main__':
    create_tables()

# %%
import pyodbc
#Currently determining which datatypes need to be used
#stackoverflow.com/questions/20229441/implications-of-nvarchar-50-vs-nvarchar-max
#stackoverflow.com/questions/35366/what-are-the-main-performance-differences-between-varchar-and-nvarchar-sql-serve
#stackoverflow.com/questions/612430/when-must-we-use-nvarchar-nchar-instead-of-varchar-char-in-sql-server
def create_tables():
    
    """create tables in the SQL Server Database"""
    commands = (
    """
    CREATE TABLE [GCV_PRD].[NS-WorkerType-en_NS-ContractType-en_Normalised] (
    Id varchar(50),
    Descriptor varchar(50),
    ParentId varchar(50),
    RelModifiedDate datetime,
    ResourceSubTypeName varchar(50),
    Definition varchar(1000),
    EffectiveDate datetime,
    ExpiryDate datetime,
    LastEditedReason varchar(255),
    Comments varchar(1000),
    Systemofrecord varchar(50)
    )
    """,)
    conn = None
    try:
        server = 'GX-ZWESQLPWV342.glblcloud.ad.pwcinternal.com'
        database = 'CommonConfig'
        conn = pyodbc.connect('Trusted_Connection=yes',DRIVER='{SQL Server}',SERVER=server,DATABASE=database)
        cur = conn.cursor()
        # create table one by one
        for command in commands:
            cur.execute(command)
        # close communication with the SQL Server
        cur.close()
        # commit the changes
        conn.commit()
    except (Exception, pyodbc.DatabaseError) as error:
        print(error)
    finally:
        if conn is not None:
            conn.close()
            
if __name__ == '__main__':
    create_tables()

# %%
import pyodbc
#Currently determining which datatypes need to be used
#stackoverflow.com/questions/20229441/implications-of-nvarchar-50-vs-nvarchar-max
#stackoverflow.com/questions/35366/what-are-the-main-performance-differences-between-varchar-and-nvarchar-sql-serve
#stackoverflow.com/questions/612430/when-must-we-use-nvarchar-nchar-instead-of-varchar-char-in-sql-server
def create_tables():
    
    """create tables in the SQL Server Database"""
    commands = (
    """
    CREATE TABLE [GCV_PRD].[NS-WorkerType-en_NS-ContractType-en_Normalised] (
    Id varchar(50),
    Descriptor varchar(50),
    ParentId varchar(50),
    RelModifiedDate datetime,
    ResourceSubTypeName varchar(50),
    Definition nv,
    EffectiveDate datetime,
    ExpiryDate datetime,
    LastEditedReason nvarchar(255),
    Comments nvarchar(255),
    Systemofrecord varchar(50)
    )
    """,)
    conn = None
    try:
        server = 'GX-ZWESQLPWV342.glblcloud.ad.pwcinternal.com'
        database = 'CommonConfig'
        conn = pyodbc.connect('Trusted_Connection=yes',DRIVER='{SQL Server}',SERVER=server,DATABASE=database)
        cur = conn.cursor()
        # create table one by one
        for command in commands:
            cur.execute(command)
        # close communication with the SQL Server
        cur.close()
        # commit the changes
        conn.commit()
    except (Exception, pyodbc.DatabaseError) as error:
        print(error)
    finally:
        if conn is not None:
            conn.close()
            
if __name__ == '__main__':
    create_tables()
# Out:
# ('42000', '[42000] [Microsoft][ODBC SQL Server Driver][SQL Server]Column, parameter, or variable #6: Cannot specify a column width on data type text. (2716) (SQLExecDirectW)')

# %%
import pyodbc
#Currently determining which datatypes need to be used
#stackoverflow.com/questions/20229441/implications-of-nvarchar-50-vs-nvarchar-max
#stackoverflow.com/questions/35366/what-are-the-main-performance-differences-between-varchar-and-nvarchar-sql-serve
#stackoverflow.com/questions/612430/when-must-we-use-nvarchar-nchar-instead-of-varchar-char-in-sql-server
def create_tables():
    
    """create tables in the SQL Server Database"""
    commands = (
    """
    CREATE TABLE [GCV_PRD].[NS-WorkerType-en_NS-ContractType-en_Normalised] (
    Id varchar(50),
    Descriptor varchar(50),
    ParentId varchar(50),
    RelModifiedDate datetime,
    ResourceSubTypeName varchar(50),
    Definition nv,
    EffectiveDate datetime,
    ExpiryDate datetime,
    LastEditedReason nvarchar(255),
    Comments nvarchar(255),
    Systemofrecord varchar(50)
    )
    """,)
    conn = None
    try:
        server = 'GX-ZWESQLPWV342.glblcloud.ad.pwcinternal.com'
        database = 'CommonConfig'
        conn = pyodbc.connect('Trusted_Connection=yes',DRIVER='{SQL Server}',SERVER=server,DATABASE=database)
        cur = conn.cursor()
        # create table one by one
        for command in commands:
            cur.execute(command)
        # close communication with the SQL Server
        cur.close()
        # commit the changes
        conn.commit()
    except (Exception, pyodbc.DatabaseError) as error:
        print(error)
    finally:
        if conn is not None:
            conn.close()
            
if __name__ == '__main__':
    create_tables()
