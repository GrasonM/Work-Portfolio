# %%
import sys
import warnings
import pandas as pd
import numpy as np
import os
import cx_Oracle as O
import datetime as datetime
import logging, logging.handlers, smtplib
import traceback
import smtplib
import sqlalchemy as sa
import pyodbc
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.application import MIMEApplication
from os.path import basename
import os
from datetime import datetime, date, timedelta
import settings
import errhandler as eh
import eHSQL
import re
import os
import requests
import urllib
import itertools
from requests.exceptions import ConnectionError, HTTPError, Timeout, TooManyRedirects
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry
from requests.auth import HTTPBasicAuth
import json
from lxml import html
import string

global r, rnumjson


def getData():
    
    global dfpivot, df_test, dfsol, dfnum, dfden, recnum, payload, r, rnumjson, dfLE, session, auth, agent, cookie, cookie2
    
    agent = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36 Edg/106.0.1370.52'}
    
    pd.set_option('display.max_columns', None)
    pd.set_option('display.max_rows', None)
    
    url1 = "https://essence.syndromicsurveillance.org/"

    session = requests.session()
    
    #session = AsyncHTMLSession()
    
    url1result = session.get(url1, headers = agent)
    
    print(f'\n{url1result.headers}\n', f'\n{url1result.request.headers}\n')
    
    print(session.cookies.get_dict())
    print(url1result.headers['Set-Cookie'])
    cookie = str(url1result.headers['Set-Cookie'])
    cookie = ' ' + cookie.replace(' Path=/; Secure; HttpOnly','').replace(';', '')
    print(cookie, '\n')
    
    url2 = "https://essence.syndromicsurveillance.org/nssp_essence"
    url2result = session.get(url2, headers=agent)
    
    print(f'\n{url2result.headers}\n', f'\n{url2result.request.headers}\n')
    
    print(session.cookies.get_dict())
    print(url2result.request.headers['Cookie'])
    cookie2 = str(url2result.request.headers['Cookie']).split()
    cookie2 = cookie2[0] + ' '
    print(cookie2, '\n')
    
    url3 = "https://essence.syndromicsurveillance.org/nssp_essence/servlet/Login"
    url3result = session.get(url3, headers=agent)
    
    print(f'\n{url3result.headers}\n', f'\n{url3result.request.headers}\n')
    
    tree = html.fromstring(url3result.text)
    authenticity_token = list(set(tree.xpath("//input[@name='csrfPreventionSalt']/@value")))[0]
    
    print(f'{authenticity_token}\n')
    
    payload = {"userId": "nservice01",
                   "password": "Testingacc!1",
                   "csrfPreventionSalt": f"{authenticity_token}"}
    
    loginpostresult = session.post(url3,
                                    data = payload,
                                    headers = agent,
                                    allow_redirects = True)
    
    print(f'\n{loginpostresult.headers}\n', f'\n{loginpostresult.request.headers}\n')
    
    url4 = "https://essence.syndromicsurveillance.org/nssp_essence/j_spring_security_check"
    url4result = session.get(url4, headers=agent)
    
    print(f'\n{url4result.headers}\n', f'\n{url4result.request.headers}\n')

    dfLE = pd.read_csv(r'C:\Users\gmoye\LegalEntities.csv')
    dfLE.rename(columns={'LE_Name':'erFacility'}, inplace = True)

    url5 = "https://essence.syndromicsurveillance.org/nssp_essence/servlet/TableBuilderPortletRedirectServlet?percentParam=noPercent&patientClass=e&endDate=4Aug2018&medicalGroupingSystem=essencesyndromes&userId=647&geographySystem=state&ccddCategory=ili%20ccdd%20v1&geography=nd&datasource=va_er&timeResolution=weekly&erFacility=6326&erFacility=6330&erFacility=6360&erFacility=6365&erFacility=6358&erFacility=6320&erFacility=6354&erFacility=6347&erFacility=6369&aqtTarget=TableBuilder&detector=nodetectordetector&startDate=29Jul2018&displayTotals=false&displayTotals=false&displayTotals=false&displayTotals=false&displayTotals=false&displayTotals=false&displayTotals=false&displayTotals=false&displayZeroCountRows=true&displayZeroCountRows=true&fieldIDs=timeResolution&fieldIDs=ageCDCILI&fieldIDs=erFacility&fieldIDs=geographystate&fieldLabels=Week&fieldLabels=CDC%20ILI%20Reporting%20Age%20Group&fieldLabels=Facility&fieldLabels=State&graphWidth=372&portletId=285297&dateconfig=16"
    url5result = session.get(url5, headers=agent)
    
    print(f'\n{url5result.headers}\n', f'\n{url5result.request.headers}\n')
    
    url6 = "https://essence.syndromicsurveillance.org/nssp_essence/servlet/TableBuilder?percentParam=noPercent&patientClass=e&medicalGroupingSystem=essencesyndromes&userId=647&geographySystem=state&ccddCategory=ili%20ccdd%20v1&geography=nd&datasource=va_er&timeResolution=weekly&erFacility=6326&erFacility=6330&erFacility=6360&erFacility=6365&erFacility=6358&erFacility=6320&erFacility=6354&erFacility=6347&erFacility=6369&aqtTarget=TableBuilder&detector=nodetectordetector&displayTotals=false&displayTotals=false&displayTotals=false&displayTotals=false&displayTotals=false&displayTotals=false&displayTotals=false&displayTotals=false&displayZeroCountRows=true&displayZeroCountRows=true&fieldIDs=timeResolution&fieldIDs=ageCDCILI&fieldIDs=erFacility&fieldIDs=geographystate&fieldLabels=Week&fieldLabels=CDC%20ILI%20Reporting%20Age%20Group&fieldLabels=Facility&fieldLabels=State&graphWidth=372&portletId=285297&dateconfig=16&startDate=06Nov22&endDate=12Nov22"
    url6result = session.get(url6, headers=agent)
    
    print(f'\n{url6result.headers}\n', f'\n{url6result.request.headers}\n')
    
    #x = dt.
    #Dateparams = startDate=06Nov22&endDate=12Nov22

# %%
getData()
# Out:
# {'Cache-Control': 'no-cache', 'Set-Cookie': 'JSESSIONID=71FC0F76A03F90A61698A7F949322517; Path=/; Secure; HttpOnly', 'Pragma': 'no-cache', 'Content-Type': 'text/html;charset=ISO-8859-1', 'Content-Length': '2156', 'Date': 'Wed, 01 Feb 2023 16:32:42 GMT'}
#
# {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36 Edg/106.0.1370.52', 'Accept-Encoding': 'gzip, deflate, br', 'Accept': '*/*', 'Connection': 'keep-alive'}
#
# {'JSESSIONID': '71FC0F76A03F90A61698A7F949322517'}
# JSESSIONID=71FC0F76A03F90A61698A7F949322517; Path=/; Secure; HttpOnly
#  JSESSIONID=71FC0F76A03F90A61698A7F949322517
#
#
# {'Strict-Transport-Security': 'max-age=0', 'X-Frame-Options': 'SAMEORIGIN', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '1; mode=block', 'Cache-Control': 'no-store', 'Pragma': 'no-cache', 'Expires': 'Wed, 31 Dec 1969 23:59:59 GMT', 'Content-Type': 'text/html;charset=ISO-8859-1', 'Content-Length': '5981', 'Date': 'Wed, 01 Feb 2023 16:32:42 GMT'}
#
# {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36 Edg/106.0.1370.52', 'Accept-Encoding': 'gzip, deflate, br', 'Accept': '*/*', 'Connection': 'keep-alive', 'Cookie': 'JSESSIONID=A46F3AE29231188073646EAD15A4FD9B; JSESSIONID=71FC0F76A03F90A61698A7F949322517'}
#
# {'JSESSIONID': 'A46F3AE29231188073646EAD15A4FD9B'}
# JSESSIONID=A46F3AE29231188073646EAD15A4FD9B; JSESSIONID=71FC0F76A03F90A61698A7F949322517
# JSESSIONID=A46F3AE29231188073646EAD15A4FD9B;
#
#
# {'Strict-Transport-Security': 'max-age=0', 'X-Frame-Options': 'SAMEORIGIN', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '1; mode=block', 'Cache-Control': 'no-store', 'Pragma': 'no-cache', 'Expires': 'Wed, 31 Dec 1969 23:59:59 GMT', 'Content-Type': 'text/html;charset=ISO-8859-1', 'Content-Length': '5981', 'Date': 'Wed, 01 Feb 2023 16:32:42 GMT'}
#
# {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36 Edg/106.0.1370.52', 'Accept-Encoding': 'gzip, deflate, br', 'Accept': '*/*', 'Connection': 'keep-alive', 'Cookie': 'JSESSIONID=A46F3AE29231188073646EAD15A4FD9B; JSESSIONID=71FC0F76A03F90A61698A7F949322517'}
#
# 9LGvXpnPqBaPGgFh7SUO
#
#
# {'Strict-Transport-Security': 'max-age=0', 'X-Frame-Options': 'SAMEORIGIN', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '1; mode=block', 'Cache-Control': 'no-store', 'Pragma': 'no-cache', 'Expires': 'Wed, 31 Dec 1969 23:59:59 GMT', 'Content-Type': 'text/html;charset=ISO-8859-1', 'Content-Length': '5981', 'Date': 'Wed, 01 Feb 2023 16:32:42 GMT'}
#
# {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36 Edg/106.0.1370.52', 'Accept-Encoding': 'gzip, deflate, br', 'Accept': '*/*', 'Connection': 'keep-alive', 'Cookie': 'JSESSIONID=A46F3AE29231188073646EAD15A4FD9B; JSESSIONID=71FC0F76A03F90A61698A7F949322517', 'Content-Length': '81', 'Content-Type': 'application/x-www-form-urlencoded'}
#
#
# {'Strict-Transport-Security': 'max-age=0', 'X-Frame-Options': 'SAMEORIGIN', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '1; mode=block', 'Cache-Control': 'no-store', 'Pragma': 'no-cache', 'Expires': 'Wed, 31 Dec 1969 23:59:59 GMT', 'Content-Type': 'text/html;charset=ISO-8859-1', 'Content-Length': '5981', 'Date': 'Wed, 01 Feb 2023 16:32:42 GMT'}
#
# {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36 Edg/106.0.1370.52', 'Accept-Encoding': 'gzip, deflate, br', 'Accept': '*/*', 'Connection': 'keep-alive', 'Cookie': 'JSESSIONID=A46F3AE29231188073646EAD15A4FD9B; JSESSIONID=71FC0F76A03F90A61698A7F949322517'}
#
#
# {'Strict-Transport-Security': 'max-age=0', 'X-Frame-Options': 'SAMEORIGIN', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '1; mode=block', 'Cache-Control': 'no-store', 'Pragma': 'no-cache', 'Expires': 'Wed, 31 Dec 1969 23:59:59 GMT', 'Content-Type': 'text/html;charset=ISO-8859-1', 'Content-Length': '5981', 'Date': 'Wed, 01 Feb 2023 16:32:42 GMT'}
#
# {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36 Edg/106.0.1370.52', 'Accept-Encoding': 'gzip, deflate, br', 'Accept': '*/*', 'Connection': 'keep-alive', 'Cookie': 'JSESSIONID=A46F3AE29231188073646EAD15A4FD9B; JSESSIONID=71FC0F76A03F90A61698A7F949322517'}
#
#
# {'Strict-Transport-Security': 'max-age=0', 'X-Frame-Options': 'SAMEORIGIN', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '1; mode=block', 'Cache-Control': 'no-store', 'Pragma': 'no-cache', 'Expires': 'Wed, 31 Dec 1969 23:59:59 GMT', 'Content-Type': 'text/html;charset=ISO-8859-1', 'Content-Length': '5981', 'Date': 'Wed, 01 Feb 2023 16:32:43 GMT'}
#
# {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36 Edg/106.0.1370.52', 'Accept-Encoding': 'gzip, deflate, br', 'Accept': '*/*', 'Connection': 'keep-alive', 'Cookie': 'JSESSIONID=A46F3AE29231188073646EAD15A4FD9B; JSESSIONID=71FC0F76A03F90A61698A7F949322517'}

# %%
def transformation():
    global denvarlist, numvarlist, dfdenweek, dfnumweek, startdate, enddate, periodlist, weeknum
    
    enddate = datetime.today().date()
    
    startdate = enddate - timedelta(days=14)
    
    enddate = datetime.strptime(str(enddate), '%Y-%m-%d').strftime('%d%b%y')
    
    startdate = datetime.strptime(str(startdate), '%Y-%m-%d').strftime('%d%b%y')
    #startdate = datetime.strptime('2022-01-17', '%Y-%m-%d').strftime('%d%b%y')
    
    urlnumjson = f'https://essence.syndromicsurveillance.org/nssp_essence/api/tableBuilder?percentParam=noPercent&patientClass=e&medicalGroupingSystem=essencesyndromes&userId=647&geographySystem=state&ccddCategory=ili ccdd v1&geography=nd&datasource=va_er&timeResolution=weekly&erFacility=6326&erFacility=6330&erFacility=6360&erFacility=6365&erFacility=6358&erFacility=6320&erFacility=6354&erFacility=6347&erFacility=6369&aqtTarget=TableBuilder&detector=nodetectordetector&displayTotals=false&displayTotals=false&displayTotals=false&displayTotals=false&displayTotals=false&displayTotals=false&displayTotals=false&displayTotals=false&displayZeroCountRows=true&displayZeroCountRows=true&fieldIDs=timeResolution&fieldIDs=ageCDCILI&fieldIDs=erFacility&fieldIDs=geographystate&fieldLabels=Week&fieldLabels=CDC ILI Reporting Age Group&fieldLabels=Facility&fieldLabels=State&graphWidth=372&portletId=285297&dateconfig=16&startDate={startdate}&endDate={enddate}&rowFields=erFacility&rowFields=ageCDCILI&rowFields=timeResolution&columnField=geographystate'
    
    with open(r'C:\Users\gmoye\headerconfignum.json') as g:
        headersnum = json.load(g)
    
    print(cookie + headersnum['cookie'] + cookie2, '\n')
    
    headersnum['cookie'] = (cookie2 + headersnum['cookie'] + cookie) 
    print(headersnum, '\n')
    print('\n')
    
    retry_strategy = Retry(total = 0, status_forcelist=[429, 413, 503, 401], allowed_methods=["HEAD","GET", "PUT", "DELETE", "OPTIONS", "TRACE"])
    adapter = HTTPAdapter(max_retries=retry_strategy)
    session.mount('https://', adapter)
    
    auth = HTTPBasicAuth('nservice01', 'Testingacc!1')
    
    r = session.get(urlnumjson, headers = headersnum, auth = auth) #headers=headers,
    
    if headersnum == r.request.headers:
        print('True')
    else:
        print('False')
    
    print(f'\n{r.headers}\n', f'\n{r.request.headers}\n')
    
    rnumjson = r.json()


    dfnum = pd.DataFrame(rnumjson)
    recnum = len(dfnum.index)
    
    dfnum = dfnum.sort_values(by=['erFacility','timeResolution','ageCDCILI'], ascending = True).reset_index(drop = True)
    
    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Central Dakota Clinic/Charles Nyhus"
    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Valley City University Student Health"
    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="UND Center for Family Medicine"
    dfnum.loc[dfnum["erFacility"]=="ND-Essentia Health Fargo Hospital","erFacility"]="Essentia ED"
    dfnum.loc[dfnum["erFacility"]=="ND-Altru Hospital","erFacility"]="Altru ED"
    dfnum.loc[dfnum["erFacility"]=="ND-Sanford Emergency Center Bismarck","erFacility"]="Sanford Medical Center Bismarck"
    dfnum.loc[dfnum["erFacility"]=="ND-Sanford Medical Center Fargo","erFacility"]="Sanford Medical Center Fargo"
    dfnum.loc[dfnum["erFacility"]=="ND-CHI St. Joseph's Health","erFacility"]="St. Alexius Health Dickinson (St. Joseph’s) ED"
    dfnum.loc[dfnum["erFacility"]=="ND-Trinity Hospital","erFacility"]="Trinity ED"
    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Urgent Medicine Associated/Kurt Kooyer"
    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="7-Day Clinic/Napoleon Espejo"
    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Midgarden Family Clinic"
    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Standing Rock IHS"
    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Fairlight Medical Center"
    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Wishek Community Clinic"
    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Northland Community Health Center McClusky"
    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="West River Health Services"
    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Altru Devil’s Lake Family Practice/Lim Elson"
    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Sanford Walk-in Fargo/Greg Pfennig"
    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Northland Community Health Center Turtle Lake"
    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Towner County Medical Center"
    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="UND Student Health Center"
    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Trinity Community Clinic New Town"
    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Trinity Community Clinic Kenmare"
    dfnum.loc[dfnum["erFacility"]=="ND-CHI St. Alexius Williston","erFacility"]="St Alexius Health Williston (Mercy) ED"
    dfnum.loc[dfnum["erFacility"]=="ND-CHI Devils Lake Hospital","erFacility"]="St Alexius Health Devil’s Lake (Mercy) ED"
    dfnum.loc[dfnum["erFacility"]=="ND-Jamestown Regional Medical Center","erFacility"]="Jamestown Regional Medical Center"
    
    periodnum = dfnum['timeResolution'].unique()
    periodnum = periodnum.tolist()
    
    numvarlist = []
    
    for week in enumerate(periodnum):
        
        dfnumweek = dfnum.loc[dfnum['timeResolution'] == week[1]]
    
        dfnumweek = pd.merge(dfnumweek, dfLE, how = 'left', on = ['erFacility'])
        dfnumweek = dfnumweek.drop(columns = ['geographystate'])
        
        weeknum = week[1]
        year = datetime.strptime(str(weeknum) + '-1', '%Y-%W-%w').strftime('%y')
        weeknum = str(week[1])
        weeknum = weeknum.replace('2022-','').replace('2023-','')
        
        dfnumweek['MMWR'] = f'{year}'+f'{weeknum}'
        
        dfnumweek['From'] = 'ILINum'
        
        col = dfnumweek.pop("LE_ID")
        dfnumweek.insert(0, 'Provider ID', col)
        
        col = dfnumweek.pop("MMWR")
        dfnumweek.insert(1, col.name, col)
        
        dfnumweek['ageCDCILI'] = dfnumweek['ageCDCILI'].astype(object)

        #weeknum = str(week[1])
        #weeknum = weeknum.replace('2022-','')
        
        print(weeknum)
        
        numvarlist.append('dfnumweek' + weeknum)
        
        globals()['dfnumweek%s' % weeknum] = dfnumweek
        
        #display(dfnumweek)
        
    numvarlist = [item.strip("'") for item in numvarlist]
        
    print(f'\n{numvarlist}\n')
        
    urldenjson = f'https://essence.syndromicsurveillance.org/nssp_essence/api/tableBuilder?percentParam=noPercent&patientClass=e&medicalGroupingSystem=essencesyndromes&userId=647&geographySystem=state&geography=nd&datasource=va_er&timeResolution=weekly&erFacility=6326&erFacility=6330&erFacility=6360&erFacility=6365&erFacility=6358&erFacility=6320&erFacility=6354&erFacility=6347&erFacility=6369&aqtTarget=TableBuilder&detector=nodetectordetector&fieldIDs=timeResolution&fieldIDs=ageCDCILI&fieldIDs=erFacility&fieldIDs=geographystate&fieldLabels=Week&fieldLabels=CDC%20ILI%20Reporting%20Age%20Group&fieldLabels=Facility&fieldLabels=State&displayTotals=false&displayTotals=false&displayTotals=false&displayTotals=false&displayZeroCountRows=true&graphWidth=431&portletId=285298&dateconfig=16&startDate={startdate}&endDate={enddate}&rowFields=erFacility&rowFields=ageCDCILI&rowFields=timeResolution&columnField=geographystate'
    
    with open(r'C:\Users\gmoye\headerconfigden.json') as g:
        headersden = json.load(g)
    
    r = session.get(urldenjson, headers=headersden, auth = auth) #headers=headers,
    rdenjson = r.json()
    
    if headersden == r.request.headers:
        print('True')
    else:
        print('False')
    
    dfden = pd.DataFrame(rdenjson)
    recden = len(dfden.index)
    
    dfden = dfden.sort_values(by=['erFacility','timeResolution','ageCDCILI'], ascending = True).reset_index(drop = True)
    
    dfden.loc[dfden["erFacility"]=="","erFacility"]="Central Dakota Clinic/Charles Nyhus"
    dfden.loc[dfden["erFacility"]=="","erFacility"]="Valley City University Student Health"
    dfden.loc[dfden["erFacility"]=="","erFacility"]="UND Center for Family Medicine"
    dfden.loc[dfden["erFacility"]=="ND-Essentia Health Fargo Hospital","erFacility"]="Essentia ED"
    dfden.loc[dfden["erFacility"]=="ND-Altru Hospital","erFacility"]="Altru ED"
    dfden.loc[dfden["erFacility"]=="ND-Sanford Emergency Center Bismarck","erFacility"]="Sanford Medical Center Bismarck"
    dfden.loc[dfden["erFacility"]=="ND-Sanford Medical Center Fargo","erFacility"]="Sanford Medical Center Fargo"
    dfden.loc[dfden["erFacility"]=="ND-CHI St. Joseph's Health","erFacility"]="St. Alexius Health Dickinson (St. Joseph’s) ED"
    dfden.loc[dfden["erFacility"]=="ND-Trinity Hospital","erFacility"]="Trinity ED"
    dfden.loc[dfden["erFacility"]=="","erFacility"]="Urgent Medicine Associated/Kurt Kooyer"
    dfden.loc[dfden["erFacility"]=="","erFacility"]="7-Day Clinic/Napoleon Espejo"
    dfden.loc[dfden["erFacility"]=="","erFacility"]="Midgarden Family Clinic"
    dfden.loc[dfden["erFacility"]=="","erFacility"]="Standing Rock IHS"
    dfden.loc[dfden["erFacility"]=="","erFacility"]="Fairlight Medical Center"
    dfden.loc[dfden["erFacility"]=="","erFacility"]="Wishek Community Clinic"
    dfden.loc[dfden["erFacility"]=="","erFacility"]="Northland Community Health Center McClusky"
    dfden.loc[dfden["erFacility"]=="","erFacility"]="West River Health Services"
    dfden.loc[dfden["erFacility"]=="","erFacility"]="Altru Devil’s Lake Family Practice/Lim Elson"
    dfden.loc[dfden["erFacility"]=="","erFacility"]="Sanford Walk-in Fargo/Greg Pfennig"
    dfden.loc[dfden["erFacility"]=="","erFacility"]="Northland Community Health Center Turtle Lake"
    dfden.loc[dfden["erFacility"]=="","erFacility"]="Towner County Medical Center"
    dfden.loc[dfden["erFacility"]=="","erFacility"]="UND Student Health Center"
    dfden.loc[dfden["erFacility"]=="","erFacility"]="Trinity Community Clinic New Town"
    dfden.loc[dfden["erFacility"]=="","erFacility"]="Trinity Community Clinic Kenmare"
    dfden.loc[dfden["erFacility"]=="ND-CHI St. Alexius Williston","erFacility"]="St Alexius Health Williston (Mercy) ED"
    dfden.loc[dfden["erFacility"]=="ND-CHI Devils Lake Hospital","erFacility"]="St Alexius Health Devil’s Lake (Mercy) ED"
    dfden.loc[dfden["erFacility"]=="ND-Jamestown Regional Medical Center","erFacility"]="Jamestown Regional Medical Center"
    
    periodden = dfden['timeResolution'].unique()
    periodden = periodden.tolist()
    
    denvarlist = []
    
    for week in enumerate(periodden):
        
        dfdenweek = dfden.loc[dfden['timeResolution'] == week[1]]
    
        dfdenweek = pd.merge(dfdenweek, dfLE, how = 'left', on = ['erFacility'])
        dfdenweek = dfdenweek.drop(columns = ['geographystate'])
        
        weekden = week[1]
        year = datetime.strptime(str(weekden) + '-1', '%Y-%W-%w').strftime('%y')
        weekden = str(week[1])
        weekden = weekden.replace('2022-','').replace('2023-','')
        
        dfdenweek['MMWR'] = f'{year}'+f'{weekden}'
        
        dfdenweek['From'] = 'ILIDen'
        
        col = dfdenweek.pop("LE_ID")
        dfdenweek.insert(0, 'Provider ID', col)
        
        col = dfdenweek.pop("MMWR")
        dfdenweek.insert(1, col.name, col)
        
        dfdenweek['ageCDCILI'] = dfdenweek['ageCDCILI'].astype(object)
        
        #weekden = str(week[1])
        #weekden = weekden.replace('2022-','')
        
        print(weekden)
        
        denvarlist.append('dfdenweek' + weekden)
        
        globals()['dfdenweek%s' % weekden] = dfdenweek
        
        #display(dfdenweek)
        
    denvarlist = [item.strip("'") for item in denvarlist]
        
    print(f'\n{denvarlist}\n')
    
    periodlist = []
    periodnum.extend(periodden)
    periodlist.extend(periodnum)
    periodlist = [item.replace('2022-','') for item in periodlist]
    periodlist = [item.replace('2023-','') for item in periodlist]
    #periodlist = [item.replace(item,float(item)) for item in periodlist]
    #periodlist = [item.strip("2022") for item in periodlist]
    periodlist = list(set(periodlist))
    print(periodlist, 'periodlist')
    
    periodnum = dfnum['timeResolution'].unique()
    periodnum = periodnum.tolist()
    
    periodnum = [item.strip("2022-") for item in periodnum]
    periodnum = [item.strip("2023-") for item in periodnum]
        
    periodden = dfden['timeResolution'].unique()
    periodden = periodden.tolist()
    
    periodden = [item.strip("2022-") for item in periodden]
    periodden = [item.strip("2023-") for item in periodden]
    
    for value in periodlist:
        
        if any(value in s for s in numvarlist) and any(value in s for s in denvarlist):
            
            print(value)
            
            df1 = 'dfnumweek'
            df2 = 'dfdenweek'
            print(df1+value,df2+value)
            df1 = eval(df1+value)
            df2 = eval(df2+value)
        
            dfsol = pd.merge(df1, df2, how = 'outer')
               
            #dfsol = pd.merge(eval(dfnumweek+value), eval(dfdenweek+value), how = 'outer')
            dfsol = dfsol.sort_values(by=['erFacility','timeResolution','ageCDCILI'], ascending = True).reset_index(drop = True)
            
            dfsol['record_no'] = np.arange(len(dfsol))+1
            rcount = dfsol.pop('record_no')
            dfsol.insert(0, rcount.name, rcount)
            
            dfpivot = dfsol.pivot(index = ['Provider ID','MMWR'], columns = ['ageCDCILI','timeResolution','From'], values=['count'])
            
            df_test = dfsol.pivot(index = ['Provider ID','MMWR'], columns = ['ageCDCILI','timeResolution','From'], values=['count'])
            df_test.columns = df_test.columns.droplevel()
            df_test.columns = [' '.join(col) for col in df_test.columns.values]
            df_test = df_test.reset_index()
            df_test = df_test.set_index(['Provider ID','MMWR'])
            
            df_test['Total patient visits'] = df_test.filter(like="ILIDen").sum(axis=1)
            df_test['total_unk'] = df_test.filter(like="Unknown").sum(axis=1)
            df_test.drop(df_test.columns[[10,11]], axis=1, inplace=True)
            
            display(df_test)
            
            date = datetime.today().strftime('%d%b%y_%H.%M.%S')
            output = fr'Y:\PROGRAM\IMMUNE\Immunize\Influenza\Inf22-23\Surveillance\ESSENCE ILI\Processed\ILI-ND-WEEK{value}-PROCESSED_{date}.xlsx'
            
            df_test.to_excel(f'{output}')
        
        elif any(value in s for s in numvarlist) and any(value not in s for s in denvarlist):
            print(value)
            dfsol = 'dfnumweek'
            print(dfsol+value)
            dfsol = eval(dfsol+value)

               
            #dfsol = pd.merge(eval(dfnumweek+value), eval(dfdenweek+value), how = 'outer')
            dfsol = dfsol.sort_values(by=['erFacility','timeResolution','ageCDCILI'], ascending = True).reset_index(drop = True)
            
            dfsol['record_no'] = np.arange(len(dfsol))+1
            rcount = dfsol.pop('record_no')
            dfsol.insert(0, rcount.name, rcount)
            
            dfpivot = dfsol.pivot(index = ['Provider ID','MMWR'], columns = ['ageCDCILI','timeResolution','From'], values=['count'])
            
            df_test = dfsol.pivot(index = ['Provider ID','MMWR'], columns = ['ageCDCILI','timeResolution','From'], values=['count'])
            df_test.columns = df_test.columns.droplevel()
            df_test.columns = [' '.join(col) for col in df_test.columns.values]
            df_test = df_test.reset_index()
            df_test = df_test.set_index(['Provider ID','MMWR'])
            
            df_test['Total patient visits'] = df_test.filter(like="ILIDen").sum(axis=1)
            df_test['total_unk'] = df_test.filter(like="Unknown").sum(axis=1)
            
            
            display(df_test)
            
        elif any(value not in s for s in numvarlist) and any(value in s for s in denvarlist):
            print(value)
            dfsol = 'dfdenweek'
            print(dfsol+value)
            dfsol = eval(dfsol+value)
            
            #dfsol = pd.merge(eval(dfnumweek+value), eval(dfdenweek+value), how = 'outer')
            dfsol = dfsol.sort_values(by=['erFacility','timeResolution','ageCDCILI'], ascending = True).reset_index(drop = True)
            
            dfsol['record_no'] = np.arange(len(dfsol))+1
            rcount = dfsol.pop('record_no')
            dfsol.insert(0, rcount.name, rcount)
            
            dfpivot = dfsol.pivot(index = ['Provider ID','MMWR'], columns = ['ageCDCILI','timeResolution','From'], values=['count'])
            
            df_test = dfsol.pivot(index = ['Provider ID','MMWR'], columns = ['ageCDCILI','timeResolution','From'], values=['count'])
            df_test.columns = df_test.columns.droplevel()
            df_test.columns = [' '.join(col) for col in df_test.columns.values]
            df_test = df_test.reset_index()
            df_test = df_test.set_index(['Provider ID','MMWR'])
            
            df_test['Total patient visits'] = df_test.filter(like="ILIDen").sum(axis=1)
            df_test['total_unk'] = df_test.filter(like="Unknown").sum(axis=1)
            
            display(df_test)
            
    logoutsecurl = 'https://essence.syndromicsurveillance.org/nssp_essence/j_spring_security_logout'
    logouturl = 'https://essence.syndromicsurveillance.org/nssp_essence/servlet/Login?logoff=true'
        
    logoutsecgetresult = session.get(logoutsecurl, headers = agent, auth = auth)
        
    print(logoutsecgetresult.ok, logoutsecgetresult.status_code)
        
    logoutgetresult = session.get(logouturl, headers = agent)
        
    print(logoutgetresult.ok, logoutgetresult.status_code, dict(referer=logoutsecurl))

# %%
year = datetime.strptime(str(weeknum), '%y-%w')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 year = datetime.strptime(str(weeknum), '%y-%w')
#
# File ~\Anaconda3\lib\_strptime.py:568, in _strptime_datetime(cls, data_string, format)
#     565 def _strptime_datetime(cls, data_string, format="%a %b %d %H:%M:%S %Y"):
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# File ~\Anaconda3\lib\_strptime.py:349, in _strptime(data_string, format)
#     347 found = format_regex.match(data_string)
#     348 if not found:
# --> 349     raise ValueError("time data %r does not match format %r" %
#     350                      (data_string, format))
#     351 if len(data_string) != found.end():
#     352     raise ValueError("unconverted data remains: %s" %
#     353                       data_string[found.end():])
#
# ValueError: time data '47' does not match format '%y-%w'

# %%
transformation()
# Out:
#  JSESSIONID=71FC0F76A03F90A61698A7F949322517s_fid=746DF1504BE13552-395436A755E7D9BC; s_lv=1662476796904; AMCVS_66818A1A54FA2E890A4C98A6%40AdobeOrg=1; AMCV_66818A1A54FA2E890A4C98A6%40AdobeOrg=1176715910%7CMCIDTS%7C19307%7CMCMID%7C50583680903926076432118761525803048643%7CMCAAMLH-1668692129%7C9%7CMCAAMB-1668692129%7C6G1ynYcLPuiQxYZrsz_pkqfLG9yMXBpb2zX5dvJdYQJzPXImdj0y%7CMCOPTOUT-1668094529s%7CNONE%7CMCSYNCSOP%7C411-19314%7CvVersion%7C5.4.0;JSESSIONID=A46F3AE29231188073646EAD15A4FD9B;
#
# {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36 Edg/106.0.1370.52', 'accept-encoding': 'gzip, deflate, br', 'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9', 'Connection': 'keep-alive', 'authority': 'essence.syndromicsurveillance.org', 'method': 'GET', 'path': '/nssp_essence/api/tableBuilder?percentParam=noPercent&patientClass=e&medicalGroupingSystem=essencesyndromes&userId=647&geographySystem=state&ccddCategory=ili%20ccdd%20v1&geography=nd&datasource=va_er&timeResolution=weekly&erFacility=6326&erFacility=6330&erFacility=6360&erFacility=6365&erFacility=6358&erFacility=6320&erFacility=6354&erFacility=6347&erFacility=6369&aqtTarget=TableBuilder&detector=nodetectordetector&displayTotals=false&displayTotals=false&displayTotals=false&displayTotals=false&displayTotals=false&displayTotals=false&displayTotals=false&displayTotals=false&displayZeroCountRows=true&displayZeroCountRows=true&fieldIDs=timeResolution&fieldIDs=ageCDCILI&fieldIDs=erFacility&fieldIDs=geographystate&fieldLabels=Week&fieldLabels=CDC%20ILI%20Reporting%20Age%20Group&fieldLabels=Facility&fieldLabels=State&graphWidth=372&portletId=285297&dateconfig=16&startDate=06Nov22&endDate=12Nov22&rowFields=erFacility&rowFields=ageCDCILI&rowFields=timeResolution&columnField=geographystate', 'scheme': 'https', 'accept-language': 'en-US,en;q=0.9', 'cache-control': 'max-age=0', 'cookie': 'JSESSIONID=A46F3AE29231188073646EAD15A4FD9B; s_fid=746DF1504BE13552-395436A755E7D9BC; s_lv=1662476796904; AMCVS_66818A1A54FA2E890A4C98A6%40AdobeOrg=1; AMCV_66818A1A54FA2E890A4C98A6%40AdobeOrg=1176715910%7CMCIDTS%7C19307%7CMCMID%7C50583680903926076432118761525803048643%7CMCAAMLH-1668692129%7C9%7CMCAAMB-1668692129%7C6G1ynYcLPuiQxYZrsz_pkqfLG9yMXBpb2zX5dvJdYQJzPXImdj0y%7CMCOPTOUT-1668094529s%7CNONE%7CMCSYNCSOP%7C411-19314%7CvVersion%7C5.4.0; JSESSIONID=71FC0F76A03F90A61698A7F949322517', 'sec-ch-ua': 'Chromium;v=106, Microsoft Edge;v=106, Not;A=Brand;v=99', 'sec-ch-ua-mobile': '?0', 'sec-ch-ua-platform': 'Windows', 'sec-fetch-dest': 'document', 'sec-fetch-mode': 'navigate', 'sec-fetch-site': 'none', 'sec-fetch-user': '?1', 'upgrade-insecure-requests': '1'}
#
#
#
# False
#
# {'vary': 'Origin', 'Strict-Transport-Security': 'max-age=31536000 ; includeSubDomains', 'X-Frame-Options': 'DENY', 'X-Content-Type-Options': 'nosniff, nosniff', 'X-XSS-Protection': '1; mode=block', 'Set-Cookie': 'JSESSIONID=3E4BCCEE5CB594F27634C519B7D03D54; Path=/nssp_essence; Secure; HttpOnly', 'Cache-Control': 'no-cache, no-store, max-age=0, must-revalidate', 'Pragma': 'no-cache', 'Expires': '0', 'Content-Type': 'application/json;charset=ISO-8859-1', 'Transfer-Encoding': 'chunked', 'Date': 'Wed, 01 Feb 2023 16:35:14 GMT'}
#
# {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36 Edg/106.0.1370.52', 'accept-encoding': 'gzip, deflate, br', 'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9', 'Connection': 'keep-alive', 'authority': 'essence.syndromicsurveillance.org', 'method': 'GET', 'path': '/nssp_essence/api/tableBuilder?percentParam=noPercent&patientClass=e&medicalGroupingSystem=essencesyndromes&userId=647&geographySystem=state&ccddCategory=ili%20ccdd%20v1&geography=nd&datasource=va_er&timeResolution=weekly&erFacility=6326&erFacility=6330&erFacility=6360&erFacility=6365&erFacility=6358&erFacility=6320&erFacility=6354&erFacility=6347&erFacility=6369&aqtTarget=TableBuilder&detector=nodetectordetector&displayTotals=false&displayTotals=false&displayTotals=false&displayTotals=false&displayTotals=false&displayTotals=false&displayTotals=false&displayTotals=false&displayZeroCountRows=true&displayZeroCountRows=true&fieldIDs=timeResolution&fieldIDs=ageCDCILI&fieldIDs=erFacility&fieldIDs=geographystate&fieldLabels=Week&fieldLabels=CDC%20ILI%20Reporting%20Age%20Group&fieldLabels=Facility&fieldLabels=State&graphWidth=372&portletId=285297&dateconfig=16&startDate=06Nov22&endDate=12Nov22&rowFields=erFacility&rowFields=ageCDCILI&rowFields=timeResolution&columnField=geographystate', 'scheme': 'https', 'accept-language': 'en-US,en;q=0.9', 'cache-control': 'max-age=0', 'cookie': 'JSESSIONID=A46F3AE29231188073646EAD15A4FD9B; s_fid=746DF1504BE13552-395436A755E7D9BC; s_lv=1662476796904; AMCVS_66818A1A54FA2E890A4C98A6%40AdobeOrg=1; AMCV_66818A1A54FA2E890A4C98A6%40AdobeOrg=1176715910%7CMCIDTS%7C19307%7CMCMID%7C50583680903926076432118761525803048643%7CMCAAMLH-1668692129%7C9%7CMCAAMB-1668692129%7C6G1ynYcLPuiQxYZrsz_pkqfLG9yMXBpb2zX5dvJdYQJzPXImdj0y%7CMCOPTOUT-1668094529s%7CNONE%7CMCSYNCSOP%7C411-19314%7CvVersion%7C5.4.0; JSESSIONID=71FC0F76A03F90A61698A7F949322517', 'sec-ch-ua': 'Chromium;v=106, Microsoft Edge;v=106, Not;A=Brand;v=99', 'sec-ch-ua-mobile': '?0', 'sec-ch-ua-platform': 'Windows', 'sec-fetch-dest': 'document', 'sec-fetch-mode': 'navigate', 'sec-fetch-site': 'none', 'sec-fetch-user': '?1', 'upgrade-insecure-requests': '1', 'Authorization': 'Basic bnNlcnZpY2UwMTpUZXN0aW5nYWNjITE='}
#
# 03
# 04
# 05
#
# ['dfnumweek03', 'dfnumweek04', 'dfnumweek05']
#
# False
# 03
# 04
# 05
#
# ['dfdenweek03', 'dfdenweek04', 'dfdenweek05']
#
# ['03', '05', '04'] periodlist
# 03
# dfnumweek03 dfdenweek03
#                   00-04 2023-03 ILINum  00-04 2023-03 ILIDen  \
# Provider ID MMWR
# 38047       2303                   1.0                  16.0
# 38048       2303                   1.0                  13.0
# 38049       2303                   4.0                  14.0
# 38050       2303                   0.0                  23.0
# 38055       2303                   2.0                   7.0
# 38056       2303                   1.0                  21.0
# 38087       2303                   2.0                  23.0
# 38089       2303                   1.0                   5.0
# 38090       2303                   0.0                  12.0
#
#                   05-24 2023-03 ILINum  05-24 2023-03 ILIDen  \
# Provider ID MMWR
# 38047       2303                   0.0                  42.0
# 38048       2303                   4.0                  35.0
# 38049       2303                   5.0                  58.0
# 38050       2303                   2.0                  85.0
# 38055       2303                   1.0                  22.0
# 38056       2303                   4.0                  63.0
# 38087       2303                   6.0                  40.0
# 38089       2303                   2.0                  31.0
# 38090       2303                   4.0                  18.0
#
#                   25-49 2023-03 ILINum  25-49 2023-03 ILIDen  \
# Provider ID MMWR
# 38047       2303                   1.0                  80.0
# 38048       2303                   0.0                  83.0
# 38049       2303                   5.0                  88.0
# 38050       2303                   3.0                 137.0
# 38055       2303                   0.0                  51.0
# 38056       2303                   4.0                  95.0
# 38087       2303                   2.0                  64.0
# 38089       2303                   1.0                  36.0
# 38090       2303                   1.0                  31.0
#
#                   50-64 2023-03 ILINum  50-64 2023-03 ILIDen  \
# Provider ID MMWR
# 38047       2303                   0.0                  32.0
# 38048       2303                   2.0                  22.0
# 38049       2303                   3.0                  42.0
# 38050       2303                   1.0                  58.0
# 38055       2303                   0.0                  15.0
# 38056       2303                   1.0                  53.0
# 38087       2303                   0.0                  26.0
# 38089       2303                   1.0                  16.0
# 38090       2303                   0.0                  19.0
#
#                   65+ 2023-03 ILINum  65+ 2023-03 ILIDen  \
# Provider ID MMWR
# 38047       2303                 0.0                38.0
# 38048       2303                 1.0                33.0
# 38049       2303                 2.0                34.0
# 38050       2303                 1.0                40.0
# 38055       2303                 1.0                29.0
# 38056       2303                 4.0                63.0
# 38087       2303                 1.0                19.0
# 38089       2303                 0.0                16.0
# 38090       2303                 0.0                28.0
#
#                   Total patient visits  total_unk
# Provider ID MMWR
# 38047       2303                 208.0        0.0
# 38048       2303                 186.0        0.0
# 38049       2303                 236.0        0.0
# 38050       2303                 343.0        0.0
# 38055       2303                 124.0        0.0
# 38056       2303                 295.0        0.0
# 38087       2303                 172.0        0.0
# 38089       2303                 104.0        0.0
# 38090       2303                 108.0        0.0
# 05
# dfnumweek05 dfdenweek05
#                   00-04 2023-05 ILINum  00-04 2023-05 ILIDen  \
# Provider ID MMWR
# 38047       2305                   2.0                  11.0
# 38048       2305                   1.0                  16.0
# 38049       2305                   1.0                  11.0
# 38050       2305                   3.0                  25.0
# 38055       2305                   0.0                   4.0
# 38056       2305                   2.0                  10.0
# 38087       2305                   0.0                   6.0
# 38089       2305                   0.0                   1.0
# 38090       2305                   1.0                   3.0
#
#                   05-24 2023-05 ILINum  05-24 2023-05 ILIDen  \
# Provider ID MMWR
# 38047       2305                   1.0                  51.0
# 38048       2305                   1.0                  30.0
# 38049       2305                   4.0                  44.0
# 38050       2305                   3.0                  66.0
# 38055       2305                   0.0                  24.0
# 38056       2305                   5.0                  33.0
# 38087       2305                   1.0                  28.0
# 38089       2305                   0.0                  10.0
# 38090       2305                   4.0                  17.0
#
#                   25-49 2023-05 ILINum  25-49 2023-05 ILIDen  \
# Provider ID MMWR
# 38047       2305                   1.0                  78.0
# 38048       2305                   3.0                  92.0
# 38049       2305                   2.0                  88.0
# 38050       2305                   5.0                 126.0
# 38055       2305                   0.0                  37.0
# 38056       2305                   2.0                  49.0
# 38087       2305                   1.0                  51.0
# 38089       2305                   1.0                  28.0
# 38090       2305                   2.0                  22.0
#
#                   50-64 2023-05 ILINum  50-64 2023-05 ILIDen  \
# Provider ID MMWR
# 38047       2305                   0.0                  17.0
# 38048       2305                   1.0                  27.0
# 38049       2305                   2.0                  32.0
# 38050       2305                   3.0                  45.0
# 38055       2305                   0.0                   9.0
# 38056       2305                   0.0                  28.0
# 38087       2305                   0.0                  16.0
# 38089       2305                   0.0                  12.0
# 38090       2305                   0.0                  13.0
#
#                   65+ 2023-05 ILINum  65+ 2023-05 ILIDen  \
# Provider ID MMWR
# 38047       2305                 1.0                35.0
# 38048       2305                 0.0                24.0
# 38049       2305                 1.0                24.0
# 38050       2305                 1.0                34.0
# 38055       2305                 0.0                20.0
# 38056       2305                 1.0                29.0
# 38087       2305                 0.0                10.0
# 38089       2305                 1.0                10.0
# 38090       2305                 0.0                29.0
#
#                   Total patient visits  total_unk
# Provider ID MMWR
# 38047       2305                 192.0        0.0
# 38048       2305                 189.0        0.0
# 38049       2305                 199.0        0.0
# 38050       2305                 296.0        0.0
# 38055       2305                  94.0        0.0
# 38056       2305                 149.0        0.0
# 38087       2305                 111.0        0.0
# 38089       2305                  61.0        0.0
# 38090       2305                  84.0        0.0
# 04
# dfnumweek04 dfdenweek04
#                   00-04 2023-04 ILINum  00-04 2023-04 ILIDen  \
# Provider ID MMWR
# 38047       2304                   0.0                  21.0
# 38048       2304                   4.0                  24.0
# 38049       2304                   5.0                  32.0
# 38050       2304                   1.0                  44.0
# 38055       2304                   2.0                  16.0
# 38056       2304                   5.0                  22.0
# 38087       2304                   2.0                  27.0
# 38089       2304                   3.0                  13.0
# 38090       2304                   3.0                  21.0
#
#                   05-24 2023-04 ILINum  05-24 2023-04 ILIDen  \
# Provider ID MMWR
# 38047       2304                   4.0                  99.0
# 38048       2304                   0.0                  62.0
# 38049       2304                   9.0                  90.0
# 38050       2304                   4.0                 140.0
# 38055       2304                   3.0                  38.0
# 38056       2304                   6.0                 100.0
# 38087       2304                   2.0                  58.0
# 38089       2304                   2.0                  32.0
# 38090       2304                  10.0                  43.0
#
#                   25-49 2023-04 ILINum  25-49 2023-04 ILIDen  \
# Provider ID MMWR
# 38047       2304                   1.0                 136.0
# 38048       2304                   0.0                 134.0
# 38049       2304                   6.0                 181.0
# 38050       2304                  11.0                 265.0
# 38055       2304                   0.0                  82.0
# 38056       2304                   6.0                 199.0
# 38087       2304                   0.0                 125.0
# 38089       2304                   1.0                  60.0
# 38090       2304                   5.0                  52.0
#
#                   50-64 2023-04 ILINum  50-64 2023-04 ILIDen  \
# Provider ID MMWR
# 38047       2304                   0.0                  53.0
# 38048       2304                   2.0                  56.0
# 38049       2304                   2.0                  79.0
# 38050       2304                   3.0                  87.0
# 38055       2304                   0.0                  27.0
# 38056       2304                   3.0                  81.0
# 38087       2304                   0.0                  37.0
# 38089       2304                   2.0                  22.0
# 38090       2304                   5.0                  43.0
#
#                   65+ 2023-04 ILINum  65+ 2023-04 ILIDen  \
# Provider ID MMWR
# 38047       2304                 0.0                60.0
# 38048       2304                 0.0                51.0
# 38049       2304                 0.0                60.0
# 38050       2304                 1.0                59.0
# 38055       2304                 0.0                38.0
# 38056       2304                 7.0               120.0
# 38087       2304                 0.0                34.0
# 38089       2304                 2.0                18.0
# 38090       2304                 5.0                47.0
#
#                   Total patient visits  total_unk
# Provider ID MMWR
# 38047       2304                 369.0        0.0
# 38048       2304                 327.0        0.0
# 38049       2304                 442.0        0.0
# 38050       2304                 595.0        0.0
# 38055       2304                 201.0        0.0
# 38056       2304                 522.0        0.0
# 38087       2304                 281.0        0.0
# 38089       2304                 145.0        0.0
# 38090       2304                 206.0        0.0
# True 200
# True 200 {'referer': 'https://essence.syndromicsurveillance.org/nssp_essence/j_spring_security_logout'}

# %%
#dvarlist = [item.strip("'") for item in denvarlist]
dvarlist = '%s' % ', '.join(map(str, denvarlist))
dvarlist = dvarlist.to_list()
dvarlist
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [174], in <cell line: 3>()
#       1 #dvarlist = [item.strip("'") for item in denvarlist]
#       2 dvarlist = '%s' % ', '.join(map(str, denvarlist))
# ----> 3 dvarlist = dvarlist.to_list()
#       4 dvarlist
#
# AttributeError: 'str' object has no attribute 'to_list'

# %%
periodlist = periodnum.append(periodden)
periodlist = periodlist.uniques
print(periodlist)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [101], in <cell line: 1>()
# ----> 1 periodlist = periodnum.append(periodden)
#       2 periodlist = periodlist.uniques
#       3 print(periodlist)
#
# NameError: name 'periodnum' is not defined

# %%
['dfnumweek%s' % week[1]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [93], in <cell line: 1>()
# ----> 1 ['dfnumweek%s' % week[1]]
#
# NameError: name 'week' is not defined

# %%
dfnum.to_csv('EssenceILINumerator.csv', index = False, encoding = 'utf-8')
    
dfden.to_csv('EssenceILIDenominator.csv', index = False, encoding = 'utf-8')

# %%
display(dfsol)
# Out:
#      record_no  Provider ID  MMWR  \
# 0            1        38047  1901
# 1            2        38047  1901
# 2            3        38047  1901
# 3            4        38047  1901
# 4            5        38047  1901
# 5            6        38047  1901
# 6            7        38047  1901
# 7            8        38047  1901
# 8            9        38047  1901
# 9           10        38047  1901
# 10          11        38047  1901
# 11          12        38047  1901
# 12          13        38047  1901
# 13          14        38047  1901
# 14          15        38047  1901
# 15          16        38047  1901
# 16          17        38047  1901
# 17          18        38047  1901
# 18          19        38047  1901
# 19          20        38047  1901
# 20          21        38047  1901
# 21          22        38047  1901
# 22          23        38047  1901
# 23          24        38047  1901
# 24          25        38047  1901
# 25          26        38047  1901
# 26          27        38047  1901
# 27          28        38047  1901
# 28          29        38047  1901
# 29          30        38047  1901
# 30          31        38048  1901
# 31          32        38048  1901
# 32          33        38048  1901
# 33          34        38048  1901
# 34          35        38048  1901
# 35          36        38048  1901
# 36          37        38048  1901
# 37          38        38048  1901
# 38          39        38048  1901
# 39          40        38048  1901
# 40          41        38048  1901
# 41          42        38048  1901
# 42          43        38048  1901
# 43          44        38048  1901
# 44          45        38048  1901
# 45          46        38048  1901
# 46          47        38048  1901
# 47          48        38048  1901
# 48          49        38048  1901
# 49          50        38048  1901
# 50          51        38048  1901
# 51          52        38048  1901
# 52          53        38048  1901
# 53          54        38048  1901
# 54          55        38048  1901
# 55          56        38048  1901
# 56          57        38048  1901
# 57          58        38048  1901
# 58          59        38048  1901
# 59          60        38048  1901
# 60          61        38090  1901
# 233  St. Alexius Health Dickinson (St. Joseph’s) ED     25-49        2022-45
# 234  St. Alexius Health Dickinson (St. Joseph’s) ED     50-64        2022-45
# 235  St. Alexius Health Dickinson (St. Joseph’s) ED     50-64        2022-45
# 236  St. Alexius Health Dickinson (St. Joseph’s) ED       65+        2022-45
# 237  St. Alexius Health Dickinson (St. Joseph’s) ED       65+        2022-45
# 238  St. Alexius Health Dickinson (St. Joseph’s) ED   Unknown        2022-45
# 239  St. Alexius Health Dickinson (St. Joseph’s) ED   Unknown        2022-45
# 240                                      Trinity ED     00-04        2022-43
# 241                                      Trinity ED     05-24        2022-43
# 242                                      Trinity ED     25-49        2022-43
# 243                                      Trinity ED     50-64        2022-43
# 244                                      Trinity ED       65+        2022-43
# 245                                      Trinity ED   Unknown        2022-43
# 246                                      Trinity ED     00-04        2022-44
# 247                                      Trinity ED     00-04        2022-44
# 248                                      Trinity ED     05-24        2022-44
# 249                                      Trinity ED     05-24        2022-44
# 250                                      Trinity ED     25-49        2022-44
# 251                                      Trinity ED     25-49        2022-44
# 252                                      Trinity ED     50-64        2022-44
# 253                                      Trinity ED     50-64        2022-44
# 254                                      Trinity ED       65+        2022-44
# 255                                      Trinity ED       65+        2022-44
# 256                                      Trinity ED   Unknown        2022-44
# 257                                      Trinity ED   Unknown        2022-44
# 258                                      Trinity ED     00-04        2022-45
# 259                                      Trinity ED     00-04        2022-45
# 260                                      Trinity ED     05-24        2022-45
# 261                                      Trinity ED     05-24        2022-45
# 262                                      Trinity ED     25-49        2022-45
# 263                                      Trinity ED     25-49        2022-45
# 264                                      Trinity ED     50-64        2022-45
# 265                                      Trinity ED     50-64        2022-45
# 266                                      Trinity ED       65+        2022-45
# 267                                      Trinity ED       65+        2022-45
# 268                                      Trinity ED   Unknown        2022-45
# 269                                      Trinity ED   Unknown        2022-45
#
#      count    From
# 0     19.0  ILIDen
# 1     44.0  ILIDen
# 2     64.0  ILIDen
# 3     30.0  ILIDen
# 4     23.0  ILIDen
# 5      0.0  ILIDen
# 6      1.0  ILINum
# 7     52.0  ILIDen
# 8      0.0  ILINum
# 9    116.0  ILIDen
# 10     0.0  ILINum
# 11   122.0  ILIDen
# 12     0.0  ILINum
# 13    64.0  ILIDen
# 14     0.0  ILINum
# 15    62.0  ILIDen
# 16     0.0  ILINum
# 17     0.0  ILIDen
# 18     3.0  ILINum
# 19    33.0  ILIDen
# 20     5.0  ILINum
# 21    54.0  ILIDen
# 22     3.0  ILINum
# 23    90.0  ILIDen
# 24     1.0  ILINum
# 25    30.0  ILIDen
# 26     0.0  ILINum
# 27    38.0  ILIDen
# 28     0.0  ILINum
# 29     0.0  ILIDen
# 30    33.0  ILIDen
# 31    42.0  ILIDen
# 32    74.0  ILIDen
# 33    32.0  ILIDen
# 34    27.0  ILIDen
# 35     0.0  ILIDen
# 36     3.0  ILINum
# 37    54.0  ILIDen
# 38     2.0  ILINum
# 39    97.0  ILIDen
# 40     2.0  ILINum
# 41   188.0  ILIDen
# 42     0.0  ILINum
# 43    52.0  ILIDen
# 44     0.0  ILINum
# 45    73.0  ILIDen
# 46     0.0  ILINum
# 47     0.0  ILIDen
# 48     2.0  ILINum
# 49    23.0  ILIDen
# 50     2.0  ILINum
# 51    41.0  ILIDen
# 52     0.0  ILINum
# 53    88.0  ILIDen
# 54     0.0  ILINum
# 55    37.0  ILIDen
# 56     2.0  ILINum
# 57    38.0  ILIDen
# 58     0.0  ILINum
# 59     0.0  ILIDen
# 60     7.0  ILIDen
# 61    16.0  ILIDen
# 62    25.0  ILIDen
# 63    27.0  ILIDen
# 64    14.0  ILIDen
# 65     0.0  ILIDen
# 66     0.0  ILINum
# 67    21.0  ILIDen
# 68     2.0  ILINum
# 69    33.0  ILIDen
# 70     0.0  ILINum
# 71    46.0  ILIDen
# 72     1.0  ILINum
# 73    30.0  ILIDen
# 74     1.0  ILINum
# 75    39.0  ILIDen
# 76     0.0  ILINum
# 77     0.0  ILIDen
# 78     0.0  ILINum
# 79    12.0  ILIDen
# 80     1.0  ILINum
# 81    20.0  ILIDen
# 82     1.0  ILINum
# 83    36.0  ILIDen
# 84     1.0  ILINum
# 85    19.0  ILIDen
# 86     0.0  ILINum
# 87    25.0  ILIDen
# 88     0.0  ILINum
# 89     0.0  ILIDen
# 90    24.0  ILIDen
# 91    47.0  ILIDen
# 92    83.0  ILIDen
# 93    24.0  ILIDen
# 94    21.0  ILIDen
# 95     0.0  ILIDen
# 96     5.0  ILINum
# 97    46.0  ILIDen
# 98     2.0  ILINum
# 99   100.0  ILIDen
# 100    4.0  ILINum
# 101  220.0  ILIDen
# 102    2.0  ILINum
# 103   73.0  ILIDen
# 104    0.0  ILINum
# 105   58.0  ILIDen
# 106    0.0  ILINum
# 107    0.0  ILIDen
# 108    2.0  ILINum
# 109   16.0  ILIDen
# 110    3.0  ILINum
# 111   49.0  ILIDen
# 112    6.0  ILINum
# 113   93.0  ILIDen
# 114    5.0  ILINum
# 115   44.0  ILIDen
# 116    0.0  ILINum
# 117   35.0  ILIDen
# 118    0.0  ILINum
# 119    0.0  ILIDen
# 120   26.0  ILIDen
# 121   59.0  ILIDen
# 122  121.0  ILIDen
# 123   40.0  ILIDen
# 124   48.0  ILIDen
# 125    0.0  ILIDen
# 126    4.0  ILINum
# 127   81.0  ILIDen
# 128    3.0  ILINum
# 129  160.0  ILIDen
# 130    2.0  ILINum
# 131  242.0  ILIDen
# 132    0.0  ILINum
# 133   89.0  ILIDen
# 134    1.0  ILINum
# 135   88.0  ILIDen
# 136    0.0  ILINum
# 137    0.0  ILIDen
# 138    2.0  ILINum
# 139   41.0  ILIDen
# 140    3.0  ILINum
# 141   88.0  ILIDen
# 142    7.0  ILINum
# 143  157.0  ILIDen
# 144    0.0  ILINum
# 145   44.0  ILIDen
# 146    1.0  ILINum
# 147   40.0  ILIDen
# 148    0.0  ILINum
# 149    0.0  ILIDen
# 150    6.0  ILIDen
# 151   14.0  ILIDen
# 152   19.0  ILIDen
# 153    6.0  ILIDen
# 154   17.0  ILIDen
# 155    0.0  ILIDen
# 156    1.0  ILINum
# 157   20.0  ILIDen
# 158    1.0  ILINum
# 159   50.0  ILIDen
# 160    0.0  ILINum
# 161   55.0  ILIDen
# 162    1.0  ILINum
# 163   30.0  ILIDen
# 164    0.0  ILINum
# 165   26.0  ILIDen
# 166    0.0  ILINum
# 167    0.0  ILIDen
# 168    2.0  ILINum
# 169   15.0  ILIDen
# 170    0.0  ILINum
# 171   20.0  ILIDen
# 172    0.0  ILINum
# 173   28.0  ILIDen
# 174    0.0  ILINum
# 175   15.0  ILIDen
# 176    0.0  ILINum
# 177   13.0  ILIDen
# 178    0.0  ILINum
# 179    0.0  ILIDen
# 180   16.0  ILIDen
# 181   28.0  ILIDen
# 182   41.0  ILIDen
# 183   10.0  ILIDen
# 184   10.0  ILIDen
# 185    0.0  ILIDen
# 186    0.0  ILINum
# 187   49.0  ILIDen
# 188    0.0  ILINum
# 189   72.0  ILIDen
# 190    0.0  ILINum
# 191  107.0  ILIDen
# 192    0.0  ILINum
# 193   37.0  ILIDen
# 194    0.0  ILINum
# 195   26.0  ILIDen
# 196    0.0  ILINum
# 197    0.0  ILIDen
# 198    1.0  ILINum
# 199   27.0  ILIDen
# 200    2.0  ILINum
# 201   32.0  ILIDen
# 202    0.0  ILINum
# 203   60.0  ILIDen
# 204    0.0  ILINum
# 205   16.0  ILIDen
# 206    0.0  ILINum
# 207   14.0  ILIDen
# 208    0.0  ILINum
# 209    0.0  ILIDen
# 210   12.0  ILIDen
# 211   15.0  ILIDen
# 212   33.0  ILIDen
# 213   16.0  ILIDen
# 214   19.0  ILIDen
# 215    0.0  ILIDen
# 216    1.0  ILINum
# 217   15.0  ILIDen
# 218    0.0  ILINum
# 219   58.0  ILIDen
# 220    0.0  ILINum
# 221   89.0  ILIDen
# 222    0.0  ILINum
# 223   31.0  ILIDen
# 224    0.0  ILINum
# 225   32.0  ILIDen
# 226    0.0  ILINum
# 227    0.0  ILIDen
# 228    0.0  ILINum
# 229   13.0  ILIDen
# 230    0.0  ILINum
# 231   24.0  ILIDen
# 232    1.0  ILINum
# 233   38.0  ILIDen
# 234    0.0  ILINum
# 235   12.0  ILIDen
# 236    1.0  ILINum
# 237   28.0  ILIDen
# 238    0.0  ILINum
# 239    0.0  ILIDen
# 240   10.0  ILIDen
# 241   39.0  ILIDen
# 242   89.0  ILIDen
# 243   36.0  ILIDen
# 244   63.0  ILIDen
# 245    0.0  ILIDen
# 246    1.0  ILINum
# 247   39.0  ILIDen
# 248    2.0  ILINum
# 249  112.0  ILIDen
# 250    4.0  ILINum
# 251  198.0  ILIDen
# 252    1.0  ILINum
# 253   81.0  ILIDen
# 254    3.0  ILINum
# 255  152.0  ILIDen
# 256    0.0  ILINum
# 257    0.0  ILIDen
# 258    5.0  ILINum
# 259   22.0  ILIDen
# 260    7.0  ILINum
# 261   72.0  ILIDen
# 262    3.0  ILINum
# 263  108.0  ILIDen
# 264    2.0  ILINum
# 265   42.0  ILIDen
# 266    2.0  ILINum
# 267   63.0  ILIDen
# 268    0.0  ILINum
# 269    0.0  ILIDen

# %%
df_test.to_csv('EssenceILISolutionFinal.csv', index = True, encoding = 'utf-8')

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'import sys\nimport warnings\nimport pandas as pd\nimport numpy as np\nimport os\nimport cx_Oracle as O\nimport datetime as dt\nimport logging, logging.handlers, smtplib\nimport traceback\nimport smtplib\nimport sqlalchemy as sa\nimport pyodbc\nfrom email.mime.multipart import MIMEMultipart\nfrom email.mime.text import MIMEText\nfrom email.mime.application import MIMEApplication\nfrom os.path import basename\nimport os\nfrom datetime import datetime, date\nimport settings\nimport errhandler as eh\nimport eHSQL\nimport re\nimport os\nimport requests\nimport urllib\nimport itertools\nfrom requests.exceptions import ConnectionError, HTTPError, Timeout, TooManyRedirects\nfrom requests.adapters import HTTPAdapter\nfrom requests.packages.urllib3.util.retry import Retry\nfrom requests.auth import HTTPBasicAuth\nimport json\nfrom lxml import html\n\nglobal r, rnumjson\n\n\ndef getData():\n    \n    global dfpivot, df_test, dfsol, dfnum, dfden, recnum, payload, r, rnumjson, dfLE, session, auth, agent\n    \n    agent = {\'user-agent\': \'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36 Edg/106.0.1370.52\'}\n    \n    pd.set_option(\'display.max_columns\', None)\n    pd.set_option(\'display.max_rows\', None)\n    \n    url1 = "https://essence.syndromicsurveillance.org/"\n\n    session = requests.session()\n    \n    #session = AsyncHTMLSession()\n    \n    url1result = session.get(url1, headers = agent)\n    \n    print(f\'\\n{url1result.headers}\\n\', f\'\\n{url1result.request.headers}\\n\')\n    \n    print(session.cookies.get_dict())\n    print(url1result.headers[\'Set-Cookie\'])\n    cookie = str(url1result.headers[\'Set-Cookie\'])\n    cookie = \' \' + cookie.replace(\' Path=/; Secure; HttpOnly\',\'\').replace(\';\', \'\')\n    print(cookie, \'\\n\')\n    \n    url2 = "https://essence.syndromicsurveillance.org/nssp_essence"\n    url2result = session.get(url2, headers=agent)\n    \n    print(f\'\\n{url2result.headers}\\n\', f\'\\n{url2result.request.headers}\\n\')\n    \n    print(session.cookies.get_dict())\n    print(url2result.request.headers[\'Cookie\'])\n    cookie2 = str(url2result.request.headers[\'Cookie\']).split()\n    cookie2 = cookie2[0] + \' \'\n    print(cookie2, \'\\n\')\n    \n    url3 = "https://essence.syndromicsurveillance.org/nssp_essence/servlet/Login"\n    url3result = session.get(url3, headers=agent)\n    \n    print(f\'\\n{url3result.headers}\\n\', f\'\\n{url3result.request.headers}\\n\')\n    \n    tree = html.fromstring(url3result.text)\n    authenticity_token = list(set(tree.xpath("//input[@name=\'csrfPreventionSalt\']/@value")))[0]\n    \n    print(f\'{authenticity_token}\\n\')\n    \n    payload = {"userId": "gmoye01",\n                   "password": "Qmwnebrvt1!!",\n                   "csrfPreventionSalt": f"{authenticity_token}"}\n    \n    loginpostresult = session.post(url3,\n                                    data = payload,\n                                    headers = agent,\n                                    allow_redirects = True)\n    \n    print(f\'\\n{loginpostresult.headers}\\n\', f\'\\n{loginpostresult.request.headers}\\n\')\n    \n    url4 = "https://essence.syndromicsurveillance.org/nssp_essence/j_spring_security_check"\n    url4result = session.get(url4, headers=agent)\n    \n    print(f\'\\n{url4result.headers}\\n\', f\'\\n{url4result.request.headers}\\n\')\n\n    dfLE = pd.read_csv(r\'C:\\Users\\gmoye\\LegalEntities.csv\')\n    dfLE.rename(columns={\'LE_Name\':\'erFacility\'}, inplace = True)\n\n    url5 = "https://essence.syndromicsurveillance.org/nssp_essence/servlet/TableBuilderPortletRedirectServlet?percentParam=noPercent&patientClass=e&endDate=4Aug2018&medicalGroupingSystem=essencesyndromes&userId=647&geographySystem=state&ccddCategory=ili%20ccdd%20v1&geography=nd&datasource=va_er&timeResolution=weekly&erFacility=6326&erFacility=6330&erFacility=6360&erFacility=6365&erFacility=6358&erFacility=6320&erFacility=6354& ...
#   'getData()',
#   'def transformation():\n    global denvarlist, numvarlist, dfdenweek, dfnumweek\n\n    dfnum = pd.DataFrame(rnumjson)\n    recnum = len(dfnum.index)\n    \n    dfnum = dfnum.sort_values(by=[\'erFacility\',\'timeResolution\',\'ageCDCILI\'], ascending = True).reset_index(drop = True)\n    \n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Central Dakota Clinic/Charles Nyhus"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Valley City University Student Health"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="UND Center for Family Medicine"\n    dfnum.loc[dfnum["erFacility"]=="ND-Essentia Health Fargo Hospital","erFacility"]="Essentia ED"\n    dfnum.loc[dfnum["erFacility"]=="ND-Altru Hospital","erFacility"]="Altru ED"\n    dfnum.loc[dfnum["erFacility"]=="ND-Sanford Emergency Center Bismarck","erFacility"]="Sanford Medical Center Bismarck"\n    dfnum.loc[dfnum["erFacility"]=="ND-Sanford Medical Center Fargo","erFacility"]="Sanford Medical Center Fargo"\n    dfnum.loc[dfnum["erFacility"]=="ND-CHI St. Joseph\'s Health","erFacility"]="St. Alexius Health Dickinson (St. Joseph’s) ED"\n    dfnum.loc[dfnum["erFacility"]=="ND-Trinity Hospital","erFacility"]="Trinity ED"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Urgent Medicine Associated/Kurt Kooyer"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="7-Day Clinic/Napoleon Espejo"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Midgarden Family Clinic"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Standing Rock IHS"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Fairlight Medical Center"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Wishek Community Clinic"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Northland Community Health Center McClusky"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="West River Health Services"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Altru Devil’s Lake Family Practice/Lim Elson"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Sanford Walk-in Fargo/Greg Pfennig"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Northland Community Health Center Turtle Lake"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Towner County Medical Center"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="UND Student Health Center"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Trinity Community Clinic New Town"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Trinity Community Clinic Kenmare"\n    dfnum.loc[dfnum["erFacility"]=="ND-CHI St. Alexius Williston","erFacility"]="St Alexius Health Williston (Mercy) ED"\n    dfnum.loc[dfnum["erFacility"]=="ND-CHI Devils Lake Hospital","erFacility"]="St Alexius Health Devil’s Lake (Mercy) ED"\n    dfnum.loc[dfnum["erFacility"]=="ND-Jamestown Regional Medical Center","erFacility"]="Jamestown Regional Medical Center"\n    \n    periodnum = dfnum[\'timeResolution\'].unique()\n    periodnum = periodnum.tolist()\n    \n    numvarlist = []\n    \n    for week in enumerate(periodnum):\n        \n        dfnumweek = dfnum.loc[dfnum[\'timeResolution\'] == week[1]]\n    \n        dfnumweek = pd.merge(dfnumweek, dfLE, how = \'left\', on = [\'erFacility\'])\n        dfnumweek = dfnumweek.drop(columns = [\'geographystate\'])\n        \n        dfnumweek[\'MMWR\'] = \'1901\'\n        \n        dfnumweek[\'From\'] = \'ILINum\'\n        \n        col = dfnumweek.pop("LE_ID")\n        dfnumweek.insert(0, \'Provider ID\', col)\n        \n        col = dfnumweek.pop("MMWR")\n        dfnumweek.insert(1, col.name, col)\n        \n        dfnumweek[\'ageCDCILI\'] = dfnumweek[\'ageCDCILI\'].astype(object)\n        \n        weeknum = str(week[1])\n        weeknum = weeknum.replace(\'2022-\',\'\')\n        \n        print(weeknum)\n        \n        numvarlist.append(\'dfnumweek\' + weeknum)\n        \n        globals()[\'dfnumweek%s\' % weeknum] = dfnumweek\n        \n        #display(dfnumweek)\n        \n    numvarlist = [item.strip("\'") for item ...
#   'transformation()',
#   'globals()'],
#  '_oh': {},
#  '_dh': [WindowsPath('C:/Users/gmoye')],
#  'In': ['',
#   'import sys\nimport warnings\nimport pandas as pd\nimport numpy as np\nimport os\nimport cx_Oracle as O\nimport datetime as dt\nimport logging, logging.handlers, smtplib\nimport traceback\nimport smtplib\nimport sqlalchemy as sa\nimport pyodbc\nfrom email.mime.multipart import MIMEMultipart\nfrom email.mime.text import MIMEText\nfrom email.mime.application import MIMEApplication\nfrom os.path import basename\nimport os\nfrom datetime import datetime, date\nimport settings\nimport errhandler as eh\nimport eHSQL\nimport re\nimport os\nimport requests\nimport urllib\nimport itertools\nfrom requests.exceptions import ConnectionError, HTTPError, Timeout, TooManyRedirects\nfrom requests.adapters import HTTPAdapter\nfrom requests.packages.urllib3.util.retry import Retry\nfrom requests.auth import HTTPBasicAuth\nimport json\nfrom lxml import html\n\nglobal r, rnumjson\n\n\ndef getData():\n    \n    global dfpivot, df_test, dfsol, dfnum, dfden, recnum, payload, r, rnumjson, dfLE, session, auth, agent\n    \n    agent = {\'user-agent\': \'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36 Edg/106.0.1370.52\'}\n    \n    pd.set_option(\'display.max_columns\', None)\n    pd.set_option(\'display.max_rows\', None)\n    \n    url1 = "https://essence.syndromicsurveillance.org/"\n\n    session = requests.session()\n    \n    #session = AsyncHTMLSession()\n    \n    url1result = session.get(url1, headers = agent)\n    \n    print(f\'\\n{url1result.headers}\\n\', f\'\\n{url1result.request.headers}\\n\')\n    \n    print(session.cookies.get_dict())\n    print(url1result.headers[\'Set-Cookie\'])\n    cookie = str(url1result.headers[\'Set-Cookie\'])\n    cookie = \' \' + cookie.replace(\' Path=/; Secure; HttpOnly\',\'\').replace(\';\', \'\')\n    print(cookie, \'\\n\')\n    \n    url2 = "https://essence.syndromicsurveillance.org/nssp_essence"\n    url2result = session.get(url2, headers=agent)\n    \n    print(f\'\\n{url2result.headers}\\n\', f\'\\n{url2result.request.headers}\\n\')\n    \n    print(session.cookies.get_dict())\n    print(url2result.request.headers[\'Cookie\'])\n    cookie2 = str(url2result.request.headers[\'Cookie\']).split()\n    cookie2 = cookie2[0] + \' \'\n    print(cookie2, \'\\n\')\n    \n    url3 = "https://essence.syndromicsurveillance.org/nssp_essence/servlet/Login"\n    url3result = session.get(url3, headers=agent)\n    \n    print(f\'\\n{url3result.headers}\\n\', f\'\\n{url3result.request.headers}\\n\')\n    \n    tree = html.fromstring(url3result.text)\n    authenticity_token = list(set(tree.xpath("//input[@name=\'csrfPreventionSalt\']/@value")))[0]\n    \n    print(f\'{authenticity_token}\\n\')\n    \n    payload = {"userId": "gmoye01",\n                   "password": "Qmwnebrvt1!!",\n                   "csrfPreventionSalt": f"{authenticity_token}"}\n    \n    loginpostresult = session.post(url3,\n                                    data = payload,\n                                    headers = agent,\n                                    allow_redirects = True)\n    \n    print(f\'\\n{loginpostresult.headers}\\n\', f\'\\n{loginpostresult.request.headers}\\n\')\n    \n    url4 = "https://essence.syndromicsurveillance.org/nssp_essence/j_spring_security_check"\n    url4result = session.get(url4, headers=agent)\n    \n    print(f\'\\n{url4result.headers}\\n\', f\'\\n{url4result.request.headers}\\n\')\n\n    dfLE = pd.read_csv(r\'C:\\Users\\gmoye\\LegalEntities.csv\')\n    dfLE.rename(columns={\'LE_Name\':\'erFacility\'}, inplace = True)\n\n    url5 = "https://essence.syndromicsurveillance.org/nssp_essence/servlet/TableBuilderPortletRedirectServlet?percentParam=noPercent&patientClass=e&endDate=4Aug2018&medicalGroupingSystem=essencesyndromes&userId=647&geographySystem=state&ccddCategory=ili%20ccdd%20v1&geography=nd&datasource=va_er&timeResolution=weekly&erFacility=6326&erFacility=6330&erFacility=6360&erFacility=6365&erFacility=6358&erFacility=6320&erFacility=6354& ...
#   'getData()',
#   'def transformation():\n    global denvarlist, numvarlist, dfdenweek, dfnumweek\n\n    dfnum = pd.DataFrame(rnumjson)\n    recnum = len(dfnum.index)\n    \n    dfnum = dfnum.sort_values(by=[\'erFacility\',\'timeResolution\',\'ageCDCILI\'], ascending = True).reset_index(drop = True)\n    \n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Central Dakota Clinic/Charles Nyhus"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Valley City University Student Health"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="UND Center for Family Medicine"\n    dfnum.loc[dfnum["erFacility"]=="ND-Essentia Health Fargo Hospital","erFacility"]="Essentia ED"\n    dfnum.loc[dfnum["erFacility"]=="ND-Altru Hospital","erFacility"]="Altru ED"\n    dfnum.loc[dfnum["erFacility"]=="ND-Sanford Emergency Center Bismarck","erFacility"]="Sanford Medical Center Bismarck"\n    dfnum.loc[dfnum["erFacility"]=="ND-Sanford Medical Center Fargo","erFacility"]="Sanford Medical Center Fargo"\n    dfnum.loc[dfnum["erFacility"]=="ND-CHI St. Joseph\'s Health","erFacility"]="St. Alexius Health Dickinson (St. Joseph’s) ED"\n    dfnum.loc[dfnum["erFacility"]=="ND-Trinity Hospital","erFacility"]="Trinity ED"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Urgent Medicine Associated/Kurt Kooyer"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="7-Day Clinic/Napoleon Espejo"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Midgarden Family Clinic"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Standing Rock IHS"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Fairlight Medical Center"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Wishek Community Clinic"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Northland Community Health Center McClusky"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="West River Health Services"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Altru Devil’s Lake Family Practice/Lim Elson"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Sanford Walk-in Fargo/Greg Pfennig"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Northland Community Health Center Turtle Lake"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Towner County Medical Center"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="UND Student Health Center"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Trinity Community Clinic New Town"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Trinity Community Clinic Kenmare"\n    dfnum.loc[dfnum["erFacility"]=="ND-CHI St. Alexius Williston","erFacility"]="St Alexius Health Williston (Mercy) ED"\n    dfnum.loc[dfnum["erFacility"]=="ND-CHI Devils Lake Hospital","erFacility"]="St Alexius Health Devil’s Lake (Mercy) ED"\n    dfnum.loc[dfnum["erFacility"]=="ND-Jamestown Regional Medical Center","erFacility"]="Jamestown Regional Medical Center"\n    \n    periodnum = dfnum[\'timeResolution\'].unique()\n    periodnum = periodnum.tolist()\n    \n    numvarlist = []\n    \n    for week in enumerate(periodnum):\n        \n        dfnumweek = dfnum.loc[dfnum[\'timeResolution\'] == week[1]]\n    \n        dfnumweek = pd.merge(dfnumweek, dfLE, how = \'left\', on = [\'erFacility\'])\n        dfnumweek = dfnumweek.drop(columns = [\'geographystate\'])\n        \n        dfnumweek[\'MMWR\'] = \'1901\'\n        \n        dfnumweek[\'From\'] = \'ILINum\'\n        \n        col = dfnumweek.pop("LE_ID")\n        dfnumweek.insert(0, \'Provider ID\', col)\n        \n        col = dfnumweek.pop("MMWR")\n        dfnumweek.insert(1, col.name, col)\n        \n        dfnumweek[\'ageCDCILI\'] = dfnumweek[\'ageCDCILI\'].astype(object)\n        \n        weeknum = str(week[1])\n        weeknum = weeknum.replace(\'2022-\',\'\')\n        \n        print(weeknum)\n        \n        numvarlist.append(\'dfnumweek\' + weeknum)\n        \n        globals()[\'dfnumweek%s\' % weeknum] = dfnumweek\n        \n        #display(dfnumweek)\n        \n    numvarlist = [item.strip("\'") for item ...
#   'transformation()',
#   'globals()'],
#  'Out': {},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x000001752C6614F0>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x1752c60a040>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x1752c60a040>,
#  '_': '',
#  '__': '',
#  '___': '',
#  '_i': 'transformation()',
#  '_ii': 'def transformation():\n    global denvarlist, numvarlist, dfdenweek, dfnumweek\n\n    dfnum = pd.DataFrame(rnumjson)\n    recnum = len(dfnum.index)\n    \n    dfnum = dfnum.sort_values(by=[\'erFacility\',\'timeResolution\',\'ageCDCILI\'], ascending = True).reset_index(drop = True)\n    \n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Central Dakota Clinic/Charles Nyhus"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Valley City University Student Health"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="UND Center for Family Medicine"\n    dfnum.loc[dfnum["erFacility"]=="ND-Essentia Health Fargo Hospital","erFacility"]="Essentia ED"\n    dfnum.loc[dfnum["erFacility"]=="ND-Altru Hospital","erFacility"]="Altru ED"\n    dfnum.loc[dfnum["erFacility"]=="ND-Sanford Emergency Center Bismarck","erFacility"]="Sanford Medical Center Bismarck"\n    dfnum.loc[dfnum["erFacility"]=="ND-Sanford Medical Center Fargo","erFacility"]="Sanford Medical Center Fargo"\n    dfnum.loc[dfnum["erFacility"]=="ND-CHI St. Joseph\'s Health","erFacility"]="St. Alexius Health Dickinson (St. Joseph’s) ED"\n    dfnum.loc[dfnum["erFacility"]=="ND-Trinity Hospital","erFacility"]="Trinity ED"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Urgent Medicine Associated/Kurt Kooyer"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="7-Day Clinic/Napoleon Espejo"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Midgarden Family Clinic"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Standing Rock IHS"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Fairlight Medical Center"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Wishek Community Clinic"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Northland Community Health Center McClusky"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="West River Health Services"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Altru Devil’s Lake Family Practice/Lim Elson"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Sanford Walk-in Fargo/Greg Pfennig"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Northland Community Health Center Turtle Lake"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Towner County Medical Center"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="UND Student Health Center"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Trinity Community Clinic New Town"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Trinity Community Clinic Kenmare"\n    dfnum.loc[dfnum["erFacility"]=="ND-CHI St. Alexius Williston","erFacility"]="St Alexius Health Williston (Mercy) ED"\n    dfnum.loc[dfnum["erFacility"]=="ND-CHI Devils Lake Hospital","erFacility"]="St Alexius Health Devil’s Lake (Mercy) ED"\n    dfnum.loc[dfnum["erFacility"]=="ND-Jamestown Regional Medical Center","erFacility"]="Jamestown Regional Medical Center"\n    \n    periodnum = dfnum[\'timeResolution\'].unique()\n    periodnum = periodnum.tolist()\n    \n    numvarlist = []\n    \n    for week in enumerate(periodnum):\n        \n        dfnumweek = dfnum.loc[dfnum[\'timeResolution\'] == week[1]]\n    \n        dfnumweek = pd.merge(dfnumweek, dfLE, how = \'left\', on = [\'erFacility\'])\n        dfnumweek = dfnumweek.drop(columns = [\'geographystate\'])\n        \n        dfnumweek[\'MMWR\'] = \'1901\'\n        \n        dfnumweek[\'From\'] = \'ILINum\'\n        \n        col = dfnumweek.pop("LE_ID")\n        dfnumweek.insert(0, \'Provider ID\', col)\n        \n        col = dfnumweek.pop("MMWR")\n        dfnumweek.insert(1, col.name, col)\n        \n        dfnumweek[\'ageCDCILI\'] = dfnumweek[\'ageCDCILI\'].astype(object)\n        \n        weeknum = str(week[1])\n        weeknum = weeknum.replace(\'2022-\',\'\')\n        \n        print(weeknum)\n        \n        numvarlist.append(\'dfnumweek\' + weeknum)\n        \n        globals()[\'dfnumweek%s\' % weeknum] = dfnumweek\n        \n        #display(dfnumweek)\n        \n    numvarlist = [item.strip("\'") fo ...
#  '_iii': 'getData()',
#  '_i1': 'import sys\nimport warnings\nimport pandas as pd\nimport numpy as np\nimport os\nimport cx_Oracle as O\nimport datetime as dt\nimport logging, logging.handlers, smtplib\nimport traceback\nimport smtplib\nimport sqlalchemy as sa\nimport pyodbc\nfrom email.mime.multipart import MIMEMultipart\nfrom email.mime.text import MIMEText\nfrom email.mime.application import MIMEApplication\nfrom os.path import basename\nimport os\nfrom datetime import datetime, date\nimport settings\nimport errhandler as eh\nimport eHSQL\nimport re\nimport os\nimport requests\nimport urllib\nimport itertools\nfrom requests.exceptions import ConnectionError, HTTPError, Timeout, TooManyRedirects\nfrom requests.adapters import HTTPAdapter\nfrom requests.packages.urllib3.util.retry import Retry\nfrom requests.auth import HTTPBasicAuth\nimport json\nfrom lxml import html\n\nglobal r, rnumjson\n\n\ndef getData():\n    \n    global dfpivot, df_test, dfsol, dfnum, dfden, recnum, payload, r, rnumjson, dfLE, session, auth, agent\n    \n    agent = {\'user-agent\': \'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36 Edg/106.0.1370.52\'}\n    \n    pd.set_option(\'display.max_columns\', None)\n    pd.set_option(\'display.max_rows\', None)\n    \n    url1 = "https://essence.syndromicsurveillance.org/"\n\n    session = requests.session()\n    \n    #session = AsyncHTMLSession()\n    \n    url1result = session.get(url1, headers = agent)\n    \n    print(f\'\\n{url1result.headers}\\n\', f\'\\n{url1result.request.headers}\\n\')\n    \n    print(session.cookies.get_dict())\n    print(url1result.headers[\'Set-Cookie\'])\n    cookie = str(url1result.headers[\'Set-Cookie\'])\n    cookie = \' \' + cookie.replace(\' Path=/; Secure; HttpOnly\',\'\').replace(\';\', \'\')\n    print(cookie, \'\\n\')\n    \n    url2 = "https://essence.syndromicsurveillance.org/nssp_essence"\n    url2result = session.get(url2, headers=agent)\n    \n    print(f\'\\n{url2result.headers}\\n\', f\'\\n{url2result.request.headers}\\n\')\n    \n    print(session.cookies.get_dict())\n    print(url2result.request.headers[\'Cookie\'])\n    cookie2 = str(url2result.request.headers[\'Cookie\']).split()\n    cookie2 = cookie2[0] + \' \'\n    print(cookie2, \'\\n\')\n    \n    url3 = "https://essence.syndromicsurveillance.org/nssp_essence/servlet/Login"\n    url3result = session.get(url3, headers=agent)\n    \n    print(f\'\\n{url3result.headers}\\n\', f\'\\n{url3result.request.headers}\\n\')\n    \n    tree = html.fromstring(url3result.text)\n    authenticity_token = list(set(tree.xpath("//input[@name=\'csrfPreventionSalt\']/@value")))[0]\n    \n    print(f\'{authenticity_token}\\n\')\n    \n    payload = {"userId": "gmoye01",\n                   "password": "Qmwnebrvt1!!",\n                   "csrfPreventionSalt": f"{authenticity_token}"}\n    \n    loginpostresult = session.post(url3,\n                                    data = payload,\n                                    headers = agent,\n                                    allow_redirects = True)\n    \n    print(f\'\\n{loginpostresult.headers}\\n\', f\'\\n{loginpostresult.request.headers}\\n\')\n    \n    url4 = "https://essence.syndromicsurveillance.org/nssp_essence/j_spring_security_check"\n    url4result = session.get(url4, headers=agent)\n    \n    print(f\'\\n{url4result.headers}\\n\', f\'\\n{url4result.request.headers}\\n\')\n\n    dfLE = pd.read_csv(r\'C:\\Users\\gmoye\\LegalEntities.csv\')\n    dfLE.rename(columns={\'LE_Name\':\'erFacility\'}, inplace = True)\n\n    url5 = "https://essence.syndromicsurveillance.org/nssp_essence/servlet/TableBuilderPortletRedirectServlet?percentParam=noPercent&patientClass=e&endDate=4Aug2018&medicalGroupingSystem=essencesyndromes&userId=647&geographySystem=state&ccddCategory=ili%20ccdd%20v1&geography=nd&datasource=va_er&timeResolution=weekly&erFacility=6326&erFacility=6330&erFacility=6360&erFacility=6365&erFacility=6358&erFacility=6320&erFacility ...
#  'sys': <module 'sys' (built-in)>,
#  'warnings': <module 'warnings' from 'C:\\Users\\gmoye\\Anaconda3\\lib\\warnings.py'>,
#  'pd': <module 'pandas' from 'C:\\Users\\gmoye\\Anaconda3\\lib\\site-packages\\pandas\\__init__.py'>,
#  'np': <module 'numpy' from 'C:\\Users\\gmoye\\Anaconda3\\lib\\site-packages\\numpy\\__init__.py'>,
#  'os': <module 'os' from 'C:\\Users\\gmoye\\Anaconda3\\lib\\os.py'>,
#  'O': <module 'cx_Oracle' from 'C:\\Users\\gmoye\\Anaconda3\\lib\\site-packages\\cx_Oracle.cp39-win_amd64.pyd'>,
#  'dt': <module 'datetime' from 'C:\\Users\\gmoye\\Anaconda3\\lib\\datetime.py'>,
#  'logging': <module 'logging' from 'C:\\Users\\gmoye\\Anaconda3\\lib\\logging\\__init__.py'>,
#  'smtplib': <module 'smtplib' from 'C:\\Users\\gmoye\\Anaconda3\\lib\\smtplib.py'>,
#  'traceback': <module 'traceback' from 'C:\\Users\\gmoye\\Anaconda3\\lib\\traceback.py'>,
#  'sa': <module 'sqlalchemy' from 'C:\\Users\\gmoye\\Anaconda3\\lib\\site-packages\\sqlalchemy\\__init__.py'>,
#  'pyodbc': <module 'pyodbc' from 'C:\\Users\\gmoye\\Anaconda3\\lib\\site-packages\\pyodbc.cp39-win_amd64.pyd'>,
#  'MIMEMultipart': email.mime.multipart.MIMEMultipart,
#  'MIMEText': email.mime.text.MIMEText,
#  'MIMEApplication': email.mime.application.MIMEApplication,
#  'basename': <function ntpath.basename(p)>,
#  'datetime': datetime.datetime,
#  'date': datetime.date,
#  'settings': <module 'settings' from 'C:\\Users\\gmoye\\settings.py'>,
#  'eh': <module 'errhandler' from 'C:\\Users\\gmoye\\errhandler.py'>,
#  'eHSQL': <module 'eHSQL' from 'C:\\Users\\gmoye\\eHSQL.py'>,
#  're': <module 're' from 'C:\\Users\\gmoye\\Anaconda3\\lib\\re.py'>,
#  'requests': <module 'requests' from 'C:\\Users\\gmoye\\Anaconda3\\lib\\site-packages\\requests\\__init__.py'>,
#  'urllib': <module 'urllib' from 'C:\\Users\\gmoye\\Anaconda3\\lib\\urllib\\__init__.py'>,
#  'itertools': <module 'itertools' (built-in)>,
#  'ConnectionError': requests.exceptions.ConnectionError,
#  'HTTPError': requests.exceptions.HTTPError,
#  'Timeout': requests.exceptions.Timeout,
#  'TooManyRedirects': requests.exceptions.TooManyRedirects,
#  'HTTPAdapter': requests.adapters.HTTPAdapter,
#  'Retry': urllib3.util.retry.Retry,
#  'HTTPBasicAuth': requests.auth.HTTPBasicAuth,
#  'json': <module 'json' from 'C:\\Users\\gmoye\\Anaconda3\\lib\\json\\__init__.py'>,
#  'html': <module 'lxml.html' from 'C:\\Users\\gmoye\\Anaconda3\\lib\\site-packages\\lxml\\html\\__init__.py'>,
#  'getData': <function __main__.getData()>,
#  '_i2': 'getData()',
#  'agent': {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36 Edg/106.0.1370.52'},
#  'session': <requests.sessions.Session at 0x1752c6e77c0>,
#  'payload': {'userId': 'gmoye01',
#   'password': 'Qmwnebrvt1!!',
#   'csrfPreventionSalt': 'JlxMB5ceNWXLUlrrSQqi'},
#  'dfLE':     LE_ID                                      erFacility
#  0   38008             Central Dakota Clinic/Charles Nyhus
#  1   38013           Valley City University Student Health
#  2   38043                  UND Center for Family Medicine
#  3   38047                                        Altru ED
#  4   38048                                     Essentia ED
#  5   38049                 Sanford Medical Center Bismarck
#  6   38050                    Sanford Medical Center Fargo
#  7   38055  St. Alexius Health Dickinson (St. Joseph’s) ED
#  8   38056                                      Trinity ED
#  9   38058          Urgent Medicine Associated/Kurt Kooyer
#  10  38061                    7-Day Clinic/Napoleon Espejo
#  11  38062                         Midgarden Family Clinic
#  12  38063                               Standing Rock IHS
#  13  38067                        Fairlight Medical Center
#  14  38070                         Wishek Community Clinic
#  15  38074      Northland Community Health Center McClusky
#  16  37075                      West River Health Services
#  17  38077    Altru Devil’s Lake Family Practice/Lim Elson
#  18  38078              Sanford Walk-in Fargo/Greg Pfennig
#  19  38079   Northland Community Health Center Turtle Lake
#  20  38080                    Towner County Medical Center
#  21  38082                       UND Student Health Center
#  22  38085               Trinity Community Clinic New Town
#  23  38086                Trinity Community Clinic Kenmare
#  24  38087          St Alexius Health Williston (Mercy) ED
#  25  38089       St Alexius Health Devil’s Lake (Mercy) ED
#  26  38090               Jamestown Regional Medical Center,
#  'auth': <requests.auth.HTTPBasicAuth at 0x1752c7046a0>,
#  'r': <Response [200]>,
#  'rnumjson': [{'erFacility': 'ND-Altru Hospital',
#    'ageCDCILI': '00-04',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 4.0},
#   {'erFacility': 'ND-Altru Hospital',
#    'ageCDCILI': '05-24',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 6.0},
#   {'erFacility': 'ND-Altru Hospital',
#    'ageCDCILI': '25-49',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 4.0},
#   {'erFacility': 'ND-Altru Hospital',
#    'ageCDCILI': '50-64',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 1.0},
#   {'erFacility': 'ND-Altru Hospital',
#    'ageCDCILI': '65+',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 0.0},
#   {'erFacility': 'ND-Altru Hospital',
#    'ageCDCILI': 'Unknown',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 0.0},
#   {'erFacility': 'ND-CHI Devils Lake Hospital',
#    'ageCDCILI': '00-04',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 2.0},
#   {'erFacility': 'ND-CHI Devils Lake Hospital',
#    'ageCDCILI': '05-24',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 0.0},
#   {'erFacility': 'ND-CHI Devils Lake Hospital',
#    'ageCDCILI': '25-49',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 0.0},
#   {'erFacility': 'ND-CHI Devils Lake Hospital',
#    'ageCDCILI': '50-64',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 0.0},
#   {'erFacility': 'ND-CHI Devils Lake Hospital',
#    'ageCDCILI': '65+',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 0.0},
#   {'erFacility': 'ND-CHI Devils Lake Hospital',
#    'ageCDCILI': 'Unknown',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 0.0},
#   {'erFacility': 'ND-CHI St. Alexius Williston',
#    'ageCDCILI': '00-04',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 2.0},
#   {'erFacility': 'ND-CHI St. Alexius Williston',
#    'ageCDCILI': '05-24',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 2.0},
#   {'erFacility': 'ND-CHI St. Alexius Williston',
#    'ageCDCILI': '25-49',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 0.0},
#   {'erFacility': 'ND-CHI St. Alexius Williston',
#    'ageCDCILI': '50-64',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 1.0},
#   {'erFacility': 'ND-CHI St. Alexius Williston',
#    'ageCDCILI': '65+',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 0.0},
#   {'erFacility': 'ND-CHI St. Alexius Williston',
#    'ageCDCILI': 'Unknown',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 0.0},
#   {'erFacility': "ND-CHI St. Joseph's Health",
#    'ageCDCILI': '00-04',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 0.0},
#   {'erFacility': "ND-CHI St. Joseph's Health",
#    'ageCDCILI': '05-24',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 0.0},
#   {'erFacility': "ND-CHI St. Joseph's Health",
#    'ageCDCILI': '25-49',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 1.0},
#   {'erFacility': "ND-CHI St. Joseph's Health",
#    'ageCDCILI': '50-64',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 0.0},
#   {'erFacility': "ND-CHI St. Joseph's Health",
#    'ageCDCILI': '65+',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 1.0},
#   {'erFacility': "ND-CHI St. Joseph's Health",
#    'ageCDCILI': 'Unknown',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 0.0},
#   {'erFacility': 'ND-Essentia Health Fargo Hospital',
#    'ageCDCILI': '00-04',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 5.0},
#   {'erFacility': 'ND-Essentia Health Fargo Hospital',
#    'ageCDCILI': '05-24',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 5.0},
#   {'erFacility': 'ND-Essentia Health Fargo Hospital',
#    'ageCDCILI': '25-49',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 1.0},
#   {'erFacility': 'ND-Essentia Health Fargo Hospital',
#    'ageCDCILI': '50-64',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 0.0},
#   {'erFacility': 'ND-Essentia Health Fargo Hospital',
#    'ageCDCILI': '65+',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 2.0},
#   {'erFacility': 'ND-Essentia Health Fargo Hospital',
#    'ageCDCILI': 'Unknown',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 0.0},
#   {'erFacility': 'ND-Jamestown Regional Medical Center',
#    'ageCDCILI': '00-04',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 1.0},
#   {'erFacility': 'ND-Jamestown Regional Medical Center',
#    'ageCDCILI': '05-24',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 2.0},
#   {'erFacility': 'ND-Jamestown Regional Medical Center',
#    'ageCDCILI': '25-49',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 1.0},
#   {'erFacility': 'ND-Jamestown Regional Medical Center',
#    'ageCDCILI': '50-64',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 1.0},
#   {'erFacility': 'ND-Jamestown Regional Medical Center',
#    'ageCDCILI': '65+',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 0.0},
#   {'erFacility': 'ND-Jamestown Regional Medical Center',
#    'ageCDCILI': 'Unknown',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 0.0},
#   {'erFacility': 'ND-Sanford Emergency Center Bismarck',
#    'ageCDCILI': '00-04',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 4.0},
#   {'erFacility': 'ND-Sanford Emergency Center Bismarck',
#    'ageCDCILI': '05-24',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 6.0},
#   {'erFacility': 'ND-Sanford Emergency Center Bismarck',
#    'ageCDCILI': '25-49',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 11.0},
#   {'erFacility': 'ND-Sanford Emergency Center Bismarck',
#    'ageCDCILI': '50-64',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 6.0},
#   {'erFacility': 'ND-Sanford Emergency Center Bismarck',
#    'ageCDCILI': '65+',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 0.0},
#   {'erFacility': 'ND-Sanford Emergency Center Bismarck',
#    'ageCDCILI': 'Unknown',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 0.0},
#   {'erFacility': 'ND-Sanford Medical Center Fargo',
#    'ageCDCILI': '00-04',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 9.0},
#   {'erFacility': 'ND-Sanford Medical Center Fargo',
#    'ageCDCILI': '05-24',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 8.0},
#   {'erFacility': 'ND-Sanford Medical Center Fargo',
#    'ageCDCILI': '25-49',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 12.0},
#   {'erFacility': 'ND-Sanford Medical Center Fargo',
#    'ageCDCILI': '50-64',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 0.0},
#   {'erFacility': 'ND-Sanford Medical Center Fargo',
#    'ageCDCILI': '65+',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 2.0},
#   {'erFacility': 'ND-Sanford Medical Center Fargo',
#    'ageCDCILI': 'Unknown',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 0.0},
#   {'erFacility': 'ND-Trinity Hospital',
#    'ageCDCILI': '00-04',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 7.0},
#   {'erFacility': 'ND-Trinity Hospital',
#    'ageCDCILI': '05-24',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 10.0},
#   {'erFacility': 'ND-Trinity Hospital',
#    'ageCDCILI': '25-49',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 8.0},
#   {'erFacility': 'ND-Trinity Hospital',
#    'ageCDCILI': '50-64',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 3.0},
#   {'erFacility': 'ND-Trinity Hospital',
#    'ageCDCILI': '65+',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 6.0},
#   {'erFacility': 'ND-Trinity Hospital',
#    'ageCDCILI': 'Unknown',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 0.0}],
#  '_i3': 'def transformation():\n    global denvarlist, numvarlist, dfdenweek, dfnumweek\n\n    dfnum = pd.DataFrame(rnumjson)\n    recnum = len(dfnum.index)\n    \n    dfnum = dfnum.sort_values(by=[\'erFacility\',\'timeResolution\',\'ageCDCILI\'], ascending = True).reset_index(drop = True)\n    \n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Central Dakota Clinic/Charles Nyhus"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Valley City University Student Health"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="UND Center for Family Medicine"\n    dfnum.loc[dfnum["erFacility"]=="ND-Essentia Health Fargo Hospital","erFacility"]="Essentia ED"\n    dfnum.loc[dfnum["erFacility"]=="ND-Altru Hospital","erFacility"]="Altru ED"\n    dfnum.loc[dfnum["erFacility"]=="ND-Sanford Emergency Center Bismarck","erFacility"]="Sanford Medical Center Bismarck"\n    dfnum.loc[dfnum["erFacility"]=="ND-Sanford Medical Center Fargo","erFacility"]="Sanford Medical Center Fargo"\n    dfnum.loc[dfnum["erFacility"]=="ND-CHI St. Joseph\'s Health","erFacility"]="St. Alexius Health Dickinson (St. Joseph’s) ED"\n    dfnum.loc[dfnum["erFacility"]=="ND-Trinity Hospital","erFacility"]="Trinity ED"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Urgent Medicine Associated/Kurt Kooyer"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="7-Day Clinic/Napoleon Espejo"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Midgarden Family Clinic"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Standing Rock IHS"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Fairlight Medical Center"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Wishek Community Clinic"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Northland Community Health Center McClusky"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="West River Health Services"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Altru Devil’s Lake Family Practice/Lim Elson"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Sanford Walk-in Fargo/Greg Pfennig"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Northland Community Health Center Turtle Lake"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Towner County Medical Center"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="UND Student Health Center"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Trinity Community Clinic New Town"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Trinity Community Clinic Kenmare"\n    dfnum.loc[dfnum["erFacility"]=="ND-CHI St. Alexius Williston","erFacility"]="St Alexius Health Williston (Mercy) ED"\n    dfnum.loc[dfnum["erFacility"]=="ND-CHI Devils Lake Hospital","erFacility"]="St Alexius Health Devil’s Lake (Mercy) ED"\n    dfnum.loc[dfnum["erFacility"]=="ND-Jamestown Regional Medical Center","erFacility"]="Jamestown Regional Medical Center"\n    \n    periodnum = dfnum[\'timeResolution\'].unique()\n    periodnum = periodnum.tolist()\n    \n    numvarlist = []\n    \n    for week in enumerate(periodnum):\n        \n        dfnumweek = dfnum.loc[dfnum[\'timeResolution\'] == week[1]]\n    \n        dfnumweek = pd.merge(dfnumweek, dfLE, how = \'left\', on = [\'erFacility\'])\n        dfnumweek = dfnumweek.drop(columns = [\'geographystate\'])\n        \n        dfnumweek[\'MMWR\'] = \'1901\'\n        \n        dfnumweek[\'From\'] = \'ILINum\'\n        \n        col = dfnumweek.pop("LE_ID")\n        dfnumweek.insert(0, \'Provider ID\', col)\n        \n        col = dfnumweek.pop("MM
#  50        38056  1901                                      Trinity ED
#  51        38056  1901                                      Trinity ED
#  52        38056  1901                                      Trinity ED
#  53        38056  1901                                      Trinity ED
#
#     ageCDCILI timeResolution  count    From
#  0      00-04        2022-45    4.0  ILINum
#  1      05-24        2022-45    6.0  ILINum
#  2      25-49        2022-45    4.0  ILINum
#  3      50-64        2022-45    1.0  ILINum
#  4        65+        2022-45    0.0  ILINum
#  5    Unknown        2022-45    0.0  ILINum
#  6      00-04        2022-45    2.0  ILINum
#  7      05-24        2022-45    0.0  ILINum
#  8      25-49        2022-45    0.0  ILINum
#  9      50-64        2022-45    0.0  ILINum
#  10       65+        2022-45    0.0  ILINum
#  11   Unknown        2022-45    0.0  ILINum
#  12     00-04        2022-45    2.0  ILINum
#  13     05-24        2022-45    2.0  ILINum
#  14     25-49        2022-45    0.0  ILINum
#  15     50-64        2022-45    1.0  ILINum
#  16       65+        2022-45    0.0  ILINum
#  17   Unknown        2022-45    0.0  ILINum
#  18     00-04        2022-45    0.0  ILINum
#  19     05-24        2022-45    0.0  ILINum
#  20     25-49        2022-45    1.0  ILINum
#  21     50-64        2022-45    0.0  ILINum
#  22       65+        2022-45    1.0  ILINum
#  23   Unknown        2022-45    0.0  ILINum
#  24     00-04        2022-45    5.0  ILINum
#  25     05-24        2022-45    5.0  ILINum
#  26     25-49        2022-45    1.0  ILINum
#  27     50-64        2022-45    0.0  ILINum
#  28       65+        2022-45    2.0  ILINum
#  29   Unknown        2022-45    0.0  ILINum
#  30     00-04        2022-45    1.0  ILINum
#  31     05-24        2022-45    2.0  ILINum
#  32     25-49        2022-45    1.0  ILINum
#  33     50-64        2022-45    1.0  ILINum
#  34       65+        2022-45    0.0  ILINum
#  35   Unknown        2022-45    0.0  ILINum
#  36     00-04        2022-45    4.0  ILINum
#  37     05-24        2022-45    6.0  ILINum
#  38     25-49        2022-45   11.0  ILINum
#  39     50-64        2022-45    6.0  ILINum
#  40       65+        2022-45    0.0  ILINum
#  41   Unknown        2022-45    0.0  ILINum
#  42     00-04        2022-45    9.0  ILINum
#  43     05-24        2022-45    8.0  ILINum
#  44     25-49        2022-45   12.0  ILINum
#  45     50-64        2022-45    0.0  ILINum
#  46       65+        2022-45    2.0  ILINum
#  47   Unknown        2022-45    0.0  ILINum
#  48     00-04        2022-45    7.0  ILINum
#  49     05-24        2022-45   10.0  ILINum
#  50     25-49        2022-45    8.0  ILINum
#  51     50-64        2022-45    3.0  ILINum
#  52       65+        2022-45    6.0  ILINum
#  53   Unknown        2022-45    0.0  ILINum  ,
#  '_i5': 'globals()'}

# %%
locals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'import sys\nimport warnings\nimport pandas as pd\nimport numpy as np\nimport os\nimport cx_Oracle as O\nimport datetime as dt\nimport logging, logging.handlers, smtplib\nimport traceback\nimport smtplib\nimport sqlalchemy as sa\nimport pyodbc\nfrom email.mime.multipart import MIMEMultipart\nfrom email.mime.text import MIMEText\nfrom email.mime.application import MIMEApplication\nfrom os.path import basename\nimport os\nfrom datetime import datetime, date\nimport settings\nimport errhandler as eh\nimport eHSQL\nimport re\nimport os\nimport requests\nimport urllib\nimport itertools\nfrom requests.exceptions import ConnectionError, HTTPError, Timeout, TooManyRedirects\nfrom requests.adapters import HTTPAdapter\nfrom requests.packages.urllib3.util.retry import Retry\nfrom requests.auth import HTTPBasicAuth\nimport json\nfrom lxml import html\n\nglobal r, rnumjson\n\n\ndef getData():\n    \n    global dfpivot, df_test, dfsol, dfnum, dfden, recnum, payload, r, rnumjson, dfLE, session, auth, agent\n    \n    agent = {\'user-agent\': \'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36 Edg/106.0.1370.52\'}\n    \n    pd.set_option(\'display.max_columns\', None)\n    pd.set_option(\'display.max_rows\', None)\n    \n    url1 = "https://essence.syndromicsurveillance.org/"\n\n    session = requests.session()\n    \n    #session = AsyncHTMLSession()\n    \n    url1result = session.get(url1, headers = agent)\n    \n    print(f\'\\n{url1result.headers}\\n\', f\'\\n{url1result.request.headers}\\n\')\n    \n    print(session.cookies.get_dict())\n    print(url1result.headers[\'Set-Cookie\'])\n    cookie = str(url1result.headers[\'Set-Cookie\'])\n    cookie = \' \' + cookie.replace(\' Path=/; Secure; HttpOnly\',\'\').replace(\';\', \'\')\n    print(cookie, \'\\n\')\n    \n    url2 = "https://essence.syndromicsurveillance.org/nssp_essence"\n    url2result = session.get(url2, headers=agent)\n    \n    print(f\'\\n{url2result.headers}\\n\', f\'\\n{url2result.request.headers}\\n\')\n    \n    print(session.cookies.get_dict())\n    print(url2result.request.headers[\'Cookie\'])\n    cookie2 = str(url2result.request.headers[\'Cookie\']).split()\n    cookie2 = cookie2[0] + \' \'\n    print(cookie2, \'\\n\')\n    \n    url3 = "https://essence.syndromicsurveillance.org/nssp_essence/servlet/Login"\n    url3result = session.get(url3, headers=agent)\n    \n    print(f\'\\n{url3result.headers}\\n\', f\'\\n{url3result.request.headers}\\n\')\n    \n    tree = html.fromstring(url3result.text)\n    authenticity_token = list(set(tree.xpath("//input[@name=\'csrfPreventionSalt\']/@value")))[0]\n    \n    print(f\'{authenticity_token}\\n\')\n    \n    payload = {"userId": "gmoye01",\n                   "password": "Qmwnebrvt1!!",\n                   "csrfPreventionSalt": f"{authenticity_token}"}\n    \n    loginpostresult = session.post(url3,\n                                    data = payload,\n                                    headers = agent,\n                                    allow_redirects = True)\n    \n    print(f\'\\n{loginpostresult.headers}\\n\', f\'\\n{loginpostresult.request.headers}\\n\')\n    \n    url4 = "https://essence.syndromicsurveillance.org/nssp_essence/j_spring_security_check"\n    url4result = session.get(url4, headers=agent)\n    \n    print(f\'\\n{url4result.headers}\\n\', f\'\\n{url4result.request.headers}\\n\')\n\n    dfLE = pd.read_csv(r\'C:\\Users\\gmoye\\LegalEntities.csv\')\n    dfLE.rename(columns={\'LE_Name\':\'erFacility\'}, inplace = True)\n\n    url5 = "https://essence.syndromicsurveillance.org/nssp_essence/servlet/TableBuilderPortletRedirectServlet?percentParam=noPercent&patientClass=e&endDate=4Aug2018&medicalGroupingSystem=essencesyndromes&userId=647&geographySystem=state&ccddCategory=ili%20ccdd%20v1&geography=nd&datasource=va_er&timeResolution=weekly&erFacility=6326&erFacility=6330&erFacility=6360&erFacility=6365&erFacility=6358&erFacility=6320&erFacility=6354& ...
#   'getData()',
#   'def transformation():\n    global denvarlist, numvarlist, dfdenweek, dfnumweek\n\n    dfnum = pd.DataFrame(rnumjson)\n    recnum = len(dfnum.index)\n    \n    dfnum = dfnum.sort_values(by=[\'erFacility\',\'timeResolution\',\'ageCDCILI\'], ascending = True).reset_index(drop = True)\n    \n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Central Dakota Clinic/Charles Nyhus"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Valley City University Student Health"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="UND Center for Family Medicine"\n    dfnum.loc[dfnum["erFacility"]=="ND-Essentia Health Fargo Hospital","erFacility"]="Essentia ED"\n    dfnum.loc[dfnum["erFacility"]=="ND-Altru Hospital","erFacility"]="Altru ED"\n    dfnum.loc[dfnum["erFacility"]=="ND-Sanford Emergency Center Bismarck","erFacility"]="Sanford Medical Center Bismarck"\n    dfnum.loc[dfnum["erFacility"]=="ND-Sanford Medical Center Fargo","erFacility"]="Sanford Medical Center Fargo"\n    dfnum.loc[dfnum["erFacility"]=="ND-CHI St. Joseph\'s Health","erFacility"]="St. Alexius Health Dickinson (St. Joseph’s) ED"\n    dfnum.loc[dfnum["erFacility"]=="ND-Trinity Hospital","erFacility"]="Trinity ED"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Urgent Medicine Associated/Kurt Kooyer"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="7-Day Clinic/Napoleon Espejo"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Midgarden Family Clinic"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Standing Rock IHS"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Fairlight Medical Center"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Wishek Community Clinic"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Northland Community Health Center McClusky"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="West River Health Services"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Altru Devil’s Lake Family Practice/Lim Elson"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Sanford Walk-in Fargo/Greg Pfennig"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Northland Community Health Center Turtle Lake"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Towner County Medical Center"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="UND Student Health Center"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Trinity Community Clinic New Town"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Trinity Community Clinic Kenmare"\n    dfnum.loc[dfnum["erFacility"]=="ND-CHI St. Alexius Williston","erFacility"]="St Alexius Health Williston (Mercy) ED"\n    dfnum.loc[dfnum["erFacility"]=="ND-CHI Devils Lake Hospital","erFacility"]="St Alexius Health Devil’s Lake (Mercy) ED"\n    dfnum.loc[dfnum["erFacility"]=="ND-Jamestown Regional Medical Center","erFacility"]="Jamestown Regional Medical Center"\n    \n    periodnum = dfnum[\'timeResolution\'].unique()\n    periodnum = periodnum.tolist()\n    \n    numvarlist = []\n    \n    for week in enumerate(periodnum):\n        \n        dfnumweek = dfnum.loc[dfnum[\'timeResolution\'] == week[1]]\n    \n        dfnumweek = pd.merge(dfnumweek, dfLE, how = \'left\', on = [\'erFacility\'])\n        dfnumweek = dfnumweek.drop(columns = [\'geographystate\'])\n        \n        dfnumweek[\'MMWR\'] = \'1901\'\n        \n        dfnumweek[\'From\'] = \'ILINum\'\n        \n        col = dfnumweek.pop("LE_ID")\n        dfnumweek.insert(0, \'Provider ID\', col)\n        \n        col = dfnumweek.pop("MMWR")\n        dfnumweek.insert(1, col.name, col)\n        \n        dfnumweek[\'ageCDCILI\'] = dfnumweek[\'ageCDCILI\'].astype(object)\n        \n        weeknum = str(week[1])\n        weeknum = weeknum.replace(\'2022-\',\'\')\n        \n        print(weeknum)\n        \n        numvarlist.append(\'dfnumweek\' + weeknum)\n        \n        globals()[\'dfnumweek%s\' % weeknum] = dfnumweek\n        \n        #display(dfnumweek)\n        \n    numvarlist = [item.strip("\'") for item ...
#   'transformation()',
#   'globals()',
#   'locals()'],
#  '_oh': {5: {...}},
#  '_dh': [WindowsPath('C:/Users/gmoye')],
#  'In': ['',
#   'import sys\nimport warnings\nimport pandas as pd\nimport numpy as np\nimport os\nimport cx_Oracle as O\nimport datetime as dt\nimport logging, logging.handlers, smtplib\nimport traceback\nimport smtplib\nimport sqlalchemy as sa\nimport pyodbc\nfrom email.mime.multipart import MIMEMultipart\nfrom email.mime.text import MIMEText\nfrom email.mime.application import MIMEApplication\nfrom os.path import basename\nimport os\nfrom datetime import datetime, date\nimport settings\nimport errhandler as eh\nimport eHSQL\nimport re\nimport os\nimport requests\nimport urllib\nimport itertools\nfrom requests.exceptions import ConnectionError, HTTPError, Timeout, TooManyRedirects\nfrom requests.adapters import HTTPAdapter\nfrom requests.packages.urllib3.util.retry import Retry\nfrom requests.auth import HTTPBasicAuth\nimport json\nfrom lxml import html\n\nglobal r, rnumjson\n\n\ndef getData():\n    \n    global dfpivot, df_test, dfsol, dfnum, dfden, recnum, payload, r, rnumjson, dfLE, session, auth, agent\n    \n    agent = {\'user-agent\': \'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36 Edg/106.0.1370.52\'}\n    \n    pd.set_option(\'display.max_columns\', None)\n    pd.set_option(\'display.max_rows\', None)\n    \n    url1 = "https://essence.syndromicsurveillance.org/"\n\n    session = requests.session()\n    \n    #session = AsyncHTMLSession()\n    \n    url1result = session.get(url1, headers = agent)\n    \n    print(f\'\\n{url1result.headers}\\n\', f\'\\n{url1result.request.headers}\\n\')\n    \n    print(session.cookies.get_dict())\n    print(url1result.headers[\'Set-Cookie\'])\n    cookie = str(url1result.headers[\'Set-Cookie\'])\n    cookie = \' \' + cookie.replace(\' Path=/; Secure; HttpOnly\',\'\').replace(\';\', \'\')\n    print(cookie, \'\\n\')\n    \n    url2 = "https://essence.syndromicsurveillance.org/nssp_essence"\n    url2result = session.get(url2, headers=agent)\n    \n    print(f\'\\n{url2result.headers}\\n\', f\'\\n{url2result.request.headers}\\n\')\n    \n    print(session.cookies.get_dict())\n    print(url2result.request.headers[\'Cookie\'])\n    cookie2 = str(url2result.request.headers[\'Cookie\']).split()\n    cookie2 = cookie2[0] + \' \'\n    print(cookie2, \'\\n\')\n    \n    url3 = "https://essence.syndromicsurveillance.org/nssp_essence/servlet/Login"\n    url3result = session.get(url3, headers=agent)\n    \n    print(f\'\\n{url3result.headers}\\n\', f\'\\n{url3result.request.headers}\\n\')\n    \n    tree = html.fromstring(url3result.text)\n    authenticity_token = list(set(tree.xpath("//input[@name=\'csrfPreventionSalt\']/@value")))[0]\n    \n    print(f\'{authenticity_token}\\n\')\n    \n    payload = {"userId": "gmoye01",\n                   "password": "Qmwnebrvt1!!",\n                   "csrfPreventionSalt": f"{authenticity_token}"}\n    \n    loginpostresult = session.post(url3,\n                                    data = payload,\n                                    headers = agent,\n                                    allow_redirects = True)\n    \n    print(f\'\\n{loginpostresult.headers}\\n\', f\'\\n{loginpostresult.request.headers}\\n\')\n    \n    url4 = "https://essence.syndromicsurveillance.org/nssp_essence/j_spring_security_check"\n    url4result = session.get(url4, headers=agent)\n    \n    print(f\'\\n{url4result.headers}\\n\', f\'\\n{url4result.request.headers}\\n\')\n\n    dfLE = pd.read_csv(r\'C:\\Users\\gmoye\\LegalEntities.csv\')\n    dfLE.rename(columns={\'LE_Name\':\'erFacility\'}, inplace = True)\n\n    url5 = "https://essence.syndromicsurveillance.org/nssp_essence/servlet/TableBuilderPortletRedirectServlet?percentParam=noPercent&patientClass=e&endDate=4Aug2018&medicalGroupingSystem=essencesyndromes&userId=647&geographySystem=state&ccddCategory=ili%20ccdd%20v1&geography=nd&datasource=va_er&timeResolution=weekly&erFacility=6326&erFacility=6330&erFacility=6360&erFacility=6365&erFacility=6358&erFacility=6320&erFacility=6354& ...
#   'getData()',
#   'def transformation():\n    global denvarlist, numvarlist, dfdenweek, dfnumweek\n\n    dfnum = pd.DataFrame(rnumjson)\n    recnum = len(dfnum.index)\n    \n    dfnum = dfnum.sort_values(by=[\'erFacility\',\'timeResolution\',\'ageCDCILI\'], ascending = True).reset_index(drop = True)\n    \n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Central Dakota Clinic/Charles Nyhus"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Valley City University Student Health"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="UND Center for Family Medicine"\n    dfnum.loc[dfnum["erFacility"]=="ND-Essentia Health Fargo Hospital","erFacility"]="Essentia ED"\n    dfnum.loc[dfnum["erFacility"]=="ND-Altru Hospital","erFacility"]="Altru ED"\n    dfnum.loc[dfnum["erFacility"]=="ND-Sanford Emergency Center Bismarck","erFacility"]="Sanford Medical Center Bismarck"\n    dfnum.loc[dfnum["erFacility"]=="ND-Sanford Medical Center Fargo","erFacility"]="Sanford Medical Center Fargo"\n    dfnum.loc[dfnum["erFacility"]=="ND-CHI St. Joseph\'s Health","erFacility"]="St. Alexius Health Dickinson (St. Joseph’s) ED"\n    dfnum.loc[dfnum["erFacility"]=="ND-Trinity Hospital","erFacility"]="Trinity ED"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Urgent Medicine Associated/Kurt Kooyer"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="7-Day Clinic/Napoleon Espejo"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Midgarden Family Clinic"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Standing Rock IHS"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Fairlight Medical Center"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Wishek Community Clinic"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Northland Community Health Center McClusky"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="West River Health Services"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Altru Devil’s Lake Family Practice/Lim Elson"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Sanford Walk-in Fargo/Greg Pfennig"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Northland Community Health Center Turtle Lake"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Towner County Medical Center"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="UND Student Health Center"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Trinity Community Clinic New Town"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Trinity Community Clinic Kenmare"\n    dfnum.loc[dfnum["erFacility"]=="ND-CHI St. Alexius Williston","erFacility"]="St Alexius Health Williston (Mercy) ED"\n    dfnum.loc[dfnum["erFacility"]=="ND-CHI Devils Lake Hospital","erFacility"]="St Alexius Health Devil’s Lake (Mercy) ED"\n    dfnum.loc[dfnum["erFacility"]=="ND-Jamestown Regional Medical Center","erFacility"]="Jamestown Regional Medical Center"\n    \n    periodnum = dfnum[\'timeResolution\'].unique()\n    periodnum = periodnum.tolist()\n    \n    numvarlist = []\n    \n    for week in enumerate(periodnum):\n        \n        dfnumweek = dfnum.loc[dfnum[\'timeResolution\'] == week[1]]\n    \n        dfnumweek = pd.merge(dfnumweek, dfLE, how = \'left\', on = [\'erFacility\'])\n        dfnumweek = dfnumweek.drop(columns = [\'geographystate\'])\n        \n        dfnumweek[\'MMWR\'] = \'1901\'\n        \n        dfnumweek[\'From\'] = \'ILINum\'\n        \n        col = dfnumweek.pop("LE_ID")\n        dfnumweek.insert(0, \'Provider ID\', col)\n        \n        col = dfnumweek.pop("MMWR")\n        dfnumweek.insert(1, col.name, col)\n        \n        dfnumweek[\'ageCDCILI\'] = dfnumweek[\'ageCDCILI\'].astype(object)\n        \n        weeknum = str(week[1])\n        weeknum = weeknum.replace(\'2022-\',\'\')\n        \n        print(weeknum)\n        \n        numvarlist.append(\'dfnumweek\' + weeknum)\n        \n        globals()[\'dfnumweek%s\' % weeknum] = dfnumweek\n        \n        #display(dfnumweek)\n        \n    numvarlist = [item.strip("\'") for item ...
#   'transformation()',
#   'globals()',
#   'locals()'],
#  'Out': {5: {...}},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x000001752C6614F0>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x1752c60a040>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x1752c60a040>,
#  '_': {...},
#  '__': '',
#  '___': '',
#  '_i': 'globals()',
#  '_ii': 'transformation()',
#  '_iii': 'def transformation():\n    global denvarlist, numvarlist, dfdenweek, dfnumweek\n\n    dfnum = pd.DataFrame(rnumjson)\n    recnum = len(dfnum.index)\n    \n    dfnum = dfnum.sort_values(by=[\'erFacility\',\'timeResolution\',\'ageCDCILI\'], ascending = True).reset_index(drop = True)\n    \n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Central Dakota Clinic/Charles Nyhus"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Valley City University Student Health"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="UND Center for Family Medicine"\n    dfnum.loc[dfnum["erFacility"]=="ND-Essentia Health Fargo Hospital","erFacility"]="Essentia ED"\n    dfnum.loc[dfnum["erFacility"]=="ND-Altru Hospital","erFacility"]="Altru ED"\n    dfnum.loc[dfnum["erFacility"]=="ND-Sanford Emergency Center Bismarck","erFacility"]="Sanford Medical Center Bismarck"\n    dfnum.loc[dfnum["erFacility"]=="ND-Sanford Medical Center Fargo","erFacility"]="Sanford Medical Center Fargo"\n    dfnum.loc[dfnum["erFacility"]=="ND-CHI St. Joseph\'s Health","erFacility"]="St. Alexius Health Dickinson (St. Joseph’s) ED"\n    dfnum.loc[dfnum["erFacility"]=="ND-Trinity Hospital","erFacility"]="Trinity ED"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Urgent Medicine Associated/Kurt Kooyer"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="7-Day Clinic/Napoleon Espejo"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Midgarden Family Clinic"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Standing Rock IHS"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Fairlight Medical Center"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Wishek Community Clinic"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Northland Community Health Center McClusky"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="West River Health Services"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Altru Devil’s Lake Family Practice/Lim Elson"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Sanford Walk-in Fargo/Greg Pfennig"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Northland Community Health Center Turtle Lake"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Towner County Medical Center"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="UND Student Health Center"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Trinity Community Clinic New Town"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Trinity Community Clinic Kenmare"\n    dfnum.loc[dfnum["erFacility"]=="ND-CHI St. Alexius Williston","erFacility"]="St Alexius Health Williston (Mercy) ED"\n    dfnum.loc[dfnum["erFacility"]=="ND-CHI Devils Lake Hospital","erFacility"]="St Alexius Health Devil’s Lake (Mercy) ED"\n    dfnum.loc[dfnum["erFacility"]=="ND-Jamestown Regional Medical Center","erFacility"]="Jamestown Regional Medical Center"\n    \n    periodnum = dfnum[\'timeResolution\'].unique()\n    periodnum = periodnum.tolist()\n    \n    numvarlist = []\n    \n    for week in enumerate(periodnum):\n        \n        dfnumweek = dfnum.loc[dfnum[\'timeResolution\'] == week[1]]\n    \n        dfnumweek = pd.merge(dfnumweek, dfLE, how = \'left\', on = [\'erFacility\'])\n        dfnumweek = dfnumweek.drop(columns = [\'geographystate\'])\n        \n        dfnumweek[\'MMWR\'] = \'1901\'\n        \n        dfnumweek[\'From\'] = \'ILINum\'\n        \n        col = dfnumweek.pop("LE_ID")\n        dfnumweek.insert(0, \'Provider ID\', col)\n        \n        col = dfnumweek.pop("MMWR")\n        dfnumweek.insert(1, col.name, col)\n        \n        dfnumweek[\'ageCDCILI\'] = dfnumweek[\'ageCDCILI\'].astype(object)\n        \n        weeknum = str(week[1])\n        weeknum = weeknum.replace(\'2022-\',\'\')\n        \n        print(weeknum)\n        \n        numvarlist.append(\'dfnumweek\' + weeknum)\n        \n        globals()[\'dfnumweek%s\' % weeknum] = dfnumweek\n        \n        #display(dfnumweek)\n        \n    numvarlist = [item.strip("\'") f ...
#  '_i1': 'import sys\nimport warnings\nimport pandas as pd\nimport numpy as np\nimport os\nimport cx_Oracle as O\nimport datetime as dt\nimport logging, logging.handlers, smtplib\nimport traceback\nimport smtplib\nimport sqlalchemy as sa\nimport pyodbc\nfrom email.mime.multipart import MIMEMultipart\nfrom email.mime.text import MIMEText\nfrom email.mime.application import MIMEApplication\nfrom os.path import basename\nimport os\nfrom datetime import datetime, date\nimport settings\nimport errhandler as eh\nimport eHSQL\nimport re\nimport os\nimport requests\nimport urllib\nimport itertools\nfrom requests.exceptions import ConnectionError, HTTPError, Timeout, TooManyRedirects\nfrom requests.adapters import HTTPAdapter\nfrom requests.packages.urllib3.util.retry import Retry\nfrom requests.auth import HTTPBasicAuth\nimport json\nfrom lxml import html\n\nglobal r, rnumjson\n\n\ndef getData():\n    \n    global dfpivot, df_test, dfsol, dfnum, dfden, recnum, payload, r, rnumjson, dfLE, session, auth, agent\n    \n    agent = {\'user-agent\': \'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36 Edg/106.0.1370.52\'}\n    \n    pd.set_option(\'display.max_columns\', None)\n    pd.set_option(\'display.max_rows\', None)\n    \n    url1 = "https://essence.syndromicsurveillance.org/"\n\n    session = requests.session()\n    \n    #session = AsyncHTMLSession()\n    \n    url1result = session.get(url1, headers = agent)\n    \n    print(f\'\\n{url1result.headers}\\n\', f\'\\n{url1result.request.headers}\\n\')\n    \n    print(session.cookies.get_dict())\n    print(url1result.headers[\'Set-Cookie\'])\n    cookie = str(url1result.headers[\'Set-Cookie\'])\n    cookie = \' \' + cookie.replace(\' Path=/; Secure; HttpOnly\',\'\').replace(\';\', \'\')\n    print(cookie, \'\\n\')\n    \n    url2 = "https://essence.syndromicsurveillance.org/nssp_essence"\n    url2result = session.get(url2, headers=agent)\n    \n    print(f\'\\n{url2result.headers}\\n\', f\'\\n{url2result.request.headers}\\n\')\n    \n    print(session.cookies.get_dict())\n    print(url2result.request.headers[\'Cookie\'])\n    cookie2 = str(url2result.request.headers[\'Cookie\']).split()\n    cookie2 = cookie2[0] + \' \'\n    print(cookie2, \'\\n\')\n    \n    url3 = "https://essence.syndromicsurveillance.org/nssp_essence/servlet/Login"\n    url3result = session.get(url3, headers=agent)\n    \n    print(f\'\\n{url3result.headers}\\n\', f\'\\n{url3result.request.headers}\\n\')\n    \n    tree = html.fromstring(url3result.text)\n    authenticity_token = list(set(tree.xpath("//input[@name=\'csrfPreventionSalt\']/@value")))[0]\n    \n    print(f\'{authenticity_token}\\n\')\n    \n    payload = {"userId": "gmoye01",\n                   "password": "Qmwnebrvt1!!",\n                   "csrfPreventionSalt": f"{authenticity_token}"}\n    \n    loginpostresult = session.post(url3,\n                                    data = payload,\n                                    headers = agent,\n                                    allow_redirects = True)\n    \n    print(f\'\\n{loginpostresult.headers}\\n\', f\'\\n{loginpostresult.request.headers}\\n\')\n    \n    url4 = "https://essence.syndromicsurveillance.org/nssp_essence/j_spring_security_check"\n    url4result = session.get(url4, headers=agent)\n    \n    print(f\'\\n{url4result.headers}\\n\', f\'\\n{url4result.request.headers}\\n\')\n\n    dfLE = pd.read_csv(r\'C:\\Users\\gmoye\\LegalEntities.csv\')\n    dfLE.rename(columns={\'LE_Name\':\'erFacility\'}, inplace = True)\n\n    url5 = "https://essence.syndromicsurveillance.org/nssp_essence/servlet/TableBuilderPortletRedirectServlet?percentParam=noPercent&patientClass=e&endDate=4Aug2018&medicalGroupingSystem=essencesyndromes&userId=647&geographySystem=state&ccddCategory=ili%20ccdd%20v1&geography=nd&datasource=va_er&timeResolution=weekly&erFacility=6326&erFacility=6330&erFacility=6360&erFacility=6365&erFacility=6358&erFacility=6320&erFacility ...
#  'sys': <module 'sys' (built-in)>,
#  'warnings': <module 'warnings' from 'C:\\Users\\gmoye\\Anaconda3\\lib\\warnings.py'>,
#  'pd': <module 'pandas' from 'C:\\Users\\gmoye\\Anaconda3\\lib\\site-packages\\pandas\\__init__.py'>,
#  'np': <module 'numpy' from 'C:\\Users\\gmoye\\Anaconda3\\lib\\site-packages\\numpy\\__init__.py'>,
#  'os': <module 'os' from 'C:\\Users\\gmoye\\Anaconda3\\lib\\os.py'>,
#  'O': <module 'cx_Oracle' from 'C:\\Users\\gmoye\\Anaconda3\\lib\\site-packages\\cx_Oracle.cp39-win_amd64.pyd'>,
#  'dt': <module 'datetime' from 'C:\\Users\\gmoye\\Anaconda3\\lib\\datetime.py'>,
#  'logging': <module 'logging' from 'C:\\Users\\gmoye\\Anaconda3\\lib\\logging\\__init__.py'>,
#  'smtplib': <module 'smtplib' from 'C:\\Users\\gmoye\\Anaconda3\\lib\\smtplib.py'>,
#  'traceback': <module 'traceback' from 'C:\\Users\\gmoye\\Anaconda3\\lib\\traceback.py'>,
#  'sa': <module 'sqlalchemy' from 'C:\\Users\\gmoye\\Anaconda3\\lib\\site-packages\\sqlalchemy\\__init__.py'>,
#  'pyodbc': <module 'pyodbc' from 'C:\\Users\\gmoye\\Anaconda3\\lib\\site-packages\\pyodbc.cp39-win_amd64.pyd'>,
#  'MIMEMultipart': email.mime.multipart.MIMEMultipart,
#  'MIMEText': email.mime.text.MIMEText,
#  'MIMEApplication': email.mime.application.MIMEApplication,
#  'basename': <function ntpath.basename(p)>,
#  'datetime': datetime.datetime,
#  'date': datetime.date,
#  'settings': <module 'settings' from 'C:\\Users\\gmoye\\settings.py'>,
#  'eh': <module 'errhandler' from 'C:\\Users\\gmoye\\errhandler.py'>,
#  'eHSQL': <module 'eHSQL' from 'C:\\Users\\gmoye\\eHSQL.py'>,
#  're': <module 're' from 'C:\\Users\\gmoye\\Anaconda3\\lib\\re.py'>,
#  'requests': <module 'requests' from 'C:\\Users\\gmoye\\Anaconda3\\lib\\site-packages\\requests\\__init__.py'>,
#  'urllib': <module 'urllib' from 'C:\\Users\\gmoye\\Anaconda3\\lib\\urllib\\__init__.py'>,
#  'itertools': <module 'itertools' (built-in)>,
#  'ConnectionError': requests.exceptions.ConnectionError,
#  'HTTPError': requests.exceptions.HTTPError,
#  'Timeout': requests.exceptions.Timeout,
#  'TooManyRedirects': requests.exceptions.TooManyRedirects,
#  'HTTPAdapter': requests.adapters.HTTPAdapter,
#  'Retry': urllib3.util.retry.Retry,
#  'HTTPBasicAuth': requests.auth.HTTPBasicAuth,
#  'json': <module 'json' from 'C:\\Users\\gmoye\\Anaconda3\\lib\\json\\__init__.py'>,
#  'html': <module 'lxml.html' from 'C:\\Users\\gmoye\\Anaconda3\\lib\\site-packages\\lxml\\html\\__init__.py'>,
#  'getData': <function __main__.getData()>,
#  '_i2': 'getData()',
#  'agent': {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36 Edg/106.0.1370.52'},
#  'session': <requests.sessions.Session at 0x1752c6e77c0>,
#  'payload': {'userId': 'gmoye01',
#   'password': 'Qmwnebrvt1!!',
#   'csrfPreventionSalt': 'JlxMB5ceNWXLUlrrSQqi'},
#  'dfLE':     LE_ID                                      erFacility
#  0   38008             Central Dakota Clinic/Charles Nyhus
#  1   38013           Valley City University Student Health
#  2   38043                  UND Center for Family Medicine
#  3   38047                                        Altru ED
#  4   38048                                     Essentia ED
#  5   38049                 Sanford Medical Center Bismarck
#  6   38050                    Sanford Medical Center Fargo
#  7   38055  St. Alexius Health Dickinson (St. Joseph’s) ED
#  8   38056                                      Trinity ED
#  9   38058          Urgent Medicine Associated/Kurt Kooyer
#  10  38061                    7-Day Clinic/Napoleon Espejo
#  11  38062                         Midgarden Family Clinic
#  12  38063                               Standing Rock IHS
#  13  38067                        Fairlight Medical Center
#  14  38070                         Wishek Community Clinic
#  15  38074      Northland Community Health Center McClusky
#  16  37075                      West River Health Services
#  17  38077    Altru Devil’s Lake Family Practice/Lim Elson
#  18  38078              Sanford Walk-in Fargo/Greg Pfennig
#  19  38079   Northland Community Health Center Turtle Lake
#  20  38080                    Towner County Medical Center
#  21  38082                       UND Student Health Center
#  22  38085               Trinity Community Clinic New Town
#  23  38086                Trinity Community Clinic Kenmare
#  24  38087          St Alexius Health Williston (Mercy) ED
#  25  38089       St Alexius Health Devil’s Lake (Mercy) ED
#  26  38090               Jamestown Regional Medical Center,
#  'auth': <requests.auth.HTTPBasicAuth at 0x1752c7046a0>,
#  'r': <Response [200]>,
#  'rnumjson': [{'erFacility': 'ND-Altru Hospital',
#    'ageCDCILI': '00-04',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 4.0},
#   {'erFacility': 'ND-Altru Hospital',
#    'ageCDCILI': '05-24',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 6.0},
#   {'erFacility': 'ND-Altru Hospital',
#    'ageCDCILI': '25-49',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 4.0},
#   {'erFacility': 'ND-Altru Hospital',
#    'ageCDCILI': '50-64',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 1.0},
#   {'erFacility': 'ND-Altru Hospital',
#    'ageCDCILI': '65+',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 0.0},
#   {'erFacility': 'ND-Altru Hospital',
#    'ageCDCILI': 'Unknown',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 0.0},
#   {'erFacility': 'ND-CHI Devils Lake Hospital',
#    'ageCDCILI': '00-04',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 2.0},
#   {'erFacility': 'ND-CHI Devils Lake Hospital',
#    'ageCDCILI': '05-24',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 0.0},
#   {'erFacility': 'ND-CHI Devils Lake Hospital',
#    'ageCDCILI': '25-49',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 0.0},
#   {'erFacility': 'ND-CHI Devils Lake Hospital',
#    'ageCDCILI': '50-64',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 0.0},
#   {'erFacility': 'ND-CHI Devils Lake Hospital',
#    'ageCDCILI': '65+',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 0.0},
#   {'erFacility': 'ND-CHI Devils Lake Hospital',
#    'ageCDCILI': 'Unknown',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 0.0},
#   {'erFacility': 'ND-CHI St. Alexius Williston',
#    'ageCDCILI': '00-04',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 2.0},
#   {'erFacility': 'ND-CHI St. Alexius Williston',
#    'ageCDCILI': '05-24',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 2.0},
#   {'erFacility': 'ND-CHI St. Alexius Williston',
#    'ageCDCILI': '25-49',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 0.0},
#   {'erFacility': 'ND-CHI St. Alexius Williston',
#    'ageCDCILI': '50-64',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 1.0},
#   {'erFacility': 'ND-CHI St. Alexius Williston',
#    'ageCDCILI': '65+',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 0.0},
#   {'erFacility': 'ND-CHI St. Alexius Williston',
#    'ageCDCILI': 'Unknown',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 0.0},
#   {'erFacility': "ND-CHI St. Joseph's Health",
#    'ageCDCILI': '00-04',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 0.0},
#   {'erFacility': "ND-CHI St. Joseph's Health",
#    'ageCDCILI': '05-24',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 0.0},
#   {'erFacility': "ND-CHI St. Joseph's Health",
#    'ageCDCILI': '25-49',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 1.0},
#   {'erFacility': "ND-CHI St. Joseph's Health",
#    'ageCDCILI': '50-64',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 0.0},
#   {'erFacility': "ND-CHI St. Joseph's Health",
#    'ageCDCILI': '65+',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 1.0},
#   {'erFacility': "ND-CHI St. Joseph's Health",
#    'ageCDCILI': 'Unknown',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 0.0},
#   {'erFacility': 'ND-Essentia Health Fargo Hospital',
#    'ageCDCILI': '00-04',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 5.0},
#   {'erFacility': 'ND-Essentia Health Fargo Hospital',
#    'ageCDCILI': '05-24',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 5.0},
#   {'erFacility': 'ND-Essentia Health Fargo Hospital',
#    'ageCDCILI': '25-49',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 1.0},
#   {'erFacility': 'ND-Essentia Health Fargo Hospital',
#    'ageCDCILI': '50-64',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 0.0},
#   {'erFacility': 'ND-Essentia Health Fargo Hospital',
#    'ageCDCILI': '65+',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 2.0},
#   {'erFacility': 'ND-Essentia Health Fargo Hospital',
#    'ageCDCILI': 'Unknown',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 0.0},
#   {'erFacility': 'ND-Jamestown Regional Medical Center',
#    'ageCDCILI': '00-04',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 1.0},
#   {'erFacility': 'ND-Jamestown Regional Medical Center',
#    'ageCDCILI': '05-24',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 2.0},
#   {'erFacility': 'ND-Jamestown Regional Medical Center',
#    'ageCDCILI': '25-49',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 1.0},
#   {'erFacility': 'ND-Jamestown Regional Medical Center',
#    'ageCDCILI': '50-64',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 1.0},
#   {'erFacility': 'ND-Jamestown Regional Medical Center',
#    'ageCDCILI': '65+',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 0.0},
#   {'erFacility': 'ND-Jamestown Regional Medical Center',
#    'ageCDCILI': 'Unknown',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 0.0},
#   {'erFacility': 'ND-Sanford Emergency Center Bismarck',
#    'ageCDCILI': '00-04',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 4.0},
#   {'erFacility': 'ND-Sanford Emergency Center Bismarck',
#    'ageCDCILI': '05-24',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 6.0},
#   {'erFacility': 'ND-Sanford Emergency Center Bismarck',
#    'ageCDCILI': '25-49',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 11.0},
#   {'erFacility': 'ND-Sanford Emergency Center Bismarck',
#    'ageCDCILI': '50-64',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 6.0},
#   {'erFacility': 'ND-Sanford Emergency Center Bismarck',
#    'ageCDCILI': '65+',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 0.0},
#   {'erFacility': 'ND-Sanford Emergency Center Bismarck',
#    'ageCDCILI': 'Unknown',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 0.0},
#   {'erFacility': 'ND-Sanford Medical Center Fargo',
#    'ageCDCILI': '00-04',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 9.0},
#   {'erFacility': 'ND-Sanford Medical Center Fargo',
#    'ageCDCILI': '05-24',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 8.0},
#   {'erFacility': 'ND-Sanford Medical Center Fargo',
#    'ageCDCILI': '25-49',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 12.0},
#   {'erFacility': 'ND-Sanford Medical Center Fargo',
#    'ageCDCILI': '50-64',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 0.0},
#   {'erFacility': 'ND-Sanford Medical Center Fargo',
#    'ageCDCILI': '65+',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 2.0},
#   {'erFacility': 'ND-Sanford Medical Center Fargo',
#    'ageCDCILI': 'Unknown',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 0.0},
#   {'erFacility': 'ND-Trinity Hospital',
#    'ageCDCILI': '00-04',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 7.0},
#   {'erFacility': 'ND-Trinity Hospital',
#    'ageCDCILI': '05-24',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 10.0},
#   {'erFacility': 'ND-Trinity Hospital',
#    'ageCDCILI': '25-49',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 8.0},
#   {'erFacility': 'ND-Trinity Hospital',
#    'ageCDCILI': '50-64',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 3.0},
#   {'erFacility': 'ND-Trinity Hospital',
#    'ageCDCILI': '65+',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 6.0},
#   {'erFacility': 'ND-Trinity Hospital',
#    'ageCDCILI': 'Unknown',
#    'timeResolution': '2022-45',
#    'geographystate': 'North Dakota',
#    'count': 0.0}],
#  '_i3': 'def transformation():\n    global denvarlist, numvarlist, dfdenweek, dfnumweek\n\n    dfnum = pd.DataFrame(rnumjson)\n    recnum = len(dfnum.index)\n    \n    dfnum = dfnum.sort_values(by=[\'erFacility\',\'timeResolution\',\'ageCDCILI\'], ascending = True).reset_index(drop = True)\n    \n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Central Dakota Clinic/Charles Nyhus"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Valley City University Student Health"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="UND Center for Family Medicine"\n    dfnum.loc[dfnum["erFacility"]=="ND-Essentia Health Fargo Hospital","erFacility"]="Essentia ED"\n    dfnum.loc[dfnum["erFacility"]=="ND-Altru Hospital","erFacility"]="Altru ED"\n    dfnum.loc[dfnum["erFacility"]=="ND-Sanford Emergency Center Bismarck","erFacility"]="Sanford Medical Center Bismarck"\n    dfnum.loc[dfnum["erFacility"]=="ND-Sanford Medical Center Fargo","erFacility"]="Sanford Medical Center Fargo"\n    dfnum.loc[dfnum["erFacility"]=="ND-CHI St. Joseph\'s Health","erFacility"]="St. Alexius Health Dickinson (St. Joseph’s) ED"\n    dfnum.loc[dfnum["erFacility"]=="ND-Trinity Hospital","erFacility"]="Trinity ED"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Urgent Medicine Associated/Kurt Kooyer"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="7-Day Clinic/Napoleon Espejo"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Midgarden Family Clinic"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Standing Rock IHS"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Fairlight Medical Center"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Wishek Community Clinic"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Northland Community Health Center McClusky"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="West River Health Services"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Altru Devil’s Lake Family Practice/Lim Elson"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Sanford Walk-in Fargo/Greg Pfennig"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Northland Community Health Center Turtle Lake"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Towner County Medical Center"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="UND Student Health Center"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Trinity Community Clinic New Town"\n    dfnum.loc[dfnum["erFacility"]=="","erFacility"]="Trinity Community Clinic Kenmare"\n    dfnum.loc[dfnum["erFacility"]=="ND-CHI St. Alexius Williston","erFacility"]="St Alexius Health Williston (Mercy) ED"\n    dfnum.loc[dfnum["erFacility"]=="ND-CHI Devils Lake Hospital","erFacility"]="St Alexius Health Devil’s Lake (Mercy) ED"\n    dfnum.loc[dfnum["erFacility"]=="ND-Jamestown Regional Medical Center","erFacility"]="Jamestown Regional Medical Center"\n    \n    periodnum = dfnum[\'timeResolution\'].unique()\n    periodnum = periodnum.tolist()\n    \n    numvarlist = []\n    \n    for week in enumerate(periodnum):\n        \n        dfnumweek = dfnum.loc[dfnum[\'timeResolution\'] == week[1]]\n    \n        dfnumweek = pd.merge(dfnumweek, dfLE, how = \'left\', on = [\'erFacility\'])\n        dfnumweek = dfnumweek.drop(columns = [\'geographystate\'])\n        \n        dfnumweek[\'MMWR\'] = \'1901\'\n        \n        dfnumweek[\'From\'] = \'ILINum\'\n        \n        col = dfnumweek.pop("LE_ID")\n        dfnumweek.insert(0, \'Provider ID\', col)\n        \n        col = dfnumweek.pop("MMWR")\n        dfnumweek.insert(1, col.name, col)\n        \n        dfnumweek[\'ageCDCILI\'] = dfnumweek[\'ageCDCILI\'].astype(object)\n        \n        weeknum = str(week[1])\n        weeknum = weeknum.replace(\'2022-\',\'\')\n        \n        print(weeknum)\n        \n        numvarlist.append(\'dfnumweek\' + weeknum)\n        \n        globals()[\'dfnumweek%s\' % weeknum] = dfnumweek\n        \n        #display(dfnumweek)\n        \n    numvarlist = [item.strip("\'") fo ...
#  6      00-04        2022-45    2.0  ILINum
#  7      05-24        2022-45    0.0  ILINum
#  8      25-49        2022-45    0.0  ILINum
#  9      50-64        2022-45    0.0  ILINum
#  10       65+        2022-45    0.0  ILINum
#  11   Unknown        2022-45    0.0  ILINum
#  12     00-04        2022-45    2.0  ILINum
#  13     05-24        2022-45    2.0  ILINum
#  14     25-49        2022-45    0.0  ILINum
#  15     50-64        2022-45    1.0  ILINum
#  16       65+        2022-45    0.0  ILINum
#  17   Unknown        2022-45    0.0  ILINum
#  18     00-04        2022-45    0.0  ILINum
#  19     05-24        2022-45    0.0  ILINum
#  20     25-49        2022-45    1.0  ILINum
#  21     50-64        2022-45    0.0  ILINum
#  22       65+        2022-45    1.0  ILINum
#  23   Unknown        2022-45    0.0  ILINum
#  24     00-04        2022-45    5.0  ILINum
#  25     05-24        2022-45    5.0  ILINum
#  26     25-49        2022-45    1.0  ILINum
#  27     50-64        2022-45    0.0  ILINum
#  28       65+        2022-45    2.0  ILINum
#  29   Unknown        2022-45    0.0  ILINum
#  30     00-04        2022-45    1.0  ILINum
#  31     05-24        2022-45    2.0  ILINum
#  32     25-49        2022-45    1.0  ILINum
#  33     50-64        2022-45    1.0  ILINum
#  34       65+        2022-45    0.0  ILINum
#  35   Unknown        2022-45    0.0  ILINum
#  36     00-04        2022-45    4.0  ILINum
#  37     05-24        2022-45    6.0  ILINum
#  38     25-49        2022-45   11.0  ILINum
#  39     50-64        2022-45    6.0  ILINum
#  40       65+        2022-45    0.0  ILINum
#  41   Unknown        2022-45    0.0  ILINum
#  42     00-04        2022-45    9.0  ILINum
#  43     05-24        2022-45    8.0  ILINum
#  44     25-49        2022-45   12.0  ILINum
#  45     50-64        2022-45    0.0  ILINum
#  46       65+        2022-45    2.0  ILINum
#  47   Unknown        2022-45    0.0  ILINum
#  48     00-04        2022-45    7.0  ILINum
#  49     05-24        2022-45   10.0  ILINum
#  50     25-49        2022-45    8.0  ILINum
#  51     50-64        2022-45    3.0  ILINum
#  52       65+        2022-45    6.0  ILINum
#  53   Unknown        2022-45    0.0  ILINum  ,
#  '_i5': 'globals()',
#  '_5': {...},
#  '_i6': 'locals()'}

# %%
# %whos
# Out:
# Variable           Type             Data/Info
# ---------------------------------------------
# ConnectionError    type             <class 'requests.exceptions.ConnectionError'>
# HTTPAdapter        type             <class 'requests.adapters.HTTPAdapter'>
# HTTPBasicAuth      type             <class 'requests.auth.HTTPBasicAuth'>
# HTTPError          type             <class 'requests.exceptions.HTTPError'>
# MIMEApplication    type             <class 'email.mime.application.MIMEApplication'>
# MIMEMultipart      type             <class 'email.mime.multipart.MIMEMultipart'>
# MIMEText           type             <class 'email.mime.text.MIMEText'>
# O                  module           <module 'cx_Oracle' from <...>acle.cp39-win_amd64.pyd'>
# Retry              _RetryMeta       <class 'urllib3.util.retry.Retry'>
# Timeout            type             <class 'requests.exceptions.Timeout'>
# TooManyRedirects   type             <class 'requests.exceptions.TooManyRedirects'>
# agent              dict             n=1
# auth               HTTPBasicAuth    <requests.auth.HTTPBasicA<...>ct at 0x00000272DC2B3820>
# basename           function         <function basename at 0x00000272D75E61F0>
# date               type             <class 'datetime.date'>
# datetime           type             <class 'datetime.datetime'>
# denvarlist         list             n=3
# dfLE               DataFrame            LE_ID                <...>n Regional Medical Center
# dfdenweek          DataFrame            Provider ID  MMWR    <...> 2022-46    0.0  ILIDen
# dfdenweek44        DataFrame            Provider ID  MMWR    <...> 2022-45    0.0  ILINum
# dfdenweek45        DataFrame            Provider ID  MMWR    <...> 2022-45    0.0  ILINum
# dfdenweek46        DataFrame            Provider ID  MMWR    <...> 2022-45    0.0  ILINum
# dfnumweek          DataFrame            Provider ID  MMWR    <...> 2022-45    0.0  ILINum
# dfnumweek45        DataFrame            Provider ID  MMWR    <...> 2022-45    0.0  ILINum
# dt                 module           <module 'datetime' from '<...>onda3\\lib\\datetime.py'>
# eHSQL              module           <module 'eHSQL' from 'C:\<...>\Users\\gmoye\\eHSQL.py'>
# eh                 module           <module 'errhandler' from<...>s\\gmoye\\errhandler.py'>
# getData            function         <function getData at 0x00000272DC251430>
# html               module           <module 'lxml.html' from <...>lxml\\html\\__init__.py'>
# itertools          module           <module 'itertools' (built-in)>
# json               module           <module 'json' from 'C:\\<...>\lib\\json\\__init__.py'>
# logging            module           <module 'logging' from 'C<...>b\\logging\\__init__.py'>
# np                 module           <module 'numpy' from 'C:\<...>ges\\numpy\\__init__.py'>
# numvarlist         list             n=1
# os                 module           <module 'os' from 'C:\\Us<...>\\Anaconda3\\lib\\os.py'>
# payload            dict             n=3
# pd                 module           <module 'pandas' from 'C:<...>es\\pandas\\__init__.py'>
# pyodbc             module           <module 'pyodbc' from 'C:<...>odbc.cp39-win_amd64.pyd'>
# r                  Response         <Response [200]>
# re                 module           <module 're' from 'C:\\Us<...>\\Anaconda3\\lib\\re.py'>
# requests           module           <module 'requests' from '<...>\\requests\\__init__.py'>
# rnumjson           list             n=54
# sa                 module           <module 'sqlalchemy' from<...>sqlalchemy\\__init__.py'>
# session            Session          <requests.sessions.Sessio<...>ct at 0x00000272DC2A2970>
# settings           module           <module 'settings' from '<...>ers\\gmoye\\settings.py'>
# smtplib            module           <module 'smtplib' from 'C<...>conda3\\lib\\smtplib.py'>
# sys                module           <module 'sys' (built-in)>
# traceback          module           <module 'traceback' from <...>nda3\\lib\\traceback.py'>
# transformation     function         <function transformation at 0x00000272E40C3040>
# urllib             module           <module 'urllib' from 'C:<...>ib\\urllib\\__init__.py'>
# warnings           module           <module 'warnings' from '<...>onda3\\lib\\warnings.py'>

# %%
value = '45'
df1 = 'dfnumweek'
df2 = 'dfdenweek'
df1 = eval(df1+value)
df2 = eval(df2+value)
print(df1)
# Out:
#     Provider ID  MMWR                                      erFacility  \
# 0         38047  1901                                        Altru ED
# 1         38047  1901                                        Altru ED
# 2         38047  1901                                        Altru ED
# 3         38047  1901                                        Altru ED
# 4         38047  1901                                        Altru ED
# 5         38047  1901                                        Altru ED
# 6         38089  1901       St Alexius Health Devil’s Lake (Mercy) ED
# 7         38089  1901       St Alexius Health Devil’s Lake (Mercy) ED
# 15     50-64        2022-45    1.0  ILINum
# 16       65+        2022-45    0.0  ILINum
# 17   Unknown        2022-45    0.0  ILINum
# 18     00-04        2022-45    0.0  ILINum
# 19     05-24        2022-45    0.0  ILINum
# 20     25-49        2022-45    1.0  ILINum
# 21     50-64        2022-45    0.0  ILINum
# 22       65+        2022-45    1.0  ILINum
# 23   Unknown        2022-45    0.0  ILINum
# 24     00-04        2022-45    5.0  ILINum
# 25     05-24        2022-45    5.0  ILINum
# 26     25-49        2022-45    1.0  ILINum
# 27     50-64        2022-45    0.0  ILINum
# 28       65+        2022-45    2.0  ILINum
# 29   Unknown        2022-45    0.0  ILINum
# 30     00-04        2022-45    1.0  ILINum
# 31     05-24        2022-45    2.0  ILINum
# 32     25-49        2022-45    1.0  ILINum
# 33     50-64        2022-45    1.0  ILINum
# 34       65+        2022-45    0.0  ILINum
# 35   Unknown        2022-45    0.0  ILINum
# 36     00-04        2022-45    4.0  ILINum
# 37     05-24        2022-45    6.0  ILINum
# 38     25-49        2022-45   11.0  ILINum
# 39     50-64        2022-45    6.0  ILINum
# 40       65+        2022-45    0.0  ILINum
# 41   Unknown        2022-45    0.0  ILINum
# 42     00-04        2022-45    9.0  ILINum
# 43     05-24        2022-45    8.0  ILINum
# 44     25-49        2022-45   12.0  ILINum
# 45     50-64        2022-45    0.0  ILINum
# 46       65+        2022-45    2.0  ILINum
# 47   Unknown        2022-45    0.0  ILINum
# 48     00-04        2022-45    7.0  ILINum
# 49     05-24        2022-45   10.0  ILINum
# 50     25-49        2022-45    8.0  ILINum
# 51     50-64        2022-45    3.0  ILINum
# 52       65+        2022-45    6.0  ILINum
# 53   Unknown        2022-45    0.0  ILINum

# %%
 
enddate = datetime.today().date()

startdate = enddate - timedelta(days=7)

enddate = datetime.strptime(str(enddate), '%Y-%m-%d').strftime('%d%b%y')

startdate = datetime.strptime(str(startdate), '%Y-%m-%d').strftime('%d%b%y')

#Dateparams = startDate=06Nov22&endDate=12Nov22
print(startdate, enddate)
# Out:
# 14Nov22 21Nov22

# %%
print(datetime.strptime(str(datetime.now()), '%Y-%m-%d-%H:%M:%S').strftime('%d%b%y-%H:%M:%S'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 print(datetime.strptime(str(datetime.now()), '%Y-%m-%d-%H:%M:%S').strftime('%d%b%y-%H:%M:%S'))
#
# File ~\Anaconda3\lib\_strptime.py:568, in _strptime_datetime(cls, data_string, format)
#     565 def _strptime_datetime(cls, data_string, format="%a %b %d %H:%M:%S %Y"):
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# File ~\Anaconda3\lib\_strptime.py:349, in _strptime(data_string, format)
#     347 found = format_regex.match(data_string)
#     348 if not found:
# --> 349     raise ValueError("time data %r does not match format %r" %
#     350                      (data_string, format))
#     351 if len(data_string) != found.end():
#     352     raise ValueError("unconverted data remains: %s" %
#     353                       data_string[found.end():])
#
# ValueError: time data '2022-11-25 10:56:50.426262' does not match format '%Y-%m-%d-%H:%M:%S'

# %%
print(datetime.strptime(str(datetime.now()), '%Y-%m-%d-%H:%M:%S'))

# %%
print(datetime.today().strftime('%d%b%y_%H:%M:%S'))
# Out:
# 25Nov22_11:01:43

# %%
pip install os-sys
# Out:
# Collecting os-sys
#   Using cached os_sys-2.1.4-py3-none-any.whl (15.6 MB)
# Requirement already satisfied: pandas in c:\users\gmoye\anaconda3\lib\site-packages (from os-sys) (1.4.2)
# Requirement already satisfied: pytz in c:\users\gmoye\anaconda3\lib\site-packages (from os-sys) (2021.3)
# Collecting cefpython3
#   Downloading cefpython3-66.1-py2.py3-none-win_amd64.whl (69.0 MB)
# Requirement already satisfied: psutil in c:\users\gmoye\anaconda3\lib\site-packages (from os-sys) (5.8.0)
# Collecting requests-download
#   Using cached requests_download-0.1.2-py2.py3-none-any.whl (5.5 kB)
# Collecting mysql-connector
#   Using cached mysql-connector-2.2.9.tar.gz (11.9 MB)
# Collecting pyvalid
#   Downloading pyvalid-1.0.4-py3-none-any.whl (11 kB)
# Collecting geocoder
#   Using cached geocoder-1.38.1-py2.py3-none-any.whl (98 kB)
# Collecting pygubu
#   Using cached pygubu-0.29-py3-none-any.whl (113 kB)
# Collecting progressNote: you may need to restart the kernel to use updated packages.
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\gmoye\Anaconda3\python.exe' 'C:\Users\gmoye\Anaconda3\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' get_requires_for_build_wheel 'C:\Users\gmoye\AppData\Local\Temp\1\tmpdml2_bjf'
#        cwd: C:\Users\gmoye\AppData\Local\Temp\1\pip-install-hi412if3\spacy_d3e5594b7f1d4745a827588caba66eb8
#   Complete output (51 lines):
#   Traceback (most recent call last):
#     File "C:\Users\gmoye\AppData\Local\Temp\1\pip-build-env-gscm5hdi\overlay\Lib\site-packages\pkg_resources\_vendor\packaging\requirements.py", line 35, in __init__
#       parsed = parse_requirement(requirement_string)
#     File "C:\Users\gmoye\AppData\Local\Temp\1\pip-build-env-gscm5hdi\overlay\Lib\site-packages\pkg_resources\_vendor\packaging\_parser.py", line 64, in parse_requirement
#       return _parse_requirement(Tokenizer(source, rules=DEFAULT_RULES))
#     File "C:\Users\gmoye\AppData\Local\Temp\1\pip-build-env-gscm5hdi\overlay\Lib\site-packages\pkg_resources\_vendor\packaging\_parser.py", line 82, in _parse_requirement
#       url, specifier, marker = _parse_requirement_details(tokenizer)
#     File "C:\Users\gmoye\AppData\Local\Temp\1\pip-build-env-gscm5hdi\overlay\Lib\site-packages\pkg_resources\_vendor\packaging\_parser.py", line 126, in _parse_requirement_details
#       marker = _parse_requirement_marker(
#     File "C:\Users\gmoye\AppData\Local\Temp\1\pip-build-env-gscm5hdi\overlay\Lib\site-packages\pkg_resources\_vendor\packaging\_parser.py", line 147, in _parse_requirement_marker
#       tokenizer.raise_syntax_error(
#     File "C:\Users\gmoye\AppData\Local\Temp\1\pip-build-env-gscm5hdi\overlay\Lib\site-packages\pkg_resources\_vendor\packaging\_tokenizer.py", line 163, in raise_syntax_error
#       raise ParserSyntaxError(
#   pkg_resources.extern.packaging._tokenizer.ParserSyntaxError: Expected end or semicolon (after version specifier)
#       spacy_lookups_data>=0.0.5<0.2.0
#                         ~~~~~~~^
#
#   The above exception was the direct cause of the following exception:
#
#   Traceback (most recent call last):
#     File "C:\Users\gmoye\Anaconda3\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py", line 349, in <module>
#       main()
#     File "C:\Users\gmoye\Anaconda3\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py", line 331, in main
#       json_out['return_val'] = hook(**hook_input['kwargs'])
#     File "C:\Users\gmoye\Anaconda3\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py", line 117, in get_requires_for_build_wheel
#       return hook(config_settings)
#     File "C:\Users\gmoye\AppData\Local\Temp\1\pip-build-env-gscm5hdi\overlay\Lib\site-packages\setuptools\build_meta.py", line 338, in get_requires_for_build_wheel
#       return self._get_build_requires(config_settings, requirements=['wheel'])
#     File "C:\Users\gmoye\AppData\Local\Temp\1\pip-build-env-gscm5hdi\overlay\Lib\site-packages\setuptools\build_meta.py", line 320, in _get_build_requires
#       self.run_setup()
#     File "C:\Users\gmoye\AppData\Local\Temp\1\pip-build-env-gscm5hdi\overlay\Lib\site-packages\setuptools\build_meta.py", line 335, in run_setup
#       exec(code, locals())
#     File "<string>", line 200, in <module>
#     File "<string>", line 190, in setup_package
#     File "C:\Users\gmoye\AppData\Local\Temp\1\pip-build-env-gscm5hdi\overlay\Lib\site-packages\setuptools\__init__.py", line 107, in setup
#       _install_setup_requires(attrs)
#     File "C:\Users\gmoye\AppData\Local\Temp\1\pip-build-env-gscm5hdi\overlay\Lib\site-packages\setuptools\__init__.py", line 78, in _install_setup_requires
#       dist.parse_config_files(ignore_option_errors=True)
#     File "C:\Users\gmoye\AppData\Local\Temp\1\pip-build-env-gscm5hdi\overlay\Lib\site-packages\setuptools\dist.py", line 874, in parse_config_files
#       self._finalize_requires()
#     File "C:\Users\gmoye\AppData\Local\Temp\1\pip-build-env-gscm5hdi\overlay\Lib\site-packages\setuptools\dist.py", line 580, in _finalize_requires
#       self._convert_extras_requirements()
#     File "C:\Users\gmoye\AppData\Local\Temp\1\pip-build-env-gscm5hdi\overlay\Lib\site-packages\setuptools\dist.py", line 595, in _convert_extras_requirements
#       for r in _reqs.parse(v):
#     File "C:\Users\gmoye\AppData\Local\Temp\1\pip-build-env-gscm5hdi\overlay\Lib\site-packages\pkg_resources\__init__.py", line 3095, in __init__
#       super(Requirement, self).__init__(requirement_string)
#     File "C:\Users\gmoye\AppData\Local\Temp\1\pip-build-env-gscm5hdi\overlay\Lib\site-packages\pkg_resources\_vendor\packaging\requirements.py", line 37, in __init__
#       raise InvalidRequirement(str(e)) from e
#   pkg_resources.extern.packaging.requirements.InvalidRequirement: Expected end or semicolon (after version specifier)
#       spacy_lookups_data>=0.0.5<0.2.0
#                         ~~~~~~~^
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/79/fd/13cdec8c1a3a2d57f5161e183639367d9d002965dfc893f222293fb1cc04/spacy-2.2.0.tar.gz#sha256=2921352c60d730978c7b2ebfac54045284dfa2022245a061f9d1336ef1b8cfb1 (from https://pypi.org/simple/spacy/) (requires-python:>=2.7,!=3.0.*,!=3.1.*,!=3.2.*,!=3.3.*). Command errored out with exit status 1: 'C:\Users\gmoye\Anaconda3\python.exe' 'C:\Users\gmoye\Anaconda3\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' get_requires_for_build_wheel 'C:\Users\gmoye\AppData\Local\Temp\1\tmpdml2_bjf' Check the logs for full command output.
# ERROR: os-sys has an invalid wheel, could not read 'os_sys-1.9.3.dist-info/WHEEL' file: KeyError("There is no item named 'os_sys-1.9.3.dist-info/WHEEL' in the archive")
#   Downloading progress-1.6.tar.gz (7.8 kB)
# Requirement already satisfied: selenium in c:\users\gmoye\anaconda3\lib\site-packages (from os-sys) (4.8.0)
# Collecting PyInstaller
#   Downloading pyinstaller-5.7.0-py3-none-win_amd64.whl (1.3 MB)
# Requirement already satisfied: matplotlib in c:\users\gmoye\anaconda3\lib\site-packages (from os-sys) (3.5.1)
# Requirement already satisfied: six in c:\users\gmoye\anaconda3\lib\site-packages (from os-sys) (1.16.0)
# Collecting spacy==2.2.0
#   Using cached spacy-2.2.0.tar.gz (5.8 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
# Collecting os-sys
#   Using cached os_sys-2.1.3-py3-none-any.whl (15.5 MB)
#   Using cached os_sys-2.1.2-py3-none-any.whl (15.4 MB)
#   Using cached os_sys-2.1.1-py3-none-any.whl (15.4 MB)
#   Using cached os_sys-2.1.0-py3-none-any.whl (15.9 MB)
#   Using cached os_sys-2.0.9-py3-none-any.whl (15.4 MB)
#   Using cached os_sys-2.0.8-py3-none-any.whl (15.4 MB)
#   Using cached os_sys-2.0.7-py3-none-any.whl (14.2 MB)
#   Using cached os_sys-2.0.6-py3-none-any.whl (14.2 MB)
#   Using cached os_sys-2.0.5-py3-none-any.whl (12.2 MB)
# Collecting enum34
#   Using cached enum34-1.1.10-py3-none-any.whl (11 kB)
# Collecting sqlalchemy<1.4,>=1.3
#   Downloading SQLAlchemy-1.3.24-cp39-cp39-win_amd64.whl (1.2 MB)
# Collecting os-sys-php
#   Using cached os_sys_php-2019.10.13-py3-none-any.whl (38.6 MB)
# Requirement already satisfied: tqdm in c:\users\gmoye\anaconda3\lib\site-packages (from os-sys) (4.64.0)
# Collecting pyspeedtest
#   Downloading pyspeedtest-1.2.7.tar.gz (6.8 kB)
# Collecting python-dateutil<2.8,>=2.7
#   Downloading python_dateutil-2.7.5-py2.py3-none-any.whl (225 kB)
# Collecting mathparse<0.2,>=0.1
#   Downloading mathparse-0.1.2-py3-none-any.whl (7.2 kB)
# Requirement already satisfied: jupyter in c:\users\gmoye\anaconda3\lib\site-packages (from os-sys) (1.0.0)
# Collecting os-sys
#   Using cached os_sys-2.0.4-py3-none-any.whl (50.9 MB)
#   Using cached os_sys-2.0.3-py3-none-any.whl (51.8 MB)
#   Using cached os_sys-2.0.2-py3-none-any.whl (54.1 MB)
#   Using cached os_sys-2.0.1-py3-none-any.whl (54.1 MB)
#   Using cached os_sys-2.0.0-py3-none-any.whl (54.1 MB)
#   Using cached os_sys-1.9.9-py3-none-any.whl (54.1 MB)
#   Using cached os_sys-1.9.8-py3-none-any.whl (54.1 MB)
#   Using cached os_sys-1.9.7-py3-none-any.whl (54.1 MB)
#   Using cached os_sys-1.9.6-py3-none-any.whl (54.1 MB)
#   Using cached os_sys-1.9.5-py3-none-any.whl (54.1 MB)
#   Using cached os_sys-1.9.4-py3-none-any.whl (54.1 MB)
#   Using cached os_sys-1.9.3-py3-none-any.whl (60.4 MB)
