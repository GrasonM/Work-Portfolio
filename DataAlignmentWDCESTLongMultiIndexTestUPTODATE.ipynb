# %%
import pandas as pd
import numpy as np
import re
import warnings, sys
#import dask as d
#import dask.dataframe as dd
#from dask.delayed import delayed
with warnings.catch_warnings():
    warnings.simplefilter('ignore', UserWarning)
    warnings.simplefilter('ignore', FutureWarning)
    pattern = "^(.*)(?=[0-9a-f]{8}-[0-9a-f]{4}-[1-5][0-9a-f]{3}-[89ab][0-9a-f]{3}-[0-9a-f]{12})"
    
    df1 = pd.read_excel("My Report_R075_all 2022-10-04 18_01 CEST.xlsx", skiprows = range(0,21), usecols = ['Party ID',
                                                                                                            'Employee ID',
                                                                                                            'Worker',
                                                                                                            'GUID', 
                                                                                                            'Cost Center - ID', 
                                                                                                            'Cost Center - Name', 
                                                                                                            'Company Reference ID',
                                                                                                            'Company - Name', 
                                                                                                            'Management Level', 
                                                                                                            'Job Level - Primary Position', 
                                                                                                            'Work Email', 
                                                                                                            'Status Details', 
                                                                                                            'Line of Service', 
                                                                                                            'Hire Date', 
                                                                                                            'Assignment Reason (Alternative)', 
                                                                                                            'Host Country (Alternative)', 
                                                                                                            'Host Country / Territory', 
                                                                                                            'Country/Territory', 
                                                                                                            'Company Hierarchy', 
                                                                                                            'Worker Type', 
                                                                                                            'Contingent Worker Type', 
                                                                                                            'Job Category'])
    df1 = df1.sort_values('Party ID')
    df1['Party ID'] = df1['Party ID'].str.replace(f'{pattern}', '')
    df1 = df1[df1['Party ID'].str.len() == 36]
    df1 = df1[df1['Contingent Worker Type'] != 'Enterprise BOT']
    #df1.to_csv("My Report_R075_all 2022-10-04 18_01 CEST.csv")
    
    
    df2 = pd.read_excel("My Report_R139_almost_all 2022-10-04 18_53 CEST.xlsx", skiprows = range(0,27), usecols = ['Party ID', 
                                                                                                                   'Employee ID',
                                                                                                                   'Worker',
                                                                                                                   'GUID', 
                                                                                                                   'Cost Center ID', 
                                                                                                                   'Cost Center Name',
                                                                                                                   'Company - Name', 
                                                                                                                   'Management Level', 
                                                                                                                   'Job Level - Primary Position', 
                                                                                                                   'Email - Primary Work', 
                                                                                                                   'Employee Status', 
                                                                                                                   'Cost Center Level 3', 
                                                                                                                   'Hire Date', 
                                                                                                                   'Termination Date', 
                                                                                                                   'Country/Territory of Work Location', 
                                                                                                                   'Country', 
                                                                                                                   'Worker Type', 
                                                                                                                   'Contingent Worker Type', 
                                                                                                                   'Job Category'])
    df2 = df2.sort_values('Party ID')
    df2['Party ID'] = df2['Party ID'].str.replace(f'{pattern}', '')
    df2 = df2[df2['Party ID'].str.len() == 36]
    df2 = df2[df2['Contingent Worker Type'] != 'Enterprise BOT']
    #df2.to_csv("My Report_R139_almost_all 2022-10-04 18_53 CEST.csv")
    
    df3 = pd.read_excel("My Report_R311_almost_all 2022-10-04 18_24 CEST.xlsx", skiprows = range(0,20), usecols = ['Party ID', 
                                                                                                                   'Employee ID', 
                                                                                                                   'Worker',
                                                                                                                   'GUID', 
                                                                                                                   'Cost Center ID', 
                                                                                                                   'Cost Center - Name', 
                                                                                                                   'Company Reference ID',
                                                                                                                   'Company - Name', 
                                                                                                                   'Management Level', 
                                                                                                                   'Job Level', 
                                                                                                                   'Email - Primary Work',
                                                                                                                   'Employee Status', 
                                                                                                                   'PwC Global Line Of Service', 
                                                                                                                   'Hire Date', 
                                                                                                                   'Company Hierarchy', 
                                                                                                                   'Cost Center Level 3', 
                                                                                                                   'Worker Type', 
                                                                                                                   'Contingent Worker Type', 
                                                                                                                   'Job Category',
                                                                                                                   'Is Inbound IA? (Exception Process)'])
    df3 = df3.sort_values('Party ID')
    df3['Party ID'] = df3['Party ID'].str.replace(f'{pattern}', '')
    df3 = df3[df3['Party ID'].str.len() == 36]
    df3 = df3[df3['Contingent Worker Type'] != 'Enterprise BOT']
    #df3.to_csv("My Report_R311_almost_all 2022-10-04 18_24 CEST.csv")
    
    df4 = pd.read_excel("PMDM_Active_Employee_Report_10.08.xlsx", skiprows = range(0,5), usecols = ['Party ID',
                                                                                                    'INAB PPI 1',
                                                                                                    'INAB PPI 2',
                                                                                                    'INAB GUID 1', 
                                                                                                    'INAB GUID 2', 
                                                                                                    'Cost Center Code', 
                                                                                                    'Cost Center Description', 
                                                                                                    'Legal Entity Party ID',
                                                                                                    'Legal Entity Name', 
                                                                                                    'Job Level ', 
                                                                                                    'Grade', 
                                                                                                    'Cloud Mail', 
                                                                                                    'Territory', 
                                                                                                    'Global LoS', 
                                                                                                    'Contract Type', 
                                                                                                    'Job Category'])
    
    #df5 = pd.read_excel("RRM_extract_10.08.xlsx")
    
    #dfwd1 = pd.concat([df1,df2]) 
    
    #dfwd2 = pd.merge(dfwd1, df3, how = 'outer', left_on = ['Party ID', 'Employee ID'], right_on = ['Party ID', 'Employee ID'], indicator = 'Exists_dfwd1_df3')
    #dfwd2 = pd.concat([dfwd1,df3], ignore_index=True).drop_duplicates() 
    #dfwd3 = pd.merge(dfwd2, df4, on = 'Party ID',how = 'outer', indicator='Exists_dfwd2_df4')

# %%
df1a = df1.loc[((df1['GUID'] == '') | (df1['GUID'] == ' ') | (df1['GUID'].isna()))]
display(df1a)
# Out:
#                                                Worker  Employee ID  \
# 37099                            Matthias Steffen [C]    101152878
# 27035                                 Junije Odja [C]    110000940
# 34721                        María Cecilia Mendez [C]    101321312
# 11586                             Daniel Burgener [C]    110000599
# 59235  Veronica Mariela Chala Rodriguez De Macher [C]    110001610
# ...                                               ...          ...
# 44543                    Pablo Patricio Giampieri [C]    101047627
# 15269                                     Enock Kweka    100861416
# 47477                           Raffaele Antonica [C]    100980418
# 10006                         Christina-Maria Pichler    101302258
# 59553                               Viktorija Lindner    101294345
#
#                                    Party ID GUID Status Details  \
# 37099  00a8d72f-b03a-4964-9af5-4e18ff0ab02b  NaN         Active
# 27035  00a8e7bc-d1e5-44e1-9aa3-c19de85fdbc3  NaN         Active
# 34721  00e9796d-ef4f-4148-8372-3cb1490a1532  NaN         Active
# 11586  0107ae1f-ded2-4de1-90a8-4fbb0306428d  NaN         Active
# 59235  012e04bf-8a21-4e79-96f9-8520abc30c2c  NaN         Active
# ...                                     ...  ...            ...
# 44543  fc4f11b6-aada-4c83-86f7-db9e725f9846  NaN         Active
# 15269  fd5c4d62-6cda-4187-b604-4e77e85f657e  NaN     Secondment
# 47477  fd7e0c50-1993-431e-b447-e617ea578597  NaN         Active
# 10006  269c020c-9349-4c85-94a7-fc4a1b43eba5  NaN         Active
# 59553  96312aa0-5a62-4f38-a4dc-d9c1a393c79b  NaN         Active
#
#                                       Work Email  Hire Date  \
# 37099                   ch_switchboard_zh@pwc.ch 2021-11-01
# 27035  dummy.do.not.use.WORK.00072866@ch.pwc.com 2017-02-08
# 34721                                        NaN 2022-10-04
# 11586  dummy.do.not.use.WORK.00070177@ch.pwc.com 2016-02-10
# 59235  dummy.do.not.use.WORK.00079564@ch.pwc.com 2019-11-13
# ...                                          ...        ...
# 44543                                        NaN 2020-12-23
# 15269                     enock.kweka.za@pwc.com 2014-02-10
# 47477                                        NaN 2020-02-01
# 10006            christina-maria.pichler@pwc.com 2022-09-01
# 59553                viktorija.lindner@gmail.com 2022-09-01
#
#              Worker Type Contingent Worker Type      Job Category  ...  \
# 37099  Contingent Worker                 Vendor  Practice Support  ...
# 27035  Contingent Worker                Retiree  Practice Support  ...
# 34721  Contingent Worker             Contractor   Client Services  ...
# 11586  Contingent Worker            Agency Temp  Practice Support  ...
# 59235  Contingent Worker                 Vendor  Practice Support  ...
# ...                  ...                    ...               ...  ...
# 44543  Contingent Worker             Freelancer   Client Services  ...
# 15269           Employee                    NaN   Client Services  ...
# 47477  Contingent Worker                 Vendor  Practice Support  ...
# 10006           Employee                    NaN   Client Services  ...
# 59553           Employee                    NaN   Client Services  ...
#
#       Country/Territory         Line of Service  \
# 37099       Switzerland  Internal Firm Services
# 27035       Switzerland  Internal Firm Services
# 34721             Chile               Assurance
# 11586       Switzerland  Internal Firm Services
# 59235       Switzerland  Internal Firm Services
# ...                 ...                     ...
# 44543         Argentina                Advisory
# 15269          Tanzania                     Tax
# 47477       Switzerland  Internal Firm Services
# 10006           Austria                Advisory
# 59553           Austria                Advisory
#
#       Assignment Reason (Alternative) Host Country (Alternative)  \
# 37099                             NaN                        NaN
# 27035                             NaN                        NaN
# 34721                             NaN                        NaN
# 11586                             NaN                        NaN
# 59235                             NaN                        NaN
# ...                               ...                        ...
# 44543                             NaN                        NaN
# 15269            Long-Term Assignment                      Kenya
# 47477                             NaN                        NaN
# 10006                             NaN                        NaN
# 59553                             NaN                        NaN
#
#       Host Country / Territory  \
# 37099                      NaN
# 27035                      NaN
# 34721                      NaN
# 11586                      NaN
# 59235                      NaN
# ...                        ...
# 44543                      NaN
# 15269                    Kenya
# 47477                      NaN
# 10006                      NaN
# 59553                      NaN
#
#                                           Company - Name Company Hierarchy  \
# 37099                          PricewaterhouseCoopers AG   PwC Switzerland
# 27035                          PricewaterhouseCoopers AG   PwC Switzerland
# 34721   PricewaterhouseCoopers Consultores Auditores SpA         PwC Chile
# 11586                          PricewaterhouseCoopers AG   PwC Switzerland
# 59235                          PricewaterhouseCoopers AG   PwC Switzerland
# ...                                                  ...               ...
# 44543  PRICE WATERHOUSE & CO. ASESORES DE EMPRESAS S.R.L     PwC Argentina
# 15269                     PricewaterhouseCoopers Limited      PwC Tanzania
# 47477                          PricewaterhouseCoopers AG   PwC Switzerland
# 10006   PwC Transaction Services Wirtschaftsprüfung GmbH       PwC Austria
# 59553   PwC Transaction Services Wirtschaftsprüfung GmbH       PwC Austria
#
#                        Company Reference ID Cost Center - ID  \
# 37099  ea5d8532-b488-4270-8e77-adc40703771f       CH10104300
# 27035  ea5d8532-b488-4270-8e77-adc40703771f       CH10104300
# 34721  28ce8e3b-59fe-40e5-8d31-1bc6ee893c79           CLS110
# 11586  ea5d8532-b488-4270-8e77-adc40703771f       CH10104200
# 59235  ea5d8532-b488-4270-8e77-adc40703771f       CH10104300
# ...                                     ...              ...
# 44543  e366e5bd-374b-432a-b6c1-b05b8668b1c0           ARI466
# 15269  cb8fafc0-261d-4160-9059-cfd4cb05b487           TZ0383
# 47477  ea5d8532-b488-4270-8e77-adc40703771f       CH10104002
# 10006  a8209460-03f6-4935-8c14-721279792e3e       AT07000004
# 59553  a8209460-03f6-4935-8c14-721279792e3e       AT07000048
#
#                              Cost Center - Name
# 37099          Corporate Real Estate Management
# 27035          Corporate Real Estate Management
# 34721                 CL-ASS-Santiago-Assurance
# 11586                                 TnT Staff
# 59235          Corporate Real Estate Management
# ...                                         ...
# 44543  AR-ADV-Buenos Aires-Transaction Services
# 15269                 TZ - TAX - Indirect - VAT
# 47477                       Firmwide Operations
# 10006                      ADV Forensic Service
# 59553                      ADV FS Banking & Cap
#
# [458 rows x 22 columns]

# %%
df2a = df2.loc[((df2['GUID'] == '') | (df2['GUID'] == ' ') | (df2['GUID'].isna()))]
display(df2a)
# Out:
#                       Worker  Employee ID  \
# 2367   Hans Hinrich Coorssen    100945773
# 2466      Hermann Baumgarten    100925850
# 38745           Nikolas Zech    100949864
# 1902           Ernst Fritsch    100726299
# 8168       Alejandro Verdugo    100753549
# ...                      ...          ...
# 1805            Ekene Nzekwe    101022243
# 1492        Daniel Vrancianu    100978630
# 25258          Jesse Buckman    100951738
# 7214          Zoltan Harsanj    100726410
# 5558          Rebecca Baseme    101248539
#
#                                    Party ID GUID Employee Status  \
# 2367   000c19fc-01a9-45b4-a50d-c0749532926e  NaN      Terminated
# 2466   009e3ff7-763f-4324-b43f-f1c54177e854  NaN      Terminated
# 38745  00aabd80-bd9f-4d63-a29e-b5ccc85f382a  NaN      Terminated
# 1902   00c79c46-5677-4375-a494-e408305390b3  NaN      Terminated
# 8168   0110de0f-4dcf-4847-ba14-63ffd6ea3b32  NaN      Terminated
# ...                                     ...  ...             ...
# 1805   fe1a4bb8-6380-48c7-8fcd-3ac5f5ec11e8  NaN      Terminated
# 1492   fe9fc3e4-aff2-4bb9-a1f6-11c303a4fc70  NaN      Terminated
# 25258  feac6338-4a79-49b3-a62d-612344f5a82f  NaN      Terminated
# 7214   ff7670b2-1623-481d-b30e-4f98dc9d24ec  NaN      Terminated
# 5558   ffa06b0b-b856-4a05-8e25-168ac73cd7cd  NaN      Terminated
#
#       Email - Primary Work  Hire Date Termination Date        Worker Type  \
# 2367                   NaN 2019-10-01       2021-12-31  Contingent Worker
# 2466                   NaN 2019-07-22       2019-12-31  Contingent Worker
# 38745                  NaN 2020-05-01       2020-05-01           Employee
# 1902                   NaN 2017-06-07       2021-01-01  Contingent Worker
# 8168       noemail@pwc.com 2012-11-12       2018-06-13           Employee
# ...                    ...        ...              ...                ...
# 1805                   NaN 2019-12-16       2020-10-31  Contingent Worker
# 1492                   NaN 2020-01-20       2020-06-30  Contingent Worker
# 25258                  NaN 2019-12-02       2020-05-14           Employee
# 7214                   NaN 2018-02-01       2019-06-30  Contingent Worker
# 5558                   NaN 2022-05-16       2022-05-16  Contingent Worker
#
#       Contingent Worker Type      Job Category  Management Level  \
# 2367              Freelancer   Client Services        Specialist
# 2466              Freelancer   Client Services        Specialist
# 38745                    NaN   Client Services    Intern/Trainee
# 1902                  Vendor  Practice Support        Specialist
# 8168                     NaN   Client Services  Senior Associate
# ...                      ...               ...               ...
# 1805              Contractor   Client Services    Intern/Trainee
# 1492                  Vendor  Practice Support        Specialist
# 25258                    NaN   Client Services  Senior Associate
# 7214              Contractor   Client Services        Specialist
# 5558                  Intern   Client Services    Intern/Trainee
#
#       Job Level - Primary Position Country/Territory of Work Location  \
# 2367                           NaN                            Germany
# 2466                           NaN                            Germany
# 38745                          NaN                            Germany
# 1902                           NaN                            Germany
# 8168            Senior Associate 2                              Chile
# ...                            ...                                ...
# 1805                           NaN                            Nigeria
# 1492                           NaN                            Germany
# 25258                          NaN                              Ghana
# 7214                           NaN                            Germany
# 5558                           NaN                          Mauritius
#
#          Country                                     Company - Name  \
# 2367     Germany  PRICEWATERHOUSECOOPERS Gesellschaft mit beschr...
# 2466     Germany  PRICEWATERHOUSECOOPERS Gesellschaft mit beschr...
# 38745    Germany  PRICEWATERHOUSECOOPERS Gesellschaft mit beschr...
# 1902     Germany  PRICEWATERHOUSECOOPERS Gesellschaft mit beschr...
# 8168       Chile   PricewaterhouseCoopers Consultores Auditores SpA
# ...          ...                                                ...
# 1805     Nigeria                     PricewaterhouseCoopers Limited
# 1492     Germany  PRICEWATERHOUSECOOPERS Gesellschaft mit beschr...
# 25258      Ghana               PricewaterhouseCoopers Ghana Limited
# 7214     Germany                         PwC Strategy& Germany GmbH
# 5558   Mauritius                         PricewaterhouseCoopers Ltd
#
#                           Cost Center Name Cost Center ID  \
# 2367                ADV BC Public & Energy     DE01001113
# 2466                  ADV BC FS Consulting     DE01000632
# 38745                         ASR IS CMAAS     DE01000789
# 1902            T&T Front Office Solutions     DE01001065
# 8168                        TAX COMPLIANCE            414
# ...                                    ...            ...
# 1805   NG - ASS - Energy - Other Assurance         NG0151
# 1492                      GL Tech Tech Rec     DE01000835
# 25258                    RAS-IT Risk Assur           0183
# 7214                  ADV SC DE Consulting     DEZ1010001
# 5558     MU - ASS - CIPS - Other Assurance         MU0145
#
#                                      Cost Center Level 3
# 2367                                      ADV Consulting
# 2466                                  SL-3 - AD CO BC FS
# 38745                                 SL-3 - AS IS CM CM
# 1902                                     SL-3 - IF V2 IT
# 8168                                         Tax [Lvl 1]
# ...                                                  ...
# 1805                                  Assurance - Energy
# 1492                                     SL-3 - IF V2 IT
# 25258                                          Assurance
# 7214                                  SL-3 - AD CO SC DE
# 5558   Assurance - Consumer, Industrial, Products, an...
#
# [1047 rows x 19 columns]

# %%
df3a = df3.loc[((df3['GUID'] == '') | (df3['GUID'] == ' ') | (df3['GUID'].isna()))]
display(df3a)
# Out:
#                             Worker  Employee ID  \
# 1514                   Tina Bhikha    101312416
# 640                        Jen Kim    101312631
# 270               Christopher Daws    101226188
# 619                  Jannik Isfort    101289198
# 1026                      Max Hart    101322519
# ...                            ...          ...
# 616                Jannek Hündling    101254273
# 1349               Sammy Bourgeois    101317782
# 403                Eva Maria Sacco    101279003
# 742   Julius Maximilian Katterbach    101322073
# 904                   Luca Grädler    101233186
#
#      Is Inbound IA? (Exception Process)                              Party ID  \
# 1514                                 No  0185b508-439a-4618-9830-c53fb04d9030
# 640                                  No  01b9ce8e-42b0-4910-b964-2237cbc1322c
# 270                                  No  020a25fd-6581-466a-b20c-ec292d412391
# 619                                  No  029d3b37-3fbc-4d0b-ba50-af9452f95462
# 1026                                 No  032c4032-cc03-4e9c-837d-b4f0c322d177
# ...                                 ...                                   ...
# 616                                  No  ff1f0770-81f3-4aa2-bf5c-c95f57474d82
# 1349                                 No  ff21fa7d-6aa4-4b05-b216-ddcbd868f98c
# 403                                  No  ff6ad920-d740-45f6-9d0e-93f23b8810e5
# 742                                  No  fffa8e46-154f-4631-82fb-6df02ac1ee79
# 904                                  No  fffb6356-c779-4e5f-83fb-57b915857986
#
#      GUID Employee Status  Hire Date Email - Primary Work Worker Type  \
# 1514  NaN     Future Hire 2023-02-13                  NaN    Employee
# 640   NaN     Future Hire 2022-11-14                  NaN    Employee
# 270   NaN     Future Hire 2023-02-01                  NaN    Employee
# 619   NaN     Future Hire 2023-01-01                  NaN    Employee
# 1026  NaN     Future Hire 2022-11-14                  NaN    Employee
# ...   ...             ...        ...                  ...         ...
# 616   NaN     Future Hire 2023-01-15                  NaN    Employee
# 1349  NaN     Future Hire 2023-02-13                  NaN    Employee
# 403   NaN     Future Hire 2023-01-01                  NaN    Employee
# 742   NaN     Future Hire 2023-03-01                  NaN    Employee
# 904   NaN     Future Hire 2023-01-15                  NaN    Employee
#
#      Contingent Worker Type PwC Global Line Of Service      Job Category  \
# 1514                    NaN                   Advisory   Client Services
# 640                     NaN                   Advisory   Client Services
# 270                     NaN                   Advisory   Client Services
# 619                     NaN                   Advisory   Client Services
# 1026                    NaN                   Advisory   Client Services
# ...                     ...                        ...               ...
# 616                     NaN                   Advisory   Client Services
# 1349                    NaN                   Advisory   Client Services
# 403                     NaN     Internal Firm Services  Practice Support
# 742                     NaN                   Advisory   Client Services
# 904                     NaN                  Assurance   Client Services
#
#      Management Level Job Level  \
# 1514       Specialist       NaN
# 640    Intern/Trainee       NaN
# 270    Intern/Trainee       NaN
# 619         Associate       NaN
# 1026   Intern/Trainee       NaN
# ...               ...       ...
# 616    Intern/Trainee       NaN
# 1349       Specialist       NaN
# 403    Senior Manager       NaN
# 742    Intern/Trainee       NaN
# 904    Intern/Trainee       NaN
#
#                                          Company - Name Company Hierarchy  \
# 1514                             PRICEWATERHOUSECOOPERS   PwC New Zealand
# 640                              PRICEWATERHOUSECOOPERS   PwC New Zealand
# 270   PRICEWATERHOUSECOOPERS Gesellschaft mit beschr...       PwC Germany
# 619   PRICEWATERHOUSECOOPERS Gesellschaft mit beschr...       PwC Germany
# 1026                             PRICEWATERHOUSECOOPERS   PwC New Zealand
# ...                                                 ...               ...
# 616   PRICEWATERHOUSECOOPERS Gesellschaft mit beschr...       PwC Germany
# 1349                             PRICEWATERHOUSECOOPERS   PwC New Zealand
# 403   PRICEWATERHOUSECOOPERS Gesellschaft mit beschr...       PwC Germany
# 742   PRICEWATERHOUSECOOPERS Gesellschaft mit beschr...       PwC Germany
# 904   PRICEWATERHOUSECOOPERS Gesellschaft mit beschr...       PwC Germany
#
#                       Company Reference ID Cost Center ID  \
# 1514  b886a7f0-9c89-48a9-be0b-eb2337697c8d         NZD311
# 640   b886a7f0-9c89-48a9-be0b-eb2337697c8d         NZD399
# 270   ff6d5af8-9ae6-47d9-8317-eaa8b0e2e7b9     DE01000561
# 619   ff6d5af8-9ae6-47d9-8317-eaa8b0e2e7b9     DE01001151
# 1026  b886a7f0-9c89-48a9-be0b-eb2337697c8d         NZD398
# ...                                    ...            ...
# 616   ff6d5af8-9ae6-47d9-8317-eaa8b0e2e7b9     DE01000792
# 1349  b886a7f0-9c89-48a9-be0b-eb2337697c8d         NZD398
# 403   ff6d5af8-9ae6-47d9-8317-eaa8b0e2e7b9     DE01000121
# 742   ff6d5af8-9ae6-47d9-8317-eaa8b0e2e7b9     DE01000221
# 904   ff6d5af8-9ae6-47d9-8317-eaa8b0e2e7b9     DE01000194
#
#                    Cost Center - Name      Cost Center Level 3
# 1514                            Deals                 Advisory
# 640   Industry & Solution Communities                 Advisory
# 270                        ADV TR VMA                ADV Deals
# 619                        ADV TR DDV                ADV Deals
# 1026                   Transformation                 Advisory
# ...                               ...                      ...
# 616          ADV BC Risk & Regulatory  ADV Business Consulting
# 1349                   Transformation                 Advisory
# 403              FIN Treasury Germany   Internal Firm Services
# 742     ADV TR Mergers & Acquisitions                ADV Deals
# 904                      ASR IS Mitte                Assurance
#
# [842 rows x 20 columns]

# %%
df1.rename(columns={'Status Details':'Employee Status',
                    'Cost Center - ID':'Cost Center ID',
                    'Cost Center - Name':'Cost Center Name'}, inplace = True)

df2.rename(columns={'Email - Primary Work':'Work Email'}, inplace = True)

df3.rename(columns={'Email - Primary Work':'Work Email',
                    'Cost Center - Name':'Cost Center Name',
                    'Job Level':'Job Level - Primary Position'}, inplace = True)

dfwd1 = pd.merge(df1, df2, how = 'outer', left_on = ['Worker', 
                                                     'Party ID', 
                                                     'Employee ID', 
                                                     'GUID', 
                                                     'Cost Center ID', 
                                                     'Cost Center Name', 
                                                     'Company - Name', 
                                                     'Management Level', 
                                                     'Job Level - Primary Position',
                                                     'Work Email',
                                                     'Employee Status',
                                                     'Hire Date',
                                                     'Worker Type',
                                                     'Contingent Worker Type',
                                                     'Job Category'], right_on = ['Worker',
                                                                                  'Party ID', 
                                                                                  'Employee ID',
                                                                                  'GUID', 
                                                                                  'Cost Center ID', 
                                                                                  'Cost Center Name', 
                                                                                  'Company - Name', 
                                                                                  'Management Level', 
                                                                                  'Job Level - Primary Position',
                                                                                  'Work Email',
                                                                                  'Employee Status',
                                                                                  'Hire Date',
                                                                                  'Worker Type',
                                                                                  'Contingent Worker Type',
                                                                                  'Job Category'], indicator = 'Exists_df1_df2')

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
display(dfwd1)
# Out:
#                 Worker  Employee ID                              Party ID  \
# 0  Johane van der Walt    100733373  959b547b-f631-411f-9189-e67fb1cb24b2
#
#             GUID Employee Status                   Work Email  Hire Date  \
# 0  jvanderwal008          Active  johane.van.der.walt@pwc.com 2019-01-01
#
#   Worker Type Contingent Worker Type     Job Category  Management Level  \
# 0    Employee                    NaN  Client Services  Senior Associate
#
#   Job Level - Primary Position Country/Territory Line of Service  \
# 0                          NaN      South Africa       Assurance
#
#   Assignment Reason (Alternative) Host Country (Alternative)  \
# 0                             NaN                        NaN
#
#   Host Country / Territory                             Company - Name  \
# 0                      NaN  PricewaterhouseCoopers South African Firm
#
#   Company Hierarchy                  Company Reference ID Cost Center ID  \
# 0  PwC South Africa  12d8572e-11f3-49b4-825b-460fff699f79         ZA0110
#
#              Cost Center Name Termination Date  \
# 0  ZA - ASS - Audit - General              NaT
#
#   Country/Territory of Work Location Country Cost Center Level 3  \
# 0                                NaN     NaN                 NaN
#
#   Exists_df1_df2
# 0      left_only

# %%
dfwd2 = pd.merge(dfwd1, df3, how = 'outer', left_on = ['Worker', 
                                                       'Party ID', 
                                                       'Employee ID', 
                                                       'GUID', 
                                                       'Cost Center ID', 
                                                       'Cost Center Name', 
                                                       'Company - Name', 
                                                       'Management Level', 
                                                       'Job Level - Primary Position',
                                                       'Work Email',
                                                       'Employee Status',
                                                       'Hire Date',
                                                       'Worker Type',
                                                       'Contingent Worker Type',
                                                       'Job Category'], right_on = ['Worker',
                                                                                    'Party ID', 
                                                                                    'Employee ID', 
                                                                                    'GUID', 
                                                                                    'Cost Center ID', 
                                                                                    'Cost Center Name', 
                                                                                    'Company - Name', 
                                                                                    'Management Level', 
                                                                                    'Job Level - Primary Position', 
                                                                                    'Work Email',
                                                                                    'Employee Status',  
                                                                                    'Hire Date', 
                                                                                    'Worker Type', 
                                                                                    'Contingent Worker Type', 
                                                                                    'Job Category'], indicator = 'Exists_dfwd1_df3')

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
display(dfwd2)
# Out:
#                               Worker  Employee ID  \
# 0           Fernanda Soto Fuenzalida    101320196
# 1                        Zezheng Gan    100689987
# 2                        Simon Letko    101074699
# 3              Jan Philipp Boltz [C]    100723663
# 4                        Naeku Edith    101297873
# ...                              ...          ...
# 116240                   Leo Horlitz    101304636
# 116241                    Nida Temaj    101297133
# 116242                  Tobias Lemke    100876064
# 116243  Julius Maximilian Katterbach    101322073
# 116244                  Luca Grädler    101233186
#
#                                     Party ID           GUID Employee Status  \
# 0       00001572-4aa2-4044-8f71-ac0ddf25244a  fsotofuenz001          Active
# 1       0000fb73-0624-4e47-a87b-72bc7d1da06f        zgan005          Active
# 2       000235db-d90f-4881-8774-8bb5c9d8eb76      sletko002          Active
# 3       0005e477-fa19-406e-b5f5-fea23f60afed      jboltz002          Active
# 4       0005e8e3-8346-4353-8467-e99c1824f9c2      nedith001          Active
# ...                                      ...            ...             ...
# 116240  ff7616e0-e202-449e-a38b-f4d3b4c7c1a0    lhorlitz001     Future Hire
# 116241  ff8a05a2-3516-4098-8a41-a9511cd71b53      ntemaj001     Future Hire
# 116242  ffeb5e4f-aa38-48df-96c0-18736a1b5391      tlemke001     Future Hire
# 116243  fffa8e46-154f-4631-82fb-6df02ac1ee79            NaN     Future Hire
# 116244  fffb6356-c779-4e5f-83fb-57b915857986            NaN     Future Hire
#
#                               Work Email  Hire Date        Worker Type  \
# 0       fernanda.soto.fuenzalida@pwc.com 2022-10-03           Employee
# 1                    zezheng.gan@pwc.com 2018-09-01           Employee
# 2                  simon.l.letko@pwc.com 2022-09-12           Employee
# 3              jan.philipp.boltz@pwc.com 2018-07-01  Contingent Worker
# 4                    naeku.edith@pwc.com 2022-09-01           Employee
# ...                                  ...        ...                ...
# 116240               leo.horlitz@pwc.com 2022-11-01           Employee
# 116241                               NaN 2022-10-15           Employee
# 116242                               NaN 2023-01-01           Employee
# 116243                               NaN 2023-03-01           Employee
# 116244                               NaN 2023-01-15           Employee
#
#        Contingent Worker Type      Job Category  Management Level  \
# 0                         NaN   Client Services         Associate
# 1                         NaN   Client Services  Senior Associate
# 2                         NaN   Client Services        Specialist
# 3                      Vendor  Practice Support        Specialist
# 4                         NaN   Client Services         Associate
# ...                       ...               ...               ...
# 116240                    NaN   Client Services         Associate
# 116241                    NaN   Client Services    Intern/Trainee
# 116242                    NaN   Client Services           Manager
# 116243                    NaN   Client Services    Intern/Trainee
# 116244                    NaN   Client Services    Intern/Trainee
#
#        Job Level - Primary Position Country/Territory         Line of Service  \
# 0                               NaN             Chile               Assurance
# 1                Senior Associate 2       Netherlands               Assurance
# 2                      Specialist 5           Austria               Assurance
# 3                               NaN           Germany  Internal Firm Services
# 4                               NaN             Kenya               Assurance
# ...                             ...               ...                     ...
# 116240                          NaN               NaN                     NaN
# 116241                          NaN               NaN                     NaN
# 116242                          NaN               NaN                     NaN
# 116243                          NaN               NaN                     NaN
# 116244                          NaN               NaN                     NaN
#
#        Assignment Reason (Alternative) Host Country (Alternative)  \
# 0                                  NaN                        NaN
# 1                                  NaN                        NaN
# 2                                  NaN                        NaN
# 3                                  NaN                        NaN
# 4                                  NaN                        NaN
# ...                                ...                        ...
# 116240                             NaN                        NaN
# 116241                             NaN                        NaN
# 116242                             NaN                        NaN
# 116243                             NaN                        NaN
# 116244                             NaN                        NaN
#
#        Host Country / Territory  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...                         ...
# 116240                      NaN
# 116241                      NaN
# 116242                      NaN
# 116243                      NaN
# 116244                      NaN
#
#                                            Company - Name Company Hierarchy_x  \
# 0        PricewaterhouseCoopers Consultores Auditores SpA           PwC Chile
# 1                                    PwC Accountants N.V.     PwC Netherlands
# 2       PwC Österreich GmbH Wirtschaftsprüfungsgesells...         PwC Austria
# 3       PRICEWATERHOUSECOOPERS Gesellschaft mit beschr...         PwC Germany
# 4                          PricewaterhouseCoopers Limited           PwC Kenya
# ...                                                   ...                 ...
# 116240                         PwC Strategy& Germany GmbH                 NaN
# 116241  PRICEWATERHOUSECOOPERS Gesellschaft mit beschr...                 NaN
# 116242  PRICEWATERHOUSECOOPERS Gesellschaft mit beschr...                 NaN
# 116243  PRICEWATERHOUSECOOPERS Gesellschaft mit beschr...                 NaN
# 116244  PRICEWATERHOUSECOOPERS Gesellschaft mit beschr...                 NaN
#
#                       Company Reference ID_x Cost Center ID  \
# 0       28ce8e3b-59fe-40e5-8d31-1bc6ee893c79         CLS110
# 1       f30abfab-4c61-4f45-b40c-1ab13706fd3c     NL12000412
# 2       5715ad3e-bf5d-46a2-a831-e68192667608     AT18000019
# 3       ff6d5af8-9ae6-47d9-8317-eaa8b0e2e7b9     DE01000238
# 4       14ee24e4-336a-4c9d-8a3f-cc5ff691c6ce         KE0183
# ...                                      ...            ...
# 116240                                   NaN     DEZ1010001
# 116241                                   NaN     DE01001163
# 116242                                   NaN     DE01000632
# 116243                                   NaN     DE01000221
# 116244                                   NaN     DE01000194
#
#                      Cost Center Name Termination Date  \
# 0           CL-ASS-Santiago-Assurance              NaT
# 1                             BAS SRG              NaT
# 2                      ASS FS Banking              NaT
# 3                     INFRA FS Berlin              NaT
# 4               KE - ASS - RAS - ITRA              NaT
# ...                               ...              ...
# 116240           ADV SC DE Consulting              NaT
# 116241                FwM New Venture              NaT
# 116242           ADV BC FS Consulting              NaT
# 116243  ADV TR Mergers & Acquisitions              NaT
# 116244                   ASR IS Mitte              NaT
#
#        Country/Territory of Work Location Country Cost Center Level 3_x  \
# 0                                     NaN     NaN                   NaN
# 1                                     NaN     NaN                   NaN
# 2                                     NaN     NaN                   NaN
# 3                                     NaN     NaN                   NaN
# 4                                     NaN     NaN                   NaN
# ...                                   ...     ...                   ...
# 116240                                NaN     NaN                   NaN
# 116241                                NaN     NaN                   NaN
# 116242                                NaN     NaN                   NaN
# 116243                                NaN     NaN                   NaN
# 116244                                NaN     NaN                   NaN
#
#        Exists_df1_df2 Is Inbound IA? (Exception Process)  \
# 0           left_only                                NaN
# 1           left_only                                NaN
# 2           left_only                                NaN
# 3           left_only                                NaN
# 4           left_only                                NaN
# ...               ...                                ...
# 116240            NaN                                 No
# 116241            NaN                                 No
# 116242            NaN                                 No
# 116243            NaN                                 No
# 116244            NaN                                 No
#
#        PwC Global Line Of Service Company Hierarchy_y  \
# 0                             NaN                 NaN
# 1                             NaN                 NaN
# 2                             NaN                 NaN
# 3                             NaN                 NaN
# 4                             NaN                 NaN
# ...                           ...                 ...
# 116240                   Advisory         PwC Germany
# 116241     Internal Firm Services         PwC Germany
# 116242                   Advisory         PwC Germany
# 116243                   Advisory         PwC Germany
# 116244                  Assurance         PwC Germany
#
#                       Company Reference ID_y    Cost Center Level 3_y  \
# 0                                        NaN                      NaN
# 1                                        NaN                      NaN
# 2                                        NaN                      NaN
# 3                                        NaN                      NaN
# 4                                        NaN                      NaN
# ...                                      ...                      ...
# 116240  5cc1b3b6-8a15-47d6-b5ad-600d68e496a9             ADV Strategy
# 116241  ff6d5af8-9ae6-47d9-8317-eaa8b0e2e7b9  IFS Firmwide Management
# 116242  ff6d5af8-9ae6-47d9-8317-eaa8b0e2e7b9           ADV Consulting
# 116243  ff6d5af8-9ae6-47d9-8317-eaa8b0e2e7b9                ADV Deals
# 116244  ff6d5af8-9ae6-47d9-8317-eaa8b0e2e7b9                Assurance
#
#        Exists_dfwd1_df3
# 0             left_only
# 1             left_only
# 2             left_only
# 3             left_only
# 4             left_only
# ...                 ...
# 116240       right_only
# 116241       right_only
# 116242       right_only
# 116243       right_only
# 116244       right_only
#
# [116245 rows x 33 columns]

# %%
dfwd2 = pd.merge(dfwd1, df3, how = 'outer', left_on = ['Worker', 
                                                       'Party ID', 
                                                       'Employee ID', 
                                                       'GUID', 
                                                       'Cost Center ID', 
                                                       'Cost Center Name', 
                                                       'Company - Name', 
                                                       'Management Level', 
                                                       'Job Level - Primary Position',
                                                       'Work Email',
                                                       'Employee Status',
                                                       'Hire Date',
                                                       'Worker Type',
                                                       'Contingent Worker Type',
                                                       'Job Category'], right_on = ['Worker',
                                                                                    'Party ID', 
                                                                                    'Employee ID', 
                                                                                    'GUID', 
                                                                                    'Cost Center ID', 
                                                                                    'Cost Center Name', 
                                                                                    'Company - Name', 
                                                                                    'Management Level', 
                                                                                    'Job Level - Primary Position', 
                                                                                    'Work Email',
                                                                                    'Employee Status',  
                                                                                    'Hire Date', 
                                                                                    'Worker Type', 
                                                                                    'Contingent Worker Type', 
                                                                                    'Job Category'], indicator = 'Exists_dfwd1_df3')


pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

col = dfwd2['Party ID']
dfwd2.insert(0, 'WD_PartyID', col)

col = dfwd2['Employee ID']
dfwd2.insert(1, 'WD_EmployeeID', col)

dfwd2.set_index(['WD_PartyID', 'WD_EmployeeID'], inplace  =  True)

col = dfwd2.pop('Employee Status')
dfwd2.insert(2, 'WD_EmployeeStatus', col)

col = dfwd2.pop('Worker')
dfwd2.insert(3, 'WD_Worker', col)

dfwd2['Hire Date'] = pd.to_datetime(dfwd2['Hire Date'], format = '%Y-%m-%d')
col = dfwd2.pop('Hire Date')
dfwd2.insert(4, col.name, col)

dfwd2['Termination Date'] = pd.to_datetime(dfwd2['Termination Date'], format = '%Y-%m-%d')
col = dfwd2.pop('Termination Date')
dfwd2.insert(5, col.name, col)

col = dfwd2.pop('GUID')
dfwd2.insert(6, 'WD_GUID', col)

dfwd2['Line of Service Build'] = dfwd2['Line of Service'].fillna(dfwd2['Cost Center Level 3_x']).fillna(dfwd2['Cost Center Level 3_y']).fillna(dfwd2['PwC Global Line Of Service'])
dfwd2.insert(7, 'LoS', dfwd2['Line of Service Build'])
dfwd2 = dfwd2.drop(columns = ['Line of Service', 'Cost Center Level 3_x', 'Cost Center Level 3_y', 'PwC Global Line Of Service', 'Line of Service Build'])

col = dfwd2.pop('Job Level - Primary Position')
dfwd2.insert(7, 'Role Level', col)

dfwd2['Role LoS Build'] = dfwd2['Role Level'].fillna(dfwd2['LoS'])
dfwd2.insert(7, 'WD_LoS', dfwd2['Role LoS Build'])
dfwd2 = dfwd2.drop(columns = ['Role Level', 'LoS', 'Role LoS Build'])

col = dfwd2.pop('Cost Center ID')
dfwd2.insert(8, 'WD_CC_Code', col)

col = dfwd2.pop('Cost Center Name')
dfwd2.insert(9, 'WD_CC_Name', col)

dfwd2['Company Reference ID Build'] = dfwd2['Company Reference ID_x'].fillna(dfwd2['Company Reference ID_y'])
dfwd2.insert(10, 'WD_CR_Code', dfwd2['Company Reference ID Build'])
dfwd2 = dfwd2.drop(columns = ['Company Reference ID_x', 'Company Reference ID_y', 'Company Reference ID Build'])

dfwd2['Company Hierarchy Build'] = dfwd2['Company Hierarchy_x'].fillna(dfwd2['Company Hierarchy_y'])
dfwd2.insert(11, 'WD_CompanyHierarchy', dfwd2['Company Hierarchy Build'])
dfwd2 = dfwd2.drop(columns = ['Company Hierarchy_x', 'Company Hierarchy_y', 'Company Hierarchy Build'])

dfwd2['Host Country Build'] = dfwd2['Host Country (Alternative)'].fillna(dfwd2['Country'])
dfwd2.insert(12, 'Host Country', dfwd2['Host Country Build'])
dfwd2 = dfwd2.drop(columns = ['Host Country (Alternative)', 'Country', 'Host Country Build'])

dfwd2['Country/Territory Build'] = dfwd2['Country/Territory'].fillna(dfwd2['Host Country / Territory']).fillna(dfwd2['Country/Territory of Work Location'])
dfwd2.insert(12, 'Location', dfwd2['Country/Territory Build'])
dfwd2 = dfwd2.drop(columns = ['Country/Territory', 'Host Country / Territory', 'Country/Territory of Work Location', 'Country/Territory Build'])

if dfwd2['WD_EmployeeStatus'].iteritems() == 'Secondment':
    if dfwd2[(dfwd2['Assignment Reason (Alternative)'] != 'No Longer on Assignment (Long)')]:
        if dfwd2[len(dfwd2['Host Country (Alternative)']) == 0]:
            dfwd2['Territory'] = dfwd2['Host Country (Alternative)']
elif dfwd2['WD_EmployeeStatus'].iteritems() == 'Secondment': 
    if dfwd2[(dfwd2['Assignment Reason (Alternative)'] != 'No Longer on Assignment (Long)')]:
        if dfwd2[len(dfwd2['Host Country / Territory']) == 0]: 
            dfwd2['Territory'] = dfwd2['Host Country / Territory'] 
else:
    dfwd2['Territory'] = dfwd2['WD_CompanyHierarchy'].str.replace('PwC ', '')

dfwd2 = dfwd2.drop(columns = ['Assignment Reason (Alternative)'])
    
dfwd2['Country Build'] = dfwd2['Territory'].fillna(dfwd2['Location']).fillna(dfwd2['Host Country'])
dfwd2.insert(12, 'WD_Country', dfwd2['Country Build'])
dfwd2 = dfwd2.drop(columns = ['Territory', 'Location', 'Host Country', 'Country Build'])

#dfwd2['WD_CompanyHierarchy'] = dfwd2.loc[dfwd2['WD_CompanyHierarchy'] == 'None'] = 'PwC ' + dfwd2['WD_Country']
#dffill = dfwd2.iloc[:, [10,11]].copy().drop_duplicates().dropna()
#
#for Code, CH in enumerate(dffill['WD_CompanyHierarchy']):
#    dfwd2['WD_CR_Code'] = dfwd2.iloc[(dfwd2['WD_CR_Code'] == 'None') & (vals[1] == str(dfwd2['WD_CompanyHierarchy']))] = dffill['WD_CR_Code'] 
               
#dfwd2['WD_CR_Code'] = dfwd2['WD_CR_Code'].fillna(dfwd2['WD_CR_Code'].where(dfwd2['WD_CompanyHierarchy'].items().drop_duplicates().dropna() == dffill['WD_CompanyHierarchy'].items()), inplace = True)

col = dfwd2.pop('Company - Name')
dfwd2.insert(13, 'WD_LE_Name', col)

col = dfwd2.pop('Management Level')
dfwd2.insert(14, 'WD_Role', col)

col = dfwd2.pop('Work Email')
dfwd2.insert(15, 'WD_Email', col)

col = dfwd2.pop('Worker Type')
dfwd2.insert(16, 'WD_WorkerType', col)

col = dfwd2.pop('Job Category')
dfwd2.insert(17, 'WD_JobCategory', col)

col = dfwd2.pop('Contingent Worker Type')
dfwd2.insert(18, 'WD_CW_Type', col)

col = dfwd2.pop('Is Inbound IA? (Exception Process)')
dfwd2.insert(19, 'Is IA?', col)

#dfwd2 = dfwd2.sort_values([dfwd2.index,'Termination Date'])
dfwd2 = dfwd2.loc[((dfwd2.groupby(dfwd2.index)['Hire Date'].transform(max) == dfwd2['Hire Date']) | (dfwd2.groupby(dfwd2.index)['Termination Date'].transform(max) == dfwd2['Termination Date']))]

dfwd2 = dfwd2.drop_duplicates()
#dfwd2 = dfwd2.sort_values(['WD_PartyID','WD_EmployeeID','Termination Date'])

dfwd2 = dfwd2.sort_values(by=['WD_PartyID','WD_EmployeeID', 'Hire Date'], ascending = True)

count1 = dfwd2['Party ID'].value_counts()
count1 = pd.DataFrame({'Party ID':count1.index, 'CountPID':count1.values})
dfwd2 = pd.merge(dfwd2, count1, on = 'Party ID', how = 'outer')

count2 = dfwd2['Employee ID'].value_counts()
count2 = pd.DataFrame({'Employee ID':count2.index, 'CountEID':count2.values})
dfwd2 = pd.merge(dfwd2, count2, on = 'Employee ID', how = 'outer')

col = dfwd2.pop('Party ID')
dfwd2.insert(0, 'WD_PartyID', col)

col = dfwd2.pop('Employee ID')
dfwd2.insert(1, 'WD_EmployeeID', col)

dfwd2['record_no'] = np.arange(len(dfwd2))+1
rcount = dfwd2.pop('record_no')
dfwd2.insert(0, rcount.name, rcount)
dfwd2['binary'] = dfwd2['WD_PartyID'].shift(1, fill_value = dfwd2['WD_PartyID'].head(1)) != dfwd2['WD_PartyID']
dfwd2['parent_id'] = dfwd2['WD_PartyID'].groupby((dfwd2['binary']).cumsum()).cumcount()+1

col = dfwd2.pop('parent_id')
dfwd2.insert(1, col.name, col)

dfwd2 = dfwd2.loc[~((dfwd2['Exists_df1_df2'] == 'right_only') & (dfwd2['WD_EmployeeStatus'] == 'Active'))]
#dfwd2 = dfwd2.loc[~((dfwd2['Hire Date'].isnull()) & (dfwd2['Termination Date'].isnull()))]

columns = list(dfwd2)
corecol = list(columns[2:20])
corecol.remove('Hire Date')
corecol.remove('Termination Date')
print(corecol)

for column in enumerate(corecol):
    #display(blocks)
    dfwd2[f'{column[1]}'] = dfwd2[f'{column[1]}'].fillna(dfwd2[f'{column[1]}'].groupby(dfwd2['WD_PartyID']).ffill().where(dfwd2['parent_id'].eq(2)))
    dfwd2[f'{column[1]}'] = dfwd2[f'{column[1]}'].fillna(dfwd2[f'{column[1]}'].groupby(dfwd2['WD_PartyID']).bfill().where((dfwd2['parent_id'].eq(1)) & (dfwd2['Exists_df1_df2'].eq('left_only'))))

dfwd2 = dfwd2.drop(columns = ['binary'])

#dfwd2 = dfwd2[['WD_PartyID',
# 'WD_EmployeeID',
# 'WD_EmployeeStatus',
# 'Status Details',
# 'Employee Status_x',
# 'Employee Status_y',
# 'WD_Worker',
# 'Hire_Date',
# 'Hire Date',
# 'Hire Date_x',
# 'Hire Date_y',
# 'Termination Date',b
# 'WD_GUID',
# 'WD_LoS',
# 'WD_CC_Code',
# 'WD_CC_Name',
# 'WD_CR_Code',b
# 'WD_CompanyHierarchy',
# 'WD_Country',
# 'WD_LE_Name',
# 'WD_Role',
# 'WD_Email',
# 'WD_WorkerType',
# 'WD_JobCategory',
# 'WD_CW_Type',
# 'Is IA?',
# 'Exists_df1_df2',
# 'Exists_dfwd1_df3',
# 'CountPID',
# 'CountEID']]

display(dfwd2)

#dfwd2['WD_CompanyHierarchy'] = dfwd2.loc[dfwd2['WD_CompanyHierarchy'] == 'None'] = 'PwC ' + dfwd2['WD_Country']
#dffill = dfwd2.iloc[:, [12,13]].copy().drop_duplicates().dropna().reset_index(drop = True)
#dffill = dffill.drop(columns = ['index'])
# Out:
# <ipython-input-213-f7f1be257553>:93: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   if dfwd2['WD_EmployeeStatus'].iteritems() == 'Secondment':
# <ipython-input-213-f7f1be257553>:97: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   elif dfwd2['WD_EmployeeStatus'].iteritems() == 'Secondment':
# ['WD_PartyID', 'WD_EmployeeID', 'WD_EmployeeStatus', 'WD_Worker', 'WD_GUID', 'WD_LoS', 'WD_CC_Code', 'WD_CC_Name', 'WD_CR_Code', 'WD_CompanyHierarchy', 'WD_Country', 'WD_LE_Name', 'WD_Role', 'WD_Email', 'WD_WorkerType', 'WD_JobCategory']
#         record_no  parent_id                            WD_PartyID  \
# 0               1          1  00001572-4aa2-4044-8f71-ac0ddf25244a
# 1               2          1  0000f2dc-783c-4671-947b-c71abdc861ae
# 2               3          1  0000fb73-0624-4e47-a87b-72bc7d1da06f
# 3               4          1  000144ca-a440-4a6f-bac2-761143b8c696
# 4               5          1  0001b817-c586-42ad-8ca1-12ea772a35d0
# ...           ...        ...                                   ...
# 113124     113125          1  fffcf0d2-74e9-430f-9a7a-f24c33c67fc4
# 113125     113126          1  fffd5de8-daef-4921-a8a8-26917f907c9b
# 113126     113127          1  fffee51f-77aa-4c64-8b02-1f5b61a4be8e
# 113127     113128          1  fffee8ee-33f8-4b1f-8e59-f89f156f6854
# 113128     113129          1  ffffff30-521c-4cde-a909-e811dbc84a2d
#
#         WD_EmployeeID WD_EmployeeStatus                         WD_Worker  \
# 0           101320196            Active          Fernanda Soto Fuenzalida
# 1           100529169        Terminated                        Karen Chan
# 2           100689987            Active                       Zezheng Gan
# 3           100903149        Terminated                  Maryna Ivantseva
# 4           101041277        Terminated                     Viknesh Maran
# ...               ...               ...                               ...
# 113124      101277365        Terminated  Haikal Husain bin Ahmad Mustaqim
# 113125      101123129        Terminated                     Antje Heissel
# 113126      100880637        Terminated                  Kajal Gayanchand
# 113127      100864650            Active                      Marc Mertens
# 113128      100733231        Terminated                  Madelein Correia
#
#         Hire Date Termination Date        WD_GUID                  WD_LoS  \
# 0      2022-10-03              NaT  fsotofuenz001               Assurance
# 1      2017-07-06       2018-12-31       kchan169                     ASR
# 2      2018-09-01              NaT        zgan005      Senior Associate 2
# 3      2019-09-15       2020-02-24  mivantseva001            SL-3 - TX CT
# 4      2021-01-04       2021-03-12     vmmaran001            Malaysia Top
# ...           ...              ...            ...                     ...
# 113124 2022-07-04       2022-09-30   hmustaqim001            Malaysia Top
# 113125 2022-01-01       2022-03-31    aheissel001               ADV Deals
# 113126 2019-03-01       2020-01-31  kgayanchan001               Assurance
# 113127 2018-11-01              NaT    mmertens011               Assurance
# 113128 2019-01-01       2020-02-29    mcorreia017  Internal Firm Services
#
#         WD_CC_Code                         WD_CC_Name  \
# 0           CLS110          CL-ASS-Santiago-Assurance
# 1           SPP157            SG Risk Services TA SPP
# 2       NL12000412                            BAS SRG
# 3             DNU1                     DNU_S3_Logic_1
# 4           KUL101                      MY ASR IX KUL
# ...            ...                                ...
# 113124      KUL169                     MY ASR RAS KUL
# 113125  DE01000223  ADV TR Business Recovery Services
# 113126        0112                       Audit - TICE
# 113127  DE01000269                        ASR IS West
# 113128        0720          Finance - Africa SSC - EM
#
#                                   WD_CR_Code WD_CompanyHierarchy  \
# 0       28ce8e3b-59fe-40e5-8d31-1bc6ee893c79           PwC Chile
# 1                                        NaN                 NaN
# 2       f30abfab-4c61-4f45-b40c-1ab13706fd3c     PwC Netherlands
# 3                                        NaN                 NaN
# 4                                        NaN                 NaN
# ...                                      ...                 ...
# 113124                                   NaN                 NaN
# 113125                                   NaN                 NaN
# 113126                                   NaN                 NaN
# 113127  ff6d5af8-9ae6-47d9-8317-eaa8b0e2e7b9         PwC Germany
# 113128                                   NaN                 NaN
#
#           WD_Country                                         WD_LE_Name  \
# 0              Chile   PricewaterhouseCoopers Consultores Auditores SpA
# 1          Singapore     PricewaterhouseCoopers Risk Services Pte. Ltd.
# 2        Netherlands                               PwC Accountants N.V.
# 3            Germany  PRICEWATERHOUSECOOPERS Gesellschaft mit beschr...
# 4           Malaysia                         PricewaterhouseCoopers PLT
# ...              ...                                                ...
# 113124      Malaysia     PricewaterhouseCoopers Risk Services Sdn. Bhd.
# 113125       Germany  PRICEWATERHOUSECOOPERS Gesellschaft mit beschr...
# 113126  South Africa          PricewaterhouseCoopers South African Firm
# 113127       Germany  PRICEWATERHOUSECOOPERS Gesellschaft mit beschr...
# 113128  South Africa          PricewaterhouseCoopers South African Firm
#
#                  WD_Role                          WD_Email      WD_WorkerType  \
# 0              Associate  fernanda.soto.fuenzalida@pwc.com           Employee
# 1         Senior Manager           karen.s.chan@sg.pwc.com           Employee
# 2       Senior Associate               zezheng.gan@pwc.com           Employee
# 3         Intern/Trainee          maryna.ivantseva@pwc.com           Employee
# 4         Intern/Trainee       viknessayan.m.maran@pwc.com           Employee
# ...                  ...                               ...                ...
# 113124    Intern/Trainee    haikal.husain.mustaqim@pwc.com           Employee
# 113125    Intern/Trainee             antje.heissel@pwc.com           Employee
# 113126  Senior Associate          kajal.gayanchand@pwc.com           Employee
# 113127    Intern/Trainee              marc.mertens@pwc.com           Employee
# 113128         Associate          madelein.correia@pwc.com  Contingent Worker
#
#           WD_JobCategory  WD_CW_Type Is IA? Exists_df1_df2 Exists_dfwd1_df3  \
# 0        Client Services         NaN    NaN      left_only        left_only
# 1        Client Services         NaN    NaN     right_only        left_only
# 2        Client Services         NaN    NaN      left_only        left_only
# 3        Client Services         NaN    NaN     right_only        left_only
# 4        Client Services         NaN    NaN     right_only        left_only
# ...                  ...         ...    ...            ...              ...
# 113124   Client Services         NaN    NaN     right_only        left_only
# 113125   Client Services         NaN    NaN     right_only        left_only
# 113126   Client Services         NaN    NaN     right_only        left_only
# 113127   Client Services         NaN    NaN      left_only        left_only
# 113128  Practice Support  Contractor    NaN     right_only        left_only
#
#         CountPID  CountEID
# 0              1         1
# 1              1         1
# 2              1         1
# 3              1         1
# 4              1         1
# ...          ...       ...
# 113124         1         1
# 113125         1         1
# 113126         1         1
# 113127         1         1
# 113128         1         1
#
# [109863 rows x 26 columns]

# %%
dfmissing = pd.read_excel("missing.xlsx", usecols = ['WD_PartyID'])

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

dftestA=[]
dftestB=[]
dftestC=[]
for guids in enumerate(dfmissing['WD_PartyID']):
    dfrows1 = df1.loc[df1['Party ID'] == f'{guids[1]}']#.set_index('record_no')
    dfrows2 = df2.loc[df2['Party ID'] == f'{guids[1]}']
    dfrows3 = df3.loc[df3['Party ID'] == f'{guids[1]}']
    dftestA.append(dfrows1)
    dftestB.append(dfrows2)
    dftestC.append(dfrows3)
    

dftestA = pd.concat(dftestA).drop_duplicates()#, axis = 0)
dftestA = dftestA.sort_values(by=['Party ID','Employee ID', 'Hire Date'], ascending = False)

dftestB = pd.concat(dftestB).drop_duplicates()#, axis = 0)
dftestB = dftestB.sort_values(by=['Party ID','Employee ID', 'Hire Date'], ascending = False)

dftestC = pd.concat(dftestC).drop_duplicates()#, axis = 0)
dftestC = dftestC.sort_values(by=['Party ID','Employee ID', 'Hire Date'], ascending = False)
display(dftestA, dftestB, dftestC)

dftestD=[]
for guids in enumerate(dfmissing['WD_PartyID']):
    dfrows4 = dfwd2.loc[dfwd2['WD_PartyID'] == f'{guids[1]}']#.set_index('record_no')
    dftestD.append(dfrows4)

dftestD = pd.concat(dftestD).drop_duplicates()#, axis = 0)
dftestD = dftestD.sort_values(by=['WD_PartyID','WD_EmployeeID', 'Hire Date'], ascending = False)
display(dftestD)

#for GUID in enumerate(dfmissing['WD_PartyID']):
#
##GUID = 'cbb5c850-b7b8-4533-a5b3-5a15c45ddf49'
#
#    dftest1 = df1.loc[df1['Party ID'] == f'{GUID[1]}']
#
#    display(dftest1)
#
#    dftest2 = df2.loc[df2['Party ID'] == f'{GUID[1]}']
#
#    display(dftest2)
#
#    dftest3 = df3.loc[df3['Party ID'] == f'{GUID[1]}']
#
#    display(dftest3)
#
#dftest2 = dfwd2.loc[dfwd2['CountPID'] == '2' & dfwd2['Exists_df1_df2']]

#display(dftest)
# Out:
#                           Worker  Employee ID  \
# 55956        Tarish Abubakar [C]    101322758
# 33225        Maame Esi Arhin [C]    101322757
# 5924   Barimah Yaw Adu-Asare [C]    101322754
#
#                                    Party ID          GUID Employee Status  \
# 55956  f52a1775-24f7-412c-ad06-b1a27f6dc468  tabubakar001          Active
# 33225  c3a8ea83-c4e0-4b01-b695-62de4ba5aa8b     marhin001          Active
# 5924   95cd51df-2e7b-4691-884d-aee0b674be63  baduasare001          Active
#
#                           Work Email Hire Date        Worker Type  \
# 55956        tarish.abubakar@pwc.com       NaT  Contingent Worker
# 33225        maame.esi.arhin@pwc.com       NaT  Contingent Worker
# 5924   barimah.yaw.adu-asare@pwc.com       NaT  Contingent Worker
#
#       Contingent Worker Type     Job Category Management Level  \
# 55956             Contractor  Client Services        Associate
# 33225             Contractor  Client Services        Associate
# 5924              Contractor  Client Services        Associate
#
#       Job Level - Primary Position Country/Territory Line of Service  \
# 55956                          NaN             Ghana        Advisory
# 33225                          NaN             Ghana        Advisory
# 5924                           NaN             Ghana        Advisory
#
#       Assignment Reason (Alternative) Host Country (Alternative)  \
# 55956                             NaN                        NaN
# 33225                             NaN                        NaN
# 5924                              NaN                        NaN
#
#       Host Country / Territory                        Company - Name  \
# 55956                      NaN  PricewaterhouseCoopers Ghana Limited
# 33225                      NaN  PricewaterhouseCoopers Ghana Limited
# 5924                       NaN  PricewaterhouseCoopers Ghana Limited
#
#       Company Hierarchy                  Company Reference ID Cost Center ID  \
# 55956         PwC Ghana  81aa3070-43ab-41c8-9131-0e531cbeed64         GH0605
# 33225         PwC Ghana  81aa3070-43ab-41c8-9131-0e531cbeed64         GH0605
# 5924          PwC Ghana  81aa3070-43ab-41c8-9131-0e531cbeed64         GH0605
#
#                             Cost Center Name
# 55956  GH - ADV - Business Recovery Services
# 33225  GH - ADV - Business Recovery Services
# 5924   GH - ADV - Business Recovery Services
#                         Worker  Employee ID  \
# 47098      Stephanie Blackwell    100951428
# 47097      Stephanie Blackwell    100951428
# 21896  Harry Pottinger-Coombes    101141621
# 15640              Dan Ballard    100720112
# 9683           Andrew Wilshire    100733526
# ...                        ...          ...
# 22063               Helen Pang    100937971
# 25031        Jennifer Phillips    100725047
# 7489           Adam Harrington    100857657
# 7488           Adam Harrington    100857657
# 18766                Ethan Yee    101162788
#
#                                    Party ID           GUID Employee Status  \
# 47098  fe43139c-f693-4dd5-97a7-43cb338ff5fc  sblackwell010          Active
# 47097  fe43139c-f693-4dd5-97a7-43cb338ff5fc  sblackwell010          Active
# 21896  fc4a339f-d648-47b8-8948-abe7ec70a607  hpottinger002          Active
# 15640  f8ec0707-af31-46f7-b751-482054b6686a    dballard005          Active
# 9683   f74a20e2-2973-4e97-a995-b6a2f6990d9d   awilshire001          Active
# ...                                     ...            ...             ...
# 22063  01eaf0db-aa65-46be-9726-4070a41097a0       hpang011          Active
# 25031  017596f5-06e6-4a15-96c8-d445c05c5d15   jphillips061          Active
# 7489   01631675-d943-4e88-a637-880972487c2a  aharringto015          Active
# 7488   01631675-d943-4e88-a637-880972487c2a  aharringto015          Active
# 18766  005a75b0-ed30-4aff-b60a-de25495d3671        eyee010          Active
#
#                               Work Email  Hire Date Termination Date  \
# 47098      stephanie.z.blackwell@pwc.com 2020-02-10       2021-02-12
# 47097      stephanie.z.blackwell@pwc.com 2019-11-18       2020-02-07
# 21896  harry.x.pottinger-coombes@pwc.com 2021-11-15       2022-02-04
# 15640              dan.a.ballard@pwc.com 2017-11-20       2018-02-23
# 9683           andrew.p.wilshire@pwc.com 2015-05-04       2018-06-14
# ...                                  ...        ...              ...
# 22063               helen.z.pang@pwc.com 2019-11-18       2020-02-21
# 25031        jennifer.a.phillips@pwc.com 2000-05-29       2018-04-06
# 7489           adam.h.harrington@pwc.com 2019-11-18       2020-02-12
# 7488           adam.h.harrington@pwc.com 2018-11-19       2019-02-22
# 18766                ethan.r.yee@pwc.com 2022-02-14       2022-07-03
#
#       Worker Type Contingent Worker Type      Job Category  Management Level  \
# 47098    Employee                    NaN   Client Services    Intern/Trainee
# 47097    Employee                    NaN   Client Services    Intern/Trainee
# 21896    Employee                    NaN   Client Services    Intern/Trainee
# 15640    Employee                    NaN   Client Services  Senior Associate
# 9683     Employee                    NaN   Client Services  Senior Associate
# ...           ...                    ...               ...               ...
# 22063    Employee                    NaN   Client Services    Intern/Trainee
# 25031    Employee                    NaN  Practice Support  Senior Associate
# 7489     Employee                    NaN   Client Services    Intern/Trainee
# 7488     Employee                    NaN   Client Services    Intern/Trainee
# 18766    Employee                    NaN   Client Services    Intern/Trainee
#
#       Job Level - Primary Position Country/Territory of Work Location  \
# 47098                          NaN                        New Zealand
# 47097                          NaN                        New Zealand
# 21896                          NaN                        New Zealand
# 15640                          NaN                        New Zealand
# 9683                           NaN                        New Zealand
# ...                            ...                                ...
# 22063                          NaN                        New Zealand
# 25031                          NaN                        New Zealand
# 7489                           NaN                        New Zealand
# 7488                           NaN                        New Zealand
# 18766                          NaN                        New Zealand
#
#            Country          Company - Name          Cost Center Name  \
# 47098  New Zealand  PRICEWATERHOUSECOOPERS                     Deals
# 47097  New Zealand  PRICEWATERHOUSECOOPERS                     Deals
# 21896  New Zealand  PRICEWATERHOUSECOOPERS                  FAS Blue
# 15640  New Zealand  PRICEWATERHOUSECOOPERS       Auckland Regulatory
# 9683   New Zealand  PRICEWATERHOUSECOOPERS     Technology Consulting
# ...            ...                     ...                       ...
# 22063  New Zealand  PRICEWATERHOUSECOOPERS     Wellington Regulatory
# 25031  New Zealand  PRICEWATERHOUSECOOPERS  Auckland Office Services
# 7489   New Zealand  PRICEWATERHOUSECOOPERS         Assurance Waikato
# 7488   New Zealand  PRICEWATERHOUSECOOPERS         Assurance Waikato
# 18766  New Zealand  PRICEWATERHOUSECOOPERS     Wellington Regulatory
#
#       Cost Center ID     Cost Center Level 3
# 47098         NZD311                Advisory
# 47097         NZD311                Advisory
# 21896         NZD200                     Tax
# 15640         NZD105               Assurance
# 9683          NZD392                Advisory
# ...              ...                     ...
# 22063         NZD145               Assurance
# 25031         NZD010  Internal Firm Services
# 7489          NZD332               Assurance
# 7488          NZD332               Assurance
# 18766         NZD145               Assurance
#
# [270 rows x 19 columns]
# Empty DataFrame
# Columns: [Worker, Employee ID, Is Inbound IA? (Exception Process), Party ID, GUID, Employee Status, Hire Date, Work Email, Worker Type, Contingent Worker Type, PwC Global Line Of Service, Job Category, Management Level, Job Level - Primary Position, Company - Name, Company Hierarchy, Company Reference ID, Cost Center ID, Cost Center Name, Cost Center Level 3]
# Index: []
#         record_no  parent_id                            WD_PartyID  \
# 115448     115449          2  fe43139c-f693-4dd5-97a7-43cb338ff5fc
# 115447     115448          1  fe43139c-f693-4dd5-97a7-43cb338ff5fc
# 114611     114612          1  fc4a339f-d648-47b8-8948-abe7ec70a607
# 113095     113096          1  f8ec0707-af31-46f7-b751-482054b6686a
# 112339     112340          1  f74a20e2-2973-4e97-a995-b6a2f6990d9d
# ...           ...        ...                                   ...
# 867           868          1  01eaf0db-aa65-46be-9726-4070a41097a0
# 670           671          1  017596f5-06e6-4a15-96c8-d445c05c5d15
# 631           632          2  01631675-d943-4e88-a637-880972487c2a
# 630           631          1  01631675-d943-4e88-a637-880972487c2a
# 161           162          1  005a75b0-ed30-4aff-b60a-de25495d3671
#
#         WD_EmployeeID WD_EmployeeStatus                WD_Worker  Hire Date  \
# 115448      100951428            Active      Stephanie Blackwell 2020-02-10
# 115447      100951428            Active      Stephanie Blackwell 2019-11-18
# 114611      101141621            Active  Harry Pottinger-Coombes 2021-11-15
# 113095      100720112            Active              Dan Ballard 2017-11-20
# 112339      100733526            Active          Andrew Wilshire 2015-05-04
# ...               ...               ...                      ...        ...
# 867         100937971            Active               Helen Pang 2019-11-18
# 670         100725047            Active        Jennifer Phillips 2000-05-29
# 631         100857657            Active          Adam Harrington 2019-11-18
# 630         100857657            Active          Adam Harrington 2018-11-19
# 161         101162788            Active                Ethan Yee 2022-02-14
#
#        Termination Date        WD_GUID                  WD_LoS WD_CC_Code  \
# 115448       2021-02-12  sblackwell010                Advisory     NZD311
# 115447       2020-02-07  sblackwell010                Advisory     NZD311
# 114611       2022-02-04  hpottinger002                     Tax     NZD200
# 113095       2018-02-23    dballard005               Assurance     NZD105
# 112339       2018-06-14   awilshire001                Advisory     NZD392
# ...                 ...            ...                     ...        ...
# 867          2020-02-21       hpang011               Assurance     NZD145
# 670          2018-04-06   jphillips061  Internal Firm Services     NZD010
# 631          2020-02-12  aharringto015               Assurance     NZD332
# 630          2019-02-22  aharringto015               Assurance     NZD332
# 161          2022-07-03        eyee010               Assurance     NZD145
#
#                       WD_CC_Name WD_CR_Code WD_CompanyHierarchy   WD_Country  \
# 115448                     Deals        NaN                 NaN  New Zealand
# 115447                     Deals        NaN                 NaN  New Zealand
# 114611                  FAS Blue        NaN                 NaN  New Zealand
# 113095       Auckland Regulatory        NaN                 NaN  New Zealand
# 112339     Technology Consulting        NaN                 NaN  New Zealand
# ...                          ...        ...                 ...          ...
# 867        Wellington Regulatory        NaN                 NaN  New Zealand
# 670     Auckland Office Services        NaN                 NaN  New Zealand
# 631            Assurance Waikato        NaN                 NaN  New Zealand
# 630            Assurance Waikato        NaN                 NaN  New Zealand
# 161        Wellington Regulatory        NaN                 NaN  New Zealand
#
#                     WD_LE_Name           WD_Role  \
# 115448  PRICEWATERHOUSECOOPERS    Intern/Trainee
# 115447  PRICEWATERHOUSECOOPERS    Intern/Trainee
# 114611  PRICEWATERHOUSECOOPERS    Intern/Trainee
# 113095  PRICEWATERHOUSECOOPERS  Senior Associate
# 112339  PRICEWATERHOUSECOOPERS  Senior Associate
# ...                        ...               ...
# 867     PRICEWATERHOUSECOOPERS    Intern/Trainee
# 670     PRICEWATERHOUSECOOPERS  Senior Associate
# 631     PRICEWATERHOUSECOOPERS    Intern/Trainee
# 630     PRICEWATERHOUSECOOPERS    Intern/Trainee
# 161     PRICEWATERHOUSECOOPERS    Intern/Trainee
#
#                                  WD_Email WD_WorkerType    WD_JobCategory  \
# 115448      stephanie.z.blackwell@pwc.com      Employee   Client Services
# 115447      stephanie.z.blackwell@pwc.com      Employee   Client Services
# 114611  harry.x.pottinger-coombes@pwc.com      Employee   Client Services
# 113095              dan.a.ballard@pwc.com      Employee   Client Services
# 112339          andrew.p.wilshire@pwc.com      Employee   Client Services
# ...                                   ...           ...               ...
# 867                  helen.z.pang@pwc.com      Employee   Client Services
# 670           jennifer.a.phillips@pwc.com      Employee  Practice Support
# 631             adam.h.harrington@pwc.com      Employee   Client Services
# 630             adam.h.harrington@pwc.com      Employee   Client Services
# 161                   ethan.r.yee@pwc.com      Employee   Client Services
#
#        WD_CW_Type Is IA? Exists_df1_df2 Exists_dfwd1_df3  CountPID  CountEID
# 115448        NaN    NaN     right_only        left_only         2         2
# 115447        NaN    NaN     right_only        left_only         2         2
# 114611        NaN    NaN     right_only        left_only         1         1
# 113095        NaN    NaN     right_only        left_only         1         1
# 112339        NaN    NaN     right_only        left_only         1         1
# ...           ...    ...            ...              ...       ...       ...
# 867           NaN    NaN     right_only        left_only         2         2
# 670           NaN    NaN     right_only        left_only         1         1
# 631           NaN    NaN     right_only        left_only         2         2
# 630           NaN    NaN     right_only        left_only         2         2
# 161           NaN    NaN     right_only        left_only         1         1
#
# [273 rows x 26 columns]

# %%
display(dffill)
# Out:
#                                WD_CR_Code WD_CompanyHierarchy
# 0    28ce8e3b-59fe-40e5-8d31-1bc6ee893c79           PwC Chile
# 1    f30abfab-4c61-4f45-b40c-1ab13706fd3c     PwC Netherlands
# 2    5715ad3e-bf5d-46a2-a831-e68192667608         PwC Austria
# 3    ff6d5af8-9ae6-47d9-8317-eaa8b0e2e7b9         PwC Germany
# 4    14ee24e4-336a-4c9d-8a3f-cc5ff691c6ce           PwC Kenya
# ..                                    ...                 ...
# 149  0abcc8a7-5a5b-4a8c-974e-161a251ea209       PwC Venezuela
# 150  361c4252-b69e-43a9-9dbc-f9b61fc31871          PwC Malawi
# 151  26b442d4-41e9-4810-beae-15a8b17e005f       PwC Mauritius
# 152  12e1b0f7-cb27-4029-ae7c-ed87f200caea          PwC Rwanda
# 153  f0f98c7d-decb-4f3f-b7ba-4f2e1d9930a3          PwC Uganda
#
# [154 rows x 2 columns]

# %%
for index, rows in dffill.iterrows():
    print(rows[0], rows[1])#,row[1])
    dfwd2['WD_CR_Code'] = dfwd2.loc[(dfwd2['WD_CR_Code'] == 'None') & (f'{rows[1]}' == dfwd2['WD_CompanyHierarchy'].)] = f'{rows[0]}'
display(dfwd2)
# Out:
# 28ce8e3b-59fe-40e5-8d31-1bc6ee893c79 PwC Chile
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-147-ad062fb91d0d> in <module>
#       1 for index, rows in dffill.iterrows():
#       2     print(rows[0], rows[1])#,row[1])
# ----> 3     dfwd2['WD_CR_Code'] = dfwd2.loc[(dfwd2['WD_CR_Code'] == 'None') & (f'{rows[1]}' == dfwd2['WD_CompanyHierarchy'].item())] = f'{rows[0]}'
#       4 display(dfwd2)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\base.py in item(self)
#     345         if len(self) == 1:
#     346             return next(iter(self))
# --> 347         raise ValueError("can only convert an array of size 1 to a Python scalar")
#     348
#     349     @property
#
# ValueError: can only convert an array of size 1 to a Python scalar

# %%
#dftest4 = dfwd2.loc[(dfwd2['WD_CR_Code'].isnull())]
dftest5 = dfwd2.loc[(dfwd2['CountPID'] == 2) & (dfwd2['WD_GUID'].isnull())]
#dftest4 = dfwd2.loc[(dfwd2['WD_GUID'].isnull()) & (dfwd2['Exists_df1_df2'] == 'right_only') & (dfwd2['CountPID'] == 2)]
#display(dftest4)

#dftest5 = dfwd2.loc[(dfwd2['WD_CompanyHierarchy'].isnull())]
#dftest = dfwd2.loc[(dfwd2['CountPID'] == 2) & (dfwd2['WD_GUID'].isnull())]
#dftest = dfwd2.loc[(dfwd2['WD_GUID'].isnull()) & (dfwd2['Exists_df1_df2'] == 'right_only') & (dfwd2['CountPID'] == 2)]
#display(dftest5)

dftest13 = []
for guids in enumerate(dftest5['WD_PartyID']):
    dfrows = dfwd2.loc[dfwd2['WD_PartyID'] == f'{guids[1]}']#.set_index('record_no')
    dftest13.append(dfrows)
#display(dftest13)
dftest13 = pd.concat(dftest13).drop_duplicates()#, axis = 0)
dftest13 = dftest13.sort_values(by=['WD_PartyID','WD_EmployeeID', 'Hire Date'], ascending = False)
display(dftest13)


#dftest2 = dfwd2.loc[dfwd2['CountPID'] == '2' & dfwd2['Exists_df1_df2']]

#display(dftest)
# Out:
#        record_no  parent_id                            WD_PartyID  \
# 87431      87432          2  cbb5c850-b7b8-4533-a5b3-5a15c45ddf49
# 87430      87431          1  cbb5c850-b7b8-4533-a5b3-5a15c45ddf49
# 86669      86670          2  c9c5d53b-4d40-475c-b25a-5b5258fab0ea
# 86668      86669          1  c9c5d53b-4d40-475c-b25a-5b5258fab0ea
# 64449      64450          2  96bf0ba2-9b1f-4934-b1bb-58a3cb574176
# 64448      64449          1  96bf0ba2-9b1f-4934-b1bb-58a3cb574176
# 54694      54695          2  7fe3a72b-2de1-42f6-b1ee-53b1c1533b48
# 54693      54694          1  7fe3a72b-2de1-42f6-b1ee-53b1c1533b48
# 47561      47562          2  6f16bc4b-df2c-4d85-9b8c-fab1c1cd1068
# 47560      47561          1  6f16bc4b-df2c-4d85-9b8c-fab1c1cd1068
#
#        WD_EmployeeID WD_EmployeeStatus                      WD_Worker  \
# 87431      101252664       Future Hire  Isaac Jonathan Santos Riveros
# 87430      101219771        Terminated  Isaac Jonathan Santos Riveros
# 86669      100949407        Terminated                Portia Maheneza
# 86668      100880178        Terminated                Portia Maheneza
# 64449      100880053        Terminated           Nur Athirah Ab Razak
# 64448      100836976        Terminated           Nur Athirah Ab Razak
# 54694      100880650            Active            Samantha Murphy [C]
# 54693      100733458        Terminated                  Samantha King
# 47561      100939095        Terminated   Saraí Yanire Godoy Gutierrez
# 47560      100752749        Terminated                    Sarai Godoy
#
#        Hire Date Termination Date    WD_GUID             WD_LoS  WD_CC_Code  \
# 87431 2022-11-01              NaT        NaN                Tax  GXD1000001
# 87430 2022-06-01       2022-06-01        NaN                Tax  DE01000213
# 86669 2019-10-14       2019-10-15        NaN          Assurance        0110
# 86668 2019-02-06       2019-03-08        NaN          Assurance        0120
# 64449 2019-02-18       2019-08-16        NaN     MYS Consulting      KUL542
# 64448 2018-02-05       2019-02-04        NaN     MYS Consulting      KUL546
# 54694 2019-02-01              NaT   sking084                Tax      ZA0385
# 54693 2018-10-01       2019-01-31        NaN                Tax        0307
# 47561 2019-09-03       2021-07-31  sgodoy005  Assurance [Lvl 1]      CLS240
# 47560 2016-12-04       2018-03-01        NaN        Associate 2         212
#
#                                     WD_CC_Name  \
# 87431                                Gx DE Tax
# 87430                                  T&L P&O
# 86669                          Audit - General
# 86668                     PCS - F&A Consulting
# 64449                   MY CON TECH_PwCCSM KUL
# 64448                    MY CON EAC_PwCCSM KUL
# 54694         ZA - TAX - Indirect - Compliance
# 54693       Tax - CIT Domestic Corporate Tax 3
# 47561  CL-ASS-SANTIAGO-Auditoria Interna (GRC)
# 47560      SPA (SYSTEMS AND PROCESS ASSURANCE)
#
#                                  WD_CR_Code WD_CompanyHierarchy    WD_Country  \
# 87431  93c2010d-0888-40a7-a3cf-d4f07959dad4         PwC Germany       Germany
# 87430                                   NaN                 NaN       Germany
# 86669                                   NaN                 NaN  South Africa
# 86668                                   NaN                 NaN  South Africa
# 64449                                   NaN                 NaN      Malaysia
# 64448                                   NaN                 NaN      Malaysia
# 54694  12d8572e-11f3-49b4-825b-460fff699f79    PwC South Africa  South Africa
# 54693                                   NaN                 NaN  South Africa
# 47561                                   NaN                 NaN         Chile
# 47560                                   NaN                 NaN         Chile
#
#                                               WD_LE_Name           WD_Role  \
# 87431     Galaxy Germany Steuerberatungsgesellschaft mbH         Associate
# 87430  PRICEWATERHOUSECOOPERS Gesellschaft mit beschr...         Associate
# 86669          PricewaterhouseCoopers South African Firm    Administrative
# 86668          PricewaterhouseCoopers South African Firm         Associate
# 64449              PwC Consulting Services (M) Sdn. Bhd.         Associate
# 64448              PwC Consulting Services (M) Sdn. Bhd.    Intern/Trainee
# 54694          PricewaterhouseCoopers South African Firm           Manager
# 54693          PricewaterhouseCoopers South African Firm           Manager
# 47561   PricewaterhouseCoopers Consultores Auditores SpA  Senior Associate
# 47560   PricewaterhouseCoopers Consultores Auditores SpA         Associate
#
#                            WD_Email      WD_WorkerType   WD_JobCategory  \
# 87431                           NaN           Employee  Client Services
# 87430                           NaN           Employee  Client Services
# 86669                           NaN           Employee  Client Services
# 86668                           NaN  Contingent Worker  Client Services
# 64449  nur.athirah.ab.razak@pwc.com  Contingent Worker  Client Services
# 64448  nur.athirah.ab.razak@pwc.com           Employee  Client Services
# 54694       samantha.w.king@pwc.com  Contingent Worker  Client Services
# 54693       samantha.w.king@pwc.com  Contingent Worker  Client Services
# 47561           sarai.godoy@pwc.com           Employee  Client Services
# 47560               noemail@pwc.com           Employee  Client Services
#
#        WD_CW_Type Is IA? Exists_df1_df2 Exists_dfwd1_df3  CountPID  CountEID
# 87431         NaN    Yes            NaN       right_only         2         1
# 87430         NaN    NaN     right_only        left_only         2         1
# 86669         NaN    NaN     right_only        left_only         2         1
# 86668  Contractor    NaN     right_only        left_only         2         1
# 64449  Contractor    NaN     right_only        left_only         2         1
# 64448         NaN    NaN     right_only        left_only         2         1
# 54694  Contractor    NaN      left_only        left_only         2         1
# 54693  Contractor    NaN     right_only        left_only         2         1
# 47561         NaN    NaN     right_only        left_only         2         1
# 47560         NaN    NaN     right_only        left_only         2         1

# %%
#def write_excel(filename, sheetname, dataframe):
#    with pd.ExcelWriter(filename, engine='openpyxl', mode='a') as writer:
#        workbook = writer.book
#        try:
#            workbook.remove(workbook[sheetname])
#        except:
#            print("Worksheet does not exist")
#        finally:
#            dataframe.to_excel(writer, sheet_name=sheetname, index = False)
#
#write_excel('test.xlsx', 'Sheet1', dfwd2)

dfwd2.to_excel('WDLongTesting-ColumnFillLoop.xlsx')
# Out:
# <ipython-input-42-18a6b244802f>:13: UserWarning: Pandas requires version '1.4.3' or newer of 'xlsxwriter' (version '1.3.7' currently installed).
#   dfwd2.to_excel('WDLongTesting-ColumnFillLoop.xlsx')

# %%
import datacompy, pandas as pd, pyspark, io

compare = datacompy.Compare(df1, df2, join_columns = ['Worker',
                                                      'Party ID', 
                                                      'Employee ID', 
                                                      'GUID', 
                                                      'Cost Center ID', 
                                                      'Cost Center Name', 
                                                      'Company - Name', 
                                                      'Management Level', 
                                                      'Job Level - Primary Position', 
                                                      'Work Email',
                                                      'Employee Status',  
                                                      'Hire Date', 
                                                      'Worker Type', 
                                                      'Contingent Worker Type', 
                                                      'Job Category'], abs_tol = 0, rel_tol = 0, df1_name = 'Active', df2_name = 'Terminated')
compare.matches(ignore_extra_columns=False)

print(compare.report())

import datacompy, pandas as pd, pyspark, io

compare = datacompy.Compare(df1, df3, join_columns = ['Worker',
                                                      'Party ID', 
                                                      'Employee ID', 
                                                      'GUID', 
                                                      'Cost Center ID', 
                                                      'Cost Center Name', 
                                                      'Company - Name', 
                                                      'Management Level', 
                                                      'Job Level - Primary Position', 
                                                      'Work Email',
                                                      'Employee Status',  
                                                      'Hire Date', 
                                                      'Worker Type', 
                                                      'Contingent Worker Type', 
                                                      'Job Category'], abs_tol = 0, rel_tol = 0, df1_name = 'Active', df2_name = 'Future Hire')
compare.matches(ignore_extra_columns=False)

print(compare.report())

import datacompy, pandas as pd, pyspark, io

compare = datacompy.Compare(df2, df3, join_columns = ['Worker',
                                                      'Party ID', 
                                                      'Employee ID', 
                                                      'GUID', 
                                                      'Cost Center ID', 
                                                      'Cost Center Name', 
                                                      'Company - Name', 
                                                      'Management Level', 
                                                      'Job Level - Primary Position', 
                                                      'Work Email',
                                                      'Employee Status',  
                                                      'Hire Date', 
                                                      'Worker Type', 
                                                      'Contingent Worker Type', 
                                                      'Job Category'], abs_tol = 0, rel_tol = 0, df1_name = 'Terminated', df2_name = 'Future Hire')
compare.matches(ignore_extra_columns=False)

print(compare.report())

import datacompy, pandas as pd, pyspark, io

compare = datacompy.Compare(dfwd1, df3, join_columns = ['Worker',
                                                      'Party ID', 
                                                      'Employee ID', 
                                                      'GUID', 
                                                      'Cost Center ID', 
                                                      'Cost Center Name', 
                                                      'Company - Name', 
                                                      'Management Level', 
                                                      'Job Level - Primary Position', 
                                                      'Work Email',
                                                      'Employee Status',  
                                                      'Hire Date', 
                                                      'Worker Type', 
                                                      'Contingent Worker Type', 
                                                      'Job Category'], abs_tol = 0, rel_tol = 0, df1_name = 'Active+Terminated', df2_name = 'Future Hire')
compare.matches(ignore_extra_columns=False)

print(compare.report())
# Out:
# DataComPy Comparison
# --------------------
#
# DataFrame Summary
# -----------------
#
#     DataFrame  Columns   Rows
# 0      Active       22  61934
# 1  Terminated       19  52699
#
# Column Summary
# --------------
#
# Number of columns in common: 15
# Number of columns in Active but not in Terminated: 7
# Number of columns in Terminated but not in Active: 4
#
# Row Summary
# -----------
#
# Matched on: worker, party id, employee id, guid, cost center id, cost center name, company - name, management level, job level - primary position, work email, employee status, hire date, worker type, contingent worker type, job category
# Any duplicates on match values: Yes
# Absolute Tolerance: 0
# Relative Tolerance: 0
# Number of rows in common: 0
# Number of rows in Active but not in Terminated: 61,934
# Number of rows in Terminated but not in Active: 52,699
#
# Number of rows with some compared columns unequal: 0
# Number of rows with all compared columns equal: 0
#
# Column Comparison
# -----------------
#
# Number of columns compared with some values unequal: 0
# Number of columns compared with all values equal: 15
# Total number of values which compare unequal: 0
#
# Sample Rows Only in Active (First 10 Columns)
# ---------------------------------------------
#
#                       worker  employee id                              party id          guid   employee status                work email  hire date        worker type contingent worker type      job category
# 44893         Gracie Ezekiel    100528746  b9b37a96-11e3-4ad3-b017-46b656e44a3c   gezekiel001            Active    gracie.ezekiel@pwc.com 2003-07-01           Employee                    NaN  Practice Support
# 52034  Joyce Borteley Bortei    100942248  d72452da-e7e8-448a-ab31-8822f56e67cc    jbortei003            Active      joyce.bortei@pwc.com 2021-11-22           Employee                    NaN   Client Services
# 58987            Siew Ee Sim    101301520  f3a9781e-9b55-4853-8f23-3db4e09d2197       ssim044            Active     siew.ee.s.sim@pwc.com 2022-09-19           Employee                    NaN   Client Services
# 6017           Sander Visser    100620474  192cdd6c-fbf6-411f-9b9b-348325ed1864    svisser020            Active     sander.visser@pwc.com 2015-07-01           Employee                    NaN   Client Services
# 57909            Kathrina Ty    100689457  ef7bc61c-d779-4dd8-9e89-997cee39edaa        kty002            Active       kathrina.ty@pwc.com 2018-09-01           Employee                    NaN   Client Services
# 43777        Jakub Konik [C]    110001237  b4f9486f-ea8b-4813-b4bc-e84f296f5f4a     jkonik003            Active  jakub.k.konik@ch.pwc.com 2018-09-18  Contingent Worker                 Vendor   Client Services
# 39815              Nils Otto    101084824  a53fe052-b616-4561-b56d-01a386df6d33      notto004            Active         nils.otto@pwc.com 2022-03-01           Employee                    NaN   Client Services
# 57530            Iris Hensen    100640435  edd621c5-87e4-4891-a3c2-4c14f7ddd05f    ihensen001            Active       iris.hensen@pwc.com 2013-06-01           Employee                    NaN   Client Services
# 60498          Alex Lanz [C]    100724114  f9fabfe6-6b59-4c01-a5c4-b2bec3e35f38      alanz001            Active         alex.lanz@pwc.com 2018-01-01  Contingent Worker                 Vendor  Practice Support
# 11083           Kay Pennings    100655409  2e64ac88-865c-4ffc-8518-00403d23b6ab  kpennings006  Leave of Absence        k.pennings@pwc.com 2017-02-01           Employee                    NaN   Client Services
#
# Sample Rows Only in Terminated (First 10 Columns)
# -------------------------------------------------
#
#                      worker  employee id                              party id           guid employee status                   work email  hire date termination date        worker type contingent worker type
# 99613    Julian Edgar Haase    100785878  b709eb7f-5107-476e-8e0e-e8647b13649c      jhaase006      Terminated   julian.edgar.haase@pwc.com 2017-10-01       2020-09-30           Employee                    NaN
# 95122        Mauricio Fromm    100987259  a15e7778-6828-4652-8cc4-4dba3a67376b      mfromm004      Terminated     mauricio.f.fromm@pwc.com 2020-08-01       2021-01-31           Employee                    NaN
# 105813           Franz Chua    100531313  d566fa93-f01a-478b-a17e-b9c728974e1e       fchua015      Terminated        franz.jh.chua@pwc.com 2017-08-21       2022-09-07           Employee                    NaN
# 106449         Alban Karila    100912647  d88035c0-9502-4d67-a2a1-bd00c0cbda1c     akarila001      Terminated         alban.karila@pwc.com 2019-07-01       2020-12-11           Employee                    NaN
# 88495      Wojciech Lesniak    100954005  8113341d-b0ea-46f9-9e88-969527b89b6b    wlesniak001      Terminated     wojciech.lesniak@pwc.com 2019-11-01       2020-04-30  Contingent Worker                 Vendor
# 89802   Subathra Sirimorhan    101054718  87a38c1e-d2cb-4dfe-afb5-3a043598568d  ssirimorha001      Terminated  subathra.sirimorhan@pwc.com 2021-03-01       2021-04-30           Employee                    NaN
# 85599         Nils Busekros    101201188  7315a006-4ee2-42b6-ab70-dcac85033942   nbusekros002          Active        nils.busekros@pwc.com 2022-02-15       2022-08-14           Employee                    NaN
# 68566              Sarah Ng    100740406  1fe54309-36d2-404b-b2a2-13f57b4bc35e         sng166      Terminated          sarah.mw.ng@pwc.com 2015-03-02       2018-07-31           Employee                    NaN
# 108768      Timera Govender    100733085  e3b58f78-4fc5-4dce-9b29-317e4ce8efb8   tgovender019      Terminated      timera.govender@pwc.com 2019-01-01       2021-10-31           Employee                    NaN
# 77718           Frank Evers    100775030  4c74282f-fe90-463c-ba98-c18d746718ff      fevers003      Terminated          frank.evers@pwc.com 1999-11-01       2019-06-30           Employee                    NaN

# %%
import datacompy, pandas as pd, pyspark, io
from pyspark.sql import SparkSession
from pyspark.sql.functions import *

logfile = "YOUR_SPARK_HOME/README.md"
spark = SparkSession.builder.appName("Data Comparisons").getOrCreate()
logdata = spark.read.text(logFile).cache()


compare = datacompy.SparkCompare(spark, df1, df2, join_columns = ['Worker',
                                                      'Party ID', 
                                                      'Employee ID', 
                                                      'GUID', 
                                                      'Cost Center ID', 
                                                      'Cost Center Name', 
                                                      'Company - Name', 
                                                      'Management Level', 
                                                      'Job Level - Primary Position', 
                                                      'Work Email',
                                                      'Employee Status',  
                                                      'Hire Date', 
                                                      'Worker Type', 
                                                      'Contingent Worker Type', 
                                                      'Job Category'])
#compare.matches(ignore_extra_columns=False)

print(compare.report())

import datacompy, pandas as pd, pyspark, io

compare = datacompy.SparkCompare(spark, df1, df3, join_columns = ['Worker',
                                                      'Party ID', 
                                                      'Employee ID', 
                                                      'GUID', 
                                                      'Cost Center ID', 
                                                      'Cost Center Name', 
                                                      'Company - Name', 
                                                      'Management Level', 
                                                      'Job Level - Primary Position', 
                                                      'Work Email',
                                                      'Employee Status',  
                                                      'Hire Date', 
                                                      'Worker Type', 
                                                      'Contingent Worker Type', 
                                                      'Job Category'])
#compare.matches(ignore_extra_columns=False)

print(compare.report())

import datacompy, pandas as pd, pyspark, io

compare = datacompy.SparkCompare(spark, df2, df3, join_columns = ['Worker',
                                                      'Party ID', 
                                                      'Employee ID', 
                                                      'GUID', 
                                                      'Cost Center ID', 
                                                      'Cost Center Name', 
                                                      'Company - Name', 
                                                      'Management Level', 
                                                      'Job Level - Primary Position', 
                                                      'Work Email',
                                                      'Employee Status',  
                                                      'Hire Date', 
                                                      'Worker Type', 
                                                      'Contingent Worker Type', 
                                                      'Job Category'])
#compare.matches(ignore_extra_columns=False)

print(compare.report())

import datacompy, pandas as pd, pyspark, io

compare = datacompy.SparkCompare(spark, dfwd1, df3, join_columns = ['Worker',
                                                      'Party ID', 
                                                      'Employee ID', 
                                                      'GUID', 
                                                      'Cost Center ID', 
                                                      'Cost Center Name', 
                                                      'Company - Name', 
                                                      'Management Level', 
                                                      'Job Level - Primary Position', 
                                                      'Work Email',
                                                      'Employee Status',  
                                                      'Hire Date', 
                                                      'Worker Type', 
                                                      'Contingent Worker Type', 
                                                      'Job Category'])
#compare.matches(ignore_extra_columns=False)

print(compare.report())

#spark.stop()

# %%
print('\n'.join([''.join([('PwC'[(x-y)%3] if((x*0.05)**2+(y*0.1)**2-1)**3-(x*0.05)**2*(y*0.1)**3<=0 else' ') for x in range(-30,30)]) for y in range(15,-15,-1)]))
# Out:
#
#
#
#                 wCPwCPwCP           PwCPwCPwC
#             wCPwCPwCPwCPwCPwC   PwCPwCPwCPwCPwCPw
#           PwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPw
#          PwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCP
#         PwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwC
#         wCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCP
#         CPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPw
#         PwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwC
#         wCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCP
#         CPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPw
#          wCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPw
#           PwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPw
#           wCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwC
#             wCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPw
#              PwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPw
#               CPwCPwCPwCPwCPwCPwCPwCPwCPwCPwCPw
#                 CPwCPwCPwCPwCPwCPwCPwCPwCPwCP
#                   CPwCPwCPwCPwCPwCPwCPwCPwC
#                     CPwCPwCPwCPwCPwCPwCPw
#                        PwCPwCPwCPwCPwC
#                           wCPwCPwCP
#                              CPw
#                               w

# %%
dfwd2.to_excel('DataReconReport.xlsx')
# Out:
# <ipython-input-214-a40abaae52a3>:1: UserWarning: Pandas requires version '1.4.3' or newer of 'xlsxwriter' (version '1.3.7' currently installed).
#   dfwd2.to_excel('DataReconReport.xlsx')
