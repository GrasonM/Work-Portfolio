# %%
import pkg_resources
installed_packages = pkg_resources.working_set
installed_packages_list = sorted(["%s==%s" % (i.key, i.version)
    for i in installed_packages])

for module in enumerate(installed_packages_list):Dis
    print(f'py -m pip install {module[1]}')
# Out:
# py -m pip install -==ompt-toolkit
# py -m pip install -andas==1.5.0
# py -m pip install -equests==2.24.0
# py -m pip install -penpyxl==3.0.5
# py -m pip install -rompt-toolkit==3.0.8
# py -m pip install -umpy==1.19.2
# py -m pip install -yodbc==4.0.0-unsupported
# py -m pip install -yqt6-qt6==6.3.1
# py -m pip install -yqt6-sip==13.4.0
# py -m pip install admin==0.0.1
# py -m pip install alabaster==0.7.12
# py -m pip install altgraph==0.17.2
# py -m pip install anaconda-client==1.7.2
# py -m pip install anaconda-navigator==1.10.0
# py -m pip install anaconda-project==0.8.3
# py -m pip install ansicon==1.89.0
# py -m pip install argh==0.26.2
# py -m pip install argon2-cffi==20.1.0
# py -m pip install asn1crypto==1.4.0
# py -m pip install astroid==2.4.2
# py -m pip install astropy==4.0.2
# py -m pip install async-generator==1.10
# py -m pip install asyncio==3.4.3
# py -m pip install atomicwrites==1.4.0
# py -m pip install attrs==20.3.0
# py -m pip install autopep8==1.5.4
# py -m pip install babel==2.8.1
# py -m pip install backcall==0.2.0
# py -m pip install backports.functools-lru-cache==1.6.4
# py -m pip install backports.shutil-get-terminal-size==1.0.0
# py -m pip install backports.tempfile==1.0
# py -m pip install backports.weakref==1.0.post1
# py -m pip install bcrypt==3.2.0
# py -m pip install beautifulsoup4==4.9.3
# py -m pip install bitarray==1.6.1
# py -m pip install bkcharts==0.2
# py -m pip install bleach==3.2.1
# py -m pip install blessed==1.19.1
# py -m pip install bokeh==2.2.3
# py -m pip install boto==2.49.0
# py -m pip install bottleneck==1.3.2
# py -m pip install brotlipy==0.7.0
# py -m pip install bs4==0.0.1
# py -m pip install certifi==2020.6.20
# py -m pip install cffi==1.14.3
# py -m pip install chardet==3.0.4
# py -m pip install charset-normalizer==2.1.1
# py -m pip install click==7.1.2
# py -m pip install cloudpickle==1.6.0
# py -m pip install clyent==1.2.2
# py -m pip install colorama==0.4.4
# py -m pip install comtypes==1.1.7
# py -m pip install conda-build==3.22.0
# py -m pip install conda-package-handling==1.9.0
# py -m pip install conda-verify==3.4.2
# py -m pip install conda==22.9.0
# py -m pip install contextlib2==0.6.0.post1
# py -m pip install cryptography==3.1.1
# py -m pip install cycler==0.10.0
# py -m pip install cython==0.29.21
# py -m pip install cytoolz==0.11.0
# py -m pip install dask==2.30.0
# py -m pip install datacompy==0.8.1
# py -m pip install datetime==4.4
# py -m pip install decorator==4.4.2
# py -m pip install defusedxml==0.6.0
# py -m pip install diff-match-patch==20200713
# py -m pip install distributed==2.30.1
# py -m pip install docutils==0.16
# py -m pip install entrypoints==0.3
# py -m pip install et-xmlfile==1.0.1
# py -m pip install fastcache==1.1.0
# py -m pip install filelock==3.0.12
# py -m pip install flake8==3.8.4
# py -m pip install flask==1.1.2
# py -m pip install fsspec==0.8.3
# py -m pip install future==0.18.2
# py -m pip install gevent==20.9.0
# py -m pip install glob2==0.7
# py -m pip install greenlet==1.1.3.post0
# py -m pip install h5py==2.10.0
# py -m pip install heapdict==1.0.1
# py -m pip install html5lib==1.1
# py -m pip install hvac==0.11.2
# py -m pip install idna==2.10
# py -m pip install imageio==2.9.0
# py -m pip install imagesize==1.2.0
# py -m pip install importlib-metadata==2.0.0
# py -m pip install iniconfig==1.1.1
# py -m pip install inquirer2-windows==1.0.0
# py -m pip install inquirer==2.9.2
# py -m pip install intervaltree==3.1.0
# py -m pip install ipykernel==5.3.4
# py -m pip install ipython-genutils==0.2.0
# py -m pip install ipython==7.19.0
# py -m pip install ipywidgets==7.5.1
# py -m pip install isort==5.6.4
# py -m pip install itsdangerous==1.1.0
# py -m pip install jdcal==1.4.1
# py -m pip install jedi==0.17.1
# py -m pip install jinja2==2.11.2
# py -m pip install jinxed==1.2.0
# py -m pip install joblib==0.17.0
# py -m pip install json5==0.9.5
# py -m pip install jsonschema==3.2.0
# py -m pip install jupyter-client==6.1.7
# py -m pip install jupyter-console==6.2.0
# py -m pip install jupyter-core==4.6.3
# py -m pip install jupyter==1.0.0
# py -m pip install jupyterlab-pygments==0.1.2
# py -m pip install jupyterlab-server==1.2.0
# py -m pip install jupyterlab==2.2.6
# py -m pip install jupyterthemes==0.20.0
# py -m pip install keyring==21.4.0
# py -m pip install kiwisolver==1.3.0
# py -m pip install lazy-object-proxy==1.4.3
# py -m pip install lesscpy==0.15.0
# py -m pip install libarchive-c==2.9
# py -m pip install llvmlite==0.34.0
# py -m pip install locket==0.2.0
# py -m pip install lxml==4.6.1
# py -m pip install markupsafe==1.1.1
# py -m pip install matplotlib==3.3.2
# py -m pip install mccabe==0.6.1
# py -m pip install menuinst==1.4.16
# py -m pip install mistune==0.8.4
# py -m pip install mkl-fft==1.2.0
# py -m pip install mkl-random==1.1.1
# py -m pip install mkl-service==2.3.0
# py -m pip install mock==4.0.2
# py -m pip install more-itertools==8.6.0
# py -m pip install mpmath==1.1.0
# py -m pip install msgpack==1.0.0
# py -m pip install multipledispatch==0.6.0
# py -m pip install navigator-updater==0.2.1
# py -m pip install nbclient==0.5.1
# py -m pip install nbconvert==6.0.7
# py -m pip install nbformat==5.0.8
# py -m pip install nest-asyncio==1.4.2
# py -m pip install networkx==2.5
# py -m pip install nltk==3.5
# py -m pip install nose==1.3.7
# py -m pip install notebook==6.1.4
# py -m pip install numba==0.51.2
# py -m pip install numexpr==2.8.3
# py -m pip install numpy==1.23.3
# py -m pip install numpydoc==1.1.0
# py -m pip install olefile==0.46
# py -m pip install openpyxl==3.0.10
# py -m pip install ordered-set==4.1.0
# py -m pip install packaging==20.4
# py -m pip install pandas==1.5.1
# py -m pip install pandocfilters==1.4.3
# py -m pip install paramiko==2.7.2
# py -m pip install parso==0.7.0
# py -m pip install partd==1.1.0
# py -m pip install path==15.0.0
# py -m pip install pathlib2==2.3.5
# py -m pip install pathtools==0.1.2
# py -m pip install patsy==0.5.1
# py -m pip install pefile==2022.5.30
# py -m pip install pep8==1.7.1
# py -m pip install pexpect==4.8.0
# py -m pip install pickleshare==0.7.5
# py -m pip install pillow==8.0.1
# py -m pip install pip==20.2.4
# py -m pip install pkginfo==1.6.1
# py -m pip install pluggy==0.13.1
# py -m pip install ply==3.11
# py -m pip install prometheus-client==0.8.0
# py -m pip install prompt-toolkit==3.0.30
# py -m pip install psutil==5.7.2
# py -m pip install py4j==0.10.9.5
# py -m pip install py==1.9.0
# py -m pip install pycodestyle==2.6.0
# py -m pip install pycosat==0.6.3
# py -m pip install pycparser==2.20
# py -m pip install pycurl==7.43.0.6
# py -m pip install pydocstyle==5.1.1
# py -m pip install pyflakes==2.2.0
# py -m pip install pygments==2.7.2
# py -m pip install pyinquirer==1.0.3
# py -m pip install pyinstaller-hooks-contrib==2022.8
# py -m pip install pyinstaller==5.3
# py -m pip install pyjwt==2.4.0
# py -m pip install pylint==2.6.0
# py -m pip install pynacl==1.4.0
# py -m pip install pyodbc==4.0.34
# py -m pip install pyopenssl==19.1.0
# py -m pip install pyparsing==2.4.7
# py -m pip install pyqt5-qt5==5.15.2
# py -m pip install pyqt5-sip==12.11.0
# py -m pip install pyqt6-plugins==6.1.0.2.2
# py -m pip install pyqt6-qt6==6.3.1
# py -m pip install pyqt6-sip==13.4.0
# py -m pip install pyqt6-tools==6.1.0.3.2
# py -m pip install pyqt6==6.3.1
# py -m pip install pyreadline==2.1
# py -m pip install pyrsistent==0.17.3
# py -m pip install pysocks==1.7.1
# py -m pip install pyspark==3.3.0
# py -m pip install pytest==0.0.0
# py -m pip install python-dateutil==2.8.1
# py -m pip install python-dotenv==0.20.0
# py -m pip install python-editor==1.0.4
# py -m pip install python-jsonrpc-server==0.4.0
# py -m pip install python-language-server==0.35.1
# py -m pip install pytz==2020.1
# py -m pip install pywavelets==1.1.1
# py -m pip install pywin32-ctypes==0.2.0
# py -m pip install pywin32==227
# py -m pip install pywinpty==0.5.7
# py -m pip install pyyaml==5.3.1
# py -m pip install pyzmq==19.0.2
# py -m pip install qdarkstyle==2.8.1
# py -m pip install qt6-applications==6.1.0.2.2
# py -m pip install qt6-tools==6.1.0.1.2
# py -m pip install qtawesome==1.0.1
# py -m pip install qtconsole==4.7.7
# py -m pip install qtgui==0.0.1
# py -m pip install qtpy==1.9.0
# py -m pip install qtwidgets==0.18
# py -m pip install readchar==3.0.5
# py -m pip install regex==2020.10.15
# py -m pip install requests==2.24.0
# py -m pip install rope==0.18.0
# py -m pip install rtree==0.9.4
# py -m pip install ruamel-yaml==0.15.87
# py -m pip install scikit-image==0.17.2
# py -m pip install scikit-learn==0.23.2
# py -m pip install scipy==1.5.2
# py -m pip install seaborn==0.11.0
# py -m pip install send2trash==1.5.0
# py -m pip install setuptools==50.3.1.post20201107
# py -m pip install simplegeneric==0.8.1
# py -m pip install singledispatch==3.4.0.3
# py -m pip install sip==4.19.13
# py -m pip install six==1.15.0
# py -m pip install snowballstemmer==2.0.0
# py -m pip install sortedcollections==1.2.1
# py -m pip install sortedcontainers==2.2.2
# py -m pip install soupsieve==2.0.1
# py -m pip install sphinx==3.2.1
# py -m pip install sphinxcontrib-applehelp==1.0.2
# py -m pip install sphinxcontrib-devhelp==1.0.2
# py -m pip install sphinxcontrib-htmlhelp==1.0.3
# py -m pip install sphinxcontrib-jsmath==1.0.1
# py -m pip install sphinxcontrib-qthelp==1.0.3
# py -m pip install sphinxcontrib-serializinghtml==1.1.4
# py -m pip install sphinxcontrib-websupport==1.2.4
# py -m pip install spyder-kernels==1.9.4
# py -m pip install spyder==4.1.5
# py -m pip install sqlalchemy==1.4.42
# py -m pip install statsmodels==0.12.0
# py -m pip install style==1.1.6
# py -m pip install sympy==1.6.2
# py -m pip install tables==3.6.1
# py -m pip install tblib==1.7.0
# py -m pip install terminado==0.9.1
# py -m pip install testpath==0.4.4
# py -m pip install threadpoolctl==2.1.0
# py -m pip install tifffile==2020.10.1
# py -m pip install toml==0.10.1
# py -m pip install toolz==0.11.1
# py -m pip install tornado==6.0.4
# py -m pip install tqdm==4.50.2
# py -m pip install traitlets==5.0.5
# py -m pip install typing-extensions==3.7.4.3
# py -m pip install uamqp==1.5.3
# py -m pip install ujson==4.0.1
# py -m pip install unicodecsv==0.14.1
# py -m pip install urllib3==1.25.11
# py -m pip install watchdog==0.10.3
# py -m pip install wcwidth==0.2.5
# py -m pip install webencodings==0.5.1
# py -m pip install werkzeug==1.0.1
# py -m pip install wheel==0.35.1
# py -m pip install widgetsnbextension==3.5.1
# py -m pip install win-inet-pton==1.1.0
# py -m pip install win-unicode-console==0.5
# py -m pip install wincertstore==0.2
# py -m pip install wrapt==1.11.2
# py -m pip install xlrd==1.2.0
# py -m pip install xlsxwriter==3.0.3
# py -m pip install xlwings==0.20.8
# py -m pip install xlwt==1.3.0
# py -m pip install xmltodict==0.12.0
# py -m pip install yapf==0.30.0
# py -m pip install zict==2.0.0
# py -m pip install zipp==3.4.0
# py -m pip install zope.event==4.5.0
# py -m pip install zope.interface==5.1.2

# %%
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
import smtplib, ssl

SMTPHOST = "smtp.gmail.com"
SMTPPORT = 465
FROMEMAIL = "grason.moye@pwc.com"
FROMEMAILPASSWORD = "Qpwoeiruty10!="

def CreateEmailMessage(toAddress, message):
    messageDetails = MIMEMultipart()
    
    messageDetails['From'] = FROMEMAIL
    messageDetails['To'] = toAddress
    messageDetails['Subject'] = "Test Email!"
    
    messageDetails.attach(MIMEText(message, 'plain'))
    
    return messageDetails

def SendEmailMessage(toAddress, message):
        messageDetails = CreateEmailMessage(toAddress, message)
        #context = ssl.create_default_context()
        
        try:
            server = smtplib.SMTP_SSL(SMTPHOST, SMTPPORT)
            server.helo()
            #server.starttls() #context=context)
            #server.login(FROMEMAIL, FROMEMAILPASSWORD)
            server.sendmail(FROMEMAIL, toAddress, messageDetails.as_string())
        except Exception as ex:
            print(ex)
        finally:
            server.quit()

# %%
SendEmailMessage("grason.moye@pwc.com", "Hello, this is an official PwC test email! :)")
# Out:
# (530, b'5.7.0 Authentication Required. Learn more at\n5.7.0  https://support.google.com/mail/?p=WantAuthError l21-20020a37f915000000b006bc56c063fcsm9850632qkj.62 - gsmtp', 'grason.moye@pwc.com')
